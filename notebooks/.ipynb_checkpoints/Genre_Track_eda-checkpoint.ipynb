# %%
from pandasql import sqldf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from bs4 import BeautifulSoup
import io
import requests
from ast import literal_eval
import glob
import datetime

# %% [markdown]
# # project_csv 6

# %% [markdown]
# # project_csv

# %%
project_csv = pd.read_csv('../data/Hot-Stuff.csv')
project_csv
# Out:
#                                                       url      WeekID  \
# 0       http://www.billboard.com/charts/hot-100/1965-0...   7/17/1965
# 1       http://www.billboard.com/charts/hot-100/1965-0...   7/24/1965
# 2       http://www.billboard.com/charts/hot-100/1965-0...   7/31/1965
# 3       http://www.billboard.com/charts/hot-100/1965-0...    8/7/1965
# 4       http://www.billboard.com/charts/hot-100/1965-0...   8/14/1965
# ...                                                   ...         ...
# 327890  https://www.billboard.com/charts/hot-100/2018-...  10/20/2018
# 327891  http://www.billboard.com/charts/hot-100/1977-0...   5/21/1977
# 327892  http://www.billboard.com/charts/hot-100/1981-0...   5/23/1981
# 327893  http://www.billboard.com/charts/hot-100/1973-0...   9/29/1973
# 327894  https://www.billboard.com/charts/hot-100/2020-...  11/28/2020
#
#         Week Position                      Song                  Performer  \
# ...

# %% [markdown]
# # genre csv

# %%
genre_csv = pd.concat([pd.read_csv(x)for x in glob.glob('../genre_csvs/*.csv')], ignore_index = True)

# %%
genre_csv = genre_csv.dropna()
genre_csv
# Out:
#                             0     1                   2  \
# 0               Lindsay Lohan  49.0       Lindsay Lohan
# 2                     Incubus  69.0             Incubus
# 3                   Zac Efron  69.0           Zac Efron
# 5                  Kris Allen  44.0          Kris Allen
# 6           The Swon Brothers  33.0   The Swon Brothers
# ...                       ...   ...                 ...
# 10053           Judson Spence   4.0       Judson Spence
# 10055  Mongo Santamaria Orch.  46.0    Mongo Santamaria
# 10056      The Yellow Balloon  22.0  The Yellow Balloon
# 10057            Ant Saunders  53.0        Ant Saunders
# 10059        Thelma Carpenter  34.0    Thelma Carpenter
#
#                                            3  \
# 0      spotify:artist:4vRSocKbGh7PsQrYRDVMEF
# 2      spotify:artist:3YcBF2ttyueytpXtEzn1Za
# 3      spotify:artist:6U1dBXJhC8gXFjamvFTmHg
# 5      spotify:artist:2zwHaEmXxX6DTv4i8ajNCM
# 6      spotify:artist:1nf0nRF0W4ybnJdda00pKY
# ...

# %%
genre_csv.columns = ['Performer', 'Artist_Popularity', 'Artist2', 'uri', 'Genre']

# %% [markdown]
# # song csv

# %%
song_csv = pd.concat([pd.read_csv(x)for x in glob.glob('../songs_csvs/*.csv')], ignore_index = True)

# %%
song_csv = song_csv.dropna()
song_csv
# Out:
#            0     1                   2  \
# 0      False  14.0        Dale & Grace
# 1      False  34.0        Bobby Vinton
# 2      False  10.0  Marianne Faithfull
# 3      False  10.0       Bobby Sherman
# 4      False  37.0        Wayne Newton
# ...      ...   ...                 ...
# 26991  False  41.0              Nocera
# 26992  False   1.0       Andy Williams
# 26995  False  42.0           Choirboys
# 26996  False  15.0        Carrie Lucas
# 26999  False   7.0       George Lamond
#
#                                                 3         4  \
# 0                          Stop and Think It Over  155013.0
# 1                       Trouble Is My Middle Name  146626.0
# 2                           Come And Stay With Me  144800.0
# 3                               Cried Like a Baby  196672.0
# 4                       Red Roses For A Blue Lady  143066.0
# ...                                           ...       ...
# 26991                      Summertime, Summertime  206613.0
# ...

# %%
song_csv.columns = ['Explicit', 'Song_Popularity', 'Performer', 'Song', 'Duration ms', 'uri']

# %%
merged_df = song_csv.merge(genre_csv, how = 'inner', on = 'Performer')
merged_df
# Out:
#       Explicit  Song_Popularity          Performer  \
# 0        False             14.0       Dale & Grace
# 1        False              4.0       Dale & Grace
# 2        False             34.0       Bobby Vinton
# 3        False             43.0       Bobby Vinton
# 4        False              6.0       Bobby Vinton
# ...        ...              ...                ...
# 14521    False              6.0  Shawn Christopher
# 14522    False             42.0     Richie Sambora
# 14523    False             11.0      Cindy Bullens
# 14524    False             41.0             Nocera
# 14525    False             42.0          Choirboys
#
#                                         Song  Duration ms  \
# 0                     Stop and Think It Over     155013.0
# 1                        The Loneliest Night     141080.0
# 2                  Trouble Is My Middle Name     146626.0
# 3                 I Love You the Way You Are     174026.0
# ...

# %%
merged_df = merged_df.merge(project_csv, how = 'inner', on = ['Performer', 'Song'])
merged_df
# Out:
#        Explicit  Song_Popularity     Performer                    Song  \
# 0         False              4.0  Dale & Grace     The Loneliest Night
# 1         False              4.0  Dale & Grace     The Loneliest Night
# 2         False              4.0  Dale & Grace     The Loneliest Night
# 3         False              4.0  Dale & Grace     The Loneliest Night
# 4         False              4.0  Dale & Grace     The Loneliest Night
# ...         ...              ...           ...                     ...
# 122091    False             41.0        Nocera  Summertime, Summertime
# 122092    False             41.0        Nocera  Summertime, Summertime
# 122093    False             41.0        Nocera  Summertime, Summertime
# 122094    False             41.0        Nocera  Summertime, Summertime
# 122095    False             41.0        Nocera  Summertime, Summertime
#
#         Duration ms                                 uri_x  Artist_Popularity  \
# ...

# %%
merged_df['WeekID'] = pd.to_datetime(merged_df['WeekID'])

# %%
merged_df = merged_df.sort_values('WeekID')

# %%
merged_df = merged_df.drop_duplicates(subset = 'uri_x', keep='first')
merged_df
# Out:
#        Explicit  Song_Popularity                   Performer  \
# 9079      False             53.0              Connie Francis
# 6841      False              8.0                   Paul Anka
# 78654     False             21.0                The Olympics
# 94180     False             45.0                 Sheb Wooley
# 34629     False             30.0               Bobby Freeman
# ...         ...              ...                         ...
# 73347     False              0.0                    Coldplay
# 90429      True             64.0                        P!nk
# 26971      True             55.0  YoungBoy Never Broke Again
# 121353    False             71.0               Lainey Wilson
# 99624      True             53.0                 Nicki Minaj
#
#                             Song  Duration ms  \
# 9079                Stupid Cupid     133746.0
# 6841                    Midnight     118560.0
# 78654             Western Movies     140504.0
# ...

# %%
explicit_count = merged_df['Explicit'].value_counts()
explicit_count
# Out:
# False    8857
# True      834
# Name: Explicit, dtype: int64

# %%
merged_df['Year'] = merged_df['WeekID'].dt.year
merged_df
# Out:
#        Explicit  Song_Popularity                   Performer  \
# 9079      False             53.0              Connie Francis
# 6841      False              8.0                   Paul Anka
# 78654     False             21.0                The Olympics
# 94180     False             45.0                 Sheb Wooley
# 34629     False             30.0               Bobby Freeman
# ...         ...              ...                         ...
# 73347     False              0.0                    Coldplay
# 90429      True             64.0                        P!nk
# 26971      True             55.0  YoungBoy Never Broke Again
# 121353    False             71.0               Lainey Wilson
# 99624      True             53.0                 Nicki Minaj
#
#                             Song  Duration ms  \
# 9079                Stupid Cupid     133746.0
# 6841                    Midnight     118560.0
# 78654             Western Movies     140504.0
# ...

# %%
merged_df['Duration s'] = merged_df['Duration ms']/1000

# %%
merged_df['Year'] = pd.to_numeric(merged_df['Year'])

# %%
#merged_df['Genre'] = merged_df['Genre'].apply(literal_eval)

# %%
#merged_df = merged_df.explode(column = 'Genre')
#merged_df = merged_df.dropna()

# %% [markdown]
# # Top Songs Genre Graph

# %%
explicit_count = merged_df['Explicit'].value_counts()
explicit_count 
values = explicit_count.tolist()
colors = ['cadetblue', 'turquoise']
labels = ['False', 'True']
explode = (0.2, 0)
plt.pie(values, colors=colors, labels=labels,
explode=explode, autopct='%1.1f%%',
counterclock=False, shadow=True)
plt.title('Explicit')
plt.show()

# %% [markdown]
# # explicit popularity

# %% [markdown]
# # Popularity vs duration

# %%
merged_df.head()
# Out:
#       Explicit  Song_Popularity       Performer                     Song  \
# 9079     False             53.0  Connie Francis             Stupid Cupid
# 6841     False              8.0       Paul Anka                 Midnight
# 78654    False             21.0    The Olympics           Western Movies
# 94180    False             45.0     Sheb Wooley  The Purple People Eater
# 34629    False             30.0   Bobby Freeman     Do You Want To Dance
#
#        Duration ms                                 uri_x  Artist_Popularity  \
# 9079      133746.0  spotify:track:3nUrhP3KuK4R1qdxRk2Kgo               55.0
# 6841      118560.0  spotify:track:1PIAfN66ryCymC2kSZKdsr               62.0
# 78654     140504.0  spotify:track:398Q0gLfmsjJ5GFx9W2q5Y               23.0
# 94180     137960.0  spotify:track:0WkZQPNC0c7yrsMX1arVAd               32.0
# 34629     165693.0  spotify:track:4wXPZBafMKbTtdOB7BVGcp               29.0
#
#               Artist2                                  uri_y  \
# ...

# %%
genre_graph_100 = merged_df.plot(figsize=(10,6),
                             x= 'Duration s',
                             y= 'Song_Popularity',
                             title = 'Song Popularity vs Duration',
                             xlabel = 'Popularity',
                             ylabel = 'Duration ms',
                             kind = 'scatter',
                             color = 'cadetblue',
                             edgecolor = 'black',
                             alpha = 0.1)
for bars in genre_graph_100.containers:
    genre_graph_100.bar_label(bars)
plt.show()

# %% [markdown]
# # release date popularity

# %%
genre_graph_100 = merged_df.plot(figsize=(20,10),
                             x= 'Year',
                             y= 'Song_Popularity',
                             title = 'Top  Songs Release Date vs Popularity',
                             xlabel = 'Popularity',
                             ylabel = '',
                             kind = 'scatter',
                             color = 'cadetblue',
                             edgecolor = 'black',
                             alpha = 0.8)
for bars in genre_graph_100.containers:
    genre_graph_100.bar_label(bars)
plt.xticks(rotation = 90);

# %%
merged_df.loc[merged_df ['Year'] < 1960].loc[merged_df['Song_Popularity'] >= 75]
# Out:
#     Explicit  Song_Popularity    Performer              Song  Duration ms  \
# 105    False             79.0  Chuck Berry   Run Rudolph Run     165733.0
# 108    False             81.0  Bing Crosby   White Christmas     177480.0
# 110    False             90.0  Bobby Helms  Jingle Bell Rock     130973.0
#
#                                     uri_x  Artist_Popularity      Artist2  \
# 105  spotify:track:2pnPe4pJtq7689i5ydzvJJ               70.0  Chuck Berry
# 108  spotify:track:4so0Wek9Ig1p6CRCHuINwW               79.0  Bing Crosby
# 110  spotify:track:7vQbuQcyTflfCIOu3Uzzya               73.0  Bobby Helms
#
#                                      uri_y  \
# 105  spotify:artist:293zczrfYafIItmnmM3coR
# 108  spotify:artist:6ZjFtWeHP9XN7FeKSUe80S
# 110  spotify:artist:38EmEgXkgK51MT2tPY0EoC
#
#                                                  Genre  \
# 105  ['classic rock', 'rock', 'rock-and-roll', 'roc...
# 108              ['adult standards', 'easy listening']
# ...

# %%
merged_df = merged_df.reset_index(drop = True)

# %%
merged_df.loc[merged_df ['Year'] > 2010].loc[merged_df['Song_Popularity'] <= 10]
# Out:
#      Explicit  Song_Popularity      Performer  \
# 8241    False              5.0          3OH!3
# 8402    False              0.0  Rascal Flatts
# 8421    False              0.0      Sean Paul
# 8435     True              0.0    Lupe Fiasco
# 8453    False              0.0   Thomas Rhett
# 8464    False              0.0      Green Day
# 8691    False              1.0     Ed Sheeran
# 8763    False              0.0     Ed Sheeran
# 8795    False              0.0       J Balvin
# 9015    False              1.0     Ed Sheeran
# 9045    False              0.0  Blake Shelton
# 9199    False              0.0    Demi Lovato
# 9314     True              0.0     Juice WRLD
# 9445    False              0.0  Justin Bieber
# 9570    False              0.0       Maroon 5
# 9599    False              0.0  Billie Eilish
# 9686    False              0.0       Coldplay
#
#                                     Song  Duration ms  \
# 8241                        Hit It Again     183873.0
# ...

# %% [markdown]
# # explicit Popularity

# %%
sns.boxplot(data=merged_df,x = 'Explicit', y ='Song_Popularity')
plt.title('Explicit vs Popularity')
plt.ylabel('Popularity');

# %%
plt.title
# Out:
# <function matplotlib.pyplot.title(label, fontdict=None, loc=None, pad=None, *, y=None, **kwargs)>

# %% [markdown]
# # duration explicit

# %%
sns.boxplot(data=merged_df, x= 'Explicit', y = 'Duration s');
plt.title('Explicit vs Duration')
plt.ylabel('Duration');

# %% [markdown]
# # release date genre

# %%
genre_graph_100 = merged_df.plot(figsize=(20,10),
                             x= 'Genre',
                             y= 'Year',
                             title = 'Genre vs Year',
                             xlabel = 'Popularity',
                             ylabel = 'Year',
                             kind = 'scatter',
                             color = 'cadetblue',
                             edgecolor = 'black',
                             alpha = 0.8)
for bars in genre_graph_100.containers:
    genre_graph_100.bar_label(bars)
plt.xticks(rotation = 90);
# Out:
# Error in callback <function flush_figures at 0x11d4a2d30> (for post_execute):
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib_inline/backend_inline.py:121, in flush_figures()
#     118 if InlineBackend.instance().close_figures:
#     119     # ignore the tracking, just draw and close all figures
#     120     try:
# --> 121         return show(True)
#     122     except Exception as e:
#     123         # safely show traceback if in IPython, else raise
#     124         ip = get_ipython()
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib_inline/backend_inline.py:41, in show(close, block)
#      39 try:
#      40     for figure_manager in Gcf.get_all_fig_managers():
# ---> 41         display(
#      42             figure_manager.canvas.figure,
# ...

# %%
genre_graph_100 = merged_df.plot(figsize=(20,10),
                             x= 'Weeks on Chart',
                             y= 'Popularity_y',
                             title = 'Weeks on Chart vs Popularity',
                             xlabel = 'Weeks on Chart',
                             ylabel = 'Popularity',
                             kind = 'scatter',
                             color = 'cadetblue',
                             edgecolor = 'black',
                             alpha = 0.8)
for bars in genre_graph_100.containers:
    genre_graph_100.bar_label(bars)
plt.xticks(rotation = 90);

# %%
genre_graph_100 = merged_df.plot(figsize=(20,10),
                             x= 'Peak Position',
                             y= 'Popularity_y',
                             title = 'Peak Position vs Popularity',
                             xlabel = 'Weeks on Chart',
                             ylabel = 'Popularity',
                             kind = 'scatter',
                             color = 'cadetblue',
                             edgecolor = 'black',
                             alpha = 0.8)
for bars in genre_graph_100.containers:
    genre_graph_100.bar_label(bars)
plt.xticks(rotation = 90);

# %%
genre_graph_100 = merged_df.plot(figsize=(20,10),
                             x= 'Duration s',
                             y= 'Popularity_y',
                             title = 'Duration vs Popularity',
                             xlabel = 'Weeks on Chart',
                             ylabel = 'Popularity',
                             kind = 'scatter',
                             color = 'cadetblue',
                             edgecolor = 'black',
                             alpha = 0.8)
for bars in genre_graph_100.containers:
    genre_graph_100.bar_label(bars)
plt.xticks(rotation = 90);
