# %%
# import packages

# %%
from pandas.io.json import json_normalize
import json
from pandasql import sqldf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from bs4 import BeautifulSoup
import io
import requests
import json
import base64
import datetime
from urllib.parse import urlencode

# %%
# client id

# %%
client_id = '6e24789ec7874259a220f747fcd7e93e'
client_secret = '9bd8ff1ad2f34ef6a87f00124be070b2'

# %%
class SpotifyAPI(object):
    access_token = None
    access_token_expires = datetime.datetime.now()
    access_token_did_expire = True
    client_id = None
    client_secret = None
    token_url = "https://accounts.spotify.com/api/token"



    def __init__(self, client_id, client_secret, *args, **kwargs):
        super().__init__(*args, **kwargs)
        self.client_id = client_id
        self.client_secret = client_secret

    def getClientCreds(self):
        '''Returns b64 encoded string'''
        client_id = self.client_id
        client_secret = self.client_secret

        if client_id == None or client_secret == None:
            raise Exception('Must set a client id and secret')

        client_creds  = f"{client_id}:{client_secret}"
        client_creds_b64 = base64.b64encode(client_creds.encode())
        return client_creds_b64.decode()

    def getTokenHeader(self):
        client_creds_b64 = self.getClientCreds()
        return {
            'Authorization':f"Basic {client_creds_b64}"
        }

    def getTokenData(self):
        return {
            "grant_type":"client_credentials"
        }

    def perform_auth(self):
        token_url = self.token_url
        token_data = self.getTokenData()
        token_header = self.getTokenHeader()

        r = requests.post(token_url, data=token_data, headers=token_header)

        if r.status_code  not in range(200,299):
            raise Exception('Could not authenticate client.')
            #return False

        now = datetime.datetime.now()
        token_response_data = r.json()
        access_token = token_response_data['access_token']
        expires_in = token_response_data['expires_in']
        expires = now + datetime.timedelta(seconds=expires_in)
        self.access_token = access_token
        self.access_token_expires = expires
        self.access_token_did_expire = expires < now


        return True

    def get_access_token(self):
        token = self.access_token
        expires = self.access_token_expires
        now= datetime.datetime.now()
        if expires < now:
            self.perform_auth()
            return self.get_access_token()
        elif token == None:
            self.perform_auth()
            return self.get_access_token() 
        return token
    
    def get_resource_header(self):
        access_token = self.get_access_token()
        headers = {
            "Authorization": f"Bearer {access_token}", 
        }
        return headers
    
    def get_resource(self, lookup_id, resource_type='albums', version='v1'):
        endpoint = f'https://api.spotify.com/{version}/{resource_type}/{lookup_id}'
        headers = self.get_resource_header()
        r = requests.get(endpoint, headers = headers)
        if r.status_code not in range (200, 299):
            return {}
        return r.json()
    
    def get_album(self, _id ):
        return self.get_resource(_id, resource_type='albums')
    
    def get_artist(self, _id ):
        return self.get_resource(_id, resource_type='artists')
    
    def get_playlist(self, _id):
        return self.get_resource(_id, resource_type='playlists')
    
    
    def base_search(self, query_params): #type
        access_token = self.get_access_token()
        headers = self.get_resource_header()
        endpoint = "https://api.spotify.com/v1/search"
        lookup_URL = f"{endpoint}?{query_params}"
        r = requests.get(lookup_URL, headers=headers)
        if r.status_code not in range (200, 299):
            return {}
        return r.json()
    
    def search(self, query=None, operator=None, operator_query=None, search_type='artist'):
        if query == None:
            raise Exception('A query is required')
        if isinstance(query, dict):
            query = ' '.join([f'{k}:{v}' for k,v in query.items()])
        if operator != None and operator_query != None:
            if operator.lower() == 'or' or operator.lower() == 'not':
                operator = operator.upper()
                if isinstance(operator_query, str):
                    query = f'{query} {operator} {operator_query}'
        query_params = urlencode({'q': query, 'type': search_type.lower()})
        return self.base_search(query_params)

# %%
spotify = SpotifyAPI(client_id, client_secret)

# %%
# radioactive

# %%
radioactive = spotify.search({'track': 'Radioactive', 'artist': 'Imagine'}, search_type ='track')
radioactive
# Out:
# {'tracks': {'href': 'https://api.spotify.com/v1/search?query=track%3ARadioactive+artist%3AImagine&type=track&offset=0&limit=20',
#   'items': [{'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/53XhwfbYqKCa1cC15pYq2q'},
#        'href': 'https://api.spotify.com/v1/artists/53XhwfbYqKCa1cC15pYq2q',
#        'id': '53XhwfbYqKCa1cC15pYq2q',
#        'name': 'Imagine Dragons',
#        'type': 'artist',
#        'uri': 'spotify:artist:53XhwfbYqKCa1cC15pYq2q'}],
#      'available_markets': ['CA', 'US'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/6htgf3qv7vGcsdxLCDxKp8'},
#      'href': 'https://api.spotify.com/v1/albums/6htgf3qv7vGcsdxLCDxKp8',
#      'id': '6htgf3qv7vGcsdxLCDxKp8',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273b2b2747c89d2157b0b29fb6a',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02b2b2747c89d2157b0b29fb6a',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851b2b2747c89d2157b0b29fb6a',
#        'width': 64}],
#      'name': 'Night Visions',
#      'release_date': '2012-09-04',
#      'release_date_precision': 'day',
#      'total_tracks': 12,
#      'type': 'album',
#      'uri': 'spotify:album:6htgf3qv7vGcsdxLCDxKp8'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/53XhwfbYqKCa1cC15pYq2q'},
#       'href': 'https://api.spotify.com/v1/artists/53XhwfbYqKCa1cC15pYq2q',
#       'id': '53XhwfbYqKCa1cC15pYq2q',
#       'name': 'Imagine Dragons',
#       'type': 'artist',
#       'uri': 'spotify:artist:53XhwfbYqKCa1cC15pYq2q'}],
#     'available_markets': ['CA', 'US'],
#     'disc_number': 1,
#     'duration_ms': 186813,
#     'explicit': False,
#     'external_ids': {'isrc': 'USUM71201074'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4G8gkOterJn0Ywt6uhqbhp'},
#     'href': 'https://api.spotify.com/v1/tracks/4G8gkOterJn0Ywt6uhqbhp',
#     'id': '4G8gkOterJn0Ywt6uhqbhp',
#     'is_local': False,
#     'name': 'Radioactive',
#     'popularity': 72,
#     'preview_url': 'https://p.scdn.co/mp3-preview/43288a26d88c84b0ac5938c6e547b0ad99c49f78?cid=6e24789ec7874259a220f747fcd7e93e',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:4G8gkOterJn0Ywt6uhqbhp'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/53XhwfbYqKCa1cC15pYq2q'},
#        'href': 'https://api.spotify.com/v1/artists/53XhwfbYqKCa1cC15pYq2q',
#        'id': '53XhwfbYqKCa1cC15pYq2q',
#        'name': 'Imagine Dragons',
#        'type': 'artist',
#        'uri': 'spotify:artist:53XhwfbYqKCa1cC15pYq2q'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2M0IZTKgkN3ZpYluF4lKAM'},
#      'href': 'https://api.spotify.com/v1/albums/2M0IZTKgkN3ZpYluF4lKAM',
#      'id': '2M0IZTKgkN3ZpYluF4lKAM',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273d8941843ba4d684f76a94956',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02d8941843ba4d684f76a94956',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851d8941843ba4d684f76a94956',
#        'width': 64}],
#      'name': 'Radioactive',
#      'release_date': '2014-01-01',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:2M0IZTKgkN3ZpYluF4lKAM'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/53XhwfbYqKCa1cC15pYq2q'},
#       'href': 'https://api.spotify.com/v1/artists/53XhwfbYqKCa1cC15pYq2q',
#       'id': '53XhwfbYqKCa1cC15pYq2q',
#       'name': 'Imagine Dragons',
#       'type': 'artist',
#       'uri': 'spotify:artist:53XhwfbYqKCa1cC15pYq2q'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/2YZyLoL8N0Wb9xBt1NhZWg'},
#       'href': 'https://api.spotify.com/v1/artists/2YZyLoL8N0Wb9xBt1NhZWg',
#       'id': '2YZyLoL8N0Wb9xBt1NhZWg',
#       'name': 'Kendrick Lamar',
#       'type': 'artist',
#       'uri': 'spotify:artist:2YZyLoL8N0Wb9xBt1NhZWg'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 276040,
#     'explicit': True,
#     'external_ids': {'isrc': 'USUM71400693'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/69yfbpvmkIaB10msnKT7Q5'},
#     'href': 'https://api.spotify.com/v1/tracks/69yfbpvmkIaB10msnKT7Q5',
#     'id': '69yfbpvmkIaB10msnKT7Q5',
#     'is_local': False,
#     'name': 'Radioactive',
#     'popularity': 65,
#     'preview_url': 'https://p.scdn.co/mp3-preview/4a93ec26bf1ef91899cafb18195227a02e767191?cid=6e24789ec7874259a220f747fcd7e93e',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:69yfbpvmkIaB10msnKT7Q5'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/53XhwfbYqKCa1cC15pYq2q'},
#        'href': 'https://api.spotify.com/v1/artists/53XhwfbYqKCa1cC15pYq2q',
#        'id': '53XhwfbYqKCa1cC15pYq2q',
#        'name': 'Imagine Dragons',
#        'type': 'artist',
#        'uri': 'spotify:artist:53XhwfbYqKCa1cC15pYq2q'}],
#      'available_markets': ['MX', 'US'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/1rzDtYMpZDhRgKNigB467r'},
#      'href': 'https://api.spotify.com/v1/albums/1rzDtYMpZDhRgKNigB467r',
#      'id': '1rzDtYMpZDhRgKNigB467r',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273a8f95e7f840c11edfa6cc3bd',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02a8f95e7f840c11edfa6cc3bd',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851a8f95e7f840c11edfa6cc3bd',
#        'width': 64}],
#      'name': 'Night Visions (Deluxe)',
#      'release_date': '2012-09-04',
#      'release_date_precision': 'day',
#      'total_tracks': 16,
#      'type': 'album',
#      'uri': 'spotify:album:1rzDtYMpZDhRgKNigB467r'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/53XhwfbYqKCa1cC15pYq2q'},
#       'href': 'https://api.spotify.com/v1/artists/53XhwfbYqKCa1cC15pYq2q',
#       'id': '53XhwfbYqKCa1cC15pYq2q',
#       'name': 'Imagine Dragons',
#       'type': 'artist',
#       'uri': 'spotify:artist:53XhwfbYqKCa1cC15pYq2q'}],
#     'available_markets': ['MX', 'US'],
#     'disc_number': 1,
#     'duration_ms': 186813,
#     'explicit': False,
#     'external_ids': {'isrc': 'USUM71201074'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/58rFzMvW9kxNwMtGTgBQoP'},
#     'href': 'https://api.spotify.com/v1/tracks/58rFzMvW9kxNwMtGTgBQoP',
#     'id': '58rFzMvW9kxNwMtGTgBQoP',
#     'is_local': False,
#     'name': 'Radioactive',
#     'popularity': 64,
#     'preview_url': 'https://p.scdn.co/mp3-preview/43288a26d88c84b0ac5938c6e547b0ad99c49f78?cid=6e24789ec7874259a220f747fcd7e93e',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:58rFzMvW9kxNwMtGTgBQoP'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/53XhwfbYqKCa1cC15pYq2q'},
#        'href': 'https://api.spotify.com/v1/artists/53XhwfbYqKCa1cC15pYq2q',
#        'id': '53XhwfbYqKCa1cC15pYq2q',
#        'name': 'Imagine Dragons',
#        'type': 'artist',
#        'uri': 'spotify:artist:53XhwfbYqKCa1cC15pYq2q'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/0LLA5YL3g2UReWlP7nWqGh'},
#      'href': 'https://api.spotify.com/v1/albums/0LLA5YL3g2UReWlP7nWqGh',
#      'id': '0LLA5YL3g2UReWlP7nWqGh',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27381eeace38068e9444cb28a3e',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0281eeace38068e9444cb28a3e',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485181eeace38068e9444cb28a3e',
#        'width': 64}],
#      'name': 'Night Visions (Expanded Edition / Super Deluxe)',
#      'release_date': '2022-09-09',
#      'release_date_precision': 'day',
#      'total_tracks': 54,
#      'type': 'album',
#      'uri': 'spotify:album:0LLA5YL3g2UReWlP7nWqGh'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/53XhwfbYqKCa1cC15pYq2q'},
#       'href': 'https://api.spotify.com/v1/artists/53XhwfbYqKCa1cC15pYq2q',
#       'id': '53XhwfbYqKCa1cC15pYq2q',
#       'name': 'Imagine Dragons',
#       'type': 'artist',
#       'uri': 'spotify:artist:53XhwfbYqKCa1cC15pYq2q'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 186813,
#     'explicit': False,
#     'external_ids': {'isrc': 'USUM71201074'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/5Yj7eY0cs6wkGsn5mxy9j1'},
#     'href': 'https://api.spotify.com/v1/tracks/5Yj7eY0cs6wkGsn5mxy9j1',
#     'id': '5Yj7eY0cs6wkGsn5mxy9j1',
#     'is_local': False,
#     'name': 'Radioactive',
#     'popularity': 54,
#     'preview_url': 'https://p.scdn.co/mp3-preview/1c6ea8da9a90a3184c21c73c3ab6fda1dbe6ee49?cid=6e24789ec7874259a220f747fcd7e93e',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:5Yj7eY0cs6wkGsn5mxy9j1'},
#    {'album': {'album_type': 'compilation',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#        'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#        'id': '0LyfQWJT6nXafLPZqxe9Of',
#        'name': 'Various Artists',
#        'type': 'artist',
#        'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#      'available_markets': ['AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GH',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JP',
#       'KE',
#       'KH',
#       'KR',
#       'KW',
#       'LB',
#       'LK',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SN',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TT',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VE',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2n9seCBtupHlk3m2ruv6A1'},
#      'href': 'https://api.spotify.com/v1/albums/2n9seCBtupHlk3m2ruv6A1',
#      'id': '2n9seCBtupHlk3m2ruv6A1',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273dc1dacdd8a87fb48e6db4471',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02dc1dacdd8a87fb48e6db4471',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851dc1dacdd8a87fb48e6db4471',
#        'width': 64}],
#      'name': 'Car Songs',
#      'release_date': '2021-04-09',
#      'release_date_precision': 'day',
#      'total_tracks': 30,
#      'type': 'album',
#      'uri': 'spotify:album:2n9seCBtupHlk3m2ruv6A1'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/53XhwfbYqKCa1cC15pYq2q'},
#       'href': 'https://api.spotify.com/v1/artists/53XhwfbYqKCa1cC15pYq2q',
#       'id': '53XhwfbYqKCa1cC15pYq2q',
#       'name': 'Imagine Dragons',
#       'type': 'artist',
#       'uri': 'spotify:artist:53XhwfbYqKCa1cC15pYq2q'}],
#     'available_markets': ['AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GH',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JP',
#      'KE',
#      'KH',
#      'KR',
#      'KW',
#      'LB',
#      'LK',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SN',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TT',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VE',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 188000,
#     'explicit': False,
#     'external_ids': {'isrc': 'USUM71201074'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/33DPHYA8bJstGIMXkz1lFt'},
#     'href': 'https://api.spotify.com/v1/tracks/33DPHYA8bJstGIMXkz1lFt',
#     'id': '33DPHYA8bJstGIMXkz1lFt',
#     'is_local': False,
#     'name': 'Radioactive',
#     'popularity': 46,
#     'preview_url': 'https://p.scdn.co/mp3-preview/4b9f38fd712765b71770d66711497409298bc314?cid=6e24789ec7874259a220f747fcd7e93e',
#     'track_number': 22,
#     'type': 'track',
#     'uri': 'spotify:track:33DPHYA8bJstGIMXkz1lFt'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/53XhwfbYqKCa1cC15pYq2q'},
#        'href': 'https://api.spotify.com/v1/artists/53XhwfbYqKCa1cC15pYq2q',
#        'id': '53XhwfbYqKCa1cC15pYq2q',
#        'name': 'Imagine Dragons',
#        'type': 'artist',
#        'uri': 'spotify:artist:53XhwfbYqKCa1cC15pYq2q'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/0LLA5YL3g2UReWlP7nWqGh'},
#      'href': 'https://api.spotify.com/v1/albums/0LLA5YL3g2UReWlP7nWqGh',
#      'id': '0LLA5YL3g2UReWlP7nWqGh',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27381eeace38068e9444cb28a3e',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0281eeace38068e9444cb28a3e',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485181eeace38068e9444cb28a3e',
#        'width': 64}],
#      'name': 'Night Visions (Expanded Edition / Super Deluxe)',
#      'release_date': '2022-09-09',
#      'release_date_precision': 'day',
#      'total_tracks': 54,
#      'type': 'album',
#      'uri': 'spotify:album:0LLA5YL3g2UReWlP7nWqGh'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/53XhwfbYqKCa1cC15pYq2q'},
#       'href': 'https://api.spotify.com/v1/artists/53XhwfbYqKCa1cC15pYq2q',
#       'id': '53XhwfbYqKCa1cC15pYq2q',
#       'name': 'Imagine Dragons',
#       'type': 'artist',
#       'uri': 'spotify:artist:53XhwfbYqKCa1cC15pYq2q'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 3,
#     'duration_ms': 270080,
#     'explicit': False,
#     'external_ids': {'isrc': 'USUM71303062'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3T09JC1tNKcHZPhisKKUm8'},
#     'href': 'https://api.spotify.com/v1/tracks/3T09JC1tNKcHZPhisKKUm8',
#     'id': '3T09JC1tNKcHZPhisKKUm8',
#     'is_local': False,
#     'name': 'Radioactive - Live London Sessions / 2013',
#     'popularity': 48,
#     'preview_url': 'https://p.scdn.co/mp3-preview/e6df45f1c34c71afcd549365f0eb1d2e46b87d78?cid=6e24789ec7874259a220f747fcd7e93e',
#     'track_number': 13,
#     'type': 'track',
#     'uri': 'spotify:track:3T09JC1tNKcHZPhisKKUm8'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/53XhwfbYqKCa1cC15pYq2q'},
#        'href': 'https://api.spotify.com/v1/artists/53XhwfbYqKCa1cC15pYq2q',
#        'id': '53XhwfbYqKCa1cC15pYq2q',
#        'name': 'Imagine Dragons',
#        'type': 'artist',
#        'uri': 'spotify:artist:53XhwfbYqKCa1cC15pYq2q'}],
#      'available_markets': ['AD',
#       'AT',
#       'AU',
#       'BE',
#       'CA',
#       'CH',
#       'CW',
#       'DE',
#       'DK',
#       'EE',
#       'ES',
#       'FI',
#       'GB',
#       'HK',
#       'IE',
#       'IS',
#       'IT',
#       'LI',
#       'LT',
#       'LV',
#       'MC',
#       'MX',
#       'MY',
#       'NL',
#       'NO',
#       'NP',
#       'NZ',
#       'PT',
#       'SE',
#       'SG',
#       'US',
#       'UZ'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2RQtDABXELc8EqB7pujcEi'},
#      'href': 'https://api.spotify.com/v1/albums/2RQtDABXELc8EqB7pujcEi',
#      'id': '2RQtDABXELc8EqB7pujcEi',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273acb373a3501f78509ff6b941',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02acb373a3501f78509ff6b941',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851acb373a3501f78509ff6b941',
#        'width': 64}],
#      'name': 'Imagine Dragons (Live London Sessions)',
#      'release_date': '2013-01-01',
#      'release_date_precision': 'day',
#      'total_tracks': 3,
#      'type': 'album',
#      'uri': 'spotify:album:2RQtDABXELc8EqB7pujcEi'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/53XhwfbYqKCa1cC15pYq2q'},
#       'href': 'https://api.spotify.com/v1/artists/53XhwfbYqKCa1cC15pYq2q',
#       'id': '53XhwfbYqKCa1cC15pYq2q',
#       'name': 'Imagine Dragons',
#       'type': 'artist',
#       'uri': 'spotify:artist:53XhwfbYqKCa1cC15pYq2q'}],
#     'available_markets': ['AD',
#      'AT',
#      'AU',
#      'BE',
#      'CA',
#      'CH',
#      'CW',
#      'DE',
#      'DK',
#      'EE',
#      'ES',
#      'FI',
#      'GB',
#      'HK',
#      'IE',
#      'IS',
#      'IT',
#      'LI',
#      'LT',
#      'LV',
#      'MC',
#      'MX',
#      'MY',
#      'NL',
#      'NO',
#      'NP',
#      'NZ',
#      'PT',
#      'SE',
#      'SG',
#      'US',
#      'UZ'],
#     'disc_number': 1,
#     'duration_ms': 270160,
#     'explicit': False,
#     'external_ids': {'isrc': 'USUM71303062'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/7ukrAoAILpGPHaZ9uYmNL0'},
#     'href': 'https://api.spotify.com/v1/tracks/7ukrAoAILpGPHaZ9uYmNL0',
#     'id': '7ukrAoAILpGPHaZ9uYmNL0',
#     'is_local': False,
#     'name': 'Radioactive - Live London Sessions / 2013',
#     'popularity': 39,
#     'preview_url': 'https://p.scdn.co/mp3-preview/d09e038a79ba0570cc1666e47aa8cc5d67ebc29f?cid=6e24789ec7874259a220f747fcd7e93e',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:7ukrAoAILpGPHaZ9uYmNL0'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/53XhwfbYqKCa1cC15pYq2q'},
#        'href': 'https://api.spotify.com/v1/artists/53XhwfbYqKCa1cC15pYq2q',
#        'id': '53XhwfbYqKCa1cC15pYq2q',
#        'name': 'Imagine Dragons',
#        'type': 'artist',
#        'uri': 'spotify:artist:53XhwfbYqKCa1cC15pYq2q'}],
#      'available_markets': ['AE',
#       'BB',
#       'BE',
#       'BF',
#       'BH',
#       'BY',
#       'CA',
#       'DZ',
#       'EG',
#       'ES',
#       'FR',
#       'GB',
#       'GH',
#       'ID',
#       'IE',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KG',
#       'KW',
#       'KZ',
#       'LB',
#       'LU',
#       'LY',
#       'MA',
#       'MX',
#       'MY',
#       'NP',
#       'OM',
#       'PL',
#       'PT',
#       'QA',
#       'SA',
#       'TD',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UZ'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2u7XJ8cLPaDkl4hMMQoWff'},
#      'href': 'https://api.spotify.com/v1/albums/2u7XJ8cLPaDkl4hMMQoWff',
#      'id': '2u7XJ8cLPaDkl4hMMQoWff',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273380949bcb74f2e7d8d8da4e8',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02380949bcb74f2e7d8d8da4e8',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851380949bcb74f2e7d8d8da4e8',
#        'width': 64}],
#      'name': 'Radioactive',
#      'release_date': '2014-01-01',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:2u7XJ8cLPaDkl4hMMQoWff'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/53XhwfbYqKCa1cC15pYq2q'},
#       'href': 'https://api.spotify.com/v1/artists/53XhwfbYqKCa1cC15pYq2q',
#       'id': '53XhwfbYqKCa1cC15pYq2q',
#       'name': 'Imagine Dragons',
#       'type': 'artist',
#       'uri': 'spotify:artist:53XhwfbYqKCa1cC15pYq2q'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/2YZyLoL8N0Wb9xBt1NhZWg'},
#       'href': 'https://api.spotify.com/v1/artists/2YZyLoL8N0Wb9xBt1NhZWg',
#       'id': '2YZyLoL8N0Wb9xBt1NhZWg',
#       'name': 'Kendrick Lamar',
#       'type': 'artist',
#       'uri': 'spotify:artist:2YZyLoL8N0Wb9xBt1NhZWg'}],
#     'available_markets': ['AE',
#      'BB',
#      'BE',
#      'BF',
#      'BH',
#      'BY',
#      'CA',
#      'DZ',
#      'EG',
#      'ES',
#      'FR',
#      'GB',
#      'GH',
#      'ID',
#      'IE',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KG',
#      'KW',
#      'KZ',
#      'LB',
#      'LU',
#      'LY',
#      'MA',
#      'MX',
#      'MY',
#      'NP',
#      'OM',
#      'PL',
#      'PT',
#      'QA',
#      'SA',
#      'TD',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UZ'],
#     'disc_number': 1,
#     'duration_ms': 276040,
#     'explicit': False,
#     'external_ids': {'isrc': 'USUM71400767'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/5e3HJBYbAVb83D85z8k60X'},
#     'href': 'https://api.spotify.com/v1/tracks/5e3HJBYbAVb83D85z8k60X',
#     'id': '5e3HJBYbAVb83D85z8k60X',
#     'is_local': False,
#     'name': 'Radioactive',
#     'popularity': 30,
#     'preview_url': 'https://p.scdn.co/mp3-preview/8449c5f0273bb35b222f1cccd3e9a08487c98cac?cid=6e24789ec7874259a220f747fcd7e93e',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:5e3HJBYbAVb83D85z8k60X'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/53XhwfbYqKCa1cC15pYq2q'},
#        'href': 'https://api.spotify.com/v1/artists/53XhwfbYqKCa1cC15pYq2q',
#        'id': '53XhwfbYqKCa1cC15pYq2q',
#        'name': 'Imagine Dragons',
#        'type': 'artist',
#        'uri': 'spotify:artist:53XhwfbYqKCa1cC15pYq2q'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/0LLA5YL3g2UReWlP7nWqGh'},
#      'href': 'https://api.spotify.com/v1/albums/0LLA5YL3g2UReWlP7nWqGh',
#      'id': '0LLA5YL3g2UReWlP7nWqGh',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27381eeace38068e9444cb28a3e',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0281eeace38068e9444cb28a3e',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485181eeace38068e9444cb28a3e',
#        'width': 64}],
#      'name': 'Night Visions (Expanded Edition / Super Deluxe)',
#      'release_date': '2022-09-09',
#      'release_date_precision': 'day',
#      'total_tracks': 54,
#      'type': 'album',
#      'uri': 'spotify:album:0LLA5YL3g2UReWlP7nWqGh'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/53XhwfbYqKCa1cC15pYq2q'},
#       'href': 'https://api.spotify.com/v1/artists/53XhwfbYqKCa1cC15pYq2q',
#       'id': '53XhwfbYqKCa1cC15pYq2q',
#       'name': 'Imagine Dragons',
#       'type': 'artist',
#       'uri': 'spotify:artist:53XhwfbYqKCa1cC15pYq2q'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 3,
#     'duration_ms': 403693,
#     'explicit': False,
#     'external_ids': {'isrc': 'USUM71400273'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/2oWTWONg6QFSwKAPqmBszv'},
#     'href': 'https://api.spotify.com/v1/tracks/2oWTWONg6QFSwKAPqmBszv',
#     'id': '2oWTWONg6QFSwKAPqmBszv',
#     'is_local': False,
#     'name': 'Radioactive - Live From Red Rocks / 2014',
#     'popularity': 42,
#     'preview_url': 'https://p.scdn.co/mp3-preview/00523b65fc9f6d52ffecf1ea7f5196b8339a8668?cid=6e24789ec7874259a220f747fcd7e93e',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:2oWTWONg6QFSwKAPqmBszv'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/53XhwfbYqKCa1cC15pYq2q'},
#        'href': 'https://api.spotify.com/v1/artists/53XhwfbYqKCa1cC15pYq2q',
#        'id': '53XhwfbYqKCa1cC15pYq2q',
#        'name': 'Imagine Dragons',
#        'type': 'artist',
#        'uri': 'spotify:artist:53XhwfbYqKCa1cC15pYq2q'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/0LLA5YL3g2UReWlP7nWqGh'},
#      'href': 'https://api.spotify.com/v1/albums/0LLA5YL3g2UReWlP7nWqGh',
#      'id': '0LLA5YL3g2UReWlP7nWqGh',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27381eeace38068e9444cb28a3e',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0281eeace38068e9444cb28a3e',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485181eeace38068e9444cb28a3e',
#        'width': 64}],
#      'name': 'Night Visions (Expanded Edition / Super Deluxe)',
#      'release_date': '2022-09-09',
#      'release_date_precision': 'day',
#      'total_tracks': 54,
#      'type': 'album',
#      'uri': 'spotify:album:0LLA5YL3g2UReWlP7nWqGh'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/53XhwfbYqKCa1cC15pYq2q'},
#       'href': 'https://api.spotify.com/v1/artists/53XhwfbYqKCa1cC15pYq2q',
#       'id': '53XhwfbYqKCa1cC15pYq2q',
#       'name': 'Imagine Dragons',
#       'type': 'artist',
#       'uri': 'spotify:artist:53XhwfbYqKCa1cC15pYq2q'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/3kVUvbeRdcrqQ3oHk5hPdx'},
#       'href': 'https://api.spotify.com/v1/artists/3kVUvbeRdcrqQ3oHk5hPdx',
#       'id': '3kVUvbeRdcrqQ3oHk5hPdx',
#       'name': 'Grouplove',
#       'type': 'artist',
#       'uri': 'spotify:artist:3kVUvbeRdcrqQ3oHk5hPdx'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/0rlKkLkpsCnJbZethGBfAk'},
#       'href': 'https://api.spotify.com/v1/artists/0rlKkLkpsCnJbZethGBfAk',
#       'id': '0rlKkLkpsCnJbZethGBfAk',
#       'name': 'Captain Cuts',
#       'type': 'artist',
#       'uri': 'spotify:artist:0rlKkLkpsCnJbZethGBfAk'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 4,
#     'duration_ms': 240666,
#     'explicit': False,
#     'external_ids': {'isrc': 'USUM71306083'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0Htv7EQoiOtmpAoYciJZ3n'},
#     'href': 'https://api.spotify.com/v1/tracks/0Htv7EQoiOtmpAoYciJZ3n',
#     'id': '0Htv7EQoiOtmpAoYciJZ3n',
#     'is_local': False,
#     'name': 'Radioactive - Grouplove & Captain Cuts Remix',
#     'popularity': 36,
# ...
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/53XhwfbYqKCa1cC15pYq2q'},
#       'href': 'https://api.spotify.com/v1/artists/53XhwfbYqKCa1cC15pYq2q',
#       'id': '53XhwfbYqKCa1cC15pYq2q',
#       'name': 'Imagine Dragons',
#       'type': 'artist',
#       'uri': 'spotify:artist:53XhwfbYqKCa1cC15pYq2q'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'KE',
#      'KG',
#      'KH',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TR',
#      'TT',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 330680,
#     'explicit': False,
#     'external_ids': {'isrc': 'USUM71302766'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1EYRsHR5MMd6wRXpk8oi5a'},
#     'href': 'https://api.spotify.com/v1/tracks/1EYRsHR5MMd6wRXpk8oi5a',
#     'id': '1EYRsHR5MMd6wRXpk8oi5a',
#     'is_local': False,
#     'name': 'Radioactive - The Dirty Tees Mix',
#     'popularity': 20,
#     'preview_url': 'https://p.scdn.co/mp3-preview/70db7133593f5c87fac1e588d9ace08b1247eda5?cid=6e24789ec7874259a220f747fcd7e93e',
#     'track_number': 10,
#     'type': 'track',
#     'uri': 'spotify:track:1EYRsHR5MMd6wRXpk8oi5a'},
#    {'album': {'album_type': 'compilation',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#        'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#        'id': '0LyfQWJT6nXafLPZqxe9Of',
#        'name': 'Various Artists',
#        'type': 'artist',
#        'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#      'available_markets': ['AE',
#       'AR',
#       'AT',
#       'AU',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CI',
#       'CL',
#       'CO',
#       'CR',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GH',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JP',
#       'KE',
#       'KH',
#       'KR',
#       'KW',
#       'LB',
#       'LK',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MT',
#       'MX',
#       'MY',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TR',
#       'TT',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VE',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/0YsFtjCfzhaAGuVFEpwxWx'},
#      'href': 'https://api.spotify.com/v1/albums/0YsFtjCfzhaAGuVFEpwxWx',
#      'id': '0YsFtjCfzhaAGuVFEpwxWx',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2737356380a021631ea29373f7e',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e027356380a021631ea29373f7e',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048517356380a021631ea29373f7e',
#        'width': 64}],
#      'name': 'Sunday Morning Breakfast Music',
#      'release_date': '2019-12-06',
#      'release_date_precision': 'day',
#      'total_tracks': 28,
#      'type': 'album',
#      'uri': 'spotify:album:0YsFtjCfzhaAGuVFEpwxWx'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/53XhwfbYqKCa1cC15pYq2q'},
#       'href': 'https://api.spotify.com/v1/artists/53XhwfbYqKCa1cC15pYq2q',
#       'id': '53XhwfbYqKCa1cC15pYq2q',
#       'name': 'Imagine Dragons',
#       'type': 'artist',
#       'uri': 'spotify:artist:53XhwfbYqKCa1cC15pYq2q'}],
#     'available_markets': ['AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CI',
#      'CL',
#      'CO',
#      'CR',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GH',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JP',
#      'KE',
#      'KH',
#      'KR',
#      'KW',
#      'LB',
#      'LK',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MT',
#      'MX',
#      'MY',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TR',
#      'TT',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VE',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 188000,
#     'explicit': False,
#     'external_ids': {'isrc': 'USUM71201074'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1YbmpiBhMQ5l9l7lEQZpej'},
#     'href': 'https://api.spotify.com/v1/tracks/1YbmpiBhMQ5l9l7lEQZpej',
#     'id': '1YbmpiBhMQ5l9l7lEQZpej',
#     'is_local': False,
#     'name': 'Radioactive',
#     'popularity': 16,
#     'preview_url': 'https://p.scdn.co/mp3-preview/c1af134f09f4ab1317795bd0e522d3c84f06c6d8?cid=6e24789ec7874259a220f747fcd7e93e',
#     'track_number': 8,
#     'type': 'track',
#     'uri': 'spotify:track:1YbmpiBhMQ5l9l7lEQZpej'},
#    {'album': {'album_type': 'compilation',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#        'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#        'id': '0LyfQWJT6nXafLPZqxe9Of',
#        'name': 'Various Artists',
#        'type': 'artist',
#        'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#      'available_markets': ['AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GH',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JP',
#       'KE',
#       'KH',
#       'KR',
#       'KW',
#       'LB',
#       'LK',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SN',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TT',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VE',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/6ns2Pfkc5KiqmKsaFZiePO'},
#      'href': 'https://api.spotify.com/v1/albums/6ns2Pfkc5KiqmKsaFZiePO',
#      'id': '6ns2Pfkc5KiqmKsaFZiePO',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27377213b8b94daad9de8ddeff6',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0277213b8b94daad9de8ddeff6',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485177213b8b94daad9de8ddeff6',
#        'width': 64}],
#      'name': 'Simplemente Acústico',
#      'release_date': '2020-10-30',
#      'release_date_precision': 'day',
#      'total_tracks': 31,
#      'type': 'album',
#      'uri': 'spotify:album:6ns2Pfkc5KiqmKsaFZiePO'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/53XhwfbYqKCa1cC15pYq2q'},
#       'href': 'https://api.spotify.com/v1/artists/53XhwfbYqKCa1cC15pYq2q',
#       'id': '53XhwfbYqKCa1cC15pYq2q',
#       'name': 'Imagine Dragons',
#       'type': 'artist',
#       'uri': 'spotify:artist:53XhwfbYqKCa1cC15pYq2q'}],
#     'available_markets': ['AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GH',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JP',
#      'KE',
#      'KH',
#      'KR',
#      'KW',
#      'LB',
#      'LK',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SN',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TT',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VE',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 270160,
#     'explicit': False,
#     'external_ids': {'isrc': 'USUM71303062'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0p794CUAPutGF7cGeZszIU'},
#     'href': 'https://api.spotify.com/v1/tracks/0p794CUAPutGF7cGeZszIU',
#     'id': '0p794CUAPutGF7cGeZszIU',
#     'is_local': False,
#     'name': 'Radioactive - Live London Sessions / 2013',
#     'popularity': 33,
#     'preview_url': 'https://p.scdn.co/mp3-preview/d1f04f4f8ec33090e09b3e46763aa5056724359f?cid=6e24789ec7874259a220f747fcd7e93e',
#     'track_number': 25,
#     'type': 'track',
#     'uri': 'spotify:track:0p794CUAPutGF7cGeZszIU'},
#    {'album': {'album_type': 'compilation',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#        'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#        'id': '0LyfQWJT6nXafLPZqxe9Of',
#        'name': 'Various Artists',
#        'type': 'artist',
#        'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#      'available_markets': ['AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GH',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JP',
#       'KE',
#       'KH',
#       'KR',
#       'KW',
#       'LB',
#       'LK',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SN',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TT',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VE',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/258yGVacrnKwQIPNaBUw3h'},
#      'href': 'https://api.spotify.com/v1/albums/258yGVacrnKwQIPNaBUw3h',
#      'id': '258yGVacrnKwQIPNaBUw3h',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2733d5c9d3ac2c800522f9e2fa2',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e023d5c9d3ac2c800522f9e2fa2',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048513d5c9d3ac2c800522f9e2fa2',
#        'width': 64}],
#      'name': 'Acoustic Rock',
#      'release_date': '2021-03-08',
#      'release_date_precision': 'day',
#      'total_tracks': 26,
#      'type': 'album',
#      'uri': 'spotify:album:258yGVacrnKwQIPNaBUw3h'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/53XhwfbYqKCa1cC15pYq2q'},
#       'href': 'https://api.spotify.com/v1/artists/53XhwfbYqKCa1cC15pYq2q',
#       'id': '53XhwfbYqKCa1cC15pYq2q',
#       'name': 'Imagine Dragons',
#       'type': 'artist',
#       'uri': 'spotify:artist:53XhwfbYqKCa1cC15pYq2q'}],
#     'available_markets': ['AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GH',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JP',
#      'KE',
#      'KH',
#      'KR',
#      'KW',
#      'LB',
#      'LK',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SN',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TT',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VE',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 270160,
#     'explicit': False,
#     'external_ids': {'isrc': 'USUM71303062'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/10FAUhJFvLM70mhtscu7f4'},
#     'href': 'https://api.spotify.com/v1/tracks/10FAUhJFvLM70mhtscu7f4',
#     'id': '10FAUhJFvLM70mhtscu7f4',
#     'is_local': False,
#     'name': 'Radioactive - Live London Sessions / 2013',
#     'popularity': 22,
#     'preview_url': 'https://p.scdn.co/mp3-preview/d1f04f4f8ec33090e09b3e46763aa5056724359f?cid=6e24789ec7874259a220f747fcd7e93e',
#     'track_number': 26,
#     'type': 'track',
#     'uri': 'spotify:track:10FAUhJFvLM70mhtscu7f4'}],
#   'limit': 20,
#   'next': 'https://api.spotify.com/v1/search?query=track%3ARadioactive+artist%3AImagine&type=track&offset=20&limit=20',
#   'offset': 0,
#   'previous': None,
#   'total': 156}}

# %%
test = pd.DataFrame.from_dict(radioactive,orient='columns')
test
# Out:
#                                                      tracks
# href      https://api.spotify.com/v1/search?query=track%...
# items     [{'album': {'album_type': 'album', 'artists': ...
# limit                                                    20
# next      https://api.spotify.com/v1/search?query=track%...
# offset                                                    0
# previous                                               None
# total                                                   156

# %%
test= test.tracks.apply(pd.Series)
test
# Out:
# /var/folders/91/wchv5p25455f2k8078kdjvm40000gn/T/ipykernel_26479/2977931382.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   test= test.tracks.apply(pd.Series)
#                                                           0  \
# href      https://api.spotify.com/v1/search?query=track%...
# items     {'album': {'album_type': 'album', 'artists': [...
# limit                                                  20.0
# next      https://api.spotify.com/v1/search?query=track%...
# offset                                                  0.0
# previous                                                NaN
# total                                                 156.0
#
#                                                           1  \
# href                                                    NaN
# items     {'album': {'album_type': 'single', 'artists': ...
# limit                                                   NaN
# next                                                    NaN
# offset                                                  NaN
# previous                                                NaN
# total                                                   NaN
#
#                                                           2  \
# href                                                    NaN
# items     {'album': {'album_type': 'album', 'artists': [...
# limit                                                   NaN
# next                                                    NaN
# offset                                                  NaN
# previous                                                NaN
# total                                                   NaN
#
#                                                           3  \
# href                                                    NaN
# items     {'album': {'album_type': 'album', 'artists': [...
# limit                                                   NaN
# next                                                    NaN
# offset                                                  NaN
# previous                                                NaN
# total                                                   NaN
#
#                                                           4  \
# href                                                    NaN
# items     {'album': {'album_type': 'compilation', 'artis...
# limit                                                   NaN
# next                                                    NaN
# offset                                                  NaN
# previous                                                NaN
# total                                                   NaN
#
#                                                           5  \
# href                                                    NaN
# items     {'album': {'album_type': 'album', 'artists': [...
# limit                                                   NaN
# next                                                    NaN
# offset                                                  NaN
# previous                                                NaN
# total                                                   NaN
#
#                                                           6  \
# href                                                    NaN
# items     {'album': {'album_type': 'single', 'artists': ...
# limit                                                   NaN
# next                                                    NaN
# offset                                                  NaN
# previous                                                NaN
# total                                                   NaN
#
#                                                           7  \
# href                                                    NaN
# items     {'album': {'album_type': 'single', 'artists': ...
# limit                                                   NaN
# next                                                    NaN
# offset                                                  NaN
# previous                                                NaN
# total                                                   NaN
#
#                                                           8  \
# href                                                    NaN
# items     {'album': {'album_type': 'album', 'artists': [...
# limit                                                   NaN
# next                                                    NaN
# offset                                                  NaN
# previous                                                NaN
# total                                                   NaN
#
#                                                           9  \
# href                                                    NaN
# items     {'album': {'album_type': 'album', 'artists': [...
# limit                                                   NaN
# next                                                    NaN
# offset                                                  NaN
# previous                                                NaN
# total                                                   NaN
#
#                                                          10  \
# href                                                    NaN
# items     {'album': {'album_type': 'compilation', 'artis...
# limit                                                   NaN
# next                                                    NaN
# offset                                                  NaN
# previous                                                NaN
# total                                                   NaN
#
#                                                          11  \
# href                                                    NaN
# items     {'album': {'album_type': 'album', 'artists': [...
# limit                                                   NaN
# next                                                    NaN
# offset                                                  NaN
# previous                                                NaN
# total                                                   NaN
#
#                                                          12  \
# href                                                    NaN
# items     {'album': {'album_type': 'compilation', 'artis...
# limit                                                   NaN
# next                                                    NaN
# offset                                                  NaN
# previous                                                NaN
# total                                                   NaN
#
#                                                          13  \
# href                                                    NaN
# items     {'album': {'album_type': 'single', 'artists': ...
# limit                                                   NaN
# next                                                    NaN
# offset                                                  NaN
# previous                                                NaN
# total                                                   NaN
#
#                                                          14  \
# href                                                    NaN
# items     {'album': {'album_type': 'compilation', 'artis...
# limit                                                   NaN
# next                                                    NaN
# offset                                                  NaN
# previous                                                NaN
# total                                                   NaN
#
#                                                          15  \
# href                                                    NaN
# items     {'album': {'album_type': 'compilation', 'artis...
# limit                                                   NaN
# next                                                    NaN
# offset                                                  NaN
# previous                                                NaN
# total                                                   NaN
#
#                                                          16  \
# href                                                    NaN
# items     {'album': {'album_type': 'compilation', 'artis...
# limit                                                   NaN
# next                                                    NaN
# offset                                                  NaN
# previous                                                NaN
# total                                                   NaN
#
#                                                          17  \
# href                                                    NaN
# items     {'album': {'album_type': 'compilation', 'artis...
# limit                                                   NaN
# next                                                    NaN
# offset                                                  NaN
# previous                                                NaN
# total                                                   NaN
#
#                                                          18  \
# href                                                    NaN
# items     {'album': {'album_type': 'compilation', 'artis...
# limit                                                   NaN
# next                                                    NaN
# offset                                                  NaN
# previous                                                NaN
# total                                                   NaN
#
#                                                          19
# href                                                    NaN
# items     {'album': {'album_type': 'compilation', 'artis...
# limit                                                   NaN
# next                                                    NaN
# offset                                                  NaN
# previous                                                NaN
# total                                                   NaN

# %%
test2 = pd.DataFrame(test.iloc[1])
test2
# Out:
#                                                 items
# 0   {'album': {'album_type': 'album', 'artists': [...
# 1   {'album': {'album_type': 'single', 'artists': ...
# 2   {'album': {'album_type': 'album', 'artists': [...
# 3   {'album': {'album_type': 'album', 'artists': [...
# 4   {'album': {'album_type': 'compilation', 'artis...
# 5   {'album': {'album_type': 'album', 'artists': [...
# 6   {'album': {'album_type': 'single', 'artists': ...
# 7   {'album': {'album_type': 'single', 'artists': ...
# 8   {'album': {'album_type': 'album', 'artists': [...
# 9   {'album': {'album_type': 'album', 'artists': [...
# 10  {'album': {'album_type': 'compilation', 'artis...
# 11  {'album': {'album_type': 'album', 'artists': [...
# 12  {'album': {'album_type': 'compilation', 'artis...
# 13  {'album': {'album_type': 'single', 'artists': ...
# 14  {'album': {'album_type': 'compilation', 'artis...
# 15  {'album': {'album_type': 'compilation', 'artis...
# 16  {'album': {'album_type': 'compilation', 'artis...
# 17  {'album': {'album_type': 'compilation', 'artis...
# 18  {'album': {'album_type': 'compilation', 'artis...
# 19  {'album': {'album_type': 'compilation', 'artis...

# %%
test3 = test2['items'].apply(pd.Series)
test3
# Out:
#                                                 album  \
# 0   {'album_type': 'album', 'artists': [{'external...
# 1   {'album_type': 'single', 'artists': [{'externa...
# 2   {'album_type': 'album', 'artists': [{'external...
# 3   {'album_type': 'album', 'artists': [{'external...
# 4   {'album_type': 'compilation', 'artists': [{'ex...
# 5   {'album_type': 'album', 'artists': [{'external...
# 6   {'album_type': 'single', 'artists': [{'externa...
# 7   {'album_type': 'single', 'artists': [{'externa...
# 8   {'album_type': 'album', 'artists': [{'external...
# 9   {'album_type': 'album', 'artists': [{'external...
# 10  {'album_type': 'compilation', 'artists': [{'ex...
# 11  {'album_type': 'album', 'artists': [{'external...
# 12  {'album_type': 'compilation', 'artists': [{'ex...
# 13  {'album_type': 'single', 'artists': [{'externa...
# 14  {'album_type': 'compilation', 'artists': [{'ex...
# 15  {'album_type': 'compilation', 'artists': [{'ex...
# 16  {'album_type': 'compilation', 'artists': [{'ex...
# 17  {'album_type': 'compilation', 'artists': [{'ex...
# 18  {'album_type': 'compilation', 'artists': [{'ex...
# 19  {'album_type': 'compilation', 'artists': [{'ex...
#
#                                               artists  \
# 0   [{'external_urls': {'spotify': 'https://open.s...
# 1   [{'external_urls': {'spotify': 'https://open.s...
# 2   [{'external_urls': {'spotify': 'https://open.s...
# 3   [{'external_urls': {'spotify': 'https://open.s...
# 4   [{'external_urls': {'spotify': 'https://open.s...
# 5   [{'external_urls': {'spotify': 'https://open.s...
# 6   [{'external_urls': {'spotify': 'https://open.s...
# 7   [{'external_urls': {'spotify': 'https://open.s...
# 8   [{'external_urls': {'spotify': 'https://open.s...
# 9   [{'external_urls': {'spotify': 'https://open.s...
# 10  [{'external_urls': {'spotify': 'https://open.s...
# 11  [{'external_urls': {'spotify': 'https://open.s...
# 12  [{'external_urls': {'spotify': 'https://open.s...
# 13  [{'external_urls': {'spotify': 'https://open.s...
# 14  [{'external_urls': {'spotify': 'https://open.s...
# 15  [{'external_urls': {'spotify': 'https://open.s...
# 16  [{'external_urls': {'spotify': 'https://open.s...
# 17  [{'external_urls': {'spotify': 'https://open.s...
# 18  [{'external_urls': {'spotify': 'https://open.s...
# 19  [{'external_urls': {'spotify': 'https://open.s...
#
#                                     available_markets  disc_number  \
# 0                                            [CA, US]            1
# 1   [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...            1
# 2                                            [MX, US]            1
# 3   [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...            1
# 4   [AE, AL, AR, AT, AU, BA, BE, BG, BH, BO, BR, C...            1
# 5   [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...            3
# 6   [AD, AT, AU, BE, CA, CH, CW, DE, DK, EE, ES, F...            1
# 7   [AE, BB, BE, BF, BH, BY, CA, DZ, EG, ES, FR, G...            1
# 8   [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...            3
# 9   [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...            4
# 10  [AE, AL, AR, AT, AU, BA, BG, BH, BO, BR, CA, C...            1
# 11  [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...            4
# 12  [AE, AR, AT, AU, BE, BG, BH, BO, BR, CA, CH, C...            1
# 13                                   [CA, CR, MX, US]            1
# 14  [AE, AR, AT, AU, BE, BG, BH, BO, BR, CA, CH, C...            1
# 15                                               [US]            2
# 16  [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...            1
# 17  [AE, AR, AT, AU, BE, BG, BH, BO, BR, CA, CH, C...            1
# 18  [AE, AL, AR, AT, AU, BA, BE, BG, BH, BO, BR, C...            1
# 19  [AE, AL, AR, AT, AU, BA, BE, BG, BH, BO, BR, C...            1
#
#     duration_ms  explicit              external_ids  \
# 0        186813     False  {'isrc': 'USUM71201074'}
# 1        276040      True  {'isrc': 'USUM71400693'}
# 2        186813     False  {'isrc': 'USUM71201074'}
# 3        186813     False  {'isrc': 'USUM71201074'}
# 4        188000     False  {'isrc': 'USUM71201074'}
# 5        270080     False  {'isrc': 'USUM71303062'}
# 6        270160     False  {'isrc': 'USUM71303062'}
# 7        276040     False  {'isrc': 'USUM71400767'}
# 8        403693     False  {'isrc': 'USUM71400273'}
# 9        240666     False  {'isrc': 'USUM71306083'}
# 10       188000     False  {'isrc': 'USUM71201074'}
# 11       328440     False  {'isrc': 'USUM71302766'}
# 12       188000     False  {'isrc': 'USUM71201074'}
# 13       241613     False  {'isrc': 'USUM71306083'}
# 14       188000     False  {'isrc': 'USUM71201074'}
# 15       185186     False  {'isrc': 'USUM71201074'}
# 16       330680     False  {'isrc': 'USUM71302766'}
# 17       188000     False  {'isrc': 'USUM71201074'}
# 18       270160     False  {'isrc': 'USUM71303062'}
# 19       270160     False  {'isrc': 'USUM71303062'}
#
#                                         external_urls  \
# 0   {'spotify': 'https://open.spotify.com/track/4G...
# 1   {'spotify': 'https://open.spotify.com/track/69...
# 2   {'spotify': 'https://open.spotify.com/track/58...
# 3   {'spotify': 'https://open.spotify.com/track/5Y...
# 4   {'spotify': 'https://open.spotify.com/track/33...
# 5   {'spotify': 'https://open.spotify.com/track/3T...
# 6   {'spotify': 'https://open.spotify.com/track/7u...
# 7   {'spotify': 'https://open.spotify.com/track/5e...
# 8   {'spotify': 'https://open.spotify.com/track/2o...
# 9   {'spotify': 'https://open.spotify.com/track/0H...
# 10  {'spotify': 'https://open.spotify.com/track/0x...
# 11  {'spotify': 'https://open.spotify.com/track/1v...
# 12  {'spotify': 'https://open.spotify.com/track/6C...
# 13  {'spotify': 'https://open.spotify.com/track/4R...
# 14  {'spotify': 'https://open.spotify.com/track/1b...
# 15  {'spotify': 'https://open.spotify.com/track/2V...
# 16  {'spotify': 'https://open.spotify.com/track/1E...
# 17  {'spotify': 'https://open.spotify.com/track/1Y...
# 18  {'spotify': 'https://open.spotify.com/track/0p...
# 19  {'spotify': 'https://open.spotify.com/track/10...
#
#                                                  href                      id  \
# 0   https://api.spotify.com/v1/tracks/4G8gkOterJn0...  4G8gkOterJn0Ywt6uhqbhp
# 1   https://api.spotify.com/v1/tracks/69yfbpvmkIaB...  69yfbpvmkIaB10msnKT7Q5
# 2   https://api.spotify.com/v1/tracks/58rFzMvW9kxN...  58rFzMvW9kxNwMtGTgBQoP
# 3   https://api.spotify.com/v1/tracks/5Yj7eY0cs6wk...  5Yj7eY0cs6wkGsn5mxy9j1
# 4   https://api.spotify.com/v1/tracks/33DPHYA8bJst...  33DPHYA8bJstGIMXkz1lFt
# 5   https://api.spotify.com/v1/tracks/3T09JC1tNKcH...  3T09JC1tNKcHZPhisKKUm8
# 6   https://api.spotify.com/v1/tracks/7ukrAoAILpGP...  7ukrAoAILpGPHaZ9uYmNL0
# 7   https://api.spotify.com/v1/tracks/5e3HJBYbAVb8...  5e3HJBYbAVb83D85z8k60X
# 8   https://api.spotify.com/v1/tracks/2oWTWONg6QFS...  2oWTWONg6QFSwKAPqmBszv
# 9   https://api.spotify.com/v1/tracks/0Htv7EQoiOtm...  0Htv7EQoiOtmpAoYciJZ3n
# 10  https://api.spotify.com/v1/tracks/0xtzqUPM1e6D...  0xtzqUPM1e6DSVnp67Of5L
# 11  https://api.spotify.com/v1/tracks/1vOnrbY7Nwnm...  1vOnrbY7NwnmBRsXCyvH9Y
# 12  https://api.spotify.com/v1/tracks/6CSRGkRhy76j...  6CSRGkRhy76jmwwZE5Rpck
# 13  https://api.spotify.com/v1/tracks/4RE6keayatk5...  4RE6keayatk5kVgKOGDcmy
# 14  https://api.spotify.com/v1/tracks/1b6TETQ63Zj3...  1b6TETQ63Zj3nt1ua9otla
# 15  https://api.spotify.com/v1/tracks/2VhRRYsEJaxG...  2VhRRYsEJaxGJ2ueMSVorb
# 16  https://api.spotify.com/v1/tracks/1EYRsHR5MMd6...  1EYRsHR5MMd6wRXpk8oi5a
# 17  https://api.spotify.com/v1/tracks/1YbmpiBhMQ5l...  1YbmpiBhMQ5l9l7lEQZpej
# 18  https://api.spotify.com/v1/tracks/0p794CUAPutG...  0p794CUAPutGF7cGeZszIU
# 19  https://api.spotify.com/v1/tracks/10FAUhJFvLM7...  10FAUhJFvLM70mhtscu7f4
#
#     is_local                                          name  popularity  \
# 0      False                                   Radioactive          72
# 1      False                                   Radioactive          65
# 2      False                                   Radioactive          64
# 3      False                                   Radioactive          54
# 4      False                                   Radioactive          46
# 5      False     Radioactive - Live London Sessions / 2013          48
# 6      False     Radioactive - Live London Sessions / 2013          39
# 7      False                                   Radioactive          30
# 8      False      Radioactive - Live From Red Rocks / 2014          42
# 9      False  Radioactive - Grouplove & Captain Cuts Remix          36
# 10     False                                   Radioactive          30
# 11     False              Radioactive - The Dirty Tees Mix          35
# 12     False                                   Radioactive          27
# 13     False  Radioactive - Grouplove & Captain Cuts Remix          24
# 14     False                                   Radioactive          21
# 15     False                                   Radioactive          17
# 16     False              Radioactive - The Dirty Tees Mix          20
# 17     False                                   Radioactive          16
# 18     False     Radioactive - Live London Sessions / 2013          33
# 19     False     Radioactive - Live London Sessions / 2013          22
#
#                                           preview_url  track_number   type  \
# 0   https://p.scdn.co/mp3-preview/43288a26d88c84b0...             1  track
# 1   https://p.scdn.co/mp3-preview/4a93ec26bf1ef918...             1  track
# 2   https://p.scdn.co/mp3-preview/43288a26d88c84b0...             1  track
# 3   https://p.scdn.co/mp3-preview/1c6ea8da9a90a318...             1  track
# 4   https://p.scdn.co/mp3-preview/4b9f38fd712765b7...            22  track
# 5   https://p.scdn.co/mp3-preview/e6df45f1c34c71af...            13  track
# 6   https://p.scdn.co/mp3-preview/d09e038a79ba0570...             1  track
# 7   https://p.scdn.co/mp3-preview/8449c5f0273bb35b...             1  track
# 8   https://p.scdn.co/mp3-preview/00523b65fc9f6d52...             1  track
# 9   https://p.scdn.co/mp3-preview/6dc72ada4ed20dd0...             1  track
# 10  https://p.scdn.co/mp3-preview/4b9f38fd712765b7...             5  track
# 11  https://p.scdn.co/mp3-preview/672103699abbace4...             6  track
# 12  https://p.scdn.co/mp3-preview/c1af134f09f4ab13...            25  track
# 13  https://p.scdn.co/mp3-preview/7c3b093664f788e5...             1  track
# 14  https://p.scdn.co/mp3-preview/c1af134f09f4ab13...             1  track
# 15  https://p.scdn.co/mp3-preview/a5051a6ff70209c2...             6  track
# 16  https://p.scdn.co/mp3-preview/70db7133593f5c87...            10  track
# 17  https://p.scdn.co/mp3-preview/c1af134f09f4ab13...             8  track
# 18  https://p.scdn.co/mp3-preview/d1f04f4f8ec33090...            25  track
# 19  https://p.scdn.co/mp3-preview/d1f04f4f8ec33090...            26  track
#
#                                      uri
# 0   spotify:track:4G8gkOterJn0Ywt6uhqbhp
# 1   spotify:track:69yfbpvmkIaB10msnKT7Q5
# 2   spotify:track:58rFzMvW9kxNwMtGTgBQoP
# 3   spotify:track:5Yj7eY0cs6wkGsn5mxy9j1
# 4   spotify:track:33DPHYA8bJstGIMXkz1lFt
# 5   spotify:track:3T09JC1tNKcHZPhisKKUm8
# 6   spotify:track:7ukrAoAILpGPHaZ9uYmNL0
# 7   spotify:track:5e3HJBYbAVb83D85z8k60X
# 8   spotify:track:2oWTWONg6QFSwKAPqmBszv
# 9   spotify:track:0Htv7EQoiOtmpAoYciJZ3n
# 10  spotify:track:0xtzqUPM1e6DSVnp67Of5L
# 11  spotify:track:1vOnrbY7NwnmBRsXCyvH9Y
# 12  spotify:track:6CSRGkRhy76jmwwZE5Rpck
# 13  spotify:track:4RE6keayatk5kVgKOGDcmy
# 14  spotify:track:1b6TETQ63Zj3nt1ua9otla
# 15  spotify:track:2VhRRYsEJaxGJ2ueMSVorb
# 16  spotify:track:1EYRsHR5MMd6wRXpk8oi5a
# 17  spotify:track:1YbmpiBhMQ5l9l7lEQZpej
# 18  spotify:track:0p794CUAPutGF7cGeZszIU
# 19  spotify:track:10FAUhJFvLM70mhtscu7f4

# %%
test3.head(1)
# Out:
#                                                album  \
# 0  {'album_type': 'album', 'artists': [{'external...
#
#                                              artists available_markets  \
# 0  [{'external_urls': {'spotify': 'https://open.s...          [CA, US]
#
#    disc_number  duration_ms  explicit              external_ids  \
# 0            1       186813     False  {'isrc': 'USUM71201074'}
#
#                                        external_urls  \
# 0  {'spotify': 'https://open.spotify.com/track/4G...
#
#                                                 href                      id  \
# 0  https://api.spotify.com/v1/tracks/4G8gkOterJn0...  4G8gkOterJn0Ywt6uhqbhp
#
#    is_local         name  popularity  \
# 0     False  Radioactive          72
#
#                                          preview_url  track_number   type  \
# 0  https://p.scdn.co/mp3-preview/43288a26d88c84b0...             1  track
#
#                                     uri
# 0  spotify:track:4G8gkOterJn0Ywt6uhqbhp

# %%
a
