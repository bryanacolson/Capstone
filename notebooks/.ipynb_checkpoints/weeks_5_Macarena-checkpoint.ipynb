# %%
# import packages

# %%
from pandas.io.json import json_normalize
import json
from pandasql import sqldf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from bs4 import BeautifulSoup
import io
import requests
import json
import base64
import datetime
from urllib.parse import urlencode

# %%
# client id

# %%
client_id = '6e24789ec7874259a220f747fcd7e93e'
client_secret = '9bd8ff1ad2f34ef6a87f00124be070b2'

# %%
class SpotifyAPI(object):
    access_token = None
    access_token_expires = datetime.datetime.now()
    access_token_did_expire = True
    client_id = None
    client_secret = None
    token_url = "https://accounts.spotify.com/api/token"



    def __init__(self, client_id, client_secret, *args, **kwargs):
        super().__init__(*args, **kwargs)
        self.client_id = client_id
        self.client_secret = client_secret

    def getClientCreds(self):
        '''Returns b64 encoded string'''
        client_id = self.client_id
        client_secret = self.client_secret

        if client_id == None or client_secret == None:
            raise Exception('Must set a client id and secret')

        client_creds  = f"{client_id}:{client_secret}"
        client_creds_b64 = base64.b64encode(client_creds.encode())
        return client_creds_b64.decode()

    def getTokenHeader(self):
        client_creds_b64 = self.getClientCreds()
        return {
            'Authorization':f"Basic {client_creds_b64}"
        }

    def getTokenData(self):
        return {
            "grant_type":"client_credentials"
        }

    def perform_auth(self):
        token_url = self.token_url
        token_data = self.getTokenData()
        token_header = self.getTokenHeader()

        r = requests.post(token_url, data=token_data, headers=token_header)

        if r.status_code  not in range(200,299):
            raise Exception('Could not authenticate client.')
            #return False

        now = datetime.datetime.now()
        token_response_data = r.json()
        access_token = token_response_data['access_token']
        expires_in = token_response_data['expires_in']
        expires = now + datetime.timedelta(seconds=expires_in)
        self.access_token = access_token
        self.access_token_expires = expires
        self.access_token_did_expire = expires < now


        return True

    def get_access_token(self):
        token = self.access_token
        expires = self.access_token_expires
        now= datetime.datetime.now()
        if expires < now:
            self.perform_auth()
            return self.get_access_token()
        elif token == None:
            self.perform_auth()
            return self.get_access_token() 
        return token
    
    def get_resource_header(self):
        access_token = self.get_access_token()
        headers = {
            "Authorization": f"Bearer {access_token}", 
        }
        return headers
    
    def get_resource(self, lookup_id, resource_type='albums', version='v1'):
        endpoint = f'https://api.spotify.com/{version}/{resource_type}/{lookup_id}'
        headers = self.get_resource_header()
        r = requests.get(endpoint, headers = headers)
        if r.status_code not in range (200, 299):
            return {}
        return r.json()
    
    def get_album(self, _id ):
        return self.get_resource(_id, resource_type='albums')
    
    def get_artist(self, _id ):
        return self.get_resource(_id, resource_type='artists')
    
    def get_playlist(self, _id):
        return self.get_resource(_id, resource_type='playlists')
    
    
    def base_search(self, query_params): #type
        access_token = self.get_access_token()
        headers = self.get_resource_header()
        endpoint = "https://api.spotify.com/v1/search"
        lookup_URL = f"{endpoint}?{query_params}"
        r = requests.get(lookup_URL, headers=headers)
        if r.status_code not in range (200, 299):
            return {}
        return r.json()
    
    def search(self, query=None, operator=None, operator_query=None, search_type='artist'):
        if query == None:
            raise Exception('A query is required')
        if isinstance(query, dict):
            query = ' '.join([f'{k}:{v}' for k,v in query.items()])
        if operator != None and operator_query != None:
            if operator.lower() == 'or' or operator.lower() == 'not':
                operator = operator.upper()
                if isinstance(operator_query, str):
                    query = f'{query} {operator} {operator_query}'
        query_params = urlencode({'q': query, 'type': search_type.lower()})
        return self.base_search(query_params)

# %%
spotify = SpotifyAPI(client_id, client_secret)

# %%
# Macarena

# %%
Macarena_1 = spotify.search({'track': 'Macarena', 'artist': 'Los Del Rio'}, search_type ='track')
Macarena_1
# Out:
# {'tracks': {'href': 'https://api.spotify.com/v1/search?query=track%3AMacarena+artist%3ALos+Del+Rio&type=track&offset=0&limit=20',
#   'items': [{'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2JXn03fudjyRkQ1Ye9f5rk'},
#        'href': 'https://api.spotify.com/v1/artists/2JXn03fudjyRkQ1Ye9f5rk',
#        'id': '2JXn03fudjyRkQ1Ye9f5rk',
#        'name': 'Los Del Rio',
#        'type': 'artist',
#        'uri': 'spotify:artist:2JXn03fudjyRkQ1Ye9f5rk'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/6yPJmxBhq3zxj9gfTddfyU'},
#      'href': 'https://api.spotify.com/v1/albums/6yPJmxBhq3zxj9gfTddfyU',
#      'id': '6yPJmxBhq3zxj9gfTddfyU',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273a8c284ce171e96a79eabf7de',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02a8c284ce171e96a79eabf7de',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851a8c284ce171e96a79eabf7de',
#        'width': 64}],
#      'name': 'Fiesta Macarena',
#      'release_date': '1996-04-29',
#      'release_date_precision': 'day',
#      'total_tracks': 14,
#      'type': 'album',
#      'uri': 'spotify:album:6yPJmxBhq3zxj9gfTddfyU'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2JXn03fudjyRkQ1Ye9f5rk'},
#       'href': 'https://api.spotify.com/v1/artists/2JXn03fudjyRkQ1Ye9f5rk',
#       'id': '2JXn03fudjyRkQ1Ye9f5rk',
#       'name': 'Los Del Rio',
#       'type': 'artist',
#       'uri': 'spotify:artist:2JXn03fudjyRkQ1Ye9f5rk'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 249506,
#     'explicit': False,
#     'external_ids': {'isrc': 'ES5109500538'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4oaj36KzXRgDg4McgcTsZK'},
#     'href': 'https://api.spotify.com/v1/tracks/4oaj36KzXRgDg4McgcTsZK',
#     'id': '4oaj36KzXRgDg4McgcTsZK',
#     'is_local': False,
#     'name': 'Macarena',
#     'popularity': 59,
#     'preview_url': 'https://p.scdn.co/mp3-preview/b9fd8c94d695a35afabaf96795ae41cd1e285489?cid=6e24789ec7874259a220f747fcd7e93e',
#     'track_number': 12,
#     'type': 'track',
#     'uri': 'spotify:track:4oaj36KzXRgDg4McgcTsZK'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2JXn03fudjyRkQ1Ye9f5rk'},
#        'href': 'https://api.spotify.com/v1/artists/2JXn03fudjyRkQ1Ye9f5rk',
#        'id': '2JXn03fudjyRkQ1Ye9f5rk',
#        'name': 'Los Del Rio',
#        'type': 'artist',
#        'uri': 'spotify:artist:2JXn03fudjyRkQ1Ye9f5rk'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BB',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BO',
#       'BR',
#       'BS',
#       'BW',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'IE',
#       'IL',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KI',
#       'KM',
#       'KN',
#       'KW',
#       'LB',
#       'LC',
#       'LI',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MR',
#       'MT',
#       'MU',
#       'MW',
#       'MX',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TN',
#       'TO',
#       'TT',
#       'TV',
#       'TZ',
#       'UG',
#       'US',
#       'UY',
#       'VC',
#       'VE',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/1Q9ij11CdNvogM0IPG1KNc'},
#      'href': 'https://api.spotify.com/v1/albums/1Q9ij11CdNvogM0IPG1KNc',
#      'id': '1Q9ij11CdNvogM0IPG1KNc',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273442314974e3d78b3e214cdb8',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02442314974e3d78b3e214cdb8',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851442314974e3d78b3e214cdb8',
#        'width': 64}],
#      'name': 'Alegria Y Cosabuena',
#      'release_date': '2001-03-19',
#      'release_date_precision': 'day',
#      'total_tracks': 15,
#      'type': 'album',
#      'uri': 'spotify:album:1Q9ij11CdNvogM0IPG1KNc'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2JXn03fudjyRkQ1Ye9f5rk'},
#       'href': 'https://api.spotify.com/v1/artists/2JXn03fudjyRkQ1Ye9f5rk',
#       'id': '2JXn03fudjyRkQ1Ye9f5rk',
#       'name': 'Los Del Rio',
#       'type': 'artist',
#       'uri': 'spotify:artist:2JXn03fudjyRkQ1Ye9f5rk'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BB',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BO',
#      'BR',
#      'BS',
#      'BW',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'IE',
#      'IL',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KI',
#      'KM',
#      'KN',
#      'KW',
#      'LB',
#      'LC',
#      'LI',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MR',
#      'MT',
#      'MU',
#      'MW',
#      'MX',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TN',
#      'TO',
#      'TT',
#      'TV',
#      'TZ',
#      'UG',
#      'US',
#      'UY',
#      'VC',
#      'VE',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 253106,
#     'explicit': False,
#     'external_ids': {'isrc': 'ES5109600480'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/2df5QsXucx4VLiHNGusXD5'},
#     'href': 'https://api.spotify.com/v1/tracks/2df5QsXucx4VLiHNGusXD5',
#     'id': '2df5QsXucx4VLiHNGusXD5',
#     'is_local': False,
#     'name': 'Macarena - Bayside Boys Remix',
#     'popularity': 57,
#     'preview_url': 'https://p.scdn.co/mp3-preview/3cd3bed124b67e85f38f4279f3c70f257e95b9a2?cid=6e24789ec7874259a220f747fcd7e93e',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:2df5QsXucx4VLiHNGusXD5'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2JXn03fudjyRkQ1Ye9f5rk'},
#        'href': 'https://api.spotify.com/v1/artists/2JXn03fudjyRkQ1Ye9f5rk',
#        'id': '2JXn03fudjyRkQ1Ye9f5rk',
#        'name': 'Los Del Rio',
#        'type': 'artist',
#        'uri': 'spotify:artist:2JXn03fudjyRkQ1Ye9f5rk'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/1anwf7hhIur6jnVg70pXGc'},
#      'href': 'https://api.spotify.com/v1/albums/1anwf7hhIur6jnVg70pXGc',
#      'id': '1anwf7hhIur6jnVg70pXGc',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27345d14c0fbb21667e3d5fecb9',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0245d14c0fbb21667e3d5fecb9',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485145d14c0fbb21667e3d5fecb9',
#        'width': 64}],
#      'name': 'Macarena (EP)',
#      'release_date': '1995',
#      'release_date_precision': 'year',
#      'total_tracks': 5,
#      'type': 'album',
#      'uri': 'spotify:album:1anwf7hhIur6jnVg70pXGc'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2JXn03fudjyRkQ1Ye9f5rk'},
#       'href': 'https://api.spotify.com/v1/artists/2JXn03fudjyRkQ1Ye9f5rk',
#       'id': '2JXn03fudjyRkQ1Ye9f5rk',
#       'name': 'Los Del Rio',
#       'type': 'artist',
#       'uri': 'spotify:artist:2JXn03fudjyRkQ1Ye9f5rk'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 224626,
#     'explicit': False,
#     'external_ids': {'isrc': 'ES5109500537'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/07DcH2UllHvVRKjD2HEJuC'},
#     'href': 'https://api.spotify.com/v1/tracks/07DcH2UllHvVRKjD2HEJuC',
#     'id': '07DcH2UllHvVRKjD2HEJuC',
#     'is_local': False,
#     'name': 'Macarena - Bayside Boys Remix',
#     'popularity': 59,
#     'preview_url': 'https://p.scdn.co/mp3-preview/19fdc8032a4c45f2bd779aaefcdb8a079b02a9e2?cid=6e24789ec7874259a220f747fcd7e93e',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:07DcH2UllHvVRKjD2HEJuC'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2JXn03fudjyRkQ1Ye9f5rk'},
#        'href': 'https://api.spotify.com/v1/artists/2JXn03fudjyRkQ1Ye9f5rk',
#        'id': '2JXn03fudjyRkQ1Ye9f5rk',
#        'name': 'Los Del Rio',
#        'type': 'artist',
#        'uri': 'spotify:artist:2JXn03fudjyRkQ1Ye9f5rk'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/6yPJmxBhq3zxj9gfTddfyU'},
#      'href': 'https://api.spotify.com/v1/albums/6yPJmxBhq3zxj9gfTddfyU',
#      'id': '6yPJmxBhq3zxj9gfTddfyU',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273a8c284ce171e96a79eabf7de',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02a8c284ce171e96a79eabf7de',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851a8c284ce171e96a79eabf7de',
#        'width': 64}],
#      'name': 'Fiesta Macarena',
#      'release_date': '1996-04-29',
#      'release_date_precision': 'day',
#      'total_tracks': 14,
#      'type': 'album',
#      'uri': 'spotify:album:6yPJmxBhq3zxj9gfTddfyU'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2JXn03fudjyRkQ1Ye9f5rk'},
#       'href': 'https://api.spotify.com/v1/artists/2JXn03fudjyRkQ1Ye9f5rk',
#       'id': '2JXn03fudjyRkQ1Ye9f5rk',
#       'name': 'Los Del Rio',
#       'type': 'artist',
#       'uri': 'spotify:artist:2JXn03fudjyRkQ1Ye9f5rk'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 252133,
#     'explicit': False,
#     'external_ids': {'isrc': 'ES5109500537'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/7obdw7ZGr6l1GqSBkFiY11'},
#     'href': 'https://api.spotify.com/v1/tracks/7obdw7ZGr6l1GqSBkFiY11',
#     'id': '7obdw7ZGr6l1GqSBkFiY11',
#     'is_local': False,
#     'name': 'Macarena - Bayside Boys Remix',
#     'popularity': 54,
#     'preview_url': 'https://p.scdn.co/mp3-preview/442a83d3489337c20c3f29e3ab2e22f740afff82?cid=6e24789ec7874259a220f747fcd7e93e',
#     'track_number': 3,
#     'type': 'track',
#     'uri': 'spotify:track:7obdw7ZGr6l1GqSBkFiY11'},
#    {'album': {'album_type': 'compilation',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#        'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#        'id': '0LyfQWJT6nXafLPZqxe9Of',
#        'name': 'Various Artists',
#        'type': 'artist',
#        'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/7EESd9SFYO7ipX0c02vzQ6'},
#      'href': 'https://api.spotify.com/v1/albums/7EESd9SFYO7ipX0c02vzQ6',
#      'id': '7EESd9SFYO7ipX0c02vzQ6',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273cc03f455a6d2ca7f5bc92b7c',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02cc03f455a6d2ca7f5bc92b7c',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851cc03f455a6d2ca7f5bc92b7c',
#        'width': 64}],
#      'name': 'Christmas Pop',
#      'release_date': '2016-09-09',
#      'release_date_precision': 'day',
#      'total_tracks': 50,
#      'type': 'album',
#      'uri': 'spotify:album:7EESd9SFYO7ipX0c02vzQ6'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2JXn03fudjyRkQ1Ye9f5rk'},
#       'href': 'https://api.spotify.com/v1/artists/2JXn03fudjyRkQ1Ye9f5rk',
#       'id': '2JXn03fudjyRkQ1Ye9f5rk',
#       'name': 'Los Del Rio',
#       'type': 'artist',
#       'uri': 'spotify:artist:2JXn03fudjyRkQ1Ye9f5rk'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 253266,
#     'explicit': False,
#     'external_ids': {'isrc': 'ES5109600441'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/5gC7cwZNKqaNLlvHlLjjqE'},
#     'href': 'https://api.spotify.com/v1/tracks/5gC7cwZNKqaNLlvHlLjjqE',
#     'id': '5gC7cwZNKqaNLlvHlLjjqE',
#     'is_local': False,
#     'name': 'Macarena Christmas - Joy Mix',
#     'popularity': 47,
#     'preview_url': 'https://p.scdn.co/mp3-preview/120fcadb0d7eba51753c9e63fbd72a48328c12cf?cid=6e24789ec7874259a220f747fcd7e93e',
#     'track_number': 26,
#     'type': 'track',
#     'uri': 'spotify:track:5gC7cwZNKqaNLlvHlLjjqE'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2JXn03fudjyRkQ1Ye9f5rk'},
#        'href': 'https://api.spotify.com/v1/artists/2JXn03fudjyRkQ1Ye9f5rk',
#        'id': '2JXn03fudjyRkQ1Ye9f5rk',
#        'name': 'Los Del Rio',
#        'type': 'artist',
#        'uri': 'spotify:artist:2JXn03fudjyRkQ1Ye9f5rk'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/6yPJmxBhq3zxj9gfTddfyU'},
#      'href': 'https://api.spotify.com/v1/albums/6yPJmxBhq3zxj9gfTddfyU',
#      'id': '6yPJmxBhq3zxj9gfTddfyU',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273a8c284ce171e96a79eabf7de',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02a8c284ce171e96a79eabf7de',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851a8c284ce171e96a79eabf7de',
#        'width': 64}],
#      'name': 'Fiesta Macarena',
#      'release_date': '1996-04-29',
#      'release_date_precision': 'day',
#      'total_tracks': 14,
#      'type': 'album',
#      'uri': 'spotify:album:6yPJmxBhq3zxj9gfTddfyU'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2JXn03fudjyRkQ1Ye9f5rk'},
#       'href': 'https://api.spotify.com/v1/artists/2JXn03fudjyRkQ1Ye9f5rk',
#       'id': '2JXn03fudjyRkQ1Ye9f5rk',
#       'name': 'Los Del Rio',
#       'type': 'artist',
#       'uri': 'spotify:artist:2JXn03fudjyRkQ1Ye9f5rk'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 304026,
#     'explicit': False,
#     'external_ids': {'isrc': 'ES5109500776'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/5v2HaVFTu9pFOXtD907W1R'},
#     'href': 'https://api.spotify.com/v1/tracks/5v2HaVFTu9pFOXtD907W1R',
#     'id': '5v2HaVFTu9pFOXtD907W1R',
#     'is_local': False,
#     'name': 'Macarena - River Re-Mix',
#     'popularity': 47,
#     'preview_url': 'https://p.scdn.co/mp3-preview/013718d3a69d777679c2c6716ddf49c474aea428?cid=6e24789ec7874259a220f747fcd7e93e',
#     'track_number': 13,
#     'type': 'track',
#     'uri': 'spotify:track:5v2HaVFTu9pFOXtD907W1R'},
#    {'album': {'album_type': 'compilation',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#        'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#        'id': '0LyfQWJT6nXafLPZqxe9Of',
#        'name': 'Various Artists',
#        'type': 'artist',
#        'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/0jVGdTKQ0pValbbtxv5h5O'},
#      'href': 'https://api.spotify.com/v1/albums/0jVGdTKQ0pValbbtxv5h5O',
#      'id': '0jVGdTKQ0pValbbtxv5h5O',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273b33e4b3384a7a0428f990757',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02b33e4b3384a7a0428f990757',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851b33e4b3384a7a0428f990757',
#        'width': 64}],
#      'name': 'Happiness Forever',
#      'release_date': '2018-04-10',
#      'release_date_precision': 'day',
#      'total_tracks': 100,
#      'type': 'album',
#      'uri': 'spotify:album:0jVGdTKQ0pValbbtxv5h5O'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2JXn03fudjyRkQ1Ye9f5rk'},
#       'href': 'https://api.spotify.com/v1/artists/2JXn03fudjyRkQ1Ye9f5rk',
#       'id': '2JXn03fudjyRkQ1Ye9f5rk',
#       'name': 'Los Del Rio',
#       'type': 'artist',
#       'uri': 'spotify:artist:2JXn03fudjyRkQ1Ye9f5rk'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 232546,
#     'explicit': False,
#     'external_ids': {'isrc': 'ES5109500537'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6go8OpVqD9QePmdA726d81'},
#     'href': 'https://api.spotify.com/v1/tracks/6go8OpVqD9QePmdA726d81',
#     'id': '6go8OpVqD9QePmdA726d81',
#     'is_local': False,
#     'name': 'Macarena - Bayside Boys Remix',
#     'popularity': 40,
#     'preview_url': 'https://p.scdn.co/mp3-preview/47cb75435ae6fd186a0dff13c89985daad23b43e?cid=6e24789ec7874259a220f747fcd7e93e',
#     'track_number': 69,
#     'type': 'track',
#     'uri': 'spotify:track:6go8OpVqD9QePmdA726d81'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4djj97IZwNTsqwjznPmvz5'},
#        'href': 'https://api.spotify.com/v1/artists/4djj97IZwNTsqwjznPmvz5',
#        'id': '4djj97IZwNTsqwjznPmvz5',
#        'name': 'Music Room 29',
#        'type': 'artist',
#        'uri': 'spotify:artist:4djj97IZwNTsqwjznPmvz5'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/0szE9YO0h3e4C99oVAx6H1'},
#      'href': 'https://api.spotify.com/v1/albums/0szE9YO0h3e4C99oVAx6H1',
#      'id': '0szE9YO0h3e4C99oVAx6H1',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2735c659bb8a4cca619066dff4e',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e025c659bb8a4cca619066dff4e',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048515c659bb8a4cca619066dff4e',
#        'width': 64}],
#      'name': 'Navidad Latina 2021 (Streaming)',
#      'release_date': '2021-12-01',
#      'release_date_precision': 'day',
#      'total_tracks': 26,
#      'type': 'album',
#      'uri': 'spotify:album:0szE9YO0h3e4C99oVAx6H1'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2JXn03fudjyRkQ1Ye9f5rk'},
#       'href': 'https://api.spotify.com/v1/artists/2JXn03fudjyRkQ1Ye9f5rk',
#       'id': '2JXn03fudjyRkQ1Ye9f5rk',
#       'name': 'Los Del Rio',
#       'type': 'artist',
#       'uri': 'spotify:artist:2JXn03fudjyRkQ1Ye9f5rk'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
# ...
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 343440,
#     'explicit': False,
#     'external_ids': {'isrc': 'ES5109500626'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6oD7eRCXBmh3zgdJu8ohqW'},
#     'href': 'https://api.spotify.com/v1/tracks/6oD7eRCXBmh3zgdJu8ohqW',
#     'id': '6oD7eRCXBmh3zgdJu8ohqW',
#     'is_local': False,
#     'name': 'Macarena - Bass Bumpers Remix-Club Mix',
#     'popularity': 12,
#     'preview_url': 'https://p.scdn.co/mp3-preview/cce795a8fa9ae8be6d183dc3fa531c4f1b40b670?cid=6e24789ec7874259a220f747fcd7e93e',
#     'track_number': 2,
#     'type': 'track',
#     'uri': 'spotify:track:6oD7eRCXBmh3zgdJu8ohqW'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2JXn03fudjyRkQ1Ye9f5rk'},
#        'href': 'https://api.spotify.com/v1/artists/2JXn03fudjyRkQ1Ye9f5rk',
#        'id': '2JXn03fudjyRkQ1Ye9f5rk',
#        'name': 'Los Del Rio',
#        'type': 'artist',
#        'uri': 'spotify:artist:2JXn03fudjyRkQ1Ye9f5rk'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/1anwf7hhIur6jnVg70pXGc'},
#      'href': 'https://api.spotify.com/v1/albums/1anwf7hhIur6jnVg70pXGc',
#      'id': '1anwf7hhIur6jnVg70pXGc',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27345d14c0fbb21667e3d5fecb9',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0245d14c0fbb21667e3d5fecb9',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485145d14c0fbb21667e3d5fecb9',
#        'width': 64}],
#      'name': 'Macarena (EP)',
#      'release_date': '1995',
#      'release_date_precision': 'year',
#      'total_tracks': 5,
#      'type': 'album',
#      'uri': 'spotify:album:1anwf7hhIur6jnVg70pXGc'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2JXn03fudjyRkQ1Ye9f5rk'},
#       'href': 'https://api.spotify.com/v1/artists/2JXn03fudjyRkQ1Ye9f5rk',
#       'id': '2JXn03fudjyRkQ1Ye9f5rk',
#       'name': 'Los Del Rio',
#       'type': 'artist',
#       'uri': 'spotify:artist:2JXn03fudjyRkQ1Ye9f5rk'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/7CJiKj8TrQSms0WSCKbHm4'},
#       'href': 'https://api.spotify.com/v1/artists/7CJiKj8TrQSms0WSCKbHm4',
#       'id': '7CJiKj8TrQSms0WSCKbHm4',
#       'name': 'Fangoria',
#       'type': 'artist',
#       'uri': 'spotify:artist:7CJiKj8TrQSms0WSCKbHm4'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/3axI1ZcY9L4mqqjIUlu8LP'},
#       'href': 'https://api.spotify.com/v1/artists/3axI1ZcY9L4mqqjIUlu8LP',
#       'id': '3axI1ZcY9L4mqqjIUlu8LP',
#       'name': 'Big Toxic',
#       'type': 'artist',
#       'uri': 'spotify:artist:3axI1ZcY9L4mqqjIUlu8LP'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 337373,
#     'explicit': False,
#     'external_ids': {'isrc': 'ES5109300003'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4fUQotmmf00B8dYQtlbm5g'},
#     'href': 'https://api.spotify.com/v1/tracks/4fUQotmmf00B8dYQtlbm5g',
#     'id': '4fUQotmmf00B8dYQtlbm5g',
#     'is_local': False,
#     'name': 'Macarena - La Mezcla Guerillera 130 BPM',
#     'popularity': 11,
#     'preview_url': 'https://p.scdn.co/mp3-preview/c3bc454908451f4b8f0cae5b818ea00f9f9ac6fe?cid=6e24789ec7874259a220f747fcd7e93e',
#     'track_number': 4,
#     'type': 'track',
#     'uri': 'spotify:track:4fUQotmmf00B8dYQtlbm5g'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2JXn03fudjyRkQ1Ye9f5rk'},
#        'href': 'https://api.spotify.com/v1/artists/2JXn03fudjyRkQ1Ye9f5rk',
#        'id': '2JXn03fudjyRkQ1Ye9f5rk',
#        'name': 'Los Del Rio',
#        'type': 'artist',
#        'uri': 'spotify:artist:2JXn03fudjyRkQ1Ye9f5rk'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/0szlmT0E1lm7ybTjwxhkOx'},
#      'href': 'https://api.spotify.com/v1/albums/0szlmT0E1lm7ybTjwxhkOx',
#      'id': '0szlmT0E1lm7ybTjwxhkOx',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273bc569a2f5ceedcaf675fd2e3',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02bc569a2f5ceedcaf675fd2e3',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851bc569a2f5ceedcaf675fd2e3',
#        'width': 64}],
#      'name': 'Macarena Christmas (Remasterizado)',
#      'release_date': '1996',
#      'release_date_precision': 'year',
#      'total_tracks': 4,
#      'type': 'album',
#      'uri': 'spotify:album:0szlmT0E1lm7ybTjwxhkOx'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2JXn03fudjyRkQ1Ye9f5rk'},
#       'href': 'https://api.spotify.com/v1/artists/2JXn03fudjyRkQ1Ye9f5rk',
#       'id': '2JXn03fudjyRkQ1Ye9f5rk',
#       'name': 'Los Del Rio',
#       'type': 'artist',
#       'uri': 'spotify:artist:2JXn03fudjyRkQ1Ye9f5rk'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/5qeaKQ7gFhK3wGupHw90fT'},
#       'href': 'https://api.spotify.com/v1/artists/5qeaKQ7gFhK3wGupHw90fT',
#       'id': '5qeaKQ7gFhK3wGupHw90fT',
#       'name': 'DJ Dero',
#       'type': 'artist',
#       'uri': 'spotify:artist:5qeaKQ7gFhK3wGupHw90fT'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 335666,
#     'explicit': False,
#     'external_ids': {'isrc': 'ES5022000896'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/7gKyJyoZBvqx7FZDYsO7Fz'},
#     'href': 'https://api.spotify.com/v1/tracks/7gKyJyoZBvqx7FZDYsO7Fz',
#     'id': '7gKyJyoZBvqx7FZDYsO7Fz',
#     'is_local': False,
#     'name': 'Macarena (DJ Dero - Latin Piano Remix) - Remasterizado',
#     'popularity': 11,
#     'preview_url': 'https://p.scdn.co/mp3-preview/606021414a72c779c0f9fae06606e872c7191252?cid=6e24789ec7874259a220f747fcd7e93e',
#     'track_number': 4,
#     'type': 'track',
#     'uri': 'spotify:track:7gKyJyoZBvqx7FZDYsO7Fz'}],
#   'limit': 20,
#   'next': 'https://api.spotify.com/v1/search?query=track%3AMacarena+artist%3ALos+Del+Rio&type=track&offset=20&limit=20',
#   'offset': 0,
#   'previous': None,
#   'total': 41}}

# %%
test = pd.DataFrame.from_dict(Macarena_1,orient='columns')
test
# Out:
#                                                      tracks
# href      https://api.spotify.com/v1/search?query=track%...
# items     [{'album': {'album_type': 'album', 'artists': ...
# limit                                                    20
# next      https://api.spotify.com/v1/search?query=track%...
# offset                                                    0
# previous                                               None
# total                                                    41

# %%
test= test.tracks.apply(pd.Series)
test
# Out:
# /var/folders/91/wchv5p25455f2k8078kdjvm40000gn/T/ipykernel_29351/2977931382.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   test= test.tracks.apply(pd.Series)
#                                                           0  \
# href      https://api.spotify.com/v1/search?query=track%...
# items     {'album': {'album_type': 'album', 'artists': [...
# limit                                                  20.0
# next      https://api.spotify.com/v1/search?query=track%...
# offset                                                  0.0
# previous                                                NaN
# total                                                  41.0
#
#                                                           1  \
# href                                                    NaN
# items     {'album': {'album_type': 'album', 'artists': [...
# limit                                                   NaN
# next                                                    NaN
# offset                                                  NaN
# previous                                                NaN
# total                                                   NaN
#
#                                                           2  \
# href                                                    NaN
# items     {'album': {'album_type': 'single', 'artists': ...
# limit                                                   NaN
# next                                                    NaN
# offset                                                  NaN
# previous                                                NaN
# total                                                   NaN
#
#                                                           3  \
# href                                                    NaN
# items     {'album': {'album_type': 'album', 'artists': [...
# limit                                                   NaN
# next                                                    NaN
# offset                                                  NaN
# previous                                                NaN
# total                                                   NaN
#
#                                                           4  \
# href                                                    NaN
# items     {'album': {'album_type': 'compilation', 'artis...
# limit                                                   NaN
# next                                                    NaN
# offset                                                  NaN
# previous                                                NaN
# total                                                   NaN
#
#                                                           5  \
# href                                                    NaN
# items     {'album': {'album_type': 'album', 'artists': [...
# limit                                                   NaN
# next                                                    NaN
# offset                                                  NaN
# previous                                                NaN
# total                                                   NaN
#
#                                                           6  \
# href                                                    NaN
# items     {'album': {'album_type': 'compilation', 'artis...
# limit                                                   NaN
# next                                                    NaN
# offset                                                  NaN
# previous                                                NaN
# total                                                   NaN
#
#                                                           7  \
# href                                                    NaN
# items     {'album': {'album_type': 'album', 'artists': [...
# limit                                                   NaN
# next                                                    NaN
# offset                                                  NaN
# previous                                                NaN
# total                                                   NaN
#
#                                                           8  \
# href                                                    NaN
# items     {'album': {'album_type': 'single', 'artists': ...
# limit                                                   NaN
# next                                                    NaN
# offset                                                  NaN
# previous                                                NaN
# total                                                   NaN
#
#                                                           9  \
# href                                                    NaN
# items     {'album': {'album_type': 'compilation', 'artis...
# limit                                                   NaN
# next                                                    NaN
# offset                                                  NaN
# previous                                                NaN
# total                                                   NaN
#
#                                                          10  \
# href                                                    NaN
# items     {'album': {'album_type': 'compilation', 'artis...
# limit                                                   NaN
# next                                                    NaN
# offset                                                  NaN
# previous                                                NaN
# total                                                   NaN
#
#                                                          11  \
# href                                                    NaN
# items     {'album': {'album_type': 'album', 'artists': [...
# limit                                                   NaN
# next                                                    NaN
# offset                                                  NaN
# previous                                                NaN
# total                                                   NaN
#
#                                                          12  \
# href                                                    NaN
# items     {'album': {'album_type': 'album', 'artists': [...
# limit                                                   NaN
# next                                                    NaN
# offset                                                  NaN
# previous                                                NaN
# total                                                   NaN
#
#                                                          13  \
# href                                                    NaN
# items     {'album': {'album_type': 'single', 'artists': ...
# limit                                                   NaN
# next                                                    NaN
# offset                                                  NaN
# previous                                                NaN
# total                                                   NaN
#
#                                                          14  \
# href                                                    NaN
# items     {'album': {'album_type': 'album', 'artists': [...
# limit                                                   NaN
# next                                                    NaN
# offset                                                  NaN
# previous                                                NaN
# total                                                   NaN
#
#                                                          15  \
# href                                                    NaN
# items     {'album': {'album_type': 'single', 'artists': ...
# limit                                                   NaN
# next                                                    NaN
# offset                                                  NaN
# previous                                                NaN
# total                                                   NaN
#
#                                                          16  \
# href                                                    NaN
# items     {'album': {'album_type': 'compilation', 'artis...
# limit                                                   NaN
# next                                                    NaN
# offset                                                  NaN
# previous                                                NaN
# total                                                   NaN
#
#                                                          17  \
# href                                                    NaN
# items     {'album': {'album_type': 'single', 'artists': ...
# limit                                                   NaN
# next                                                    NaN
# offset                                                  NaN
# previous                                                NaN
# total                                                   NaN
#
#                                                          18  \
# href                                                    NaN
# items     {'album': {'album_type': 'single', 'artists': ...
# limit                                                   NaN
# next                                                    NaN
# offset                                                  NaN
# previous                                                NaN
# total                                                   NaN
#
#                                                          19
# href                                                    NaN
# items     {'album': {'album_type': 'single', 'artists': ...
# limit                                                   NaN
# next                                                    NaN
# offset                                                  NaN
# previous                                                NaN
# total                                                   NaN

# %%
test2 = pd.DataFrame(test.iloc[1])
test2
# Out:
#                                                 items
# 0   {'album': {'album_type': 'album', 'artists': [...
# 1   {'album': {'album_type': 'album', 'artists': [...
# 2   {'album': {'album_type': 'single', 'artists': ...
# 3   {'album': {'album_type': 'album', 'artists': [...
# 4   {'album': {'album_type': 'compilation', 'artis...
# 5   {'album': {'album_type': 'album', 'artists': [...
# 6   {'album': {'album_type': 'compilation', 'artis...
# 7   {'album': {'album_type': 'album', 'artists': [...
# 8   {'album': {'album_type': 'single', 'artists': ...
# 9   {'album': {'album_type': 'compilation', 'artis...
# 10  {'album': {'album_type': 'compilation', 'artis...
# 11  {'album': {'album_type': 'album', 'artists': [...
# 12  {'album': {'album_type': 'album', 'artists': [...
# 13  {'album': {'album_type': 'single', 'artists': ...
# 14  {'album': {'album_type': 'album', 'artists': [...
# 15  {'album': {'album_type': 'single', 'artists': ...
# 16  {'album': {'album_type': 'compilation', 'artis...
# 17  {'album': {'album_type': 'single', 'artists': ...
# 18  {'album': {'album_type': 'single', 'artists': ...
# 19  {'album': {'album_type': 'single', 'artists': ...

# %%
test3 = test2['items'].apply(pd.Series)
test3
# Out:
#                                                 album  \
# 0   {'album_type': 'album', 'artists': [{'external...
# 1   {'album_type': 'album', 'artists': [{'external...
# 2   {'album_type': 'single', 'artists': [{'externa...
# 3   {'album_type': 'album', 'artists': [{'external...
# 4   {'album_type': 'compilation', 'artists': [{'ex...
# 5   {'album_type': 'album', 'artists': [{'external...
# 6   {'album_type': 'compilation', 'artists': [{'ex...
# 7   {'album_type': 'album', 'artists': [{'external...
# 8   {'album_type': 'single', 'artists': [{'externa...
# 9   {'album_type': 'compilation', 'artists': [{'ex...
# 10  {'album_type': 'compilation', 'artists': [{'ex...
# 11  {'album_type': 'album', 'artists': [{'external...
# 12  {'album_type': 'album', 'artists': [{'external...
# 13  {'album_type': 'single', 'artists': [{'externa...
# 14  {'album_type': 'album', 'artists': [{'external...
# 15  {'album_type': 'single', 'artists': [{'externa...
# 16  {'album_type': 'compilation', 'artists': [{'ex...
# 17  {'album_type': 'single', 'artists': [{'externa...
# 18  {'album_type': 'single', 'artists': [{'externa...
# 19  {'album_type': 'single', 'artists': [{'externa...
#
#                                               artists  \
# 0   [{'external_urls': {'spotify': 'https://open.s...
# 1   [{'external_urls': {'spotify': 'https://open.s...
# 2   [{'external_urls': {'spotify': 'https://open.s...
# 3   [{'external_urls': {'spotify': 'https://open.s...
# 4   [{'external_urls': {'spotify': 'https://open.s...
# 5   [{'external_urls': {'spotify': 'https://open.s...
# 6   [{'external_urls': {'spotify': 'https://open.s...
# 7   [{'external_urls': {'spotify': 'https://open.s...
# 8   [{'external_urls': {'spotify': 'https://open.s...
# 9   [{'external_urls': {'spotify': 'https://open.s...
# 10  [{'external_urls': {'spotify': 'https://open.s...
# 11  [{'external_urls': {'spotify': 'https://open.s...
# 12  [{'external_urls': {'spotify': 'https://open.s...
# 13  [{'external_urls': {'spotify': 'https://open.s...
# 14  [{'external_urls': {'spotify': 'https://open.s...
# 15  [{'external_urls': {'spotify': 'https://open.s...
# 16  [{'external_urls': {'spotify': 'https://open.s...
# 17  [{'external_urls': {'spotify': 'https://open.s...
# 18  [{'external_urls': {'spotify': 'https://open.s...
# 19  [{'external_urls': {'spotify': 'https://open.s...
#
#                                     available_markets  disc_number  \
# 0   [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...            1
# 1   [AD, AE, AG, AL, AO, AR, AT, AU, BA, BB, BE, B...            1
# 2   [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...            1
# 3   [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...            1
# 4   [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...            1
# 5   [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...            1
# 6   [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...            1
# 7   [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...            1
# 8   [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...            1
# 9   [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...            1
# 10  [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...            1
# 11  [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...            1
# 12  [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...            1
# 13  [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...            1
# 14  [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...            1
# 15  [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...            1
# 16  [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...            1
# 17  [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...            1
# 18  [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...            1
# 19  [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...            1
#
#     duration_ms  explicit              external_ids  \
# 0        249506     False  {'isrc': 'ES5109500538'}
# 1        253106     False  {'isrc': 'ES5109600480'}
# 2        224626     False  {'isrc': 'ES5109500537'}
# 3        252133     False  {'isrc': 'ES5109500537'}
# 4        253266     False  {'isrc': 'ES5109600441'}
# 5        304026     False  {'isrc': 'ES5109500776'}
# 6        232546     False  {'isrc': 'ES5109500537'}
# 7        254293     False  {'isrc': 'ES5109600441'}
# 8        227093     False  {'isrc': 'ES5022000895'}
# 9        249506     False  {'isrc': 'ES5109500538'}
# 10       222626     False  {'isrc': 'ES5109500538'}
# 11       206906     False  {'isrc': 'ES5109500625'}
# 12       257040     False  {'isrc': 'ES5022000893'}
# 13       306186     False  {'isrc': 'ES5109300002'}
# 14       248666     False  {'isrc': 'ES5109500538'}
# 15       257040     False  {'isrc': 'ES5022000893'}
# 16       253106     False  {'isrc': 'ES5109600480'}
# 17       343440     False  {'isrc': 'ES5109500626'}
# 18       337373     False  {'isrc': 'ES5109300003'}
# 19       335666     False  {'isrc': 'ES5022000896'}
#
#                                         external_urls  \
# 0   {'spotify': 'https://open.spotify.com/track/4o...
# 1   {'spotify': 'https://open.spotify.com/track/2d...
# 2   {'spotify': 'https://open.spotify.com/track/07...
# 3   {'spotify': 'https://open.spotify.com/track/7o...
# 4   {'spotify': 'https://open.spotify.com/track/5g...
# 5   {'spotify': 'https://open.spotify.com/track/5v...
# 6   {'spotify': 'https://open.spotify.com/track/6g...
# 7   {'spotify': 'https://open.spotify.com/track/0t...
# 8   {'spotify': 'https://open.spotify.com/track/1I...
# 9   {'spotify': 'https://open.spotify.com/track/5y...
# 10  {'spotify': 'https://open.spotify.com/track/6m...
# 11  {'spotify': 'https://open.spotify.com/track/3l...
# 12  {'spotify': 'https://open.spotify.com/track/3m...
# 13  {'spotify': 'https://open.spotify.com/track/1F...
# 14  {'spotify': 'https://open.spotify.com/track/38...
# 15  {'spotify': 'https://open.spotify.com/track/7d...
# 16  {'spotify': 'https://open.spotify.com/track/78...
# 17  {'spotify': 'https://open.spotify.com/track/6o...
# 18  {'spotify': 'https://open.spotify.com/track/4f...
# 19  {'spotify': 'https://open.spotify.com/track/7g...
#
#                                                  href                      id  \
# 0   https://api.spotify.com/v1/tracks/4oaj36KzXRgD...  4oaj36KzXRgDg4McgcTsZK
# 1   https://api.spotify.com/v1/tracks/2df5QsXucx4V...  2df5QsXucx4VLiHNGusXD5
# 2   https://api.spotify.com/v1/tracks/07DcH2UllHvV...  07DcH2UllHvVRKjD2HEJuC
# 3   https://api.spotify.com/v1/tracks/7obdw7ZGr6l1...  7obdw7ZGr6l1GqSBkFiY11
# 4   https://api.spotify.com/v1/tracks/5gC7cwZNKqaN...  5gC7cwZNKqaNLlvHlLjjqE
# 5   https://api.spotify.com/v1/tracks/5v2HaVFTu9pF...  5v2HaVFTu9pFOXtD907W1R
# 6   https://api.spotify.com/v1/tracks/6go8OpVqD9Qe...  6go8OpVqD9QePmdA726d81
# 7   https://api.spotify.com/v1/tracks/0tfORpCYcR3a...  0tfORpCYcR3aX6K8URKzRI
# 8   https://api.spotify.com/v1/tracks/1IDOgGgrZuXI...  1IDOgGgrZuXIFOluTTI2Fs
# 9   https://api.spotify.com/v1/tracks/5yczrVYTvdUc...  5yczrVYTvdUcI0sGOFuobz
# 10  https://api.spotify.com/v1/tracks/6mhw2fEPH4fM...  6mhw2fEPH4fMF0wolNm96e
# 11  https://api.spotify.com/v1/tracks/3lfjkYDzQS9R...  3lfjkYDzQS9RsPO0qS4blN
# 12  https://api.spotify.com/v1/tracks/3mbmmddF7fxU...  3mbmmddF7fxUNFkXV91ecm
# 13  https://api.spotify.com/v1/tracks/1FSRbSFPdDvt...  1FSRbSFPdDvt6kBzlbB1Qe
# 14  https://api.spotify.com/v1/tracks/3810crowNXd1...  3810crowNXd1rrr5amWq29
# 15  https://api.spotify.com/v1/tracks/7dC7etNwJh1o...  7dC7etNwJh1ow04xzaaYux
# 16  https://api.spotify.com/v1/tracks/78EpI14cWmzP...  78EpI14cWmzPUEybf6U4Hu
# 17  https://api.spotify.com/v1/tracks/6oD7eRCXBmh3...  6oD7eRCXBmh3zgdJu8ohqW
# 18  https://api.spotify.com/v1/tracks/4fUQotmmf00B...  4fUQotmmf00B8dYQtlbm5g
# 19  https://api.spotify.com/v1/tracks/7gKyJyoZBvqx...  7gKyJyoZBvqx7FZDYsO7Fz
#
#     is_local                                               name  popularity  \
# 0      False                                           Macarena          59
# 1      False                      Macarena - Bayside Boys Remix          57
# 2      False                      Macarena - Bayside Boys Remix          59
# 3      False                      Macarena - Bayside Boys Remix          54
# 4      False                       Macarena Christmas - Joy Mix          47
# 5      False                            Macarena - River Re-Mix          47
# 6      False                      Macarena - Bayside Boys Remix          40
# 7      False                       Macarena Christmas - Joy Mix          40
# 8      False      Macarena (Bayside Boys Remix) - Remasterizado          31
# 9      False                                           Macarena          31
# 10     False                                           Macarena          61
# 11     False           Macarena - Bass Bumpers Remix Radio Edit          25
# 12     False  Macarena / Joy The world / Jingle Bells / Sile...          22
# 13     False                    Macarena - River Re-Mix 103 BPM          20
# 14     False                                           Macarena          25
# 15     False  Macarena / Joy The world / Jingle Bells / Sile...          14
# 16     False                      Macarena - Bayside Boys Remix          13
# 17     False             Macarena - Bass Bumpers Remix-Club Mix          12
# 18     False            Macarena - La Mezcla Guerillera 130 BPM          11
# 19     False  Macarena (DJ Dero - Latin Piano Remix) - Remas...          11
#
#                                           preview_url  track_number   type  \
# 0   https://p.scdn.co/mp3-preview/b9fd8c94d695a35a...            12  track
# 1   https://p.scdn.co/mp3-preview/3cd3bed124b67e85...             1  track
# 2   https://p.scdn.co/mp3-preview/19fdc8032a4c45f2...             1  track
# 3   https://p.scdn.co/mp3-preview/442a83d3489337c2...             3  track
# 4   https://p.scdn.co/mp3-preview/120fcadb0d7eba51...            26  track
# 5   https://p.scdn.co/mp3-preview/013718d3a69d7776...            13  track
# 6   https://p.scdn.co/mp3-preview/47cb75435ae6fd18...            69  track
# 7   https://p.scdn.co/mp3-preview/a44e6a29eaffec05...            13  track
# 8   https://p.scdn.co/mp3-preview/633620b927d01449...             3  track
# 9   https://p.scdn.co/mp3-preview/27d4601c3f22eea2...            59  track
# 10  https://p.scdn.co/mp3-preview/f5c9da2a29e55ce5...            10  track
# 11  https://p.scdn.co/mp3-preview/c4cf9c8fe269c649...            14  track
# 12  https://p.scdn.co/mp3-preview/c3bf1a39d247aa72...             7  track
# 13  https://p.scdn.co/mp3-preview/011b77360d890d17...             5  track
# 14  https://p.scdn.co/mp3-preview/300c39baaa5923d2...             1  track
# 15  https://p.scdn.co/mp3-preview/3d51b007ff8cf424...             1  track
# 16  https://p.scdn.co/mp3-preview/98d72d06f1918348...             3  track
# 17  https://p.scdn.co/mp3-preview/cce795a8fa9ae8be...             2  track
# 18  https://p.scdn.co/mp3-preview/c3bc454908451f4b...             4  track
# 19  https://p.scdn.co/mp3-preview/606021414a72c779...             4  track
#
#                                      uri
# 0   spotify:track:4oaj36KzXRgDg4McgcTsZK
# 1   spotify:track:2df5QsXucx4VLiHNGusXD5
# 2   spotify:track:07DcH2UllHvVRKjD2HEJuC
# 3   spotify:track:7obdw7ZGr6l1GqSBkFiY11
# 4   spotify:track:5gC7cwZNKqaNLlvHlLjjqE
# 5   spotify:track:5v2HaVFTu9pFOXtD907W1R
# 6   spotify:track:6go8OpVqD9QePmdA726d81
# 7   spotify:track:0tfORpCYcR3aX6K8URKzRI
# 8   spotify:track:1IDOgGgrZuXIFOluTTI2Fs
# 9   spotify:track:5yczrVYTvdUcI0sGOFuobz
# 10  spotify:track:6mhw2fEPH4fMF0wolNm96e
# 11  spotify:track:3lfjkYDzQS9RsPO0qS4blN
# 12  spotify:track:3mbmmddF7fxUNFkXV91ecm
# 13  spotify:track:1FSRbSFPdDvt6kBzlbB1Qe
# 14  spotify:track:3810crowNXd1rrr5amWq29
# 15  spotify:track:7dC7etNwJh1ow04xzaaYux
# 16  spotify:track:78EpI14cWmzPUEybf6U4Hu
# 17  spotify:track:6oD7eRCXBmh3zgdJu8ohqW
# 18  spotify:track:4fUQotmmf00B8dYQtlbm5g
# 19  spotify:track:7gKyJyoZBvqx7FZDYsO7Fz

# %%
test3.head(1)
# Out:
#                                                album  \
# 0  {'album_type': 'album', 'artists': [{'external...
#
#                                              artists  \
# 0  [{'external_urls': {'spotify': 'https://open.s...
#
#                                    available_markets  disc_number  \
# 0  [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...            1
#
#    duration_ms  explicit              external_ids  \
# 0       249506     False  {'isrc': 'ES5109500538'}
#
#                                        external_urls  \
# 0  {'spotify': 'https://open.spotify.com/track/4o...
#
#                                                 href                      id  \
# 0  https://api.spotify.com/v1/tracks/4oaj36KzXRgD...  4oaj36KzXRgDg4McgcTsZK
#
#    is_local      name  popularity  \
# 0     False  Macarena          59
#
#                                          preview_url  track_number   type  \
# 0  https://p.scdn.co/mp3-preview/b9fd8c94d695a35a...            12  track
#
#                                     uri
# 0  spotify:track:4oaj36KzXRgDg4McgcTsZK
