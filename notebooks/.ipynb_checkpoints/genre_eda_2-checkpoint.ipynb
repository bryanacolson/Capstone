# %%
from pandasql import sqldf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from bs4 import BeautifulSoup
import io
import requests
from ast import literal_eval
import glob
import datetime

# %% [markdown]
# # project_csv

# %%
project_csv = pd.read_csv('../data/Hot-Stuff.csv')
project_csv
# Out:
#                                                       url      WeekID  \
# 0       http://www.billboard.com/charts/hot-100/1965-0...   7/17/1965
# 1       http://www.billboard.com/charts/hot-100/1965-0...   7/24/1965
# 2       http://www.billboard.com/charts/hot-100/1965-0...   7/31/1965
# 3       http://www.billboard.com/charts/hot-100/1965-0...    8/7/1965
# 4       http://www.billboard.com/charts/hot-100/1965-0...   8/14/1965
# ...                                                   ...         ...
# 327890  https://www.billboard.com/charts/hot-100/2018-...  10/20/2018
# 327891  http://www.billboard.com/charts/hot-100/1977-0...   5/21/1977
# 327892  http://www.billboard.com/charts/hot-100/1981-0...   5/23/1981
# 327893  http://www.billboard.com/charts/hot-100/1973-0...   9/29/1973
# 327894  https://www.billboard.com/charts/hot-100/2020-...  11/28/2020
#
#         Week Position                      Song                  Performer  \
# 0                  34    Don't Just Stand There                 Patty Duke
# 1                  22    Don't Just Stand There                 Patty Duke
# 2                  14    Don't Just Stand There                 Patty Duke
# 3                  10    Don't Just Stand There                 Patty Duke
# 4                   8    Don't Just Stand There                 Patty Duke
# ...               ...                       ...                        ...
# 327890             22            God Is A Woman              Ariana Grande
# 327891             22   I Wanna Get Next To You                 Rose Royce
# 327892             22          I Can't Stand It  Eric Clapton And His Band
# 327893             22  Here I Am Come & Take Me                   Al Green
# 327894             22                     Hawai        Maluma & The Weeknd
#
#                                            SongID  Instance  \
# 0                Don't Just Stand TherePatty Duke         1
# 1                Don't Just Stand TherePatty Duke         1
# 2                Don't Just Stand TherePatty Duke         1
# 3                Don't Just Stand TherePatty Duke         1
# 4                Don't Just Stand TherePatty Duke         1
# ...                                           ...       ...
# 327890                God Is A WomanAriana Grande         1
# 327891          I Wanna Get Next To YouRose Royce         1
# 327892  I Can't Stand ItEric Clapton And His Band         1
# 327893           Here I Am Come & Take MeAl Green         1
# 327894                   HawaiMaluma & The Weeknd         1
#
#         Previous Week Position  Peak Position  Weeks on Chart
# 0                         45.0             34               4
# 1                         34.0             22               5
# 2                         22.0             14               6
# 3                         14.0             10               7
# 4                         10.0              8               8
# ...                        ...            ...             ...
# 327890                    21.0              8              13
# 327891                    10.0             10              13
# 327892                    12.0             10              13
# 327893                    16.0             10              13
# 327894                    12.0             12              13
#
# [327895 rows x 10 columns]

# %%
project_csv = project_csv.dropna()
project_csv
# Out:
#                                                       url      WeekID  \
# 0       http://www.billboard.com/charts/hot-100/1965-0...   7/17/1965
# 1       http://www.billboard.com/charts/hot-100/1965-0...   7/24/1965
# 2       http://www.billboard.com/charts/hot-100/1965-0...   7/31/1965
# 3       http://www.billboard.com/charts/hot-100/1965-0...    8/7/1965
# 4       http://www.billboard.com/charts/hot-100/1965-0...   8/14/1965
# ...                                                   ...         ...
# 327890  https://www.billboard.com/charts/hot-100/2018-...  10/20/2018
# 327891  http://www.billboard.com/charts/hot-100/1977-0...   5/21/1977
# 327892  http://www.billboard.com/charts/hot-100/1981-0...   5/23/1981
# 327893  http://www.billboard.com/charts/hot-100/1973-0...   9/29/1973
# 327894  https://www.billboard.com/charts/hot-100/2020-...  11/28/2020
#
#         Week Position                      Song                  Performer  \
# 0                  34    Don't Just Stand There                 Patty Duke
# 1                  22    Don't Just Stand There                 Patty Duke
# 2                  14    Don't Just Stand There                 Patty Duke
# 3                  10    Don't Just Stand There                 Patty Duke
# 4                   8    Don't Just Stand There                 Patty Duke
# ...               ...                       ...                        ...
# 327890             22            God Is A Woman              Ariana Grande
# 327891             22   I Wanna Get Next To You                 Rose Royce
# 327892             22          I Can't Stand It  Eric Clapton And His Band
# 327893             22  Here I Am Come & Take Me                   Al Green
# 327894             22                     Hawai        Maluma & The Weeknd
#
#                                            SongID  Instance  \
# 0                Don't Just Stand TherePatty Duke         1
# 1                Don't Just Stand TherePatty Duke         1
# 2                Don't Just Stand TherePatty Duke         1
# 3                Don't Just Stand TherePatty Duke         1
# 4                Don't Just Stand TherePatty Duke         1
# ...                                           ...       ...
# 327890                God Is A WomanAriana Grande         1
# 327891          I Wanna Get Next To YouRose Royce         1
# 327892  I Can't Stand ItEric Clapton And His Band         1
# 327893           Here I Am Come & Take MeAl Green         1
# 327894                   HawaiMaluma & The Weeknd         1
#
#         Previous Week Position  Peak Position  Weeks on Chart
# 0                         45.0             34               4
# 1                         34.0             22               5
# 2                         22.0             14               6
# 3                         14.0             10               7
# 4                         10.0              8               8
# ...                        ...            ...             ...
# 327890                    21.0              8              13
# 327891                    10.0             10              13
# 327892                    12.0             10              13
# 327893                    16.0             10              13
# 327894                    12.0             12              13
#
# [295941 rows x 10 columns]

# %%
new_csvs = pd.concat([pd.read_csv(x)for x in glob.glob('../csvs_6/*.csv')], ignore_index = True)
new_csvs
# Out:
#            0     1                   2                          3         4  \
# 0      False  14.0        Dale & Grace     Stop and Think It Over  155013.0
# 1      False  34.0        Bobby Vinton  Trouble Is My Middle Name  146626.0
# 2      False  10.0  Marianne Faithfull      Come And Stay With Me  144800.0
# 3      False  10.0       Bobby Sherman          Cried Like a Baby  196672.0
# 4      False  37.0        Wayne Newton  Red Roses For A Blue Lady  143066.0
# ...      ...   ...                 ...                        ...       ...
# 28384  False  42.0           Choirboys            Run to Paradise  251586.0
# 28385  False  15.0        Carrie Lucas             Dance with You  396200.0
# 28386    NaN   NaN                 NaN                        NaN       NaN
# 28387    NaN   NaN                 NaN                        NaN       NaN
# 28388  False   7.0       George Lamond     Baby, I Believe In You  235906.0
#
#                                           5
# 0      spotify:track:2stpBzukWP5LxmqEY2k5vO
# 1      spotify:track:5qAAs6ndwSQJ7YZ4wZ3Py8
# 2      spotify:track:1D2VIwDVHzh5n7nkGk0vij
# 3      spotify:track:2s3AAZ3nRXseiqy3udyHbF
# 4      spotify:track:5aKfKf7YIZOg0S8P1hNJjw
# ...                                     ...
# 28384  spotify:track:2b5Tg7SfwZF1UGFgqvtAO3
# 28385  spotify:track:273Yfa9Ie7uxzG7jbkf963
# 28386                                   NaN
# 28387                                   NaN
# 28388  spotify:track:0wWOeA6NFUbsz7JESOGpEY
#
# [28389 rows x 6 columns]

# %%
new_csvs = new_csvs.dropna()
new_csvs
# Out:
#            0     1                   2  \
# 0      False  14.0        Dale & Grace
# 1      False  34.0        Bobby Vinton
# 2      False  10.0  Marianne Faithfull
# 3      False  10.0       Bobby Sherman
# 4      False  37.0        Wayne Newton
# ...      ...   ...                 ...
# 28380  False  41.0              Nocera
# 28381  False   1.0       Andy Williams
# 28384  False  42.0           Choirboys
# 28385  False  15.0        Carrie Lucas
# 28388  False   7.0       George Lamond
#
#                                                 3         4  \
# 0                          Stop and Think It Over  155013.0
# 1                       Trouble Is My Middle Name  146626.0
# 2                           Come And Stay With Me  144800.0
# 3                               Cried Like a Baby  196672.0
# 4                       Red Roses For A Blue Lady  143066.0
# ...                                           ...       ...
# 28380                      Summertime, Summertime  206613.0
# 28381  Do You Mind - 1960 #70 Billboard chart hit  136560.0
# 28384                             Run to Paradise  251586.0
# 28385                              Dance with You  396200.0
# 28388                      Baby, I Believe In You  235906.0
#
#                                           5
# 0      spotify:track:2stpBzukWP5LxmqEY2k5vO
# 1      spotify:track:5qAAs6ndwSQJ7YZ4wZ3Py8
# 2      spotify:track:1D2VIwDVHzh5n7nkGk0vij
# 3      spotify:track:2s3AAZ3nRXseiqy3udyHbF
# 4      spotify:track:5aKfKf7YIZOg0S8P1hNJjw
# ...                                     ...
# 28380  spotify:track:4tSteFXglCBaG6sFvYCBVX
# 28381  spotify:track:4yzLxHEO5nPKwxjGYLF5xI
# 28384  spotify:track:2b5Tg7SfwZF1UGFgqvtAO3
# 28385  spotify:track:273Yfa9Ie7uxzG7jbkf963
# 28388  spotify:track:0wWOeA6NFUbsz7JESOGpEY
#
# [18301 rows x 6 columns]

# %%
new_csvs.columns = ['Explicit', 'Song_Popularity', 'Performer', 'Song', 'Duration ms', 'uri' ]
new_csvs
# Out:
#       Explicit  Song_Popularity           Performer  \
# 0        False             14.0        Dale & Grace
# 1        False             34.0        Bobby Vinton
# 2        False             10.0  Marianne Faithfull
# 3        False             10.0       Bobby Sherman
# 4        False             37.0        Wayne Newton
# ...        ...              ...                 ...
# 28380    False             41.0              Nocera
# 28381    False              1.0       Andy Williams
# 28384    False             42.0           Choirboys
# 28385    False             15.0        Carrie Lucas
# 28388    False              7.0       George Lamond
#
#                                              Song  Duration ms  \
# 0                          Stop and Think It Over     155013.0
# 1                       Trouble Is My Middle Name     146626.0
# 2                           Come And Stay With Me     144800.0
# 3                               Cried Like a Baby     196672.0
# 4                       Red Roses For A Blue Lady     143066.0
# ...                                           ...          ...
# 28380                      Summertime, Summertime     206613.0
# 28381  Do You Mind - 1960 #70 Billboard chart hit     136560.0
# 28384                             Run to Paradise     251586.0
# 28385                              Dance with You     396200.0
# 28388                      Baby, I Believe In You     235906.0
#
#                                         uri
# 0      spotify:track:2stpBzukWP5LxmqEY2k5vO
# 1      spotify:track:5qAAs6ndwSQJ7YZ4wZ3Py8
# 2      spotify:track:1D2VIwDVHzh5n7nkGk0vij
# 3      spotify:track:2s3AAZ3nRXseiqy3udyHbF
# 4      spotify:track:5aKfKf7YIZOg0S8P1hNJjw
# ...                                     ...
# 28380  spotify:track:4tSteFXglCBaG6sFvYCBVX
# 28381  spotify:track:4yzLxHEO5nPKwxjGYLF5xI
# 28384  spotify:track:2b5Tg7SfwZF1UGFgqvtAO3
# 28385  spotify:track:273Yfa9Ie7uxzG7jbkf963
# 28388  spotify:track:0wWOeA6NFUbsz7JESOGpEY
#
# [18301 rows x 6 columns]

# %%
genre_csvs = pd.concat([pd.read_csv(x)for x in glob.glob('../genre_csvs/*.csv')], ignore_index = True)
genre_csvs
# Out:
#                         0     1                   2  \
# 0           Lindsay Lohan  49.0       Lindsay Lohan
# 1                     NaN   NaN                 NaN
# 2                 Incubus  69.0             Incubus
# 3               Zac Efron  69.0           Zac Efron
# 4                     NaN   NaN                 NaN
# ...                   ...   ...                 ...
# 10056  The Yellow Balloon  22.0  The Yellow Balloon
# 10057        Ant Saunders  53.0        Ant Saunders
# 10058                 NaN   NaN                 NaN
# 10059    Thelma Carpenter  34.0    Thelma Carpenter
# 10060                 NaN   NaN                 NaN
#
#                                            3  \
# 0      spotify:artist:4vRSocKbGh7PsQrYRDVMEF
# 1                                        NaN
# 2      spotify:artist:3YcBF2ttyueytpXtEzn1Za
# 3      spotify:artist:6U1dBXJhC8gXFjamvFTmHg
# 4                                        NaN
# ...                                      ...
# 10056  spotify:artist:2EogrfOq2qlvRnJDaQ5BF0
# 10057  spotify:artist:4jpsw9CQS439N0B7SecMgf
# 10058                                    NaN
# 10059  spotify:artist:5NBLIcKY8kA94L3s5wkPAk
# 10060                                    NaN
#
#                                                        4
# 0                         ['dance pop', 'post-teen pop']
# 1                                                    NaN
# 2      ['alternative metal', 'alternative rock', 'fun...
# 3      ['hollywood', 'pop', 'post-teen pop', 'show tu...
# 4                                                    NaN
# ...                                                  ...
# 10056     ['bubblegum pop', 'freakbeat', 'sunshine pop']
# 10057                               ['chill r&b', 'pop']
# 10058                                                NaN
# 10059                                                 []
# 10060                                                NaN
#
# [10061 rows x 5 columns]

# %%
genre_csvs = genre_csvs.dropna()
genre_csvs
# Out:
#                             0     1                   2  \
# 0               Lindsay Lohan  49.0       Lindsay Lohan
# 2                     Incubus  69.0             Incubus
# 3                   Zac Efron  69.0           Zac Efron
# 5                  Kris Allen  44.0          Kris Allen
# 6           The Swon Brothers  33.0   The Swon Brothers
# ...                       ...   ...                 ...
# 10053           Judson Spence   4.0       Judson Spence
# 10055  Mongo Santamaria Orch.  46.0    Mongo Santamaria
# 10056      The Yellow Balloon  22.0  The Yellow Balloon
# 10057            Ant Saunders  53.0        Ant Saunders
# 10059        Thelma Carpenter  34.0    Thelma Carpenter
#
#                                            3  \
# 0      spotify:artist:4vRSocKbGh7PsQrYRDVMEF
# 2      spotify:artist:3YcBF2ttyueytpXtEzn1Za
# 3      spotify:artist:6U1dBXJhC8gXFjamvFTmHg
# 5      spotify:artist:2zwHaEmXxX6DTv4i8ajNCM
# 6      spotify:artist:1nf0nRF0W4ybnJdda00pKY
# ...                                      ...
# 10053  spotify:artist:2iDXfUayTfaawalL8HDDj6
# 10055  spotify:artist:2oVwztjpHpJlAvlVVuqVa0
# 10056  spotify:artist:2EogrfOq2qlvRnJDaQ5BF0
# 10057  spotify:artist:4jpsw9CQS439N0B7SecMgf
# 10059  spotify:artist:5NBLIcKY8kA94L3s5wkPAk
#
#                                                        4
# 0                         ['dance pop', 'post-teen pop']
# 2      ['alternative metal', 'alternative rock', 'fun...
# 3      ['hollywood', 'pop', 'post-teen pop', 'show tu...
# 5      ['acoustic pop', 'idol', 'neo mellow', 'post-t...
# 6      ['contemporary country', 'country pop', 'oklah...
# ...                                                  ...
# 10053                                                 []
# 10055  ['afro-cuban percussion', 'boogaloo', 'cuban r...
# 10056     ['bubblegum pop', 'freakbeat', 'sunshine pop']
# 10057                               ['chill r&b', 'pop']
# 10059                                                 []
#
# [5716 rows x 5 columns]

# %%
genre_csvs.columns = ['Performer', 'Artist_Popularity', 'Performer2', 'uri', 'Genre' ]

# %%
genre_csvs[['Performer', 'Genre', 'Artist_Popularity']]
# Out:
#                     Performer  \
# 0               Lindsay Lohan
# 2                     Incubus
# 3                   Zac Efron
# 5                  Kris Allen
# 6           The Swon Brothers
# ...                       ...
# 10053           Judson Spence
# 10055  Mongo Santamaria Orch.
# 10056      The Yellow Balloon
# 10057            Ant Saunders
# 10059        Thelma Carpenter
#
#                                                    Genre  Artist_Popularity
# 0                         ['dance pop', 'post-teen pop']               49.0
# 2      ['alternative metal', 'alternative rock', 'fun...               69.0
# 3      ['hollywood', 'pop', 'post-teen pop', 'show tu...               69.0
# 5      ['acoustic pop', 'idol', 'neo mellow', 'post-t...               44.0
# 6      ['contemporary country', 'country pop', 'oklah...               33.0
# ...                                                  ...                ...
# 10053                                                 []                4.0
# 10055  ['afro-cuban percussion', 'boogaloo', 'cuban r...               46.0
# 10056     ['bubblegum pop', 'freakbeat', 'sunshine pop']               22.0
# 10057                               ['chill r&b', 'pop']               53.0
# 10059                                                 []               34.0
#
# [5716 rows x 3 columns]

# %%
genre_csvs
# Out:
#                     Performer  Artist_Popularity          Performer2  \
# 0               Lindsay Lohan               49.0       Lindsay Lohan
# 2                     Incubus               69.0             Incubus
# 3                   Zac Efron               69.0           Zac Efron
# 5                  Kris Allen               44.0          Kris Allen
# 6           The Swon Brothers               33.0   The Swon Brothers
# ...                       ...                ...                 ...
# 10053           Judson Spence                4.0       Judson Spence
# 10055  Mongo Santamaria Orch.               46.0    Mongo Santamaria
# 10056      The Yellow Balloon               22.0  The Yellow Balloon
# 10057            Ant Saunders               53.0        Ant Saunders
# 10059        Thelma Carpenter               34.0    Thelma Carpenter
#
#                                          uri  \
# 0      spotify:artist:4vRSocKbGh7PsQrYRDVMEF
# 2      spotify:artist:3YcBF2ttyueytpXtEzn1Za
# 3      spotify:artist:6U1dBXJhC8gXFjamvFTmHg
# 5      spotify:artist:2zwHaEmXxX6DTv4i8ajNCM
# 6      spotify:artist:1nf0nRF0W4ybnJdda00pKY
# ...                                      ...
# 10053  spotify:artist:2iDXfUayTfaawalL8HDDj6
# 10055  spotify:artist:2oVwztjpHpJlAvlVVuqVa0
# 10056  spotify:artist:2EogrfOq2qlvRnJDaQ5BF0
# 10057  spotify:artist:4jpsw9CQS439N0B7SecMgf
# 10059  spotify:artist:5NBLIcKY8kA94L3s5wkPAk
#
#                                                    Genre
# 0                         ['dance pop', 'post-teen pop']
# 2      ['alternative metal', 'alternative rock', 'fun...
# 3      ['hollywood', 'pop', 'post-teen pop', 'show tu...
# 5      ['acoustic pop', 'idol', 'neo mellow', 'post-t...
# 6      ['contemporary country', 'country pop', 'oklah...
# ...                                                  ...
# 10053                                                 []
# 10055  ['afro-cuban percussion', 'boogaloo', 'cuban r...
# 10056     ['bubblegum pop', 'freakbeat', 'sunshine pop']
# 10057                               ['chill r&b', 'pop']
# 10059                                                 []
#
# [5716 rows x 5 columns]

# %%
genre_csvs = genre_csvs.loc[genre_csvs['Performer']==genre_csvs['Performer2']]

# %%
genre_csvs['Artist_Popularity'].hist();

# %%
top_genres = genre_csvs.loc[genre_csvs['Artist_Popularity']>=90].sort_values('Artist_Popularity', ascending = False)
top_genres
# Out:
#            Performer  Artist_Popularity      Performer2  \
# 2324       Bad Bunny              100.0       Bad Bunny
# 3065    Taylor Swift               99.0    Taylor Swift
# 3056      The Weeknd               97.0      The Weeknd
# 3353           Drake               97.0           Drake
# 806              SZA               95.0             SZA
# 3061       21 Savage               94.0       21 Savage
# 3067          Eminem               93.0          Eminem
# 3474             BTS               93.0             BTS
# 3446      Ed Sheeran               92.0      Ed Sheeran
# 3222   Justin Bieber               92.0   Justin Bieber
# 3264          Future               91.0          Future
# 3497      Juice WRLD               91.0      Juice WRLD
# 3352   Ariana Grande               91.0   Ariana Grande
# 3261      Kanye West               91.0      Kanye West
# 3167    Travis Scott               91.0    Travis Scott
# 3143         Shakira               91.0         Shakira
# 3265  Kendrick Lamar               90.0  Kendrick Lamar
# 2100         Rihanna               90.0         Rihanna
# 3157     Chris Brown               90.0     Chris Brown
# 3472    Harry Styles               90.0    Harry Styles
# 3495   Billie Eilish               90.0   Billie Eilish
# 2210        Lil Baby               90.0        Lil Baby
# 3963    Lana Del Rey               90.0    Lana Del Rey
# 4269           Ozuna               90.0           Ozuna
#
#                                         uri  \
# 2324  spotify:artist:4q3ewBCX7sLwd24euuV69X
# 3065  spotify:artist:06HL4z0CvFAxyc27GXpf02
# 3056  spotify:artist:1Xyo4u8uXC1ZmMpatF05PJ
# 3353  spotify:artist:3TVXtAsR1Inumwj472S9r4
# 806   spotify:artist:7tYKF4w9nC0nq9CsPZTHyP
# 3061  spotify:artist:1URnnhqYAYcrqrcwql10ft
# 3067  spotify:artist:7dGJo4pcD2V6oG8kP0tJRR
# 3474  spotify:artist:3Nrfpe0tUJi4K4DXYWgMUX
# 3446  spotify:artist:6eUKZXaKkcviH0Ku9w2n3V
# 3222  spotify:artist:1uNFoZAHBGtllmzznpCI3s
# 3264  spotify:artist:1RyvyyTE3xzB2ZywiAwp0i
# 3497  spotify:artist:4MCBfE4596Uoi2O4DtmEMz
# 3352  spotify:artist:66CXWjxzNUsdJxJ2JdwvnR
# 3261  spotify:artist:5K4W6rqBFWDnAN6FQUkS6x
# 3167  spotify:artist:0Y5tJX1MQlPlqiwlOH1tJY
# 3143  spotify:artist:0EmeFodog0BfCgMzAIvKQp
# 3265  spotify:artist:2YZyLoL8N0Wb9xBt1NhZWg
# 2100  spotify:artist:5pKCCKE2ajJHZ9KAiaK11H
# 3157  spotify:artist:7bXgB6jMjp9ATFy66eO08Z
# 3472  spotify:artist:6KImCVD70vtIoJWnq6nGn3
# 3495  spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH
# 2210  spotify:artist:5f7VJjfbwm532GiveGC0ZK
# 3963  spotify:artist:00FQb4jTyendYWaN8pK0wa
# 4269  spotify:artist:1i8SpTcr7yvPOmcqrbnVXY
#
#                                                   Genre
# 2324      ['reggaeton', 'trap latino', 'urbano latino']
# 3065                                            ['pop']
# 3056  ['canadian contemporary r&b', 'canadian pop', ...
# 3353  ['canadian hip hop', 'canadian pop', 'hip hop'...
# 806                                      ['pop', 'r&b']
# 3061                             ['atl hip hop', 'rap']
# 3067              ['detroit hip hop', 'hip hop', 'rap']
# 3474                       ['k-pop', 'k-pop boy group']
# 3446                                  ['pop', 'uk pop']
# 3222                            ['canadian pop', 'pop']
# 3264  ['atl hip hop', 'rap', 'southern hip hop', 'tr...
# 3497                     ['chicago rap', 'melodic rap']
# 3352                               ['dance pop', 'pop']
# 3261                             ['chicago rap', 'rap']
# 3167                              ['rap', 'slap house']
# 3143        ['colombian pop', 'dance pop', 'latin pop']
# 3265  ['conscious hip hop', 'hip hop', 'rap', 'west ...
# 2100  ['barbadian pop', 'dance pop', 'pop', 'urban c...
# 3157                        ['dance pop', 'pop', 'r&b']
# 3472                                            ['pop']
# 3495                   ['art pop', 'electropop', 'pop']
# 2210         ['atl hip hop', 'atl trap', 'rap', 'trap']
# 3963                                 ['art pop', 'pop']
# 4269  ['puerto rican pop', 'reggaeton', 'trap latino...

# %%
top_genres['Genre'] = top_genres['Genre'].apply(literal_eval)
top_genres = top_genres.explode(column = "Genre")
top_genres = top_genres.dropna()
top_genres
# Out:
#          Performer  Artist_Popularity    Performer2  \
# 2324     Bad Bunny              100.0     Bad Bunny
# 2324     Bad Bunny              100.0     Bad Bunny
# 2324     Bad Bunny              100.0     Bad Bunny
# 3065  Taylor Swift               99.0  Taylor Swift
# 3056    The Weeknd               97.0    The Weeknd
# ...            ...                ...           ...
# 3963  Lana Del Rey               90.0  Lana Del Rey
# 4269         Ozuna               90.0         Ozuna
# 4269         Ozuna               90.0         Ozuna
# 4269         Ozuna               90.0         Ozuna
# 4269         Ozuna               90.0         Ozuna
#
#                                         uri                      Genre
# 2324  spotify:artist:4q3ewBCX7sLwd24euuV69X                  reggaeton
# 2324  spotify:artist:4q3ewBCX7sLwd24euuV69X                trap latino
# 2324  spotify:artist:4q3ewBCX7sLwd24euuV69X              urbano latino
# 3065  spotify:artist:06HL4z0CvFAxyc27GXpf02                        pop
# 3056  spotify:artist:1Xyo4u8uXC1ZmMpatF05PJ  canadian contemporary r&b
# ...                                     ...                        ...
# 3963  spotify:artist:00FQb4jTyendYWaN8pK0wa                        pop
# 4269  spotify:artist:1i8SpTcr7yvPOmcqrbnVXY           puerto rican pop
# 4269  spotify:artist:1i8SpTcr7yvPOmcqrbnVXY                  reggaeton
# 4269  spotify:artist:1i8SpTcr7yvPOmcqrbnVXY                trap latino
# 4269  spotify:artist:1i8SpTcr7yvPOmcqrbnVXY              urbano latino
#
# [65 rows x 5 columns]

# %%
top_genres.drop_duplicates()
# Out:
#          Performer  Artist_Popularity    Performer2  \
# 2324     Bad Bunny              100.0     Bad Bunny
# 2324     Bad Bunny              100.0     Bad Bunny
# 2324     Bad Bunny              100.0     Bad Bunny
# 3065  Taylor Swift               99.0  Taylor Swift
# 3056    The Weeknd               97.0    The Weeknd
# ...            ...                ...           ...
# 3963  Lana Del Rey               90.0  Lana Del Rey
# 4269         Ozuna               90.0         Ozuna
# 4269         Ozuna               90.0         Ozuna
# 4269         Ozuna               90.0         Ozuna
# 4269         Ozuna               90.0         Ozuna
#
#                                         uri                      Genre
# 2324  spotify:artist:4q3ewBCX7sLwd24euuV69X                  reggaeton
# 2324  spotify:artist:4q3ewBCX7sLwd24euuV69X                trap latino
# 2324  spotify:artist:4q3ewBCX7sLwd24euuV69X              urbano latino
# 3065  spotify:artist:06HL4z0CvFAxyc27GXpf02                        pop
# 3056  spotify:artist:1Xyo4u8uXC1ZmMpatF05PJ  canadian contemporary r&b
# ...                                     ...                        ...
# 3963  spotify:artist:00FQb4jTyendYWaN8pK0wa                        pop
# 4269  spotify:artist:1i8SpTcr7yvPOmcqrbnVXY           puerto rican pop
# 4269  spotify:artist:1i8SpTcr7yvPOmcqrbnVXY                  reggaeton
# 4269  spotify:artist:1i8SpTcr7yvPOmcqrbnVXY                trap latino
# 4269  spotify:artist:1i8SpTcr7yvPOmcqrbnVXY              urbano latino
#
# [65 rows x 5 columns]

# %%
top_genres = top_genres.value_counts('Genre')
pd.DataFrame(top_genres)
# Out:
#                             0
# Genre
# pop                        11
# rap                         8
# dance pop                   4
# atl hip hop                 3
# canadian pop                3
# hip hop                     3
# r&b                         2
# reggaeton                   2
# art pop                     2
# trap                        2
# chicago rap                 2
# trap latino                 2
# urbano latino               2
# puerto rican pop            1
# southern hip hop            1
# slap house                  1
# uk pop                      1
# urban contemporary          1
# toronto rap                 1
# latin pop                   1
# melodic rap                 1
# k-pop boy group             1
# k-pop                       1
# electropop                  1
# detroit hip hop             1
# conscious hip hop           1
# colombian pop               1
# canadian hip hop            1
# canadian contemporary r&b   1
# barbadian pop               1
# atl trap                    1
# west coast rap              1

# %%
# genre_csvs['Genre'] = genre_csvs['Genre'].apply(literal_eval)

# %%
# genre_csvs = genre_csvs.explode(column = "Genre")
# genre_csvs = genre_csvs.dropna()

# %%
#popular_genres = genres_csvs['Genre'].value_counts().head(100).index.to_list()
#popular_genres

# %%
#popular_genres = genres_csvs['Genre'].value_counts().head(100).index.to_list()
#popular_genres

# %%
# genre_graph = genres_csvs.loc[genres_csvs['Genre'].isin(popular_genres)].plot(figsize=(10,6),
#                              x= 'Genre',
#                              y= 'Artist_Popularity',
#                              title = 'Genre Popularity',
#                              xlabel = 'Genre',
#                              ylabel = 'Popularity',
#                              kind = 'scatter',
#                              color = 'cadetblue',
                             
#                              alpha = 0.8)
# for bars in genre_graph.containers:
#     genre_graph.bar_label(scatter)
# plt.xticks(rotation = 90);

# %% [markdown]
# # song csv

# %%
merged_df = genre_csvs.merge(project_csv, how = 'inner', on = ['Performer'])
merged_df
# Out:
#                Performer  Artist_Popularity        Performer2  \
# 0          Lindsay Lohan               49.0     Lindsay Lohan
# 1          Lindsay Lohan               49.0     Lindsay Lohan
# 2          Lindsay Lohan               49.0     Lindsay Lohan
# 3          Lindsay Lohan               49.0     Lindsay Lohan
# 4          Lindsay Lohan               49.0     Lindsay Lohan
# ...                  ...                ...               ...
# 196968  Thelma Carpenter               34.0  Thelma Carpenter
# 196969  Thelma Carpenter               34.0  Thelma Carpenter
# 196970  Thelma Carpenter               34.0  Thelma Carpenter
# 196971  Thelma Carpenter               34.0  Thelma Carpenter
# 196972  Thelma Carpenter               34.0  Thelma Carpenter
#
#                                           uri                           Genre  \
# 0       spotify:artist:4vRSocKbGh7PsQrYRDVMEF  ['dance pop', 'post-teen pop']
# 1       spotify:artist:4vRSocKbGh7PsQrYRDVMEF  ['dance pop', 'post-teen pop']
# 2       spotify:artist:4vRSocKbGh7PsQrYRDVMEF  ['dance pop', 'post-teen pop']
# 3       spotify:artist:4vRSocKbGh7PsQrYRDVMEF  ['dance pop', 'post-teen pop']
# 4       spotify:artist:4vRSocKbGh7PsQrYRDVMEF  ['dance pop', 'post-teen pop']
# ...                                       ...                             ...
# 196968  spotify:artist:5NBLIcKY8kA94L3s5wkPAk                              []
# 196969  spotify:artist:5NBLIcKY8kA94L3s5wkPAk                              []
# 196970  spotify:artist:5NBLIcKY8kA94L3s5wkPAk                              []
# 196971  spotify:artist:5NBLIcKY8kA94L3s5wkPAk                              []
# 196972  spotify:artist:5NBLIcKY8kA94L3s5wkPAk                              []
#
#                                                       url      WeekID  \
# 0       http://www.billboard.com/charts/hot-100/2005-1...   12/3/2005
# 1       http://www.billboard.com/charts/hot-100/2005-1...  12/10/2005
# 2       http://www.billboard.com/charts/hot-100/2005-1...  12/17/2005
# 3       http://www.billboard.com/charts/hot-100/2005-1...  12/24/2005
# 4       http://www.billboard.com/charts/hot-100/2005-1...  12/31/2005
# ...                                                   ...         ...
# 196968  http://www.billboard.com/charts/hot-100/1961-0...    1/7/1961
# 196969  http://www.billboard.com/charts/hot-100/1961-0...   1/14/1961
# 196970  http://www.billboard.com/charts/hot-100/1961-0...   1/21/1961
# 196971  http://www.billboard.com/charts/hot-100/1961-0...   1/28/1961
# 196972  http://www.billboard.com/charts/hot-100/1961-0...    2/4/1961
#
#         Week Position                                               Song  \
# 0                  58  Confessions Of A Broken Heart (Daughter To Fat...
# 1                  87  Confessions Of A Broken Heart (Daughter To Fat...
# 2                  91  Confessions Of A Broken Heart (Daughter To Fat...
# 3                  57  Confessions Of A Broken Heart (Daughter To Fat...
# 4                  97  Confessions Of A Broken Heart (Daughter To Fat...
# ...               ...                                                ...
# 196968             74                          Yes, I'm Lonesome Tonight
# 196969             67                          Yes, I'm Lonesome Tonight
# 196970             58                          Yes, I'm Lonesome Tonight
# 196971             55                          Yes, I'm Lonesome Tonight
# 196972             74                          Yes, I'm Lonesome Tonight
#
#                                                    SongID  Instance  \
# 0       Confessions Of A Broken Heart (Daughter To Fat...         1
# 1       Confessions Of A Broken Heart (Daughter To Fat...         1
# 2       Confessions Of A Broken Heart (Daughter To Fat...         1
# 3       Confessions Of A Broken Heart (Daughter To Fat...         1
# 4       Confessions Of A Broken Heart (Daughter To Fat...         1
# ...                                                   ...       ...
# 196968          Yes, I'm Lonesome TonightThelma Carpenter         1
# 196969          Yes, I'm Lonesome TonightThelma Carpenter         1
# 196970          Yes, I'm Lonesome TonightThelma Carpenter         1
# 196971          Yes, I'm Lonesome TonightThelma Carpenter         1
# 196972          Yes, I'm Lonesome TonightThelma Carpenter         1
#
#         Previous Week Position  Peak Position  Weeks on Chart
# 0                         66.0             58               2
# 1                         58.0             58               3
# 2                         87.0             58               4
# 3                         91.0             57               5
# 4                         57.0             57               6
# ...                        ...            ...             ...
# 196968                    85.0             74               2
# 196969                    74.0             67               3
# 196970                    67.0             58               4
# 196971                    58.0             55               5
# 196972                    55.0             55               6
#
# [196973 rows x 14 columns]

# %%
merged_df['WeekID'] = pd.to_datetime(merged_df['WeekID'])

# %%
merged_df['Year'] = merged_df['WeekID'].dt.year
merged_df
# Out:
#                Performer  Artist_Popularity        Performer2  \
# 0          Lindsay Lohan               49.0     Lindsay Lohan
# 1          Lindsay Lohan               49.0     Lindsay Lohan
# 2          Lindsay Lohan               49.0     Lindsay Lohan
# 3          Lindsay Lohan               49.0     Lindsay Lohan
# 4          Lindsay Lohan               49.0     Lindsay Lohan
# ...                  ...                ...               ...
# 196968  Thelma Carpenter               34.0  Thelma Carpenter
# 196969  Thelma Carpenter               34.0  Thelma Carpenter
# 196970  Thelma Carpenter               34.0  Thelma Carpenter
# 196971  Thelma Carpenter               34.0  Thelma Carpenter
# 196972  Thelma Carpenter               34.0  Thelma Carpenter
#
#                                           uri                           Genre  \
# 0       spotify:artist:4vRSocKbGh7PsQrYRDVMEF  ['dance pop', 'post-teen pop']
# 1       spotify:artist:4vRSocKbGh7PsQrYRDVMEF  ['dance pop', 'post-teen pop']
# 2       spotify:artist:4vRSocKbGh7PsQrYRDVMEF  ['dance pop', 'post-teen pop']
# 3       spotify:artist:4vRSocKbGh7PsQrYRDVMEF  ['dance pop', 'post-teen pop']
# 4       spotify:artist:4vRSocKbGh7PsQrYRDVMEF  ['dance pop', 'post-teen pop']
# ...                                       ...                             ...
# 196968  spotify:artist:5NBLIcKY8kA94L3s5wkPAk                              []
# 196969  spotify:artist:5NBLIcKY8kA94L3s5wkPAk                              []
# 196970  spotify:artist:5NBLIcKY8kA94L3s5wkPAk                              []
# 196971  spotify:artist:5NBLIcKY8kA94L3s5wkPAk                              []
# 196972  spotify:artist:5NBLIcKY8kA94L3s5wkPAk                              []
#
#                                                       url     WeekID  \
# 0       http://www.billboard.com/charts/hot-100/2005-1... 2005-12-03
# 1       http://www.billboard.com/charts/hot-100/2005-1... 2005-12-10
# 2       http://www.billboard.com/charts/hot-100/2005-1... 2005-12-17
# 3       http://www.billboard.com/charts/hot-100/2005-1... 2005-12-24
# 4       http://www.billboard.com/charts/hot-100/2005-1... 2005-12-31
# ...                                                   ...        ...
# 196968  http://www.billboard.com/charts/hot-100/1961-0... 1961-01-07
# 196969  http://www.billboard.com/charts/hot-100/1961-0... 1961-01-14
# 196970  http://www.billboard.com/charts/hot-100/1961-0... 1961-01-21
# 196971  http://www.billboard.com/charts/hot-100/1961-0... 1961-01-28
# 196972  http://www.billboard.com/charts/hot-100/1961-0... 1961-02-04
#
#         Week Position                                               Song  \
# 0                  58  Confessions Of A Broken Heart (Daughter To Fat...
# 1                  87  Confessions Of A Broken Heart (Daughter To Fat...
# 2                  91  Confessions Of A Broken Heart (Daughter To Fat...
# 3                  57  Confessions Of A Broken Heart (Daughter To Fat...
# 4                  97  Confessions Of A Broken Heart (Daughter To Fat...
# ...               ...                                                ...
# 196968             74                          Yes, I'm Lonesome Tonight
# 196969             67                          Yes, I'm Lonesome Tonight
# 196970             58                          Yes, I'm Lonesome Tonight
# 196971             55                          Yes, I'm Lonesome Tonight
# 196972             74                          Yes, I'm Lonesome Tonight
#
#                                                    SongID  Instance  \
# 0       Confessions Of A Broken Heart (Daughter To Fat...         1
# 1       Confessions Of A Broken Heart (Daughter To Fat...         1
# 2       Confessions Of A Broken Heart (Daughter To Fat...         1
# 3       Confessions Of A Broken Heart (Daughter To Fat...         1
# 4       Confessions Of A Broken Heart (Daughter To Fat...         1
# ...                                                   ...       ...
# 196968          Yes, I'm Lonesome TonightThelma Carpenter         1
# 196969          Yes, I'm Lonesome TonightThelma Carpenter         1
# 196970          Yes, I'm Lonesome TonightThelma Carpenter         1
# 196971          Yes, I'm Lonesome TonightThelma Carpenter         1
# 196972          Yes, I'm Lonesome TonightThelma Carpenter         1
#
#         Previous Week Position  Peak Position  Weeks on Chart  Year
# 0                         66.0             58               2  2005
# 1                         58.0             58               3  2005
# 2                         87.0             58               4  2005
# 3                         91.0             57               5  2005
# 4                         57.0             57               6  2005
# ...                        ...            ...             ...   ...
# 196968                    85.0             74               2  1961
# 196969                    74.0             67               3  1961
# 196970                    67.0             58               4  1961
# 196971                    58.0             55               5  1961
# 196972                    55.0             55               6  1961
#
# [196973 rows x 15 columns]

# %%
merged_df.loc[(merged_df['Year']>=1950)&(merged_df['Year']<=1959),'Genre']
merged_df.loc[(merged_df['Year']>=1960)&(merged_df['Year']<=1969),'Genre']
merged_df.loc[(merged_df['Year']>=1970)&(merged_df['Year']<=1979),'Genre']
merged_df.loc[(merged_df['Year']>=1980)&(merged_df['Year']<=1989),'Genre']
merged_df.loc[(merged_df['Year']>=1990)&(merged_df['Year']<=1999),'Genre']
merged_df.loc[(merged_df['Year']>=2000)&(merged_df['Year']<=2009),'Genre']
merged_df.loc[(merged_df['Year']>=2010)&(merged_df['Year']<=2019),'Genre']
merged_df.loc[(merged_df['Year']>=2020)&(merged_df['Year']<=2029),'Genre']
merged_df
# Out:
#                Performer  Artist_Popularity        Performer2  \
# 0          Lindsay Lohan               49.0     Lindsay Lohan
# 1          Lindsay Lohan               49.0     Lindsay Lohan
# 2          Lindsay Lohan               49.0     Lindsay Lohan
# 3          Lindsay Lohan               49.0     Lindsay Lohan
# 4          Lindsay Lohan               49.0     Lindsay Lohan
# ...                  ...                ...               ...
# 196968  Thelma Carpenter               34.0  Thelma Carpenter
# 196969  Thelma Carpenter               34.0  Thelma Carpenter
# 196970  Thelma Carpenter               34.0  Thelma Carpenter
# 196971  Thelma Carpenter               34.0  Thelma Carpenter
# 196972  Thelma Carpenter               34.0  Thelma Carpenter
#
#                                           uri                           Genre  \
# 0       spotify:artist:4vRSocKbGh7PsQrYRDVMEF  ['dance pop', 'post-teen pop']
# 1       spotify:artist:4vRSocKbGh7PsQrYRDVMEF  ['dance pop', 'post-teen pop']
# 2       spotify:artist:4vRSocKbGh7PsQrYRDVMEF  ['dance pop', 'post-teen pop']
# 3       spotify:artist:4vRSocKbGh7PsQrYRDVMEF  ['dance pop', 'post-teen pop']
# 4       spotify:artist:4vRSocKbGh7PsQrYRDVMEF  ['dance pop', 'post-teen pop']
# ...                                       ...                             ...
# 196968  spotify:artist:5NBLIcKY8kA94L3s5wkPAk                              []
# 196969  spotify:artist:5NBLIcKY8kA94L3s5wkPAk                              []
# 196970  spotify:artist:5NBLIcKY8kA94L3s5wkPAk                              []
# 196971  spotify:artist:5NBLIcKY8kA94L3s5wkPAk                              []
# 196972  spotify:artist:5NBLIcKY8kA94L3s5wkPAk                              []
#
#                                                       url     WeekID  \
# 0       http://www.billboard.com/charts/hot-100/2005-1... 2005-12-03
# 1       http://www.billboard.com/charts/hot-100/2005-1... 2005-12-10
# 2       http://www.billboard.com/charts/hot-100/2005-1... 2005-12-17
# 3       http://www.billboard.com/charts/hot-100/2005-1... 2005-12-24
# 4       http://www.billboard.com/charts/hot-100/2005-1... 2005-12-31
# ...                                                   ...        ...
# 196968  http://www.billboard.com/charts/hot-100/1961-0... 1961-01-07
# 196969  http://www.billboard.com/charts/hot-100/1961-0... 1961-01-14
# 196970  http://www.billboard.com/charts/hot-100/1961-0... 1961-01-21
# 196971  http://www.billboard.com/charts/hot-100/1961-0... 1961-01-28
# 196972  http://www.billboard.com/charts/hot-100/1961-0... 1961-02-04
#
#         Week Position                                               Song  \
# 0                  58  Confessions Of A Broken Heart (Daughter To Fat...
# 1                  87  Confessions Of A Broken Heart (Daughter To Fat...
# 2                  91  Confessions Of A Broken Heart (Daughter To Fat...
# 3                  57  Confessions Of A Broken Heart (Daughter To Fat...
# 4                  97  Confessions Of A Broken Heart (Daughter To Fat...
# ...               ...                                                ...
# 196968             74                          Yes, I'm Lonesome Tonight
# 196969             67                          Yes, I'm Lonesome Tonight
# 196970             58                          Yes, I'm Lonesome Tonight
# 196971             55                          Yes, I'm Lonesome Tonight
# 196972             74                          Yes, I'm Lonesome Tonight
#
#                                                    SongID  Instance  \
# 0       Confessions Of A Broken Heart (Daughter To Fat...         1
# 1       Confessions Of A Broken Heart (Daughter To Fat...         1
# 2       Confessions Of A Broken Heart (Daughter To Fat...         1
# 3       Confessions Of A Broken Heart (Daughter To Fat...         1
# 4       Confessions Of A Broken Heart (Daughter To Fat...         1
# ...                                                   ...       ...
# 196968          Yes, I'm Lonesome TonightThelma Carpenter         1
# 196969          Yes, I'm Lonesome TonightThelma Carpenter         1
# 196970          Yes, I'm Lonesome TonightThelma Carpenter         1
# 196971          Yes, I'm Lonesome TonightThelma Carpenter         1
# 196972          Yes, I'm Lonesome TonightThelma Carpenter         1
#
#         Previous Week Position  Peak Position  Weeks on Chart  Year
# 0                         66.0             58               2  2005
# 1                         58.0             58               3  2005
# 2                         87.0             58               4  2005
# 3                         91.0             57               5  2005
# 4                         57.0             57               6  2005
# ...                        ...            ...             ...   ...
# 196968                    85.0             74               2  1961
# 196969                    74.0             67               3  1961
# 196970                    67.0             58               4  1961
# 196971                    58.0             55               5  1961
# 196972                    55.0             55               6  1961
#
# [196973 rows x 15 columns]

# %% [raw]
# genre_year = merged_df.head(20)

# %%
genre_graph = merged_df.plot(figsize=(10,6),
                             x= 'Year',
                             y= 'Artist_Popularity',
                             title = 'Year vs Artist Popularity',
                             xlabel = 'Year',
                             ylabel = 'Artist Popularity',
                             kind = 'scatter',
                             color = 'cadetblue',
                             
                             alpha = 0.8)
for bars in genre_graph.containers:
    genre_graph.bar_label(scatter)
plt.xticks(rotation = 90);

# %%
merged_df.loc[(merged_df['Year']>=1950)&(merged_df['Year']<=1959),'Decade']="1950's"
merged_df.loc[(merged_df['Year']>=1960)&(merged_df['Year']<=1969),'Decade']="1960's"
merged_df.loc[(merged_df['Year']>=1970)&(merged_df['Year']<=1979),'Decade']="1970's"
merged_df.loc[(merged_df['Year']>=1980)&(merged_df['Year']<=1989),'Decade']="1980's"
merged_df.loc[(merged_df['Year']>=1990)&(merged_df['Year']<=1999),'Decade']="1990's"
merged_df.loc[(merged_df['Year']>=2000)&(merged_df['Year']<=2009),'Decade']="2000's"
merged_df.loc[(merged_df['Year']>=2010)&(merged_df['Year']<=2019),'Decade']="2010's"
merged_df.loc[(merged_df['Year']>=2020)&(merged_df['Year']<=2029),'Decade']="2020's"
merged_df
# Out:
#                Performer  Artist_Popularity        Performer2  \
# 0          Lindsay Lohan               49.0     Lindsay Lohan
# 1          Lindsay Lohan               49.0     Lindsay Lohan
# 2          Lindsay Lohan               49.0     Lindsay Lohan
# 3          Lindsay Lohan               49.0     Lindsay Lohan
# 4          Lindsay Lohan               49.0     Lindsay Lohan
# ...                  ...                ...               ...
# 196968  Thelma Carpenter               34.0  Thelma Carpenter
# 196969  Thelma Carpenter               34.0  Thelma Carpenter
# 196970  Thelma Carpenter               34.0  Thelma Carpenter
# 196971  Thelma Carpenter               34.0  Thelma Carpenter
# 196972  Thelma Carpenter               34.0  Thelma Carpenter
#
#                                           uri                           Genre  \
# 0       spotify:artist:4vRSocKbGh7PsQrYRDVMEF  ['dance pop', 'post-teen pop']
# 1       spotify:artist:4vRSocKbGh7PsQrYRDVMEF  ['dance pop', 'post-teen pop']
# 2       spotify:artist:4vRSocKbGh7PsQrYRDVMEF  ['dance pop', 'post-teen pop']
# 3       spotify:artist:4vRSocKbGh7PsQrYRDVMEF  ['dance pop', 'post-teen pop']
# 4       spotify:artist:4vRSocKbGh7PsQrYRDVMEF  ['dance pop', 'post-teen pop']
# ...                                       ...                             ...
# 196968  spotify:artist:5NBLIcKY8kA94L3s5wkPAk                              []
# 196969  spotify:artist:5NBLIcKY8kA94L3s5wkPAk                              []
# 196970  spotify:artist:5NBLIcKY8kA94L3s5wkPAk                              []
# 196971  spotify:artist:5NBLIcKY8kA94L3s5wkPAk                              []
# 196972  spotify:artist:5NBLIcKY8kA94L3s5wkPAk                              []
#
#                                                       url     WeekID  \
# 0       http://www.billboard.com/charts/hot-100/2005-1... 2005-12-03
# 1       http://www.billboard.com/charts/hot-100/2005-1... 2005-12-10
# 2       http://www.billboard.com/charts/hot-100/2005-1... 2005-12-17
# 3       http://www.billboard.com/charts/hot-100/2005-1... 2005-12-24
# 4       http://www.billboard.com/charts/hot-100/2005-1... 2005-12-31
# ...                                                   ...        ...
# 196968  http://www.billboard.com/charts/hot-100/1961-0... 1961-01-07
# 196969  http://www.billboard.com/charts/hot-100/1961-0... 1961-01-14
# 196970  http://www.billboard.com/charts/hot-100/1961-0... 1961-01-21
# 196971  http://www.billboard.com/charts/hot-100/1961-0... 1961-01-28
# 196972  http://www.billboard.com/charts/hot-100/1961-0... 1961-02-04
#
#         Week Position                                               Song  \
# 0                  58  Confessions Of A Broken Heart (Daughter To Fat...
# 1                  87  Confessions Of A Broken Heart (Daughter To Fat...
# 2                  91  Confessions Of A Broken Heart (Daughter To Fat...
# 3                  57  Confessions Of A Broken Heart (Daughter To Fat...
# 4                  97  Confessions Of A Broken Heart (Daughter To Fat...
# ...               ...                                                ...
# 196968             74                          Yes, I'm Lonesome Tonight
# 196969             67                          Yes, I'm Lonesome Tonight
# 196970             58                          Yes, I'm Lonesome Tonight
# 196971             55                          Yes, I'm Lonesome Tonight
# 196972             74                          Yes, I'm Lonesome Tonight
#
#                                                    SongID  Instance  \
# 0       Confessions Of A Broken Heart (Daughter To Fat...         1
# 1       Confessions Of A Broken Heart (Daughter To Fat...         1
# 2       Confessions Of A Broken Heart (Daughter To Fat...         1
# 3       Confessions Of A Broken Heart (Daughter To Fat...         1
# 4       Confessions Of A Broken Heart (Daughter To Fat...         1
# ...                                                   ...       ...
# 196968          Yes, I'm Lonesome TonightThelma Carpenter         1
# 196969          Yes, I'm Lonesome TonightThelma Carpenter         1
# 196970          Yes, I'm Lonesome TonightThelma Carpenter         1
# 196971          Yes, I'm Lonesome TonightThelma Carpenter         1
# 196972          Yes, I'm Lonesome TonightThelma Carpenter         1
#
#         Previous Week Position  Peak Position  Weeks on Chart  Year  Decade
# 0                         66.0             58               2  2005  2000's
# 1                         58.0             58               3  2005  2000's
# 2                         87.0             58               4  2005  2000's
# 3                         91.0             57               5  2005  2000's
# 4                         57.0             57               6  2005  2000's
# ...                        ...            ...             ...   ...     ...
# 196968                    85.0             74               2  1961  1960's
# 196969                    74.0             67               3  1961  1960's
# 196970                    67.0             58               4  1961  1960's
# 196971                    58.0             55               5  1961  1960's
# 196972                    55.0             55               6  1961  1960's
#
# [196973 rows x 16 columns]

# %%
weeks = merged_df.value_counts(['Performer', 'Weeks on Chart'])
weeks
weeks = pd.DataFrame(weeks)
weeks
# Out:
#                                  0
# Performer       Weeks on Chart
# Drake           2               65
# The Beatles     2               62
#                 3               61
# Aretha Franklin 2               61
# The Beatles     4               60
# ...                             ..
# Jordan Knight   19               1
#                 20               1
# Jordan Pruitt   3                1
#                 4                1
# will.i.am       9                1
#
# [60865 rows x 1 columns]

# %%
large_number = merged_df.value_counts(['Performer', 'Song'])
large_number
# Out:
# Performer                         Song
# Imagine Dragons                   Radioactive                       85
# AWOLNATION                        Sail                              77
# Jason Mraz                        I'm Yours                         75
# The Weeknd                        Blinding Lights                   74
# LeAnn Rimes                       How Do I Live                     68
#                                                                     ..
# Tommy Edwards                     It's Not The End Of Everything     1
# Country Joe & The Fish            Not So Sweet Martha Lorraine       1
# Nicki Minaj                       Yikes                              1
# Cornelius Brothers & Sister Rose  Let Me Down Easy                   1
# The O'Jays                        Looky Looky (Look At Me Girl)      1
# Length: 17673, dtype: int64

# %%
decade_boxplot = sns.boxplot(data=merged_df, x = "Decade", y = "Song_Popularity")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [31], in <cell line: 1>()
# ----> 1 decade_boxplot = sns.boxplot(data=merged_df, x = "Decade", y = "Song_Popularity")
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:46, in _deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#      36     warnings.warn(
#      37         "Pass the following variable{} as {}keyword arg{}: {}. "
#      38         "From version 0.12, the only valid positional argument "
#    (...)
#      43         FutureWarning
#      44     )
#      45 kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46 return f(**kwargs)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/seaborn/categorical.py:2243, in boxplot(x, y, hue, data, order, hue_order, orient, color, palette, saturation, width, dodge, fliersize, linewidth, whis, ax, **kwargs)
#    2231 @_deprecate_positional_args
#    2232 def boxplot(
#    2233     *,
#    (...)
#    2240     **kwargs
#    2241 ):
# -> 2243     plotter = _BoxPlotter(x, y, hue, data, order, hue_order,
#    2244                           orient, color, palette, saturation,
#    2245                           width, dodge, fliersize, linewidth)
#    2247     if ax is None:
#    2248         ax = plt.gca()
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/seaborn/categorical.py:406, in _BoxPlotter.__init__(self, x, y, hue, data, order, hue_order, orient, color, palette, saturation, width, dodge, fliersize, linewidth)
#     402 def __init__(self, x, y, hue, data, order, hue_order,
#     403              orient, color, palette, saturation,
#     404              width, dodge, fliersize, linewidth):
# --> 406     self.establish_variables(x, y, hue, data, orient, order, hue_order)
#     407     self.establish_colors(color, palette, saturation)
#     409     self.dodge = dodge
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/seaborn/categorical.py:153, in _CategoricalPlotter.establish_variables(self, x, y, hue, data, orient, order, hue_order, units)
#     151     if isinstance(var, str):
#     152         err = "Could not interpret input '{}'".format(var)
# --> 153         raise ValueError(err)
#     155 # Figure out the plotting orientation
#     156 orient = infer_orient(
#     157     x, y, orient, require_numeric=self.require_numeric
#     158 )
#
# ValueError: Could not interpret input 'Song_Popularity'

# %%
decade_boxplot = sns.boxplot(data=merged_df, x = "Decade", y = "Duration ms")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [32], in <cell line: 1>()
# ----> 1 decade_boxplot = sns.boxplot(data=merged_df, x = "Decade", y = "Duration ms")
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:46, in _deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#      36     warnings.warn(
#      37         "Pass the following variable{} as {}keyword arg{}: {}. "
#      38         "From version 0.12, the only valid positional argument "
#    (...)
#      43         FutureWarning
#      44     )
#      45 kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46 return f(**kwargs)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/seaborn/categorical.py:2243, in boxplot(x, y, hue, data, order, hue_order, orient, color, palette, saturation, width, dodge, fliersize, linewidth, whis, ax, **kwargs)
#    2231 @_deprecate_positional_args
#    2232 def boxplot(
#    2233     *,
#    (...)
#    2240     **kwargs
#    2241 ):
# -> 2243     plotter = _BoxPlotter(x, y, hue, data, order, hue_order,
#    2244                           orient, color, palette, saturation,
#    2245                           width, dodge, fliersize, linewidth)
#    2247     if ax is None:
#    2248         ax = plt.gca()
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/seaborn/categorical.py:406, in _BoxPlotter.__init__(self, x, y, hue, data, order, hue_order, orient, color, palette, saturation, width, dodge, fliersize, linewidth)
#     402 def __init__(self, x, y, hue, data, order, hue_order,
#     403              orient, color, palette, saturation,
#     404              width, dodge, fliersize, linewidth):
# --> 406     self.establish_variables(x, y, hue, data, orient, order, hue_order)
#     407     self.establish_colors(color, palette, saturation)
#     409     self.dodge = dodge
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/seaborn/categorical.py:153, in _CategoricalPlotter.establish_variables(self, x, y, hue, data, orient, order, hue_order, units)
#     151     if isinstance(var, str):
#     152         err = "Could not interpret input '{}'".format(var)
# --> 153         raise ValueError(err)
#     155 # Figure out the plotting orientation
#     156 orient = infer_orient(
#     157     x, y, orient, require_numeric=self.require_numeric
#     158 )
#
# ValueError: Could not interpret input 'Duration ms'

# %%
decade_boxplot = sns.boxplot(data=merged_df, x = "Decade", y = "Artist_Popularity")

# %%
debut_df = merged_df.sort_values('WeekID').drop_duplicates('Performer')
debut_df
# Out:
#               Performer  Artist_Popularity       Performer2  \
# 153211        Bobby Day               47.0        Bobby Day
# 33035     Bobby Freeman               29.0    Bobby Freeman
# 157446     The Olympics               23.0     The Olympics
# 68914      The Platters               61.0     The Platters
# 84774     Nat King Cole               78.0    Nat King Cole
# ...                 ...                ...              ...
# 170722           Giveon               81.0           Giveon
# 14121        Kali Uchis               82.0       Kali Uchis
# 195358           Mooski               47.0           Mooski
# 183387  Duncan Laurence               70.0  Duncan Laurence
# 14049            Cico P               49.0           Cico P
#
#                                           uri  \
# 153211  spotify:artist:4SLfKHcufUqU46DiTAHIsj
# 33035   spotify:artist:5oMWW19j0AXl7Sy4Xn9rmg
# 157446  spotify:artist:3KtW4xANJkgfEnFgMxaj8h
# 68914   spotify:artist:6KWcxMWVNVIYbdOQyJtsSy
# 84774   spotify:artist:7v4imS0moSyGdXyLgVTIV7
# ...                                       ...
# 170722  spotify:artist:4fxd5Ee7UefO4CUXgwJ7IP
# 14121   spotify:artist:1U1el3k54VvEUzo3ybLPlM
# 195358  spotify:artist:4NqH3V7GS0Igs1VyGMXEi8
# 183387  spotify:artist:3klZnJvYGIbWritVwQD434
# 14049   spotify:artist:3jAZsSIIA8HLjxR99biJyx
#
#                                                     Genre  \
# 153211  ['doo-wop', 'rhythm and blues', 'rock-and-roll...
# 33035   ['doo-wop', 'rhythm and blues', 'rock-and-roll...
# 157446                    ['doo-wop', 'rhythm and blues']
# 68914   ['adult standards', 'doo-wop', 'lounge', 'rock...
# 84774                                 ['adult standards']
# ...                                                   ...
# 170722                                     ['pop', 'r&b']
# 14121                            ['colombian pop', 'pop']
# 195358                                    ['alabama rap']
# 183387                                      ['dutch pop']
# 14049                                         ['pop rap']
#
#                                                       url     WeekID  \
# 153211  http://www.billboard.com/charts/hot-100/1958-0... 1958-08-09
# 33035   http://www.billboard.com/charts/hot-100/1958-0... 1958-08-09
# 157446  http://www.billboard.com/charts/hot-100/1958-0... 1958-08-09
# 68914   http://www.billboard.com/charts/hot-100/1958-0... 1958-08-09
# 84774   http://www.billboard.com/charts/hot-100/1958-0... 1958-08-09
# ...                                                   ...        ...
# 170722  https://www.billboard.com/charts/hot-100/2021-... 2021-03-06
# 14121   https://www.billboard.com/charts/hot-100/2021-... 2021-03-13
# 195358  https://www.billboard.com/charts/hot-100/2021-... 2021-03-13
# 183387  https://www.billboard.com/charts/hot-100/2021-... 2021-05-08
# 14049   https://www.billboard.com/charts/hot-100/2021-... 2021-05-22
#
#         Week Position                               Song  \
# 153211             33                      Rock-in Robin
# 33035              44  Betty Lou Got A New Pair Of Shoes
# 157446             21                     Western Movies
# 68914              68            You're Making A Mistake
# 84774              46   Come Closer To Me (Acercate Mas)
# ...               ...                                ...
# 170722            100                    Like I Want You
# 14121              39                          Telepatia
# 195358             66                         Track Star
# 183387             90                             Arcade
# 14049              91                              Tampa
#
#                                                 SongID  Instance  \
# 153211                          Rock-in RobinBobby Day         1
# 33035   Betty Lou Got A New Pair Of ShoesBobby Freeman         1
# 157446                      Western MoviesThe Olympics         1
# 68914              You're Making A MistakeThe Platters         1
# 84774    Come Closer To Me (Acercate Mas)Nat King Cole         1
# ...                                                ...       ...
# 170722                           Like I Want YouGiveon         1
# 14121                              TelepatiaKali Uchis         1
# 195358                                Track StarMooski         1
# 183387                           ArcadeDuncan Laurence         2
# 14049                                      TampaCico P         1
#
#         Previous Week Position  Peak Position  Weeks on Chart  Year  Decade
# 153211                    35.0             33               2  1958  1950's
# 33035                     78.0             44               2  1958  1950's
# 157446                    23.0             21               2  1958  1950's
# 68914                     65.0             65               2  1958  1950's
# 84774                     53.0             46               2  1958  1950's
# ...                        ...            ...             ...   ...     ...
# 170722                    95.0             95               2  2021  2020's
# 14121                     54.0             39               2  2021  2020's
# 195358                    99.0             66               2  2021  2020's
# 183387                    94.0             90               3  2021  2020's
# 14049                     97.0             91               2  2021  2020's
#
# [4110 rows x 16 columns]

# %%
debut_df.groupby('Decade')['Artist_Popularity'].mean()
# Out:
# Decade
# 1950's    30.676471
# 1960's    29.266376
# 1970's    36.458824
# 1980's    40.558059
# 1990's    45.151111
# 2000's    55.639155
# 2010's    66.857520
# 2020's    68.487179
# Name: Artist_Popularity, dtype: float64

# %%
debut_df.groupby('Decade')['Artist_Popularity'].describe()
# Out:
#         count       mean        std   min   25%   50%    75%    max
# Decade
# 1950's  238.0  30.676471  21.936626   0.0  10.0  30.0  46.75   82.0
# 1960's  916.0  29.266376  20.238658   0.0  10.0  29.0  45.00   85.0
# 1970's  765.0  36.458824  21.613997   0.0  20.0  37.0  53.00   86.0
# 1980's  577.0  40.558059  19.561970   0.0  29.0  44.0  55.00   84.0
# 1990's  675.0  45.151111  19.135414   0.0  32.0  48.0  59.00   93.0
# 2000's  521.0  55.639155  17.274267   0.0  46.0  58.0  67.00   99.0
# 2010's  379.0  66.857520  15.554334   5.0  58.0  68.0  78.00  100.0
# 2020's   39.0  68.487179  14.975193  14.0  61.0  70.0  81.00   85.0

# %%
sns.boxplot(data=debut_df, x = "Decade", y = "Artist_Popularity")
# Out:
# <AxesSubplot:xlabel='Decade', ylabel='Artist_Popularity'>

# %%
merged_df_peak = merged_df.drop_duplicates(subset = 'uri', keep='first')
merged_df_peak
# Out:
#                  Performer  Artist_Popularity          Performer2  \
# 0            Lindsay Lohan               49.0       Lindsay Lohan
# 5                  Incubus               69.0             Incubus
# 91               Zac Efron               69.0           Zac Efron
# 93              Kris Allen               44.0          Kris Allen
# 126      The Swon Brothers               33.0   The Swon Brothers
# ...                    ...                ...                 ...
# 196936       British Lions                3.0       British Lions
# 196939       Judson Spence                4.0       Judson Spence
# 196952  The Yellow Balloon               22.0  The Yellow Balloon
# 196961        Ant Saunders               53.0        Ant Saunders
# 196968    Thelma Carpenter               34.0    Thelma Carpenter
#
#                                           uri  \
# 0       spotify:artist:4vRSocKbGh7PsQrYRDVMEF
# 5       spotify:artist:3YcBF2ttyueytpXtEzn1Za
# 91      spotify:artist:6U1dBXJhC8gXFjamvFTmHg
# 93      spotify:artist:2zwHaEmXxX6DTv4i8ajNCM
# 126     spotify:artist:1nf0nRF0W4ybnJdda00pKY
# ...                                       ...
# 196936  spotify:artist:79EQ2MmIK2wQakeotwFuNF
# 196939  spotify:artist:2iDXfUayTfaawalL8HDDj6
# 196952  spotify:artist:2EogrfOq2qlvRnJDaQ5BF0
# 196961  spotify:artist:4jpsw9CQS439N0B7SecMgf
# 196968  spotify:artist:5NBLIcKY8kA94L3s5wkPAk
#
#                                                     Genre  \
# 0                          ['dance pop', 'post-teen pop']
# 5       ['alternative metal', 'alternative rock', 'fun...
# 91      ['hollywood', 'pop', 'post-teen pop', 'show tu...
# 93      ['acoustic pop', 'idol', 'neo mellow', 'post-t...
# 126     ['contemporary country', 'country pop', 'oklah...
# ...                                                   ...
# 196936                                                 []
# 196939                                                 []
# 196952     ['bubblegum pop', 'freakbeat', 'sunshine pop']
# 196961                               ['chill r&b', 'pop']
# 196968                                                 []
#
#                                                       url     WeekID  \
# 0       http://www.billboard.com/charts/hot-100/2005-1... 2005-12-03
# 5       http://www.billboard.com/charts/hot-100/2007-0... 2007-02-03
# 91      http://www.billboard.com/charts/hot-100/2007-0... 2007-09-08
# 93      http://www.billboard.com/charts/hot-100/2009-0... 2009-06-13
# 126     http://www.billboard.com/charts/hot-100/2013-0... 2013-07-06
# ...                                                   ...        ...
# 196936  http://www.billboard.com/charts/hot-100/1978-0... 1978-07-29
# 196939  http://www.billboard.com/charts/hot-100/1988-1... 1988-10-22
# 196952  http://www.billboard.com/charts/hot-100/1967-0... 1967-04-08
# 196961  https://www.billboard.com/charts/hot-100/2019-... 2019-11-30
# 196968  http://www.billboard.com/charts/hot-100/1961-0... 1961-01-07
#
#         Week Position                                               Song  \
# 0                  58  Confessions Of A Broken Heart (Daughter To Fat...
# 5                  88                                         Anna-Molly
# 91                 46                                          Bet On It
# 93                 94                                  Ain't No Sunshine
# 126                78                                       Danny's Song
# ...               ...                                                ...
# 196936             87                                Wild In The Streets
# 196939             72                                   Yeah, Yeah, Yeah
# 196952             71                                     Yellow Balloon
# 196961             98                                      Yellow Hearts
# 196968             74                          Yes, I'm Lonesome Tonight
#
#                                                    SongID  Instance  \
# 0       Confessions Of A Broken Heart (Daughter To Fat...         1
# 5                                       Anna-MollyIncubus         1
# 91                                     Bet On ItZac Efron         1
# 93                            Ain't No SunshineKris Allen         1
# 126                         Danny's SongThe Swon Brothers         1
# ...                                                   ...       ...
# 196936                   Wild In The StreetsBritish Lions         1
# 196939                      Yeah, Yeah, YeahJudson Spence         1
# 196952                   Yellow BalloonThe Yellow Balloon         1
# 196961                          Yellow HeartsAnt Saunders         1
# 196968          Yes, I'm Lonesome TonightThelma Carpenter         1
#
#         Previous Week Position  Peak Position  Weeks on Chart  Year  Decade
# 0                         66.0             58               2  2005  2000's
# 5                         93.0             66               8  2007  2000's
# 91                        66.0             46               2  2007  2000's
# 93                        37.0             37               2  2009  2000's
# 126                       66.0             66               2  2013  2010's
# ...                        ...            ...             ...   ...     ...
# 196936                    89.0             87               2  1978  1970's
# 196939                    86.0             72               2  1988  1980's
# 196952                    89.0             71               2  1967  1960's
# 196961                    81.0             81               2  2019  2010's
# 196968                    85.0             74               2  1961  1960's
#
# [4110 rows x 16 columns]

# %%
merged_df_1970 = merged_df.loc[merged_df['Year']>=1970].loc[merged_df['Year']<=1979].drop_duplicates(subset = 'SongID', keep = 'first')

# %%
merged_df_1970
# Out:
#                Performer  Artist_Popularity        Performer2  \
# 190     Bay City Rollers               48.0  Bay City Rollers
# 191     Bay City Rollers               48.0  Bay City Rollers
# 192     Bay City Rollers               48.0  Bay City Rollers
# 195     Bay City Rollers               48.0  Bay City Rollers
# 221     Bay City Rollers               48.0  Bay City Rollers
# ...                  ...                ...               ...
# 196741       Susan Jacks               36.0       Susan Jacks
# 196749       Lee Garrett                0.0       Lee Garrett
# 196898      The McCrarys               10.0      The McCrarys
# 196922      Five Special                8.0      Five Special
# 196936     British Lions                3.0     British Lions
#
#                                           uri  \
# 190     spotify:artist:3r9TXuXfOUxXjgYgAR0fP8
# 191     spotify:artist:3r9TXuXfOUxXjgYgAR0fP8
# 192     spotify:artist:3r9TXuXfOUxXjgYgAR0fP8
# 195     spotify:artist:3r9TXuXfOUxXjgYgAR0fP8
# 221     spotify:artist:3r9TXuXfOUxXjgYgAR0fP8
# ...                                       ...
# 196741  spotify:artist:6GH8lDgqqfg1KSDfFRFGzK
# 196749  spotify:artist:4QHt3AkCsysFBI5bC0Wv4Z
# 196898  spotify:artist:6LyH8I33ztRvEXtm1sZbpY
# 196922  spotify:artist:7onUSIg238obN7lDtmB1wT
# 196936  spotify:artist:79EQ2MmIK2wQakeotwFuNF
#
#                                       Genre  \
# 190     ['bubblegum pop', 'classic uk pop']
# 191     ['bubblegum pop', 'classic uk pop']
# 192     ['bubblegum pop', 'classic uk pop']
# 195     ['bubblegum pop', 'classic uk pop']
# 221     ['bubblegum pop', 'classic uk pop']
# ...                                     ...
# 196741                                   []
# 196749                                   []
# 196898                  ['post-disco soul']
# 196922                       ['post-disco']
# 196936                                   []
#
#                                                       url     WeekID  \
# 190     http://www.billboard.com/charts/hot-100/1976-0... 1976-06-19
# 191     http://www.billboard.com/charts/hot-100/1977-0... 1977-02-19
# 192     http://www.billboard.com/charts/hot-100/1975-1... 1975-10-18
# 195     http://www.billboard.com/charts/hot-100/1977-1... 1977-10-22
# 221     http://www.billboard.com/charts/hot-100/1976-0... 1976-02-14
# ...                                                   ...        ...
# 196741  http://www.billboard.com/charts/hot-100/1975-0... 1975-03-15
# 196749  http://www.billboard.com/charts/hot-100/1976-0... 1976-05-29
# 196898  http://www.billboard.com/charts/hot-100/1978-0... 1978-08-26
# 196922  http://www.billboard.com/charts/hot-100/1979-0... 1979-08-04
# 196936  http://www.billboard.com/charts/hot-100/1978-0... 1978-07-29
#
#         Week Position                       Song  \
# 190                54  Rock And Roll Love Letter
# 191                73                 Dedication
# 192                75             Saturday Night
# 195                78     The Way I Feel Tonight
# 221                38                Money Honey
# ...               ...                        ...
# 196741             96        You're A Part Of Me
# 196749             75       You're My Everything
# 196898             69                        You
# 196922             59         Why Leave Us Alone
# 196936             87        Wild In The Streets
#
#                                            SongID  Instance  \
# 190     Rock And Roll Love LetterBay City Rollers         1
# 191                    DedicationBay City Rollers         1
# 192                Saturday NightBay City Rollers         1
# 195        The Way I Feel TonightBay City Rollers         1
# 221                   Money HoneyBay City Rollers         1
# ...                                           ...       ...
# 196741             You're A Part Of MeSusan Jacks         1
# 196749            You're My EverythingLee Garrett         1
# 196898                            YouThe McCrarys         1
# 196922             Why Leave Us AloneFive Special         1
# 196936           Wild In The StreetsBritish Lions         1
#
#         Previous Week Position  Peak Position  Weeks on Chart  Year  Decade
# 190                       28.0             28               8  1976  1970's
# 191                       85.0             73               2  1977  1970's
# 192                       85.0             75               2  1975  1970's
# 195                       89.0             78               2  1977  1970's
# 221                       51.0             38               2  1976  1970's
# ...                        ...            ...             ...   ...     ...
# 196741                    99.0             96               2  1975  1970's
# 196749                    80.0             75               2  1976  1970's
# 196898                    80.0             69               2  1978  1970's
# 196922                    84.0             59               2  1979  1970's
# 196936                    89.0             87               2  1978  1970's
#
# [3671 rows x 16 columns]

# %%
peak_df = merged_df.sort_values('Peak Position', ascending = True).drop_duplicates(subset = 'Performer', keep='first')

# %%
peak_df.loc[peak_df['Peak Position']<=90].loc[peak_df['Artist_Popularity']>=99]
# Out:
#           Performer  Artist_Popularity    Performer2  \
# 68059  Taylor Swift               99.0  Taylor Swift
# 35209     Bad Bunny              100.0     Bad Bunny
#
#                                          uri  \
# 68059  spotify:artist:06HL4z0CvFAxyc27GXpf02
# 35209  spotify:artist:4q3ewBCX7sLwd24euuV69X
#
#                                                Genre  \
# 68059                                        ['pop']
# 35209  ['reggaeton', 'trap latino', 'urbano latino']
#
#                                                      url     WeekID  \
# 68059  http://www.billboard.com/charts/hot-100/2015-0... 2015-07-04
# 35209  https://www.billboard.com/charts/hot-100/2020-... 2020-04-11
#
#        Week Position              Song                     SongID  Instance  \
# 68059             40      Shake It Off   Shake It OffTaylor Swift         1
# 35209             89  Si Veo A Tu Mama  Si Veo A Tu MamaBad Bunny         1
#
#        Previous Week Position  Peak Position  Weeks on Chart  Year  Decade
# 68059                    39.0              1              44  2015  2010's
# 35209                    92.0             32               5  2020  2020's

# %%
genre_graph = peak_df.plot(figsize=(10,6),
                             x= 'Peak Position',
                             y= 'Artist_Popularity',
                             title = 'Peak Position vs Artist Popularity',
                             xlabel = 'Peak Position',
                             ylabel = 'Artist Popularity',
                             kind = 'scatter',
                             color = 'cadetblue',
                             
                             alpha = 0.8)
for bars in genre_graph.containers:
    genre_graph.bar_label(scatter)
plt.xticks(rotation = 90);

# %%
genre_graph = merged_df.plot(figsize=(10,6),
                             x= 'Year',
                             y= 'Artist_Popularity',
                             title = 'Year vs Artist Popularity',
                             xlabel = 'Year',
                             ylabel = 'Artist Popularity',
                             kind = 'scatter',
                             color = 'cadetblue',
                             
                             alpha = 0.8)
for bars in genre_graph.containers:
    genre_graph.bar_label(scatter)
plt.xticks(rotation = 90);

# %%
merged_df = merged_df.merge(new_csvs, how = 'inner', on = ['Performer'])
merged_df
# Out:
#              Performer  Artist_Popularity     Performer2  \
# 0        Lindsay Lohan               49.0  Lindsay Lohan
# 1        Lindsay Lohan               49.0  Lindsay Lohan
# 2        Lindsay Lohan               49.0  Lindsay Lohan
# 3        Lindsay Lohan               49.0  Lindsay Lohan
# 4        Lindsay Lohan               49.0  Lindsay Lohan
# ...                ...                ...            ...
# 2415949   Ant Saunders               53.0   Ant Saunders
# 2415950   Ant Saunders               53.0   Ant Saunders
# 2415951   Ant Saunders               53.0   Ant Saunders
# 2415952   Ant Saunders               53.0   Ant Saunders
# 2415953   Ant Saunders               53.0   Ant Saunders
#
#                                          uri_x  \
# 0        spotify:artist:4vRSocKbGh7PsQrYRDVMEF
# 1        spotify:artist:4vRSocKbGh7PsQrYRDVMEF
# 2        spotify:artist:4vRSocKbGh7PsQrYRDVMEF
# 3        spotify:artist:4vRSocKbGh7PsQrYRDVMEF
# 4        spotify:artist:4vRSocKbGh7PsQrYRDVMEF
# ...                                        ...
# 2415949  spotify:artist:4jpsw9CQS439N0B7SecMgf
# 2415950  spotify:artist:4jpsw9CQS439N0B7SecMgf
# 2415951  spotify:artist:4jpsw9CQS439N0B7SecMgf
# 2415952  spotify:artist:4jpsw9CQS439N0B7SecMgf
# 2415953  spotify:artist:4jpsw9CQS439N0B7SecMgf
#
#                                   Genre  \
# 0        ['dance pop', 'post-teen pop']
# 1        ['dance pop', 'post-teen pop']
# 2        ['dance pop', 'post-teen pop']
# 3        ['dance pop', 'post-teen pop']
# 4        ['dance pop', 'post-teen pop']
# ...                                 ...
# 2415949            ['chill r&b', 'pop']
# 2415950            ['chill r&b', 'pop']
# 2415951            ['chill r&b', 'pop']
# 2415952            ['chill r&b', 'pop']
# 2415953            ['chill r&b', 'pop']
#
#                                                        url     WeekID  \
# 0        http://www.billboard.com/charts/hot-100/2005-1... 2005-12-03
# 1        http://www.billboard.com/charts/hot-100/2005-1... 2005-12-10
# 2        http://www.billboard.com/charts/hot-100/2005-1... 2005-12-17
# 3        http://www.billboard.com/charts/hot-100/2005-1... 2005-12-24
# 4        http://www.billboard.com/charts/hot-100/2005-1... 2005-12-31
# ...                                                    ...        ...
# 2415949  https://www.billboard.com/charts/hot-100/2019-... 2019-12-14
# 2415950  https://www.billboard.com/charts/hot-100/2019-... 2019-12-21
# 2415951  https://www.billboard.com/charts/hot-100/2019-... 2019-12-28
# 2415952  https://www.billboard.com/charts/hot-100/2020-... 2020-01-04
# 2415953  https://www.billboard.com/charts/hot-100/2020-... 2020-01-11
#
#          Week Position                                             Song_x  \
# 0                   58  Confessions Of A Broken Heart (Daughter To Fat...
# 1                   87  Confessions Of A Broken Heart (Daughter To Fat...
# 2                   91  Confessions Of A Broken Heart (Daughter To Fat...
# 3                   57  Confessions Of A Broken Heart (Daughter To Fat...
# 4                   97  Confessions Of A Broken Heart (Daughter To Fat...
# ...                ...                                                ...
# 2415949             84                                      Yellow Hearts
# 2415950             95                                      Yellow Hearts
# 2415951             95                                      Yellow Hearts
# 2415952             94                                      Yellow Hearts
# 2415953             92                                      Yellow Hearts
#
#                                                     SongID  ...  \
# 0        Confessions Of A Broken Heart (Daughter To Fat...  ...
# 1        Confessions Of A Broken Heart (Daughter To Fat...  ...
# 2        Confessions Of A Broken Heart (Daughter To Fat...  ...
# 3        Confessions Of A Broken Heart (Daughter To Fat...  ...
# 4        Confessions Of A Broken Heart (Daughter To Fat...  ...
# ...                                                    ...  ...
# 2415949                          Yellow HeartsAnt Saunders  ...
# 2415950                          Yellow HeartsAnt Saunders  ...
# 2415951                          Yellow HeartsAnt Saunders  ...
# 2415952                          Yellow HeartsAnt Saunders  ...
# 2415953                          Yellow HeartsAnt Saunders  ...
#
#          Previous Week Position  Peak Position  Weeks on Chart  Year  Decade  \
# 0                          66.0             58               2  2005  2000's
# 1                          58.0             58               3  2005  2000's
# 2                          87.0             58               4  2005  2000's
# 3                          91.0             57               5  2005  2000's
# 4                          57.0             57               6  2005  2000's
# ...                         ...            ...             ...   ...     ...
# 2415949                    90.0             81               4  2019  2010's
# 2415950                    84.0             81               5  2019  2010's
# 2415951                    95.0             81               6  2019  2010's
# 2415952                    95.0             81               7  2020  2020's
# 2415953                    94.0             81               8  2020  2020's
#
#         Explicit Song_Popularity  \
# 0          False            45.0
# 1          False            45.0
# 2          False            45.0
# 3          False            45.0
# 4          False            45.0
# ...          ...             ...
# 2415949    False            65.0
# 2415950    False            65.0
# 2415951    False            65.0
# 2415952    False            65.0
# 2415953    False            65.0
#
#                                                     Song_y Duration ms  \
# 0        Confessions Of A Broken Heart (Daughter To Fat...    220800.0
# 1        Confessions Of A Broken Heart (Daughter To Fat...    220800.0
# 2        Confessions Of A Broken Heart (Daughter To Fat...    220800.0
# 3        Confessions Of A Broken Heart (Daughter To Fat...    220800.0
# 4        Confessions Of A Broken Heart (Daughter To Fat...    220800.0
# ...                                                    ...         ...
# 2415949                                      Yellow Hearts    223257.0
# 2415950                                      Yellow Hearts    223257.0
# 2415951                                      Yellow Hearts    223257.0
# 2415952                                      Yellow Hearts    223257.0
# 2415953                                      Yellow Hearts    223257.0
#
#                                         uri_y
# 0        spotify:track:0x7663BmBYv7m1ejUzXHfd
# 1        spotify:track:0x7663BmBYv7m1ejUzXHfd
# 2        spotify:track:0x7663BmBYv7m1ejUzXHfd
# 3        spotify:track:0x7663BmBYv7m1ejUzXHfd
# 4        spotify:track:0x7663BmBYv7m1ejUzXHfd
# ...                                       ...
# 2415949  spotify:track:2W4yABdLc4Jnds67Poi5Nl
# 2415950  spotify:track:2W4yABdLc4Jnds67Poi5Nl
# 2415951  spotify:track:2W4yABdLc4Jnds67Poi5Nl
# 2415952  spotify:track:2W4yABdLc4Jnds67Poi5Nl
# 2415953  spotify:track:2W4yABdLc4Jnds67Poi5Nl
#
# [2415954 rows x 21 columns]

# %%
peak_df = merged_df.loc[merged_df['Artist_Popularity']>=90]
peak_df
# Out:
#             Performer  Artist_Popularity    Performer2  \
# 97022             SZA               95.0           SZA
# 97023             SZA               95.0           SZA
# 97024             SZA               95.0           SZA
# 97025             SZA               95.0           SZA
# 97026             SZA               95.0           SZA
# ...               ...                ...           ...
# 2305837  Lana Del Rey               90.0  Lana Del Rey
# 2305838  Lana Del Rey               90.0  Lana Del Rey
# 2305839  Lana Del Rey               90.0  Lana Del Rey
# 2305840  Lana Del Rey               90.0  Lana Del Rey
# 2305841  Lana Del Rey               90.0  Lana Del Rey
#
#                                          uri_x               Genre  \
# 97022    spotify:artist:7tYKF4w9nC0nq9CsPZTHyP      ['pop', 'r&b']
# 97023    spotify:artist:7tYKF4w9nC0nq9CsPZTHyP      ['pop', 'r&b']
# 97024    spotify:artist:7tYKF4w9nC0nq9CsPZTHyP      ['pop', 'r&b']
# 97025    spotify:artist:7tYKF4w9nC0nq9CsPZTHyP      ['pop', 'r&b']
# 97026    spotify:artist:7tYKF4w9nC0nq9CsPZTHyP      ['pop', 'r&b']
# ...                                        ...                 ...
# 2305837  spotify:artist:00FQb4jTyendYWaN8pK0wa  ['art pop', 'pop']
# 2305838  spotify:artist:00FQb4jTyendYWaN8pK0wa  ['art pop', 'pop']
# 2305839  spotify:artist:00FQb4jTyendYWaN8pK0wa  ['art pop', 'pop']
# 2305840  spotify:artist:00FQb4jTyendYWaN8pK0wa  ['art pop', 'pop']
# 2305841  spotify:artist:00FQb4jTyendYWaN8pK0wa  ['art pop', 'pop']
#
#                                                        url     WeekID  \
# 97022    http://www.billboard.com/charts/hot-100/2017-0... 2017-08-26
# 97023    http://www.billboard.com/charts/hot-100/2017-0... 2017-08-26
# 97024    http://www.billboard.com/charts/hot-100/2017-0... 2017-09-02
# 97025    http://www.billboard.com/charts/hot-100/2017-0... 2017-09-02
# 97026    http://www.billboard.com/charts/hot-100/2017-0... 2017-09-09
# ...                                                    ...        ...
# 2305837  http://www.billboard.com/charts/hot-100/2013-1... 2013-10-12
# 2305838  http://www.billboard.com/charts/hot-100/2013-1... 2013-10-12
# 2305839  http://www.billboard.com/charts/hot-100/2013-1... 2013-10-12
# 2305840  http://www.billboard.com/charts/hot-100/2013-1... 2013-10-12
# 2305841  http://www.billboard.com/charts/hot-100/2013-1... 2013-10-12
#
#          Week Position               Song_x                           SongID  \
# 97022               75          The Weekend                   The WeekendSZA
# 97023               75          The Weekend                   The WeekendSZA
# 97024               75          The Weekend                   The WeekendSZA
# 97025               75          The Weekend                   The WeekendSZA
# 97026               72          The Weekend                   The WeekendSZA
# ...                ...                  ...                              ...
# 2305837             83  Young And Beautiful  Young And BeautifulLana Del Rey
# 2305838             83  Young And Beautiful  Young And BeautifulLana Del Rey
# 2305839             83  Young And Beautiful  Young And BeautifulLana Del Rey
# 2305840             83  Young And Beautiful  Young And BeautifulLana Del Rey
# 2305841             83  Young And Beautiful  Young And BeautifulLana Del Rey
#
#          ...  Previous Week Position  Peak Position  Weeks on Chart  Year  \
# 97022    ...                    89.0             75               2  2017
# 97023    ...                    89.0             75               2  2017
# 97024    ...                    75.0             75               3  2017
# 97025    ...                    75.0             75               3  2017
# 97026    ...                    75.0             72               4  2017
# ...      ...                     ...            ...             ...   ...
# 2305837  ...                    79.0             57              21  2013
# 2305838  ...                    79.0             57              21  2013
# 2305839  ...                    79.0             57              21  2013
# 2305840  ...                    79.0             57              21  2013
# 2305841  ...                    79.0             57              21  2013
#
#          Decade Explicit Song_Popularity  \
# 97022    2010's     True            78.0
# 97023    2010's     True            79.0
# 97024    2010's     True            78.0
# 97025    2010's     True            79.0
# 97026    2010's     True            78.0
# ...         ...      ...             ...
# 2305837  2010's    False            72.0
# 2305838  2010's    False            69.0
# 2305839  2010's    False             5.0
# 2305840  2010's    False            83.0
# 2305841  2010's    False            68.0
#
#                                                     Song_y Duration ms  \
# 97022                                          The Weekend    272186.0
# 97023                                        Broken Clocks    231253.0
# 97024                                          The Weekend    272186.0
# 97025                                        Broken Clocks    231253.0
# 97026                                          The Weekend    272186.0
# ...                                                    ...         ...
# 2305837                                      Ultraviolence    251480.0
# 2305838                                        Video Games    281960.0
# 2305839  Summertime Sadness (Lana Del Rey Vs. Cedric Ge...    214912.0
# 2305840                                Young And Beautiful    236053.0
# 2305841                                     Shades Of Cool    342093.0
#
#                                         uri_y
# 97022    spotify:track:6gU9OKjOE7ghfEd55oRO57
# 97023    spotify:track:2fXwCWkh6YG5zU1IyvQrbs
# 97024    spotify:track:6gU9OKjOE7ghfEd55oRO57
# 97025    spotify:track:2fXwCWkh6YG5zU1IyvQrbs
# 97026    spotify:track:6gU9OKjOE7ghfEd55oRO57
# ...                                       ...
# 2305837  spotify:track:1y3r6RXiJZNBV1EI0NggpS
# 2305838  spotify:track:24jvD83UgLmrdGjhWTFslY
# 2305839  spotify:track:5lu3zAHbQKwcCQRls0kxW8
# 2305840  spotify:track:2nMeu6UenVvwUktBCpLMK9
# 2305841  spotify:track:4VSg5K1hnbmIg4PwRdY6wV
#
# [234390 rows x 21 columns]

# %%
checkpoint['Duration m'] = peak_df['Duration ms']/1000/60
# Out:
# /var/folders/91/wchv5p25455f2k8078kdjvm40000gn/T/ipykernel_58709/1189127727.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   peak_df['Duration m'] = peak_df['Duration ms']/1000/60
#             Performer  Artist_Popularity    Performer2  \
# 97022             SZA               95.0           SZA
# 97023             SZA               95.0           SZA
# 97024             SZA               95.0           SZA
# 97025             SZA               95.0           SZA
# 97026             SZA               95.0           SZA
# ...               ...                ...           ...
# 2305837  Lana Del Rey               90.0  Lana Del Rey
# 2305838  Lana Del Rey               90.0  Lana Del Rey
# 2305839  Lana Del Rey               90.0  Lana Del Rey
# 2305840  Lana Del Rey               90.0  Lana Del Rey
# 2305841  Lana Del Rey               90.0  Lana Del Rey
#
#                                          uri_x               Genre  \
# 97022    spotify:artist:7tYKF4w9nC0nq9CsPZTHyP      ['pop', 'r&b']
# 97023    spotify:artist:7tYKF4w9nC0nq9CsPZTHyP      ['pop', 'r&b']
# 97024    spotify:artist:7tYKF4w9nC0nq9CsPZTHyP      ['pop', 'r&b']
# 97025    spotify:artist:7tYKF4w9nC0nq9CsPZTHyP      ['pop', 'r&b']
# 97026    spotify:artist:7tYKF4w9nC0nq9CsPZTHyP      ['pop', 'r&b']
# ...                                        ...                 ...
# 2305837  spotify:artist:00FQb4jTyendYWaN8pK0wa  ['art pop', 'pop']
# 2305838  spotify:artist:00FQb4jTyendYWaN8pK0wa  ['art pop', 'pop']
# 2305839  spotify:artist:00FQb4jTyendYWaN8pK0wa  ['art pop', 'pop']
# 2305840  spotify:artist:00FQb4jTyendYWaN8pK0wa  ['art pop', 'pop']
# 2305841  spotify:artist:00FQb4jTyendYWaN8pK0wa  ['art pop', 'pop']
#
#                                                        url     WeekID  \
# 97022    http://www.billboard.com/charts/hot-100/2017-0... 2017-08-26
# 97023    http://www.billboard.com/charts/hot-100/2017-0... 2017-08-26
# 97024    http://www.billboard.com/charts/hot-100/2017-0... 2017-09-02
# 97025    http://www.billboard.com/charts/hot-100/2017-0... 2017-09-02
# 97026    http://www.billboard.com/charts/hot-100/2017-0... 2017-09-09
# ...                                                    ...        ...
# 2305837  http://www.billboard.com/charts/hot-100/2013-1... 2013-10-12
# 2305838  http://www.billboard.com/charts/hot-100/2013-1... 2013-10-12
# 2305839  http://www.billboard.com/charts/hot-100/2013-1... 2013-10-12
# 2305840  http://www.billboard.com/charts/hot-100/2013-1... 2013-10-12
# 2305841  http://www.billboard.com/charts/hot-100/2013-1... 2013-10-12
#
#          Week Position               Song_x                           SongID  \
# 97022               75          The Weekend                   The WeekendSZA
# 97023               75          The Weekend                   The WeekendSZA
# 97024               75          The Weekend                   The WeekendSZA
# 97025               75          The Weekend                   The WeekendSZA
# 97026               72          The Weekend                   The WeekendSZA
# ...                ...                  ...                              ...
# 2305837             83  Young And Beautiful  Young And BeautifulLana Del Rey
# 2305838             83  Young And Beautiful  Young And BeautifulLana Del Rey
# 2305839             83  Young And Beautiful  Young And BeautifulLana Del Rey
# 2305840             83  Young And Beautiful  Young And BeautifulLana Del Rey
# 2305841             83  Young And Beautiful  Young And BeautifulLana Del Rey
#
#          ...  Peak Position  Weeks on Chart  Year  Decade  Explicit  \
# 97022    ...             75               2  2017  2010's      True
# 97023    ...             75               2  2017  2010's      True
# 97024    ...             75               3  2017  2010's      True
# 97025    ...             75               3  2017  2010's      True
# 97026    ...             72               4  2017  2010's      True
# ...      ...            ...             ...   ...     ...       ...
# 2305837  ...             57              21  2013  2010's     False
# 2305838  ...             57              21  2013  2010's     False
# 2305839  ...             57              21  2013  2010's     False
# 2305840  ...             57              21  2013  2010's     False
# 2305841  ...             57              21  2013  2010's     False
#
#         Song_Popularity                                             Song_y  \
# 97022              78.0                                        The Weekend
# 97023              79.0                                      Broken Clocks
# 97024              78.0                                        The Weekend
# 97025              79.0                                      Broken Clocks
# 97026              78.0                                        The Weekend
# ...                 ...                                                ...
# 2305837            72.0                                      Ultraviolence
# 2305838            69.0                                        Video Games
# 2305839             5.0  Summertime Sadness (Lana Del Rey Vs. Cedric Ge...
# 2305840            83.0                                Young And Beautiful
# 2305841            68.0                                     Shades Of Cool
#
#          Duration ms                                 uri_y  Duration m
# 97022       272186.0  spotify:track:6gU9OKjOE7ghfEd55oRO57    4.536433
# 97023       231253.0  spotify:track:2fXwCWkh6YG5zU1IyvQrbs    3.854217
# 97024       272186.0  spotify:track:6gU9OKjOE7ghfEd55oRO57    4.536433
# 97025       231253.0  spotify:track:2fXwCWkh6YG5zU1IyvQrbs    3.854217
# 97026       272186.0  spotify:track:6gU9OKjOE7ghfEd55oRO57    4.536433
# ...              ...                                   ...         ...
# 2305837     251480.0  spotify:track:1y3r6RXiJZNBV1EI0NggpS    4.191333
# 2305838     281960.0  spotify:track:24jvD83UgLmrdGjhWTFslY    4.699333
# 2305839     214912.0  spotify:track:5lu3zAHbQKwcCQRls0kxW8    3.581867
# 2305840     236053.0  spotify:track:2nMeu6UenVvwUktBCpLMK9    3.934217
# 2305841     342093.0  spotify:track:4VSg5K1hnbmIg4PwRdY6wV    5.701550
#
# [234390 rows x 22 columns]

# %%
genre_graph_100 = peak_df.plot(figsize=(20,10),
                             x= 'Decade',
                             y= 'Duration m',
                             title = 'Duration vs Artist Popularity',
                             xlabel = 'Duration',
                             ylabel = 'Artist Popularity',
                             kind = 'bar',
                             color = 'cadetblue',
                             edgecolor = 'black',
                             alpha = 0.8)
for bars in genre_graph_100.containers:
    genre_graph_100.bar_label(bars)
plt.xticks(rotation = 90);

# %%
time_df = peak_df.head(100)

# %%
genre_graph_100 = time_df.plot(figsize=(20,10),
                             x= 'Duration m',
                             y= 'Artist_Popularity',
                             title = 'Duration vs Artist Popularity',
                             xlabel = 'Duration',
                             ylabel = 'Artist Popularity',
                             kind = 'bar',
                             color = 'cadetblue',
                             edgecolor = 'black',
                             alpha = 0.8)
for bars in genre_graph_100.containers:
    genre_graph_100.bar_label(bars)
plt.xticks(rotation = 90);

# %%
peak_df = peak_df.drop_duplicates(subset = 'uri_x', keep = 'first')

# %%
peak_df = peak_df.head(20)
peak_df

# %%
peak_df = peak_df.sort_values('Artist_Popularity', ascending = False)

# %%
boxplot = sns.boxplot(data=peak_df, x = "Artist_Popularity", y = "Duration m")
plt.setp(boxplot.get_xticklabels(), rotation = 90)

# %%
merged_df2 = merged_df.drop_duplicates()
merged_df2

# %%
merged_df = merged_df2.sort_values('Artist_Popularity', ascending = False)
merged_df = pd.DataFrame(merged_df)
merged_df

# %%
merged_df = merged_df.explode(column = "Genre")
merged_df = merged_df.dropna()
merged_df

# %%
merged_df_final = merged_df.drop_duplicates(subset = 'uri_x', keep='first')
merged_df_final

# %%
merged_df_final['Genre'] = merged_df_final['Genre'].apply(literal_eval)
merged_df_final = merged_df_final.explode(column = "Genre")
merged_df_final = merged_df_final.dropna()
popular_genres = merged_df_final.sort_values('Genre',ascending = True)
popular_genres

# %%
merged_df_final_head = merged_df_final.head(20)

# %%
genre_graph_100 = merged_df_final_head.plot(figsize=(20,10),
                             x= 'Genre',
                             y= 'Artist_Popularity',
                             title = 'Genre vs Artist Popularity',
                             xlabel = 'Genre',
                             ylabel = 'Artist Popularity',
                             kind = 'barh',
                             color = 'cadetblue',
                             edgecolor = 'black',
                             alpha = 0.8)
for bars in genre_graph_100.containers:
    genre_graph_100.bar_label(bars)
plt.xticks(rotation = 90);

# %%
genre_graph_100 = merged_df.plot(figsize=(20,10),
                             x= 'Performer',
                             y= 'Artist_Popularity',
                             title = 'Performer vs Artist Popularity',
                             xlabel = 'Performer',
                             ylabel = 'Artist Popularity',
                             kind = 'barh',
                             color = 'cadetblue',
                             edgecolor = 'black',
                             alpha = 0.8)
for bars in genre_graph_100.containers:
    genre_graph_100.bar_label(bars)
plt.xticks(rotation = 90);

# %%
genre_graph_100 = merged_df.plot(figsize=(20,10),
                             x= 'Genre',
                             y= 'Artist_Popularity',
                             title = 'Genre vs Artist Popularity',
                             xlabel = 'Genre',
                             ylabel = 'Artist Popularity',
                             kind = 'scatter',
                             color = 'cadetblue',
                             edgecolor = 'black',
                             alpha = 0.8)
for bars in genre_graph_100.containers:
    genre_graph_100.bar_label(bars)
plt.xticks(rotation = 90);

# %%
genre_graph_100 = merged_df.plot(figsize=(20,10),
                             x= 'Genre',
                             y= 'Artist_Popularity',
                             title = 'Genre vs Artist Popularity',
                             xlabel = 'Genre',
                             ylabel = 'Artist Popularity',
                             kind = 'scatter',
                             color = 'cadetblue',
                             edgecolor = 'black',
                             alpha = 0.8)
for bars in genre_graph_100.containers:
    genre_graph_100.bar_label(bars)
plt.xticks(rotation = 90);

# %%
pop_genre = merged_df.loc[merged_df['Song_Popularity']>=0].sort_values(by = ['Genre'], ascending = False)
pop_genre

# %%
gen_df = pop_genre.groupby(['Genre'])['Song_Popularity'].max().reset_index()
gen_df

# %%
pop_genre = pop_genre.sort_values('Song_Popularity', ascending = False)
pop_genre

# %%
genre_graph_100 = pop_genre.plot(figsize=(20,10),
                             x= 'Genre',
                             y= 'Artist_Popularity',
                             title = 'Genre vs Artist Popularity',
                             xlabel = 'Genre',
                             ylabel = 'Artist Popularity',
                             kind = 'scatter',
                             color = 'cadetblue',
                             edgecolor = 'black',
                             alpha = 0.8)
for bars in genre_graph_100.containers:
    genre_graph_100.bar_label(bars)
plt.xticks(rotation = 90);

# %% [markdown]
# # 1960

# %%
merged_df_1960 = merged_df.drop(columns=['Performer', 'Artist_Popularity', 'Performer2', 'uri_x', 'url', 'WeekID', 'Week Position', 'Song_x', 'SongID', 'Instance', 'Previous Week Position', 'Peak Position', 'Weeks on Chart', 'Song_Popularity', 'Song_y', 'Duration ms', 'uri_y'] )
merged_df_1960 = merged_df_1960.loc[merged_df_1960['Year']>=1960].loc[merged_df_1960['Year']<=1969].sort_values(by = ['Explicit', 'Genre'], ascending = False).head(20)
merged_df_1960

# %% [markdown]
# # 1970

# %%
merged_df = merged_df.loc[merged_df['Genre']!='edm']

# %%
merged_df_1970 = merged_df.drop(columns=['Performer', 'Artist_Popularity', 'Performer2', 'uri_x', 'url', 'WeekID', 'Week Position', 'Song_x', 'SongID', 'Instance', 'Previous Week Position', 'Peak Position', 'Weeks on Chart', 'Song_Popularity', 'Song_y', 'Duration ms', 'uri_y'] )
merged_df_1970 = merged_df_1970.loc[merged_df_1970['Year']>=1970].loc[merged_df_1970['Year']<=1979].sort_values(by = ['Explicit', 'Genre'], ascending = False).head(20)
merged_df_1970

# %%
merged_df_1980 = merged_df.drop(columns=['Performer', 'Artist_Popularity', 'Performer2', 'uri_x', 'url', 'WeekID', 'Week Position', 'Song_x', 'SongID', 'Instance', 'Previous Week Position', 'Peak Position', 'Weeks on Chart', 'Song_Popularity', 'Song_y', 'Duration ms', 'uri_y'] )
merged_df_1980 = merged_df_1980.loc[merged_df_1980['Year']>=1980].loc[merged_df_1980['Year']<=1989].sort_values(by = ['Explicit', 'Genre'], ascending = False).head(20)
merged_df_1980

# %% [markdown]
# # 1980

# %%
merged_df_1980 = merged_df.drop(columns=['Performer', 'Artist_Popularity', 'Performer2', 'uri_x', 'url', 'WeekID', 'Week Position', 'Song_x', 'SongID', 'Instance', 'Previous Week Position', 'Peak Position', 'Weeks on Chart', 'Song_Popularity', 'Song_y', 'Duration ms', 'uri_y'] )
merged_df_1980 = merged_df_1980.loc[merged_df_1980['Year']>=1980].loc[merged_df_1980['Year']<=1989].sort_values(by = ['Explicit', 'Genre'], ascending = False).head(20)
merged_df_1980

# %% [markdown]
# # 1990

# %%
merged_df = merged_df.loc[merged_df['Genre']!='viral rap']

# %%
merged_df_1990 = merged_df.drop(columns=['Performer', 'Artist_Popularity', 'Performer2', 'uri_x', 'url', 'WeekID', 'Week Position', 'Song_x', 'SongID', 'Instance', 'Previous Week Position', 'Peak Position', 'Weeks on Chart', 'Song_Popularity', 'Song_y', 'Duration ms', 'uri_y'] )
merged_df_1990 = merged_df_1990.loc[merged_df_1990['Year']>=1990].loc[merged_df_1990['Year']<=1999].sort_values(by = ['Explicit', 'Genre'], ascending = False).head(20)
merged_df_1990

# %% [markdown]
# # 2000

# %%
merged_df_2000 = merged_df.drop(columns=['Performer', 'Artist_Popularity', 'Performer2', 'uri_x', 'url', 'WeekID', 'Week Position', 'Song_x', 'SongID', 'Instance', 'Previous Week Position', 'Peak Position', 'Weeks on Chart', 'Song_Popularity', 'Song_y', 'Duration ms', 'uri_y'] )
merged_df_2000 = merged_df_2000.loc[merged_df_2000['Year']>=2000].loc[merged_df_2000['Year']<=2009].sort_values(by = ['Explicit', 'Genre'], ascending = False).head(20)
merged_df_2000

# %% [markdown]
# # 2010

# %%
merged_df_2010 = merged_df.drop(columns=['Performer', 'Artist_Popularity', 'Performer2', 'uri_x', 'url', 'WeekID', 'Week Position', 'Song_x', 'SongID', 'Instance', 'Previous Week Position', 'Peak Position', 'Weeks on Chart', 'Song_Popularity', 'Song_y', 'Duration ms', 'uri_y'] )
merged_df_2010 = merged_df_2010.loc[merged_df_2010['Year']>=2010].loc[merged_df_2010['Year']<=2022].sort_values(by = ['Explicit', 'Genre'], ascending = False).head(20)
merged_df_2010

# %%
merged_df['Year'] = pd.to_numeric(merged_df['Year'])
merged_df['Genre'] = merged_df['Genre'].apply(literal_eval)
merged_df

# %% [markdown]
# # most popular artists debuted in 70s

# %%
merged_df.loc[merged_df ['Year'] < 1970].loc[merged_df['Artist_Popularity'] >= 75]
merged_df

# %%
merged_df = merged_df.loc[merged_df['Performer']!='M']
merged_df = merged_df.loc[merged_df['Performer']!='Malo']
merged_df = merged_df.loc[merged_df['Performer']!='Ocean']
merged_df = merged_df.loc[merged_df['Performer']!='Q']
merged_df = merged_df.loc[merged_df['Performer']!='Machine']
merged_df = merged_df.loc[merged_df['Performer']!='Pilot']
min_df = merged_df.groupby(['Performer', 'Artist_Popularity'])['Year'].min().reset_index()
min_df

# %%
min_df = merged_df.groupby(['Performer', 'Artist_Popularity'])['Year'].min().reset_index()
min_df

# %%
merged_df.loc[merged_df['Performer']=='Pilot']

# %%
min_df = merged_df.groupby(['Genre', 'Explicit'])['Year'].min().reset_index()
min_df

# %% [markdown]
# # 1970

# %% [markdown]
# # Explicit 1970

# %%
merged_df.loc[merged_df['Year']>=1970].loc[merged_df['Year']<=1979]

# %%
min_df.sort_values(['Genre', 'Explicit', 'Year'])

# %%
min_df = min_df.value_counts(['Genre', 'Explicit'])
min_df = pd.DataFrame(min_df)
min_df = min_df.head(20)
min_df

# %%
merged_df = merged_df.loc[merged_df['Performer']!='Mina']
merged_df = merged_df.loc[merged_df['Performer']!='Oliver']
min_df = merged_df.groupby(['Performer', 'Artist_Popularity'])['Year'].min().reset_index()

# %%
merged_df.loc[merged_df['Performer']=='Oliver']

# %% [markdown]
# # 1960s

# %%
min_df.loc[min_df['Year']>=1960].loc[min_df['Year']<=1969].sort_values('Artist_Popularity', ascending = False).head(5)

# %%
merged_df = merged_df.loc[merged_df['Performer']!='Junior']
merged_df=merged_df.loc[merged_df['Performer']!='Chris Christian']
min_df = merged_df.groupby(['Performer', 'Artist_Popularity'])['Year'].min().reset_index()

# %%
merged_df.loc[merged_df['Performer']=='Chris Christian']

# %%
merged_df = merged_df.sort_values('Artist_Popularity')
merged_df = merged_df.drop_duplicates()
merged_df = merged_df.head(100)
merged_df

# %%
min_df.loc[min_df['Year']>=1960].loc[min_df['Year']<=1969].sort_values('Explicit', ascending = False)

# %% [markdown]
# # 1980s

# %%
min_df.loc[min_df['Year']>=1980].loc[min_df['Year']<=1989].sort_values('Artist_Popularity', ascending = False).head(5)

# %%
merged_df = merged_df.loc[merged_df['Performer']!='Five']
merged_df = merged_df.loc[merged_df['Performer']!='Link']
min_df = merged_df.groupby(['Performer', 'Artist_Popularity'])['Year'].min().reset_index()

# %%
min_df.loc[merged_df['Performer']=='Link']

# %% [markdown]
# # 1990s

# %%
min_df.loc[min_df['Year']>=1990].loc[min_df['Year']<=1999].sort_values('Artist_Popularity', ascending = False).head(5)

# %% [markdown]
# # 2000s

# %%
min_df.loc[min_df['Year']>=2000].loc[min_df['Year']<=2009].sort_values('Artist_Popularity', ascending = False).head(5)

# %% [markdown]
# # 2010s

# %%
min_df.loc[min_df['Year']>=2010].loc[min_df['Year']<=2021].sort_values('Artist_Popularity', ascending = False).head(5)

# %%
genre_graph_100 = merged_df.plot(figsize=(20,10),
                             x= 'Genre',
                             y= 'Artist_Popularity',
                             title = 'Duration vs Artist Popularity',
                             xlabel = 'Duration ms',
                             ylabel = 'Artist Popularity',
                             kind = 'scatter',
                             color = 'cadetblue',
                             edgecolor = 'black',
                             alpha = 0.8)
for bars in genre_graph_100.containers:
    genre_graph_100.bar_label(bars)
plt.xticks(rotation = 90);

# %%
merged_df['Duration s'] = merged_df['Duration ms']/1000
merged_df

# %%
merged_df['Genre'] = merged_df['Genre'].apply(literal_eval)

# %%
merged_df = merged_df.explode(column = "Genre")
merged_df = merged_df.dropna()

# %%
popular_genres = merged_df['Genre'].value_counts().head(20).index.to_list()

# %%
merged_df['WeekID'] = pd.to_datetime(merged_df['WeekID'])

# %%
merged_df = merged_df.sort_values('WeekID')

# %%
merged_df = merged_df.drop_duplicates(subset = 'uri', keep='first')
merged_df

# %%
merged_df['Year'] = merged_df['WeekID'].dt.year
merged_df

# %%
merged_df.loc[merged_df ['Year'] < 1960].loc[merged_df['Artist_Popularity'] >= 75]

# %% [markdown]
# # release_date genre

# %%
merged_df.explode(column = 'Genre')

# %%
merged_df = merged_df.explode(column = 'Genre')

# %%
genre_df_2010 =genre_df[genre_df['Year'] >= 2010]['Genre'].value_counts()
pd.DataFrame(genre_df_2010)

# %%
genre_df = genre_df.sort_values('Year',ascending = False)

# %%
genre_df = genre_df.head(250)

# %%
genre_graph_100 = genre_df.plot(figsize=(20,10),
                             x= 'Genre',
                             y= 'Year',
                             title = 'Genre vs Year',
                             xlabel = 'Song Popularity',
                             ylabel = 'Year',
                             kind = 'scatter',
                             color = 'cadetblue',
                             edgecolor = 'black',
                             alpha = 0.8)
for bars in genre_graph_100.containers:
    genre_graph_100.bar_label(bars)
plt.xticks(rotation = 90);
