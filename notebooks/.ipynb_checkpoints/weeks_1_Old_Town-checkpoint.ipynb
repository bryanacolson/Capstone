# %%
# import packages

# %%
from pandas.io.json import json_normalize
import json
from pandasql import sqldf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from bs4 import BeautifulSoup
import io
import requests
import json
import base64
import datetime
from urllib.parse import urlencode

# %%
# client id

# %%
client_id = '6e24789ec7874259a220f747fcd7e93e'
client_secret = '9bd8ff1ad2f34ef6a87f00124be070b2'

# %%
class SpotifyAPI(object):
    access_token = None
    access_token_expires = datetime.datetime.now()
    access_token_did_expire = True
    client_id = None
    client_secret = None
    token_url = "https://accounts.spotify.com/api/token"



    def __init__(self, client_id, client_secret, *args, **kwargs):
        super().__init__(*args, **kwargs)
        self.client_id = client_id
        self.client_secret = client_secret

    def getClientCreds(self):
        '''Returns b64 encoded string'''
        client_id = self.client_id
        client_secret = self.client_secret

        if client_id == None or client_secret == None:
            raise Exception('Must set a client id and secret')

        client_creds  = f"{client_id}:{client_secret}"
        client_creds_b64 = base64.b64encode(client_creds.encode())
        return client_creds_b64.decode()

    def getTokenHeader(self):
        client_creds_b64 = self.getClientCreds()
        return {
            'Authorization':f"Basic {client_creds_b64}"
        }

    def getTokenData(self):
        return {
            "grant_type":"client_credentials"
        }

    def perform_auth(self):
        token_url = self.token_url
        token_data = self.getTokenData()
        token_header = self.getTokenHeader()

        r = requests.post(token_url, data=token_data, headers=token_header)

        if r.status_code  not in range(200,299):
            raise Exception('Could not authenticate client.')
            #return False

        now = datetime.datetime.now()
        token_response_data = r.json()
        access_token = token_response_data['access_token']
        expires_in = token_response_data['expires_in']
        expires = now + datetime.timedelta(seconds=expires_in)
        self.access_token = access_token
        self.access_token_expires = expires
        self.access_token_did_expire = expires < now


        return True

    def get_access_token(self):
        token = self.access_token
        expires = self.access_token_expires
        now= datetime.datetime.now()
        if expires < now:
            self.perform_auth()
            return self.get_access_token()
        elif token == None:
            self.perform_auth()
            return self.get_access_token() 
        return token
    
    def get_resource_header(self):
        access_token = self.get_access_token()
        headers = {
            "Authorization": f"Bearer {access_token}", 
        }
        return headers
    
    def get_resource(self, lookup_id, resource_type='albums', version='v1'):
        endpoint = f'https://api.spotify.com/{version}/{resource_type}/{lookup_id}'
        headers = self.get_resource_header()
        r = requests.get(endpoint, headers = headers)
        if r.status_code not in range (200, 299):
            return {}
        return r.json()
    
    def get_album(self, _id ):
        return self.get_resource(_id, resource_type='albums')
    
    def get_artist(self, _id ):
        return self.get_resource(_id, resource_type='artists')
    
    def get_playlist(self, _id):
        return self.get_resource(_id, resource_type='playlists')
    
    
    def base_search(self, query_params): #type
        access_token = self.get_access_token()
        headers = self.get_resource_header()
        endpoint = "https://api.spotify.com/v1/search"
        lookup_URL = f"{endpoint}?{query_params}"
        r = requests.get(lookup_URL, headers=headers)
        if r.status_code not in range (200, 299):
            return {}
        return r.json()
    
    def search(self, query=None, operator=None, operator_query=None, search_type='artist'):
        if query == None:
            raise Exception('A query is required')
        if isinstance(query, dict):
            query = ' '.join([f'{k}:{v}' for k,v in query.items()])
        if operator != None and operator_query != None:
            if operator.lower() == 'or' or operator.lower() == 'not':
                operator = operator.upper()
                if isinstance(operator_query, str):
                    query = f'{query} {operator} {operator_query}'
        query_params = urlencode({'q': query, 'type': search_type.lower()})
        return self.base_search(query_params)

# %%
spotify = SpotifyAPI(client_id, client_secret)

# %%
# radioactive

# %%
radioactive = spotify.search({'track': 'Old Town Road', 'artist': 'Lil'}, search_type ='track')
radioactive
# Out:
# {'tracks': {'href': 'https://api.spotify.com/v1/search?query=track%3AOld+Town+Road+artist%3ALil&type=track&offset=0&limit=20',
#   'items': [{'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7jVv8c5Fj3E9VhNjxT4snq'},
#        'href': 'https://api.spotify.com/v1/artists/7jVv8c5Fj3E9VhNjxT4snq',
#        'id': '7jVv8c5Fj3E9VhNjxT4snq',
#        'name': 'Lil Nas X',
#        'type': 'artist',
#        'uri': 'spotify:artist:7jVv8c5Fj3E9VhNjxT4snq'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4IRiXE5NROxknUSAUSjMoO'},
#      'href': 'https://api.spotify.com/v1/albums/4IRiXE5NROxknUSAUSjMoO',
#      'id': '4IRiXE5NROxknUSAUSjMoO',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273c0e7bf5cdd630f314f20586a',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02c0e7bf5cdd630f314f20586a',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851c0e7bf5cdd630f314f20586a',
#        'width': 64}],
#      'name': '7 EP',
#      'release_date': '2019-06-21',
#      'release_date_precision': 'day',
#      'total_tracks': 8,
#      'type': 'album',
#      'uri': 'spotify:album:4IRiXE5NROxknUSAUSjMoO'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7jVv8c5Fj3E9VhNjxT4snq'},
#       'href': 'https://api.spotify.com/v1/artists/7jVv8c5Fj3E9VhNjxT4snq',
#       'id': '7jVv8c5Fj3E9VhNjxT4snq',
#       'name': 'Lil Nas X',
#       'type': 'artist',
#       'uri': 'spotify:artist:7jVv8c5Fj3E9VhNjxT4snq'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/60rpJ9SgigSd16DOAG7GSa'},
#       'href': 'https://api.spotify.com/v1/artists/60rpJ9SgigSd16DOAG7GSa',
#       'id': '60rpJ9SgigSd16DOAG7GSa',
#       'name': 'Billy Ray Cyrus',
#       'type': 'artist',
#       'uri': 'spotify:artist:60rpJ9SgigSd16DOAG7GSa'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 157066,
#     'explicit': False,
#     'external_ids': {'isrc': 'USSM11902498'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/2YpeDb67231RjR0MgVLzsG'},
#     'href': 'https://api.spotify.com/v1/tracks/2YpeDb67231RjR0MgVLzsG',
#     'id': '2YpeDb67231RjR0MgVLzsG',
#     'is_local': False,
#     'name': 'Old Town Road - Remix',
#     'popularity': 78,
#     'preview_url': 'https://p.scdn.co/mp3-preview/b1b4f28e5b4fc6791db78234435a20a7704c7774?cid=6e24789ec7874259a220f747fcd7e93e',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:2YpeDb67231RjR0MgVLzsG'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7jVv8c5Fj3E9VhNjxT4snq'},
#        'href': 'https://api.spotify.com/v1/artists/7jVv8c5Fj3E9VhNjxT4snq',
#        'id': '7jVv8c5Fj3E9VhNjxT4snq',
#        'name': 'Lil Nas X',
#        'type': 'artist',
#        'uri': 'spotify:artist:7jVv8c5Fj3E9VhNjxT4snq'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4IRiXE5NROxknUSAUSjMoO'},
#      'href': 'https://api.spotify.com/v1/albums/4IRiXE5NROxknUSAUSjMoO',
#      'id': '4IRiXE5NROxknUSAUSjMoO',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273c0e7bf5cdd630f314f20586a',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02c0e7bf5cdd630f314f20586a',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851c0e7bf5cdd630f314f20586a',
#        'width': 64}],
#      'name': '7 EP',
#      'release_date': '2019-06-21',
#      'release_date_precision': 'day',
#      'total_tracks': 8,
#      'type': 'album',
#      'uri': 'spotify:album:4IRiXE5NROxknUSAUSjMoO'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7jVv8c5Fj3E9VhNjxT4snq'},
#       'href': 'https://api.spotify.com/v1/artists/7jVv8c5Fj3E9VhNjxT4snq',
#       'id': '7jVv8c5Fj3E9VhNjxT4snq',
#       'name': 'Lil Nas X',
#       'type': 'artist',
#       'uri': 'spotify:artist:7jVv8c5Fj3E9VhNjxT4snq'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 113000,
#     'explicit': False,
#     'external_ids': {'isrc': 'USSM11901941'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0F7FA14euOIX8KcbEturGH'},
#     'href': 'https://api.spotify.com/v1/tracks/0F7FA14euOIX8KcbEturGH',
#     'id': '0F7FA14euOIX8KcbEturGH',
#     'is_local': False,
#     'name': 'Old Town Road',
#     'popularity': 76,
#     'preview_url': 'https://p.scdn.co/mp3-preview/614acab009c3c05b3e21c63cfe9d274c22c5b509?cid=6e24789ec7874259a220f747fcd7e93e',
#     'track_number': 8,
#     'type': 'track',
#     'uri': 'spotify:track:0F7FA14euOIX8KcbEturGH'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7jVv8c5Fj3E9VhNjxT4snq'},
#        'href': 'https://api.spotify.com/v1/artists/7jVv8c5Fj3E9VhNjxT4snq',
#        'id': '7jVv8c5Fj3E9VhNjxT4snq',
#        'name': 'Lil Nas X',
#        'type': 'artist',
#        'uri': 'spotify:artist:7jVv8c5Fj3E9VhNjxT4snq'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/2auC28zjQyVTsiZKNgPRGs'},
#        'href': 'https://api.spotify.com/v1/artists/2auC28zjQyVTsiZKNgPRGs',
#        'id': '2auC28zjQyVTsiZKNgPRGs',
#        'name': 'RM',
#        'type': 'artist',
#        'uri': 'spotify:artist:2auC28zjQyVTsiZKNgPRGs'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/3Nrfpe0tUJi4K4DXYWgMUX'},
#        'href': 'https://api.spotify.com/v1/artists/3Nrfpe0tUJi4K4DXYWgMUX',
#        'id': '3Nrfpe0tUJi4K4DXYWgMUX',
#        'name': 'BTS',
#        'type': 'artist',
#        'uri': 'spotify:artist:3Nrfpe0tUJi4K4DXYWgMUX'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/7CQho9XJ69KLTUdM9vUZyW'},
#      'href': 'https://api.spotify.com/v1/albums/7CQho9XJ69KLTUdM9vUZyW',
#      'id': '7CQho9XJ69KLTUdM9vUZyW',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2738d9ae1d1c51889c9f7d15048',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e028d9ae1d1c51889c9f7d15048',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048518d9ae1d1c51889c9f7d15048',
#        'width': 64}],
#      'name': 'Old Town Road (feat. RM of BTS) [Seoul Town Road Remix]',
#      'release_date': '2019-07-24',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:7CQho9XJ69KLTUdM9vUZyW'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7jVv8c5Fj3E9VhNjxT4snq'},
#       'href': 'https://api.spotify.com/v1/artists/7jVv8c5Fj3E9VhNjxT4snq',
#       'id': '7jVv8c5Fj3E9VhNjxT4snq',
#       'name': 'Lil Nas X',
#       'type': 'artist',
#       'uri': 'spotify:artist:7jVv8c5Fj3E9VhNjxT4snq'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/2auC28zjQyVTsiZKNgPRGs'},
#       'href': 'https://api.spotify.com/v1/artists/2auC28zjQyVTsiZKNgPRGs',
#       'id': '2auC28zjQyVTsiZKNgPRGs',
#       'name': 'RM',
#       'type': 'artist',
#       'uri': 'spotify:artist:2auC28zjQyVTsiZKNgPRGs'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/3Nrfpe0tUJi4K4DXYWgMUX'},
#       'href': 'https://api.spotify.com/v1/artists/3Nrfpe0tUJi4K4DXYWgMUX',
#       'id': '3Nrfpe0tUJi4K4DXYWgMUX',
#       'name': 'BTS',
#       'type': 'artist',
#       'uri': 'spotify:artist:3Nrfpe0tUJi4K4DXYWgMUX'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 114133,
#     'explicit': False,
#     'external_ids': {'isrc': 'USSM11904830'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6woeVu3fVMflqen1t4N6pg'},
#     'href': 'https://api.spotify.com/v1/tracks/6woeVu3fVMflqen1t4N6pg',
#     'id': '6woeVu3fVMflqen1t4N6pg',
#     'is_local': False,
#     'name': 'Old Town Road (feat. RM of BTS) - Seoul Town Road Remix',
#     'popularity': 66,
#     'preview_url': 'https://p.scdn.co/mp3-preview/562c379bb78312ab7f1c069cd87dd9337d477b58?cid=6e24789ec7874259a220f747fcd7e93e',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:6woeVu3fVMflqen1t4N6pg'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7jVv8c5Fj3E9VhNjxT4snq'},
#        'href': 'https://api.spotify.com/v1/artists/7jVv8c5Fj3E9VhNjxT4snq',
#        'id': '7jVv8c5Fj3E9VhNjxT4snq',
#        'name': 'Lil Nas X',
#        'type': 'artist',
#        'uri': 'spotify:artist:7jVv8c5Fj3E9VhNjxT4snq'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/60rpJ9SgigSd16DOAG7GSa'},
#        'href': 'https://api.spotify.com/v1/artists/60rpJ9SgigSd16DOAG7GSa',
#        'id': '60rpJ9SgigSd16DOAG7GSa',
#        'name': 'Billy Ray Cyrus',
#        'type': 'artist',
#        'uri': 'spotify:artist:60rpJ9SgigSd16DOAG7GSa'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/6xvpfMjWTougrRRtK7iikz'},
#        'href': 'https://api.spotify.com/v1/artists/6xvpfMjWTougrRRtK7iikz',
#        'id': '6xvpfMjWTougrRRtK7iikz',
#        'name': 'Mason Ramsey',
#        'type': 'artist',
#        'uri': 'spotify:artist:6xvpfMjWTougrRRtK7iikz'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/0ycVaTFV4Me1jr7wM9Zqip'},
#      'href': 'https://api.spotify.com/v1/albums/0ycVaTFV4Me1jr7wM9Zqip',
#      'id': '0ycVaTFV4Me1jr7wM9Zqip',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27379216e7558b3ec2b12273d79',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0279216e7558b3ec2b12273d79',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485179216e7558b3ec2b12273d79',
#        'width': 64}],
#      'name': 'Old Town Road (Remix)',
#      'release_date': '2019-07-12',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:0ycVaTFV4Me1jr7wM9Zqip'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7jVv8c5Fj3E9VhNjxT4snq'},
#       'href': 'https://api.spotify.com/v1/artists/7jVv8c5Fj3E9VhNjxT4snq',
#       'id': '7jVv8c5Fj3E9VhNjxT4snq',
#       'name': 'Lil Nas X',
#       'type': 'artist',
#       'uri': 'spotify:artist:7jVv8c5Fj3E9VhNjxT4snq'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/60rpJ9SgigSd16DOAG7GSa'},
#       'href': 'https://api.spotify.com/v1/artists/60rpJ9SgigSd16DOAG7GSa',
#       'id': '60rpJ9SgigSd16DOAG7GSa',
#       'name': 'Billy Ray Cyrus',
#       'type': 'artist',
#       'uri': 'spotify:artist:60rpJ9SgigSd16DOAG7GSa'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/6xvpfMjWTougrRRtK7iikz'},
#       'href': 'https://api.spotify.com/v1/artists/6xvpfMjWTougrRRtK7iikz',
#       'id': '6xvpfMjWTougrRRtK7iikz',
#       'name': 'Mason Ramsey',
#       'type': 'artist',
#       'uri': 'spotify:artist:6xvpfMjWTougrRRtK7iikz'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/50co4Is1HCEo8bhOyUWKpn'},
#       'href': 'https://api.spotify.com/v1/artists/50co4Is1HCEo8bhOyUWKpn',
#       'id': '50co4Is1HCEo8bhOyUWKpn',
#       'name': 'Young Thug',
#       'type': 'artist',
#       'uri': 'spotify:artist:50co4Is1HCEo8bhOyUWKpn'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 171293,
#     'explicit': False,
#     'external_ids': {'isrc': 'USSM11904496'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6jmZlyf9DxcIoRrjw02YXm'},
#     'href': 'https://api.spotify.com/v1/tracks/6jmZlyf9DxcIoRrjw02YXm',
#     'id': '6jmZlyf9DxcIoRrjw02YXm',
#     'is_local': False,
#     'name': 'Old Town Road - Remix',
#     'popularity': 53,
#     'preview_url': 'https://p.scdn.co/mp3-preview/121d2a949eb20cf5670a8dd90c7d323dc7569eff?cid=6e24789ec7874259a220f747fcd7e93e',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:6jmZlyf9DxcIoRrjw02YXm'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7jVv8c5Fj3E9VhNjxT4snq'},
#        'href': 'https://api.spotify.com/v1/artists/7jVv8c5Fj3E9VhNjxT4snq',
#        'id': '7jVv8c5Fj3E9VhNjxT4snq',
#        'name': 'Lil Nas X',
#        'type': 'artist',
#        'uri': 'spotify:artist:7jVv8c5Fj3E9VhNjxT4snq'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/60rpJ9SgigSd16DOAG7GSa'},
#        'href': 'https://api.spotify.com/v1/artists/60rpJ9SgigSd16DOAG7GSa',
#        'id': '60rpJ9SgigSd16DOAG7GSa',
#        'name': 'Billy Ray Cyrus',
#        'type': 'artist',
#        'uri': 'spotify:artist:60rpJ9SgigSd16DOAG7GSa'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/5fMUXHkw8R8eOP2RNVYEZX'},
#        'href': 'https://api.spotify.com/v1/artists/5fMUXHkw8R8eOP2RNVYEZX',
#        'id': '5fMUXHkw8R8eOP2RNVYEZX',
#        'name': 'Diplo',
#        'type': 'artist',
#        'uri': 'spotify:artist:5fMUXHkw8R8eOP2RNVYEZX'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/66FxETmTBazRMZNbvGtGQl'},
#      'href': 'https://api.spotify.com/v1/albums/66FxETmTBazRMZNbvGtGQl',
#      'id': '66FxETmTBazRMZNbvGtGQl',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2739a64ba0457f1ae04b525e6d9',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e029a64ba0457f1ae04b525e6d9',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048519a64ba0457f1ae04b525e6d9',
#        'width': 64}],
#      'name': 'Old Town Road (Diplo Remix)',
#      'release_date': '2019-04-29',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:66FxETmTBazRMZNbvGtGQl'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7jVv8c5Fj3E9VhNjxT4snq'},
#       'href': 'https://api.spotify.com/v1/artists/7jVv8c5Fj3E9VhNjxT4snq',
#       'id': '7jVv8c5Fj3E9VhNjxT4snq',
#       'name': 'Lil Nas X',
#       'type': 'artist',
#       'uri': 'spotify:artist:7jVv8c5Fj3E9VhNjxT4snq'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/60rpJ9SgigSd16DOAG7GSa'},
#       'href': 'https://api.spotify.com/v1/artists/60rpJ9SgigSd16DOAG7GSa',
#       'id': '60rpJ9SgigSd16DOAG7GSa',
#       'name': 'Billy Ray Cyrus',
#       'type': 'artist',
#       'uri': 'spotify:artist:60rpJ9SgigSd16DOAG7GSa'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/5fMUXHkw8R8eOP2RNVYEZX'},
#       'href': 'https://api.spotify.com/v1/artists/5fMUXHkw8R8eOP2RNVYEZX',
#       'id': '5fMUXHkw8R8eOP2RNVYEZX',
#       'name': 'Diplo',
#       'type': 'artist',
#       'uri': 'spotify:artist:5fMUXHkw8R8eOP2RNVYEZX'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 204026,
#     'explicit': False,
#     'external_ids': {'isrc': 'USSM11902898'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3kgKVcBpBGuSeaEC0AZGlb'},
#     'href': 'https://api.spotify.com/v1/tracks/3kgKVcBpBGuSeaEC0AZGlb',
#     'id': '3kgKVcBpBGuSeaEC0AZGlb',
#     'is_local': False,
#     'name': 'Old Town Road - Diplo Remix',
#     'popularity': 59,
#     'preview_url': 'https://p.scdn.co/mp3-preview/b195ae0f4f2728e4aad768954644b5a60833713d?cid=6e24789ec7874259a220f747fcd7e93e',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:3kgKVcBpBGuSeaEC0AZGlb'},
#    {'album': {'album_type': 'compilation',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#        'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#        'id': '0LyfQWJT6nXafLPZqxe9Of',
#        'name': 'Various Artists',
#        'type': 'artist',
#        'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#      'available_markets': ['US'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/6Xo8vxClsqZvYUXCgPuEcB'},
#      'href': 'https://api.spotify.com/v1/albums/6Xo8vxClsqZvYUXCgPuEcB',
#      'id': '6Xo8vxClsqZvYUXCgPuEcB',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27351c0a111cfc77a27116e1d1a',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0251c0a111cfc77a27116e1d1a',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485151c0a111cfc77a27116e1d1a',
#        'width': 64}],
#      'name': "NOW That's What I Call Music, Vol. 71",
#      'release_date': '2019-08-02',
#      'release_date_precision': 'day',
#      'total_tracks': 20,
#      'type': 'album',
#      'uri': 'spotify:album:6Xo8vxClsqZvYUXCgPuEcB'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7jVv8c5Fj3E9VhNjxT4snq'},
#       'href': 'https://api.spotify.com/v1/artists/7jVv8c5Fj3E9VhNjxT4snq',
#       'id': '7jVv8c5Fj3E9VhNjxT4snq',
#       'name': 'Lil Nas X',
#       'type': 'artist',
#       'uri': 'spotify:artist:7jVv8c5Fj3E9VhNjxT4snq'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/60rpJ9SgigSd16DOAG7GSa'},
#       'href': 'https://api.spotify.com/v1/artists/60rpJ9SgigSd16DOAG7GSa',
#       'id': '60rpJ9SgigSd16DOAG7GSa',
#       'name': 'Billy Ray Cyrus',
#       'type': 'artist',
#       'uri': 'spotify:artist:60rpJ9SgigSd16DOAG7GSa'}],
#     'available_markets': ['US'],
#     'disc_number': 1,
#     'duration_ms': 155386,
#     'explicit': False,
#     'external_ids': {'isrc': 'USSM11902498'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6zpiwiexX8HpFCZLyIWKDv'},
#     'href': 'https://api.spotify.com/v1/tracks/6zpiwiexX8HpFCZLyIWKDv',
#     'id': '6zpiwiexX8HpFCZLyIWKDv',
#     'is_local': False,
#     'name': 'Old Town Road (feat. Billy Ray Cyrus) - Remix',
#     'popularity': 35,
#     'preview_url': 'https://p.scdn.co/mp3-preview/d8bc2293391ccd43e56c19f56557eaed1093941a?cid=6e24789ec7874259a220f747fcd7e93e',
#     'track_number': 7,
#     'type': 'track',
#     'uri': 'spotify:track:6zpiwiexX8HpFCZLyIWKDv'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5fMUXHkw8R8eOP2RNVYEZX'},
#        'href': 'https://api.spotify.com/v1/artists/5fMUXHkw8R8eOP2RNVYEZX',
#        'id': '5fMUXHkw8R8eOP2RNVYEZX',
#        'name': 'Diplo',
#        'type': 'artist',
#        'uri': 'spotify:artist:5fMUXHkw8R8eOP2RNVYEZX'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2Om5VEKaBd4Afht33ToQGD'},
#      'href': 'https://api.spotify.com/v1/albums/2Om5VEKaBd4Afht33ToQGD',
#      'id': '2Om5VEKaBd4Afht33ToQGD',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273d79c10cdf4a58309a37d195a',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02d79c10cdf4a58309a37d195a',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851d79c10cdf4a58309a37d195a',
#        'width': 64}],
#      'name': 'Diplo Presents Thomas Wesley Chapter 1: Snake Oil',
#      'release_date': '2020-05-29',
#      'release_date_precision': 'day',
#      'total_tracks': 12,
#      'type': 'album',
#      'uri': 'spotify:album:2Om5VEKaBd4Afht33ToQGD'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7jVv8c5Fj3E9VhNjxT4snq'},
#       'href': 'https://api.spotify.com/v1/artists/7jVv8c5Fj3E9VhNjxT4snq',
#       'id': '7jVv8c5Fj3E9VhNjxT4snq',
#       'name': 'Lil Nas X',
#       'type': 'artist',
#       'uri': 'spotify:artist:7jVv8c5Fj3E9VhNjxT4snq'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/60rpJ9SgigSd16DOAG7GSa'},
#       'href': 'https://api.spotify.com/v1/artists/60rpJ9SgigSd16DOAG7GSa',
#       'id': '60rpJ9SgigSd16DOAG7GSa',
#       'name': 'Billy Ray Cyrus',
#       'type': 'artist',
#       'uri': 'spotify:artist:60rpJ9SgigSd16DOAG7GSa'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/5fMUXHkw8R8eOP2RNVYEZX'},
#       'href': 'https://api.spotify.com/v1/artists/5fMUXHkw8R8eOP2RNVYEZX',
#       'id': '5fMUXHkw8R8eOP2RNVYEZX',
#       'name': 'Diplo',
#       'type': 'artist',
#       'uri': 'spotify:artist:5fMUXHkw8R8eOP2RNVYEZX'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 204026,
#     'explicit': False,
#     'external_ids': {'isrc': 'USSM11902898'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0PqK2PJF68X1RUV7pnGoko'},
#     'href': 'https://api.spotify.com/v1/tracks/0PqK2PJF68X1RUV7pnGoko',
#     'id': '0PqK2PJF68X1RUV7pnGoko',
#     'is_local': False,
#     'name': 'Old Town Road (Diplo Remix)',
#     'popularity': 30,
#     'preview_url': 'https://p.scdn.co/mp3-preview/1a001324f66c101c17cda56aa7363097bdcd2908?cid=6e24789ec7874259a220f747fcd7e93e',
#     'track_number': 12,
#     'type': 'track',
#     'uri': 'spotify:track:0PqK2PJF68X1RUV7pnGoko'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1YE1MDlrP32Hs7sutlaWYO'},
#        'href': 'https://api.spotify.com/v1/artists/1YE1MDlrP32Hs7sutlaWYO',
#        'id': '1YE1MDlrP32Hs7sutlaWYO',
#        'name': 'Lil Deela',
#        'type': 'artist',
#        'uri': 'spotify:artist:1YE1MDlrP32Hs7sutlaWYO'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
# ...
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 113737,
#     'explicit': False,
#     'external_ids': {'isrc': 'QMEZE2146553'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3mQSAAR06CJn6OUaPBfqI7'},
#     'href': 'https://api.spotify.com/v1/tracks/3mQSAAR06CJn6OUaPBfqI7',
#     'id': '3mQSAAR06CJn6OUaPBfqI7',
#     'is_local': False,
#     'name': 'Old Town Road',
#     'popularity': 6,
#     'preview_url': 'https://p.scdn.co/mp3-preview/31222edfdc8d3819e455827027c16e1b404375cf?cid=6e24789ec7874259a220f747fcd7e93e',
#     'track_number': 35,
#     'type': 'track',
#     'uri': 'spotify:track:3mQSAAR06CJn6OUaPBfqI7'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4WZv3WA0kyMXBrQ8GNzxeC'},
#        'href': 'https://api.spotify.com/v1/artists/4WZv3WA0kyMXBrQ8GNzxeC',
#        'id': '4WZv3WA0kyMXBrQ8GNzxeC',
#        'name': 'lil Bill The Rap God',
#        'type': 'artist',
#        'uri': 'spotify:artist:4WZv3WA0kyMXBrQ8GNzxeC'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/5z0R9iimw3CznEfmcNfsnJ'},
#        'href': 'https://api.spotify.com/v1/artists/5z0R9iimw3CznEfmcNfsnJ',
#        'id': '5z0R9iimw3CznEfmcNfsnJ',
#        'name': 'William Stella',
#        'type': 'artist',
#        'uri': 'spotify:artist:5z0R9iimw3CznEfmcNfsnJ'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/1MKhuYq7PJSYBUaBgihg15'},
#      'href': 'https://api.spotify.com/v1/albums/1MKhuYq7PJSYBUaBgihg15',
#      'id': '1MKhuYq7PJSYBUaBgihg15',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27324c4d051234e6459e7c3edac',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0224c4d051234e6459e7c3edac',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485124c4d051234e6459e7c3edac',
#        'width': 64}],
#      'name': 'Star',
#      'release_date': '2019-05-21',
#      'release_date_precision': 'day',
#      'total_tracks': 10,
#      'type': 'album',
#      'uri': 'spotify:album:1MKhuYq7PJSYBUaBgihg15'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4WZv3WA0kyMXBrQ8GNzxeC'},
#       'href': 'https://api.spotify.com/v1/artists/4WZv3WA0kyMXBrQ8GNzxeC',
#       'id': '4WZv3WA0kyMXBrQ8GNzxeC',
#       'name': 'lil Bill The Rap God',
#       'type': 'artist',
#       'uri': 'spotify:artist:4WZv3WA0kyMXBrQ8GNzxeC'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/5z0R9iimw3CznEfmcNfsnJ'},
#       'href': 'https://api.spotify.com/v1/artists/5z0R9iimw3CznEfmcNfsnJ',
#       'id': '5z0R9iimw3CznEfmcNfsnJ',
#       'name': 'William Stella',
#       'type': 'artist',
#       'uri': 'spotify:artist:5z0R9iimw3CznEfmcNfsnJ'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 226840,
#     'explicit': True,
#     'external_ids': {'isrc': 'SE5751984180'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3LSkGzydcOc4hbR6nMwZVr'},
#     'href': 'https://api.spotify.com/v1/tracks/3LSkGzydcOc4hbR6nMwZVr',
#     'id': '3LSkGzydcOc4hbR6nMwZVr',
#     'is_local': False,
#     'name': 'oLd tOwN RoAd Pt.1',
#     'popularity': 0,
#     'preview_url': 'https://p.scdn.co/mp3-preview/3ee9565b4c129bd848d3c7332c406758580f17b2?cid=6e24789ec7874259a220f747fcd7e93e',
#     'track_number': 6,
#     'type': 'track',
#     'uri': 'spotify:track:3LSkGzydcOc4hbR6nMwZVr'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1RSfwPGQasuvaAiKfCtQ3v'},
#        'href': 'https://api.spotify.com/v1/artists/1RSfwPGQasuvaAiKfCtQ3v',
#        'id': '1RSfwPGQasuvaAiKfCtQ3v',
#        'name': 'Lil Vegetable',
#        'type': 'artist',
#        'uri': 'spotify:artist:1RSfwPGQasuvaAiKfCtQ3v'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5em9blOAZpz37gTuB0Kn29'},
#      'href': 'https://api.spotify.com/v1/albums/5em9blOAZpz37gTuB0Kn29',
#      'id': '5em9blOAZpz37gTuB0Kn29',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273d15d4887bd8a0c5ce2d9085b',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02d15d4887bd8a0c5ce2d9085b',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851d15d4887bd8a0c5ce2d9085b',
#        'width': 64}],
#      'name': 'Apple Road (Parody of Old Town Road)',
#      'release_date': '2019-05-06',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:5em9blOAZpz37gTuB0Kn29'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1RSfwPGQasuvaAiKfCtQ3v'},
#       'href': 'https://api.spotify.com/v1/artists/1RSfwPGQasuvaAiKfCtQ3v',
#       'id': '1RSfwPGQasuvaAiKfCtQ3v',
#       'name': 'Lil Vegetable',
#       'type': 'artist',
#       'uri': 'spotify:artist:1RSfwPGQasuvaAiKfCtQ3v'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/1tOIUpyMNpZwDGo9UHXx3T'},
#       'href': 'https://api.spotify.com/v1/artists/1tOIUpyMNpZwDGo9UHXx3T',
#       'id': '1tOIUpyMNpZwDGo9UHXx3T',
#       'name': 'Sam Meyn',
#       'type': 'artist',
#       'uri': 'spotify:artist:1tOIUpyMNpZwDGo9UHXx3T'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 115130,
#     'explicit': False,
#     'external_ids': {'isrc': 'QZGWW1901159'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/68UmCkHVi26H6dHUlYb2oS'},
#     'href': 'https://api.spotify.com/v1/tracks/68UmCkHVi26H6dHUlYb2oS',
#     'id': '68UmCkHVi26H6dHUlYb2oS',
#     'is_local': False,
#     'name': 'Apple Road (Parody of Old Town Road)',
#     'popularity': 0,
#     'preview_url': 'https://p.scdn.co/mp3-preview/0e5468e67783919c3fa822d76d786c89115ee888?cid=6e24789ec7874259a220f747fcd7e93e',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:68UmCkHVi26H6dHUlYb2oS'}],
#   'limit': 20,
#   'next': None,
#   'offset': 0,
#   'previous': None,
#   'total': 15}}

# %%
test = pd.DataFrame.from_dict(radioactive,orient='columns')
test
# Out:
#                                                      tracks
# href      https://api.spotify.com/v1/search?query=track%...
# items     [{'album': {'album_type': 'single', 'artists':...
# limit                                                    20
# next                                                   None
# offset                                                    0
# previous                                               None
# total                                                    15

# %%
test= test.tracks.apply(pd.Series)
test
# Out:
# /var/folders/91/wchv5p25455f2k8078kdjvm40000gn/T/ipykernel_27868/2977931382.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   test= test.tracks.apply(pd.Series)
# /var/folders/91/wchv5p25455f2k8078kdjvm40000gn/T/ipykernel_27868/2977931382.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   test= test.tracks.apply(pd.Series)
#                                                           0  \
# href      https://api.spotify.com/v1/search?query=track%...
# items     {'album': {'album_type': 'single', 'artists': ...
# limit                                                  20.0
# next                                                    NaN
# offset                                                  0.0
# previous                                                NaN
# total                                                  15.0
#
#                                                           1  \
# href                                                    NaN
# items     {'album': {'album_type': 'single', 'artists': ...
# limit                                                   NaN
# next                                                    NaN
# offset                                                  NaN
# previous                                                NaN
# total                                                   NaN
#
#                                                           2  \
# href                                                    NaN
# items     {'album': {'album_type': 'single', 'artists': ...
# limit                                                   NaN
# next                                                    NaN
# offset                                                  NaN
# previous                                                NaN
# total                                                   NaN
#
#                                                           3  \
# href                                                    NaN
# items     {'album': {'album_type': 'single', 'artists': ...
# limit                                                   NaN
# next                                                    NaN
# offset                                                  NaN
# previous                                                NaN
# total                                                   NaN
#
#                                                           4  \
# href                                                    NaN
# items     {'album': {'album_type': 'single', 'artists': ...
# limit                                                   NaN
# next                                                    NaN
# offset                                                  NaN
# previous                                                NaN
# total                                                   NaN
#
#                                                           5  \
# href                                                    NaN
# items     {'album': {'album_type': 'compilation', 'artis...
# limit                                                   NaN
# next                                                    NaN
# offset                                                  NaN
# previous                                                NaN
# total                                                   NaN
#
#                                                           6  \
# href                                                    NaN
# items     {'album': {'album_type': 'album', 'artists': [...
# limit                                                   NaN
# next                                                    NaN
# offset                                                  NaN
# previous                                                NaN
# total                                                   NaN
#
#                                                           7  \
# href                                                    NaN
# items     {'album': {'album_type': 'single', 'artists': ...
# limit                                                   NaN
# next                                                    NaN
# offset                                                  NaN
# previous                                                NaN
# total                                                   NaN
#
#                                                           8  \
# href                                                    NaN
# items     {'album': {'album_type': 'album', 'artists': [...
# limit                                                   NaN
# next                                                    NaN
# offset                                                  NaN
# previous                                                NaN
# total                                                   NaN
#
#                                                           9  \
# href                                                    NaN
# items     {'album': {'album_type': 'single', 'artists': ...
# limit                                                   NaN
# next                                                    NaN
# offset                                                  NaN
# previous                                                NaN
# total                                                   NaN
#
#                                                          10  \
# href                                                    NaN
# items     {'album': {'album_type': 'album', 'artists': [...
# limit                                                   NaN
# next                                                    NaN
# offset                                                  NaN
# previous                                                NaN
# total                                                   NaN
#
#                                                          11  \
# href                                                    NaN
# items     {'album': {'album_type': 'single', 'artists': ...
# limit                                                   NaN
# next                                                    NaN
# offset                                                  NaN
# previous                                                NaN
# total                                                   NaN
#
#                                                          12  \
# href                                                    NaN
# items     {'album': {'album_type': 'compilation', 'artis...
# limit                                                   NaN
# next                                                    NaN
# offset                                                  NaN
# previous                                                NaN
# total                                                   NaN
#
#                                                          13  \
# href                                                    NaN
# items     {'album': {'album_type': 'album', 'artists': [...
# limit                                                   NaN
# next                                                    NaN
# offset                                                  NaN
# previous                                                NaN
# total                                                   NaN
#
#                                                          14
# href                                                    NaN
# items     {'album': {'album_type': 'single', 'artists': ...
# limit                                                   NaN
# next                                                    NaN
# offset                                                  NaN
# previous                                                NaN
# total                                                   NaN

# %%
test2 = pd.DataFrame(test.iloc[1])
test2
# Out:
#                                                 items
# 0   {'album': {'album_type': 'single', 'artists': ...
# 1   {'album': {'album_type': 'single', 'artists': ...
# 2   {'album': {'album_type': 'single', 'artists': ...
# 3   {'album': {'album_type': 'single', 'artists': ...
# 4   {'album': {'album_type': 'single', 'artists': ...
# 5   {'album': {'album_type': 'compilation', 'artis...
# 6   {'album': {'album_type': 'album', 'artists': [...
# 7   {'album': {'album_type': 'single', 'artists': ...
# 8   {'album': {'album_type': 'album', 'artists': [...
# 9   {'album': {'album_type': 'single', 'artists': ...
# 10  {'album': {'album_type': 'album', 'artists': [...
# 11  {'album': {'album_type': 'single', 'artists': ...
# 12  {'album': {'album_type': 'compilation', 'artis...
# 13  {'album': {'album_type': 'album', 'artists': [...
# 14  {'album': {'album_type': 'single', 'artists': ...

# %%
test3 = test2['items'].apply(pd.Series)
test3
# Out:
#                                                 album  \
# 0   {'album_type': 'single', 'artists': [{'externa...
# 1   {'album_type': 'single', 'artists': [{'externa...
# 2   {'album_type': 'single', 'artists': [{'externa...
# 3   {'album_type': 'single', 'artists': [{'externa...
# 4   {'album_type': 'single', 'artists': [{'externa...
# 5   {'album_type': 'compilation', 'artists': [{'ex...
# 6   {'album_type': 'album', 'artists': [{'external...
# 7   {'album_type': 'single', 'artists': [{'externa...
# 8   {'album_type': 'album', 'artists': [{'external...
# 9   {'album_type': 'single', 'artists': [{'externa...
# 10  {'album_type': 'album', 'artists': [{'external...
# 11  {'album_type': 'single', 'artists': [{'externa...
# 12  {'album_type': 'compilation', 'artists': [{'ex...
# 13  {'album_type': 'album', 'artists': [{'external...
# 14  {'album_type': 'single', 'artists': [{'externa...
#
#                                               artists  \
# 0   [{'external_urls': {'spotify': 'https://open.s...
# 1   [{'external_urls': {'spotify': 'https://open.s...
# 2   [{'external_urls': {'spotify': 'https://open.s...
# 3   [{'external_urls': {'spotify': 'https://open.s...
# 4   [{'external_urls': {'spotify': 'https://open.s...
# 5   [{'external_urls': {'spotify': 'https://open.s...
# 6   [{'external_urls': {'spotify': 'https://open.s...
# 7   [{'external_urls': {'spotify': 'https://open.s...
# 8   [{'external_urls': {'spotify': 'https://open.s...
# 9   [{'external_urls': {'spotify': 'https://open.s...
# 10  [{'external_urls': {'spotify': 'https://open.s...
# 11  [{'external_urls': {'spotify': 'https://open.s...
# 12  [{'external_urls': {'spotify': 'https://open.s...
# 13  [{'external_urls': {'spotify': 'https://open.s...
# 14  [{'external_urls': {'spotify': 'https://open.s...
#
#                                     available_markets  disc_number  \
# 0   [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...            1
# 1   [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...            1
# 2   [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...            1
# 3   [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...            1
# 4   [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...            1
# 5                                                [US]            1
# 6   [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...            1
# 7   [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...            1
# 8   [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...            1
# 9   [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...            1
# 10  [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...            1
# 11  [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...            1
# 12  [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...            1
# 13  [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...            1
# 14  [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...            1
#
#     duration_ms  explicit              external_ids  \
# 0        157066     False  {'isrc': 'USSM11902498'}
# 1        113000     False  {'isrc': 'USSM11901941'}
# 2        114133     False  {'isrc': 'USSM11904830'}
# 3        171293     False  {'isrc': 'USSM11904496'}
# 4        204026     False  {'isrc': 'USSM11902898'}
# 5        155386     False  {'isrc': 'USSM11902498'}
# 6        204026     False  {'isrc': 'USSM11902898'}
# 7        113663     False  {'isrc': 'GBMA21963024'}
# 8        204026     False  {'isrc': 'USSM11902898'}
# 9        113663     False  {'isrc': 'GBMA21963021'}
# 10       204026     False  {'isrc': 'USSM11902898'}
# 11       162925      True  {'isrc': 'QZGWW1959725'}
# 12       113737     False  {'isrc': 'QMEZE2146553'}
# 13       226840      True  {'isrc': 'SE5751984180'}
# 14       115130     False  {'isrc': 'QZGWW1901159'}
#
#                                         external_urls  \
# 0   {'spotify': 'https://open.spotify.com/track/2Y...
# 1   {'spotify': 'https://open.spotify.com/track/0F...
# 2   {'spotify': 'https://open.spotify.com/track/6w...
# 3   {'spotify': 'https://open.spotify.com/track/6j...
# 4   {'spotify': 'https://open.spotify.com/track/3k...
# 5   {'spotify': 'https://open.spotify.com/track/6z...
# 6   {'spotify': 'https://open.spotify.com/track/0P...
# 7   {'spotify': 'https://open.spotify.com/track/3S...
# 8   {'spotify': 'https://open.spotify.com/track/7n...
# 9   {'spotify': 'https://open.spotify.com/track/4X...
# 10  {'spotify': 'https://open.spotify.com/track/1q...
# 11  {'spotify': 'https://open.spotify.com/track/6Z...
# 12  {'spotify': 'https://open.spotify.com/track/3m...
# 13  {'spotify': 'https://open.spotify.com/track/3L...
# 14  {'spotify': 'https://open.spotify.com/track/68...
#
#                                                  href                      id  \
# 0   https://api.spotify.com/v1/tracks/2YpeDb67231R...  2YpeDb67231RjR0MgVLzsG
# 1   https://api.spotify.com/v1/tracks/0F7FA14euOIX...  0F7FA14euOIX8KcbEturGH
# 2   https://api.spotify.com/v1/tracks/6woeVu3fVMfl...  6woeVu3fVMflqen1t4N6pg
# 3   https://api.spotify.com/v1/tracks/6jmZlyf9DxcI...  6jmZlyf9DxcIoRrjw02YXm
# 4   https://api.spotify.com/v1/tracks/3kgKVcBpBGuS...  3kgKVcBpBGuSeaEC0AZGlb
# 5   https://api.spotify.com/v1/tracks/6zpiwiexX8Hp...  6zpiwiexX8HpFCZLyIWKDv
# 6   https://api.spotify.com/v1/tracks/0PqK2PJF68X1...  0PqK2PJF68X1RUV7pnGoko
# 7   https://api.spotify.com/v1/tracks/3S0wWGhuBdmX...  3S0wWGhuBdmXb4bs8fW2OC
# 8   https://api.spotify.com/v1/tracks/7nM8wFdIkdyT...  7nM8wFdIkdyTHfAm83p9Ky
# 9   https://api.spotify.com/v1/tracks/4X0baEnStEnC...  4X0baEnStEnCZ0ddViAUZj
# 10  https://api.spotify.com/v1/tracks/1qXtwXPuyOkL...  1qXtwXPuyOkLMd7njBUfMp
# 11  https://api.spotify.com/v1/tracks/6ZrcHJNMK2bb...  6ZrcHJNMK2bbR55SJ3vcDF
# 12  https://api.spotify.com/v1/tracks/3mQSAAR06CJn...  3mQSAAR06CJn6OUaPBfqI7
# 13  https://api.spotify.com/v1/tracks/3LSkGzydcOc4...  3LSkGzydcOc4hbR6nMwZVr
# 14  https://api.spotify.com/v1/tracks/68UmCkHVi26H...  68UmCkHVi26H6dHUlYb2oS
#
#     is_local                                               name  popularity  \
# 0      False                              Old Town Road - Remix          78
# 1      False                                      Old Town Road          76
# 2      False  Old Town Road (feat. RM of BTS) - Seoul Town R...          66
# 3      False                              Old Town Road - Remix          53
# 4      False                        Old Town Road - Diplo Remix          59
# 5      False      Old Town Road (feat. Billy Ray Cyrus) - Remix          35
# 6      False                        Old Town Road (Diplo Remix)          30
# 7      False                                      Old Town Road          30
# 8      False                        Old Town Road - Diplo Remix          18
# 9      False                                      Old Town Road          24
# 10     False                        Old Town Road (Diplo Remix)          15
# 11     False                                      Old Town Road           0
# 12     False                                      Old Town Road           6
# 13     False                                 oLd tOwN RoAd Pt.1           0
# 14     False               Apple Road (Parody of Old Town Road)           0
#
#                                           preview_url  track_number   type  \
# 0   https://p.scdn.co/mp3-preview/b1b4f28e5b4fc679...             1  track
# 1   https://p.scdn.co/mp3-preview/614acab009c3c05b...             8  track
# 2   https://p.scdn.co/mp3-preview/562c379bb78312ab...             1  track
# 3   https://p.scdn.co/mp3-preview/121d2a949eb20cf5...             1  track
# 4   https://p.scdn.co/mp3-preview/b195ae0f4f2728e4...             1  track
# 5   https://p.scdn.co/mp3-preview/d8bc2293391ccd43...             7  track
# 6   https://p.scdn.co/mp3-preview/1a001324f66c101c...            12  track
# 7   https://p.scdn.co/mp3-preview/4e48e8cd7ccd4b4c...             1  track
# 8   https://p.scdn.co/mp3-preview/1a001324f66c101c...            14  track
# 9   https://p.scdn.co/mp3-preview/4e48e8cd7ccd4b4c...             1  track
# 10  https://p.scdn.co/mp3-preview/1a001324f66c101c...            12  track
# 11  https://p.scdn.co/mp3-preview/a5b50eedf8246c84...             1  track
# 12  https://p.scdn.co/mp3-preview/31222edfdc8d3819...            35  track
# 13  https://p.scdn.co/mp3-preview/3ee9565b4c129bd8...             6  track
# 14  https://p.scdn.co/mp3-preview/0e5468e67783919c...             1  track
#
#                                      uri
# 0   spotify:track:2YpeDb67231RjR0MgVLzsG
# 1   spotify:track:0F7FA14euOIX8KcbEturGH
# 2   spotify:track:6woeVu3fVMflqen1t4N6pg
# 3   spotify:track:6jmZlyf9DxcIoRrjw02YXm
# 4   spotify:track:3kgKVcBpBGuSeaEC0AZGlb
# 5   spotify:track:6zpiwiexX8HpFCZLyIWKDv
# 6   spotify:track:0PqK2PJF68X1RUV7pnGoko
# 7   spotify:track:3S0wWGhuBdmXb4bs8fW2OC
# 8   spotify:track:7nM8wFdIkdyTHfAm83p9Ky
# 9   spotify:track:4X0baEnStEnCZ0ddViAUZj
# 10  spotify:track:1qXtwXPuyOkLMd7njBUfMp
# 11  spotify:track:6ZrcHJNMK2bbR55SJ3vcDF
# 12  spotify:track:3mQSAAR06CJn6OUaPBfqI7
# 13  spotify:track:3LSkGzydcOc4hbR6nMwZVr
# 14  spotify:track:68UmCkHVi26H6dHUlYb2oS

# %%
test3.head(1)
# Out:
#                                                album  \
# 0  {'album_type': 'single', 'artists': [{'externa...
#
#                                              artists  \
# 0  [{'external_urls': {'spotify': 'https://open.s...
#
#                                    available_markets  disc_number  \
# 0  [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...            1
#
#    duration_ms  explicit              external_ids  \
# 0       157066     False  {'isrc': 'USSM11902498'}
#
#                                        external_urls  \
# 0  {'spotify': 'https://open.spotify.com/track/2Y...
#
#                                                 href                      id  \
# 0  https://api.spotify.com/v1/tracks/2YpeDb67231R...  2YpeDb67231RjR0MgVLzsG
#
#    is_local                   name  popularity  \
# 0     False  Old Town Road - Remix          78
#
#                                          preview_url  track_number   type  \
# 0  https://p.scdn.co/mp3-preview/b1b4f28e5b4fc679...             1  track
#
#                                     uri
# 0  spotify:track:2YpeDb67231RjR0MgVLzsG
