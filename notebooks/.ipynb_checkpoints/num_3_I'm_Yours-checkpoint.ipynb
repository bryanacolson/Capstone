# %%
# import packages

# %%
from pandas.io.json import json_normalize
import json
from pandasql import sqldf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from bs4 import BeautifulSoup
import io
import requests
import json
import base64
import datetime
from urllib.parse import urlencode

# %%
# client id

# %%
client_id = '6e24789ec7874259a220f747fcd7e93e'
client_secret = '9bd8ff1ad2f34ef6a87f00124be070b2'

# %%
class SpotifyAPI(object):
    access_token = None
    access_token_expires = datetime.datetime.now()
    access_token_did_expire = True
    client_id = None
    client_secret = None
    token_url = "https://accounts.spotify.com/api/token"



    def __init__(self, client_id, client_secret, *args, **kwargs):
        super().__init__(*args, **kwargs)
        self.client_id = client_id
        self.client_secret = client_secret

    def getClientCreds(self):
        '''Returns b64 encoded string'''
        client_id = self.client_id
        client_secret = self.client_secret

        if client_id == None or client_secret == None:
            raise Exception('Must set a client id and secret')

        client_creds  = f"{client_id}:{client_secret}"
        client_creds_b64 = base64.b64encode(client_creds.encode())
        return client_creds_b64.decode()

    def getTokenHeader(self):
        client_creds_b64 = self.getClientCreds()
        return {
            'Authorization':f"Basic {client_creds_b64}"
        }

    def getTokenData(self):
        return {
            "grant_type":"client_credentials"
        }

    def perform_auth(self):
        token_url = self.token_url
        token_data = self.getTokenData()
        token_header = self.getTokenHeader()

        r = requests.post(token_url, data=token_data, headers=token_header)

        if r.status_code  not in range(200,299):
            raise Exception('Could not authenticate client.')
            #return False

        now = datetime.datetime.now()
        token_response_data = r.json()
        access_token = token_response_data['access_token']
        expires_in = token_response_data['expires_in']
        expires = now + datetime.timedelta(seconds=expires_in)
        self.access_token = access_token
        self.access_token_expires = expires
        self.access_token_did_expire = expires < now


        return True

    def get_access_token(self):
        token = self.access_token
        expires = self.access_token_expires
        now= datetime.datetime.now()
        if expires < now:
            self.perform_auth()
            return self.get_access_token()
        elif token == None:
            self.perform_auth()
            return self.get_access_token() 
        return token
    
    def get_resource_header(self):
        access_token = self.get_access_token()
        headers = {
            "Authorization": f"Bearer {access_token}", 
        }
        return headers
    
    def get_resource(self, lookup_id, resource_type='albums', version='v1'):
        endpoint = f'https://api.spotify.com/{version}/{resource_type}/{lookup_id}'
        headers = self.get_resource_header()
        r = requests.get(endpoint, headers = headers)
        if r.status_code not in range (200, 299):
            return {}
        return r.json()
    
    def get_album(self, _id ):
        return self.get_resource(_id, resource_type='albums')
    
    def get_artist(self, _id ):
        return self.get_resource(_id, resource_type='artists')
    
    def get_playlist(self, _id):
        return self.get_resource(_id, resource_type='playlists')
    
    
    def base_search(self, query_params): #type
        access_token = self.get_access_token()
        headers = self.get_resource_header()
        endpoint = "https://api.spotify.com/v1/search"
        lookup_URL = f"{endpoint}?{query_params}"
        r = requests.get(lookup_URL, headers=headers)
        if r.status_code not in range (200, 299):
            return {}
        return r.json()
    
    def search(self, query=None, operator=None, operator_query=None, search_type='artist'):
        if query == None:
            raise Exception('A query is required')
        if isinstance(query, dict):
            query = ' '.join([f'{k}:{v}' for k,v in query.items()])
        if operator != None and operator_query != None:
            if operator.lower() == 'or' or operator.lower() == 'not':
                operator = operator.upper()
                if isinstance(operator_query, str):
                    query = f'{query} {operator} {operator_query}'
        query_params = urlencode({'q': query, 'type': search_type.lower()})
        return self.base_search(query_params)

# %%
spotify = SpotifyAPI(client_id, client_secret)

# %%
# radioactive

# %%
Im_Yours = spotify.search({'track': 'Im Yours', 'artist': 'Jason'}, search_type ='track')
Im_Yours
# Out:
# {'tracks': {'href': 'https://api.spotify.com/v1/search?query=track%3AIm+Yours+artist%3AJason&type=track&offset=0&limit=20',
#   'items': [{'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4phGZZrJZRo4ElhRtViYdl'},
#        'href': 'https://api.spotify.com/v1/artists/4phGZZrJZRo4ElhRtViYdl',
#        'id': '4phGZZrJZRo4ElhRtViYdl',
#        'name': 'Jason Mraz',
#        'type': 'artist',
#        'uri': 'spotify:artist:4phGZZrJZRo4ElhRtViYdl'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/04G0YylSjvDQZrjOfE5jA5'},
#      'href': 'https://api.spotify.com/v1/albums/04G0YylSjvDQZrjOfE5jA5',
#      'id': '04G0YylSjvDQZrjOfE5jA5',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2730f2e51f7121539e221c51161',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e020f2e51f7121539e221c51161',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048510f2e51f7121539e221c51161',
#        'width': 64}],
#      'name': 'We Sing. We Dance. We Steal Things.',
#      'release_date': '2008-05-12',
#      'release_date_precision': 'day',
#      'total_tracks': 12,
#      'type': 'album',
#      'uri': 'spotify:album:04G0YylSjvDQZrjOfE5jA5'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4phGZZrJZRo4ElhRtViYdl'},
#       'href': 'https://api.spotify.com/v1/artists/4phGZZrJZRo4ElhRtViYdl',
#       'id': '4phGZZrJZRo4ElhRtViYdl',
#       'name': 'Jason Mraz',
#       'type': 'artist',
#       'uri': 'spotify:artist:4phGZZrJZRo4ElhRtViYdl'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 242946,
#     'explicit': False,
#     'external_ids': {'isrc': 'USEE10800667'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1EzrEOXmMH3G43AXT1y7pA'},
#     'href': 'https://api.spotify.com/v1/tracks/1EzrEOXmMH3G43AXT1y7pA',
#     'id': '1EzrEOXmMH3G43AXT1y7pA',
#     'is_local': False,
#     'name': "I'm Yours",
#     'popularity': 79,
#     'preview_url': 'https://p.scdn.co/mp3-preview/975f7acc6041b1b74b5a4bdacf8843df6c51505c?cid=6e24789ec7874259a220f747fcd7e93e',
#     'track_number': 2,
#     'type': 'track',
#     'uri': 'spotify:track:1EzrEOXmMH3G43AXT1y7pA'},
#    {'album': {'album_type': 'compilation',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#        'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#        'id': '0LyfQWJT6nXafLPZqxe9Of',
#        'name': 'Various Artists',
#        'type': 'artist',
#        'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AR',
#       'AT',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BG',
#       'BH',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DM',
#       'DO',
#       'EC',
#       'EE',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GD',
#       'GE',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LT',
#       'LU',
#       'LV',
#       'MC',
#       'MD',
#       'ME',
#       'MH',
#       'MK',
#       'MN',
#       'MO',
#       'MT',
#       'MV',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'SA',
#       'SB',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SM',
#       'SR',
#       'SV',
#       'TH',
#       'TJ',
#       'TL',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/3YBHGYTcnNwa0TcwpMUKk9'},
#      'href': 'https://api.spotify.com/v1/albums/3YBHGYTcnNwa0TcwpMUKk9',
#      'id': '3YBHGYTcnNwa0TcwpMUKk9',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2730543421c2ebffe8995907e7c',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e020543421c2ebffe8995907e7c',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048510543421c2ebffe8995907e7c',
#        'width': 64}],
#      'name': 'Silvester Party Hits 2022 / 2023',
#      'release_date': '2022-11-25',
#      'release_date_precision': 'day',
#      'total_tracks': 78,
#      'type': 'album',
#      'uri': 'spotify:album:3YBHGYTcnNwa0TcwpMUKk9'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4phGZZrJZRo4ElhRtViYdl'},
#       'href': 'https://api.spotify.com/v1/artists/4phGZZrJZRo4ElhRtViYdl',
#       'id': '4phGZZrJZRo4ElhRtViYdl',
#       'name': 'Jason Mraz',
#       'type': 'artist',
#       'uri': 'spotify:artist:4phGZZrJZRo4ElhRtViYdl'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AR',
#      'AT',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BG',
#      'BH',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DM',
#      'DO',
#      'EC',
#      'EE',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GD',
#      'GE',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LT',
#      'LU',
#      'LV',
#      'MC',
#      'MD',
#      'ME',
#      'MH',
#      'MK',
#      'MN',
#      'MO',
#      'MT',
#      'MV',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'SA',
#      'SB',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SM',
#      'SR',
#      'SV',
#      'TH',
#      'TJ',
#      'TL',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK'],
#     'disc_number': 1,
#     'duration_ms': 242040,
#     'explicit': False,
#     'external_ids': {'isrc': 'USEE10800667'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/00Dr2e9a3Ut6aUVGe8IoHH'},
#     'href': 'https://api.spotify.com/v1/tracks/00Dr2e9a3Ut6aUVGe8IoHH',
#     'id': '00Dr2e9a3Ut6aUVGe8IoHH',
#     'is_local': False,
#     'name': "I'm Yours",
#     'popularity': 0,
#     'preview_url': 'https://p.scdn.co/mp3-preview/a4fd098ade918bf63888dc1feb73f722d3361ccd?cid=6e24789ec7874259a220f747fcd7e93e',
#     'track_number': 70,
#     'type': 'track',
#     'uri': 'spotify:track:00Dr2e9a3Ut6aUVGe8IoHH'},
#    {'album': {'album_type': 'compilation',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#        'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#        'id': '0LyfQWJT6nXafLPZqxe9Of',
#        'name': 'Various Artists',
#        'type': 'artist',
#        'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/7qpKIA5x6guzdggZA9RJDf'},
#      'href': 'https://api.spotify.com/v1/albums/7qpKIA5x6guzdggZA9RJDf',
#      'id': '7qpKIA5x6guzdggZA9RJDf',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2737bdeec74a41ed05e29eaa9a5',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e027bdeec74a41ed05e29eaa9a5',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048517bdeec74a41ed05e29eaa9a5',
#        'width': 64}],
#      'name': 'Cozy Morning',
#      'release_date': '2022-12-02',
#      'release_date_precision': 'day',
#      'total_tracks': 28,
#      'type': 'album',
#      'uri': 'spotify:album:7qpKIA5x6guzdggZA9RJDf'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4phGZZrJZRo4ElhRtViYdl'},
#       'href': 'https://api.spotify.com/v1/artists/4phGZZrJZRo4ElhRtViYdl',
#       'id': '4phGZZrJZRo4ElhRtViYdl',
#       'name': 'Jason Mraz',
#       'type': 'artist',
#       'uri': 'spotify:artist:4phGZZrJZRo4ElhRtViYdl'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 242040,
#     'explicit': False,
#     'external_ids': {'isrc': 'USEE10800667'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/5Wgjc8n0W2SDKgfBsqF46L'},
#     'href': 'https://api.spotify.com/v1/tracks/5Wgjc8n0W2SDKgfBsqF46L',
#     'id': '5Wgjc8n0W2SDKgfBsqF46L',
#     'is_local': False,
#     'name': "I'm Yours",
#     'popularity': 0,
#     'preview_url': 'https://p.scdn.co/mp3-preview/a4fd098ade918bf63888dc1feb73f722d3361ccd?cid=6e24789ec7874259a220f747fcd7e93e',
#     'track_number': 3,
#     'type': 'track',
#     'uri': 'spotify:track:5Wgjc8n0W2SDKgfBsqF46L'},
#    {'album': {'album_type': 'compilation',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#        'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#        'id': '0LyfQWJT6nXafLPZqxe9Of',
#        'name': 'Various Artists',
#        'type': 'artist',
#        'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/1wmPV5N8Yug3leAVG4TMWr'},
#      'href': 'https://api.spotify.com/v1/albums/1wmPV5N8Yug3leAVG4TMWr',
#      'id': '1wmPV5N8Yug3leAVG4TMWr',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273a9aa1e434050fa121c33e227',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02a9aa1e434050fa121c33e227',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851a9aa1e434050fa121c33e227',
#        'width': 64}],
#      'name': 'Modern Classics - Pop',
#      'release_date': '2022-11-25',
#      'release_date_precision': 'day',
#      'total_tracks': 30,
#      'type': 'album',
#      'uri': 'spotify:album:1wmPV5N8Yug3leAVG4TMWr'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4phGZZrJZRo4ElhRtViYdl'},
#       'href': 'https://api.spotify.com/v1/artists/4phGZZrJZRo4ElhRtViYdl',
#       'id': '4phGZZrJZRo4ElhRtViYdl',
#       'name': 'Jason Mraz',
#       'type': 'artist',
#       'uri': 'spotify:artist:4phGZZrJZRo4ElhRtViYdl'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 242040,
#     'explicit': False,
#     'external_ids': {'isrc': 'USEE10800667'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/37QJGL7UHOSveSq1JfIyom'},
#     'href': 'https://api.spotify.com/v1/tracks/37QJGL7UHOSveSq1JfIyom',
#     'id': '37QJGL7UHOSveSq1JfIyom',
#     'is_local': False,
#     'name': "I'm Yours",
#     'popularity': 0,
#     'preview_url': 'https://p.scdn.co/mp3-preview/a4fd098ade918bf63888dc1feb73f722d3361ccd?cid=6e24789ec7874259a220f747fcd7e93e',
#     'track_number': 20,
#     'type': 'track',
#     'uri': 'spotify:track:37QJGL7UHOSveSq1JfIyom'},
#    {'album': {'album_type': 'compilation',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#        'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#        'id': '0LyfQWJT6nXafLPZqxe9Of',
#        'name': 'Various Artists',
#        'type': 'artist',
#        'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5fQGgxRgeSOOLJoyatusfN'},
#      'href': 'https://api.spotify.com/v1/albums/5fQGgxRgeSOOLJoyatusfN',
#      'id': '5fQGgxRgeSOOLJoyatusfN',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273cc18003fd44977007dfa4c76',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02cc18003fd44977007dfa4c76',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851cc18003fd44977007dfa4c76',
#        'width': 64}],
#      'name': 'Happy New Year 2023',
#      'release_date': '2022-12-02',
#      'release_date_precision': 'day',
#      'total_tracks': 68,
#      'type': 'album',
#      'uri': 'spotify:album:5fQGgxRgeSOOLJoyatusfN'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4phGZZrJZRo4ElhRtViYdl'},
#       'href': 'https://api.spotify.com/v1/artists/4phGZZrJZRo4ElhRtViYdl',
#       'id': '4phGZZrJZRo4ElhRtViYdl',
#       'name': 'Jason Mraz',
#       'type': 'artist',
#       'uri': 'spotify:artist:4phGZZrJZRo4ElhRtViYdl'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 242040,
#     'explicit': False,
#     'external_ids': {'isrc': 'USEE10800667'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6cAlQrApxMYdz9lt4FWVBH'},
#     'href': 'https://api.spotify.com/v1/tracks/6cAlQrApxMYdz9lt4FWVBH',
#     'id': '6cAlQrApxMYdz9lt4FWVBH',
#     'is_local': False,
#     'name': "I'm Yours",
#     'popularity': 0,
#     'preview_url': 'https://p.scdn.co/mp3-preview/a4fd098ade918bf63888dc1feb73f722d3361ccd?cid=6e24789ec7874259a220f747fcd7e93e',
#     'track_number': 68,
#     'type': 'track',
#     'uri': 'spotify:track:6cAlQrApxMYdz9lt4FWVBH'},
#    {'album': {'album_type': 'compilation',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#        'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#        'id': '0LyfQWJT6nXafLPZqxe9Of',
#        'name': 'Various Artists',
#        'type': 'artist',
#        'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/79edhnFwe5f1aNDqyP7gcj'},
#      'href': 'https://api.spotify.com/v1/albums/79edhnFwe5f1aNDqyP7gcj',
#      'id': '79edhnFwe5f1aNDqyP7gcj',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27334ec48afdb1dfe72528785aa',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0234ec48afdb1dfe72528785aa',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485134ec48afdb1dfe72528785aa',
#        'width': 64}],
#      'name': 'Silvester Party TikTok Hits 2023',
#      'release_date': '2022-12-02',
#      'release_date_precision': 'day',
#      'total_tracks': 71,
#      'type': 'album',
#      'uri': 'spotify:album:79edhnFwe5f1aNDqyP7gcj'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4phGZZrJZRo4ElhRtViYdl'},
#       'href': 'https://api.spotify.com/v1/artists/4phGZZrJZRo4ElhRtViYdl',
#       'id': '4phGZZrJZRo4ElhRtViYdl',
#       'name': 'Jason Mraz',
#       'type': 'artist',
#       'uri': 'spotify:artist:4phGZZrJZRo4ElhRtViYdl'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 242040,
#     'explicit': False,
#     'external_ids': {'isrc': 'USEE10800667'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3HN0AC9gB2DJjOlPsI25br'},
#     'href': 'https://api.spotify.com/v1/tracks/3HN0AC9gB2DJjOlPsI25br',
#     'id': '3HN0AC9gB2DJjOlPsI25br',
#     'is_local': False,
#     'name': "I'm Yours",
#     'popularity': 0,
#     'preview_url': 'https://p.scdn.co/mp3-preview/a4fd098ade918bf63888dc1feb73f722d3361ccd?cid=6e24789ec7874259a220f747fcd7e93e',
#     'track_number': 63,
#     'type': 'track',
#     'uri': 'spotify:track:3HN0AC9gB2DJjOlPsI25br'},
#    {'album': {'album_type': 'compilation',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#        'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#        'id': '0LyfQWJT6nXafLPZqxe9Of',
#        'name': 'Various Artists',
#        'type': 'artist',
#        'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2a7cc8SJP9xsDkujMg6z8Y'},
#      'href': 'https://api.spotify.com/v1/albums/2a7cc8SJP9xsDkujMg6z8Y',
#      'id': '2a7cc8SJP9xsDkujMg6z8Y',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27368f81f32123423314a0c46ce',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0268f81f32123423314a0c46ce',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485168f81f32123423314a0c46ce',
#        'width': 64}],
#      'name': 'Mellow Pop',
#      'release_date': '2022-11-25',
#      'release_date_precision': 'day',
#      'total_tracks': 50,
#      'type': 'album',
#      'uri': 'spotify:album:2a7cc8SJP9xsDkujMg6z8Y'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4phGZZrJZRo4ElhRtViYdl'},
#       'href': 'https://api.spotify.com/v1/artists/4phGZZrJZRo4ElhRtViYdl',
#       'id': '4phGZZrJZRo4ElhRtViYdl',
#       'name': 'Jason Mraz',
#       'type': 'artist',
#       'uri': 'spotify:artist:4phGZZrJZRo4ElhRtViYdl'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 242040,
#     'explicit': False,
#     'external_ids': {'isrc': 'USEE10800667'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/2U9jmCadmcaJiGgT9FH1XM'},
#     'href': 'https://api.spotify.com/v1/tracks/2U9jmCadmcaJiGgT9FH1XM',
#     'id': '2U9jmCadmcaJiGgT9FH1XM',
#     'is_local': False,
#     'name': "I'm Yours",
#     'popularity': 0,
#     'preview_url': 'https://p.scdn.co/mp3-preview/a4fd098ade918bf63888dc1feb73f722d3361ccd?cid=6e24789ec7874259a220f747fcd7e93e',
#     'track_number': 44,
#     'type': 'track',
#     'uri': 'spotify:track:2U9jmCadmcaJiGgT9FH1XM'},
#    {'album': {'album_type': 'compilation',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#        'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#        'id': '0LyfQWJT6nXafLPZqxe9Of',
#        'name': 'Various Artists',
#        'type': 'artist',
#        'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/7AykMHB8LZ9j3AjwmR8CG1'},
#      'href': 'https://api.spotify.com/v1/albums/7AykMHB8LZ9j3AjwmR8CG1',
#      'id': '7AykMHB8LZ9j3AjwmR8CG1',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27324a1826c805adc23ef6573fd',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0224a1826c805adc23ef6573fd',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485124a1826c805adc23ef6573fd',
#        'width': 64}],
#      'name': 'Timeless Love Songs',
#      'release_date': '2022-12-02',
#      'release_date_precision': 'day',
#      'total_tracks': 65,
#      'type': 'album',
#      'uri': 'spotify:album:7AykMHB8LZ9j3AjwmR8CG1'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4phGZZrJZRo4ElhRtViYdl'},
#       'href': 'https://api.spotify.com/v1/artists/4phGZZrJZRo4ElhRtViYdl',
#       'id': '4phGZZrJZRo4ElhRtViYdl',
#       'name': 'Jason Mraz',
#       'type': 'artist',
#       'uri': 'spotify:artist:4phGZZrJZRo4ElhRtViYdl'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
# ...
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 242946,
#     'explicit': False,
#     'external_ids': {'isrc': 'USEE10800667'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/08rQ80583Alesr2BMMAVfQ'},
#     'href': 'https://api.spotify.com/v1/tracks/08rQ80583Alesr2BMMAVfQ',
#     'id': '08rQ80583Alesr2BMMAVfQ',
#     'is_local': False,
#     'name': "I'm Yours",
#     'popularity': 32,
#     'preview_url': 'https://p.scdn.co/mp3-preview/975f7acc6041b1b74b5a4bdacf8843df6c51505c?cid=6e24789ec7874259a220f747fcd7e93e',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:08rQ80583Alesr2BMMAVfQ'},
#    {'album': {'album_type': 'compilation',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#        'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#        'id': '0LyfQWJT6nXafLPZqxe9Of',
#        'name': 'Various Artists',
#        'type': 'artist',
#        'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5JkZZ6CtGWSRv3maWUnpL0'},
#      'href': 'https://api.spotify.com/v1/albums/5JkZZ6CtGWSRv3maWUnpL0',
#      'id': '5JkZZ6CtGWSRv3maWUnpL0',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273c2ced90dfec8e6ad76f1a5ee',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02c2ced90dfec8e6ad76f1a5ee',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851c2ced90dfec8e6ad76f1a5ee',
#        'width': 64}],
#      'name': 'Wedding Songs 2021',
#      'release_date': '2021-03-26',
#      'release_date_precision': 'day',
#      'total_tracks': 30,
#      'type': 'album',
#      'uri': 'spotify:album:5JkZZ6CtGWSRv3maWUnpL0'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4phGZZrJZRo4ElhRtViYdl'},
#       'href': 'https://api.spotify.com/v1/artists/4phGZZrJZRo4ElhRtViYdl',
#       'id': '4phGZZrJZRo4ElhRtViYdl',
#       'name': 'Jason Mraz',
#       'type': 'artist',
#       'uri': 'spotify:artist:4phGZZrJZRo4ElhRtViYdl'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DJ',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FJ',
#      'FM',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 242040,
#     'explicit': False,
#     'external_ids': {'isrc': 'USEE10800667'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/66BVPsCvlfSeFRNKENpMsx'},
#     'href': 'https://api.spotify.com/v1/tracks/66BVPsCvlfSeFRNKENpMsx',
#     'id': '66BVPsCvlfSeFRNKENpMsx',
#     'is_local': False,
#     'name': "I'm Yours",
#     'popularity': 21,
#     'preview_url': 'https://p.scdn.co/mp3-preview/c782977ab382a2450458d29e708776f0554b2539?cid=6e24789ec7874259a220f747fcd7e93e',
#     'track_number': 16,
#     'type': 'track',
#     'uri': 'spotify:track:66BVPsCvlfSeFRNKENpMsx'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4phGZZrJZRo4ElhRtViYdl'},
#        'href': 'https://api.spotify.com/v1/artists/4phGZZrJZRo4ElhRtViYdl',
#        'id': '4phGZZrJZRo4ElhRtViYdl',
#        'name': 'Jason Mraz',
#        'type': 'artist',
#        'uri': 'spotify:artist:4phGZZrJZRo4ElhRtViYdl'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2KRilDRNGoK60NM5gXfF63'},
#      'href': 'https://api.spotify.com/v1/albums/2KRilDRNGoK60NM5gXfF63',
#      'id': '2KRilDRNGoK60NM5gXfF63',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2730fa1a1cb7fef0a002f934084',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e020fa1a1cb7fef0a002f934084',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048510fa1a1cb7fef0a002f934084',
#        'width': 64}],
#      'name': 'Look For The Good (Deluxe Edition)',
#      'release_date': '2021-07-16',
#      'release_date_precision': 'day',
#      'total_tracks': 18,
#      'type': 'album',
#      'uri': 'spotify:album:2KRilDRNGoK60NM5gXfF63'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4phGZZrJZRo4ElhRtViYdl'},
#       'href': 'https://api.spotify.com/v1/artists/4phGZZrJZRo4ElhRtViYdl',
#       'id': '4phGZZrJZRo4ElhRtViYdl',
#       'name': 'Jason Mraz',
#       'type': 'artist',
#       'uri': 'spotify:artist:4phGZZrJZRo4ElhRtViYdl'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 2,
#     'duration_ms': 303774,
#     'explicit': False,
#     'external_ids': {'isrc': 'QMRSZ2101526'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4AC7IWNxwTguS9jdQsLr2U'},
#     'href': 'https://api.spotify.com/v1/tracks/4AC7IWNxwTguS9jdQsLr2U',
#     'id': '4AC7IWNxwTguS9jdQsLr2U',
#     'is_local': False,
#     'name': "I'm Yours - Deluxe Version",
#     'popularity': 24,
#     'preview_url': 'https://p.scdn.co/mp3-preview/8ff7e7e5025822189128e64f4ed01605f88a098e?cid=6e24789ec7874259a220f747fcd7e93e',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:4AC7IWNxwTguS9jdQsLr2U'},
#    {'album': {'album_type': 'compilation',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#        'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#        'id': '0LyfQWJT6nXafLPZqxe9Of',
#        'name': 'Various Artists',
#        'type': 'artist',
#        'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#      'available_markets': ['US'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/67C96QsTFtr2y1anvpoDgp'},
#      'href': 'https://api.spotify.com/v1/albums/67C96QsTFtr2y1anvpoDgp',
#      'id': '67C96QsTFtr2y1anvpoDgp',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27399766f3ba5fb9756c1af4bb0',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0299766f3ba5fb9756c1af4bb0',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485199766f3ba5fb9756c1af4bb0',
#        'width': 64}],
#      'name': "NOW That's What I Call Music 29, 30, 31",
#      'release_date': '2009-01-01',
#      'release_date_precision': 'day',
#      'total_tracks': 60,
#      'type': 'album',
#      'uri': 'spotify:album:67C96QsTFtr2y1anvpoDgp'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4phGZZrJZRo4ElhRtViYdl'},
#       'href': 'https://api.spotify.com/v1/artists/4phGZZrJZRo4ElhRtViYdl',
#       'id': '4phGZZrJZRo4ElhRtViYdl',
#       'name': 'Jason Mraz',
#       'type': 'artist',
#       'uri': 'spotify:artist:4phGZZrJZRo4ElhRtViYdl'}],
#     'available_markets': ['US'],
#     'disc_number': 1,
#     'duration_ms': 211853,
#     'explicit': False,
#     'external_ids': {'isrc': 'USEE10800666'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/2ppFosjLbRP2bnc2RHvx4S'},
#     'href': 'https://api.spotify.com/v1/tracks/2ppFosjLbRP2bnc2RHvx4S',
#     'id': '2ppFosjLbRP2bnc2RHvx4S',
#     'is_local': False,
#     'name': "I'm Yours",
#     'popularity': 13,
#     'preview_url': 'https://p.scdn.co/mp3-preview/2be4b3cbc9c6ff53b230c1dc94bf2a94b58c9cc0?cid=6e24789ec7874259a220f747fcd7e93e',
#     'track_number': 38,
#     'type': 'track',
#     'uri': 'spotify:track:2ppFosjLbRP2bnc2RHvx4S'}],
#   'limit': 20,
#   'next': 'https://api.spotify.com/v1/search?query=track%3AIm+Yours+artist%3AJason&type=track&offset=20&limit=20',
#   'offset': 0,
#   'previous': None,
#   'total': 221}}

# %%
test = pd.DataFrame.from_dict(Im_Yours,orient='columns')
test
# Out:
#                                                      tracks
# href      https://api.spotify.com/v1/search?query=track%...
# items     [{'album': {'album_type': 'album', 'artists': ...
# limit                                                    20
# next      https://api.spotify.com/v1/search?query=track%...
# offset                                                    0
# previous                                               None
# total                                                   221

# %%
test= test.tracks.apply(pd.Series)
test
# Out:
# /var/folders/91/wchv5p25455f2k8078kdjvm40000gn/T/ipykernel_28065/2977931382.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   test= test.tracks.apply(pd.Series)
#                                                           0  \
# href      https://api.spotify.com/v1/search?query=track%...
# items     {'album': {'album_type': 'album', 'artists': [...
# limit                                                  20.0
# next      https://api.spotify.com/v1/search?query=track%...
# offset                                                  0.0
# previous                                                NaN
# total                                                 221.0
#
#                                                           1  \
# href                                                    NaN
# items     {'album': {'album_type': 'compilation', 'artis...
# limit                                                   NaN
# next                                                    NaN
# offset                                                  NaN
# previous                                                NaN
# total                                                   NaN
#
#                                                           2  \
# href                                                    NaN
# items     {'album': {'album_type': 'compilation', 'artis...
# limit                                                   NaN
# next                                                    NaN
# offset                                                  NaN
# previous                                                NaN
# total                                                   NaN
#
#                                                           3  \
# href                                                    NaN
# items     {'album': {'album_type': 'compilation', 'artis...
# limit                                                   NaN
# next                                                    NaN
# offset                                                  NaN
# previous                                                NaN
# total                                                   NaN
#
#                                                           4  \
# href                                                    NaN
# items     {'album': {'album_type': 'compilation', 'artis...
# limit                                                   NaN
# next                                                    NaN
# offset                                                  NaN
# previous                                                NaN
# total                                                   NaN
#
#                                                           5  \
# href                                                    NaN
# items     {'album': {'album_type': 'compilation', 'artis...
# limit                                                   NaN
# next                                                    NaN
# offset                                                  NaN
# previous                                                NaN
# total                                                   NaN
#
#                                                           6  \
# href                                                    NaN
# items     {'album': {'album_type': 'compilation', 'artis...
# limit                                                   NaN
# next                                                    NaN
# offset                                                  NaN
# previous                                                NaN
# total                                                   NaN
#
#                                                           7  \
# href                                                    NaN
# items     {'album': {'album_type': 'compilation', 'artis...
# limit                                                   NaN
# next                                                    NaN
# offset                                                  NaN
# previous                                                NaN
# total                                                   NaN
#
#                                                           8  \
# href                                                    NaN
# items     {'album': {'album_type': 'compilation', 'artis...
# limit                                                   NaN
# next                                                    NaN
# offset                                                  NaN
# previous                                                NaN
# total                                                   NaN
#
#                                                           9  \
# href                                                    NaN
# items     {'album': {'album_type': 'album', 'artists': [...
# limit                                                   NaN
# next                                                    NaN
# offset                                                  NaN
# previous                                                NaN
# total                                                   NaN
#
#                                                          10  \
# href                                                    NaN
# items     {'album': {'album_type': 'single', 'artists': ...
# limit                                                   NaN
# next                                                    NaN
# offset                                                  NaN
# previous                                                NaN
# total                                                   NaN
#
#                                                          11  \
# href                                                    NaN
# items     {'album': {'album_type': 'album', 'artists': [...
# limit                                                   NaN
# next                                                    NaN
# offset                                                  NaN
# previous                                                NaN
# total                                                   NaN
#
#                                                          12  \
# href                                                    NaN
# items     {'album': {'album_type': 'album', 'artists': [...
# limit                                                   NaN
# next                                                    NaN
# offset                                                  NaN
# previous                                                NaN
# total                                                   NaN
#
#                                                          13  \
# href                                                    NaN
# items     {'album': {'album_type': 'album', 'artists': [...
# limit                                                   NaN
# next                                                    NaN
# offset                                                  NaN
# previous                                                NaN
# total                                                   NaN
#
#                                                          14  \
# href                                                    NaN
# items     {'album': {'album_type': 'single', 'artists': ...
# limit                                                   NaN
# next                                                    NaN
# offset                                                  NaN
# previous                                                NaN
# total                                                   NaN
#
#                                                          15  \
# href                                                    NaN
# items     {'album': {'album_type': 'compilation', 'artis...
# limit                                                   NaN
# next                                                    NaN
# offset                                                  NaN
# previous                                                NaN
# total                                                   NaN
#
#                                                          16  \
# href                                                    NaN
# items     {'album': {'album_type': 'album', 'artists': [...
# limit                                                   NaN
# next                                                    NaN
# offset                                                  NaN
# previous                                                NaN
# total                                                   NaN
#
#                                                          17  \
# href                                                    NaN
# items     {'album': {'album_type': 'compilation', 'artis...
# limit                                                   NaN
# next                                                    NaN
# offset                                                  NaN
# previous                                                NaN
# total                                                   NaN
#
#                                                          18  \
# href                                                    NaN
# items     {'album': {'album_type': 'album', 'artists': [...
# limit                                                   NaN
# next                                                    NaN
# offset                                                  NaN
# previous                                                NaN
# total                                                   NaN
#
#                                                          19
# href                                                    NaN
# items     {'album': {'album_type': 'compilation', 'artis...
# limit                                                   NaN
# next                                                    NaN
# offset                                                  NaN
# previous                                                NaN
# total                                                   NaN

# %%
test2 = pd.DataFrame(test.iloc[1])
test2
# Out:
#                                                 items
# 0   {'album': {'album_type': 'album', 'artists': [...
# 1   {'album': {'album_type': 'compilation', 'artis...
# 2   {'album': {'album_type': 'compilation', 'artis...
# 3   {'album': {'album_type': 'compilation', 'artis...
# 4   {'album': {'album_type': 'compilation', 'artis...
# 5   {'album': {'album_type': 'compilation', 'artis...
# 6   {'album': {'album_type': 'compilation', 'artis...
# 7   {'album': {'album_type': 'compilation', 'artis...
# 8   {'album': {'album_type': 'compilation', 'artis...
# 9   {'album': {'album_type': 'album', 'artists': [...
# 10  {'album': {'album_type': 'single', 'artists': ...
# 11  {'album': {'album_type': 'album', 'artists': [...
# 12  {'album': {'album_type': 'album', 'artists': [...
# 13  {'album': {'album_type': 'album', 'artists': [...
# 14  {'album': {'album_type': 'single', 'artists': ...
# 15  {'album': {'album_type': 'compilation', 'artis...
# 16  {'album': {'album_type': 'album', 'artists': [...
# 17  {'album': {'album_type': 'compilation', 'artis...
# 18  {'album': {'album_type': 'album', 'artists': [...
# 19  {'album': {'album_type': 'compilation', 'artis...

# %%
test3 = test2['items'].apply(pd.Series)
test3
# Out:
#                                                 album  \
# 0   {'album_type': 'album', 'artists': [{'external...
# 1   {'album_type': 'compilation', 'artists': [{'ex...
# 2   {'album_type': 'compilation', 'artists': [{'ex...
# 3   {'album_type': 'compilation', 'artists': [{'ex...
# 4   {'album_type': 'compilation', 'artists': [{'ex...
# 5   {'album_type': 'compilation', 'artists': [{'ex...
# 6   {'album_type': 'compilation', 'artists': [{'ex...
# 7   {'album_type': 'compilation', 'artists': [{'ex...
# 8   {'album_type': 'compilation', 'artists': [{'ex...
# 9   {'album_type': 'album', 'artists': [{'external...
# 10  {'album_type': 'single', 'artists': [{'externa...
# 11  {'album_type': 'album', 'artists': [{'external...
# 12  {'album_type': 'album', 'artists': [{'external...
# 13  {'album_type': 'album', 'artists': [{'external...
# 14  {'album_type': 'single', 'artists': [{'externa...
# 15  {'album_type': 'compilation', 'artists': [{'ex...
# 16  {'album_type': 'album', 'artists': [{'external...
# 17  {'album_type': 'compilation', 'artists': [{'ex...
# 18  {'album_type': 'album', 'artists': [{'external...
# 19  {'album_type': 'compilation', 'artists': [{'ex...
#
#                                               artists  \
# 0   [{'external_urls': {'spotify': 'https://open.s...
# 1   [{'external_urls': {'spotify': 'https://open.s...
# 2   [{'external_urls': {'spotify': 'https://open.s...
# 3   [{'external_urls': {'spotify': 'https://open.s...
# 4   [{'external_urls': {'spotify': 'https://open.s...
# 5   [{'external_urls': {'spotify': 'https://open.s...
# 6   [{'external_urls': {'spotify': 'https://open.s...
# 7   [{'external_urls': {'spotify': 'https://open.s...
# 8   [{'external_urls': {'spotify': 'https://open.s...
# 9   [{'external_urls': {'spotify': 'https://open.s...
# 10  [{'external_urls': {'spotify': 'https://open.s...
# 11  [{'external_urls': {'spotify': 'https://open.s...
# 12  [{'external_urls': {'spotify': 'https://open.s...
# 13  [{'external_urls': {'spotify': 'https://open.s...
# 14  [{'external_urls': {'spotify': 'https://open.s...
# 15  [{'external_urls': {'spotify': 'https://open.s...
# 16  [{'external_urls': {'spotify': 'https://open.s...
# 17  [{'external_urls': {'spotify': 'https://open.s...
# 18  [{'external_urls': {'spotify': 'https://open.s...
# 19  [{'external_urls': {'spotify': 'https://open.s...
#
#                                     available_markets  disc_number  \
# 0   [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...            1
# 1   [AD, AE, AG, AL, AM, AR, AT, AZ, BA, BB, BD, B...            1
# 2   [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...            1
# 3   [AD, AE, AG, AL, AM, AO, AR, AZ, BA, BB, BD, B...            1
# 4   [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...            1
# 5   [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...            1
# 6   [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...            1
# 7   [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...            1
# 8                                                [US]            1
# 9   [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...            1
# 10  [AR, BO, BR, BZ, CA, CL, CO, CR, DO, EC, GT, G...            1
# 11                                           [CA, US]            1
# 12  [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...            1
# 13                                           [CA, US]            1
# 14  [AR, BO, BR, BZ, CA, CL, CO, CR, DO, EC, GT, G...            1
# 15  [AD, AE, AG, AL, AM, AO, AR, AZ, BA, BB, BD, B...            1
# 16  [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...            1
# 17  [AD, AE, AG, AL, AM, AO, AR, AU, AZ, BA, BB, B...            1
# 18  [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...            2
# 19                                               [US]            1
#
#     duration_ms  explicit              external_ids  \
# 0        242946     False  {'isrc': 'USEE10800667'}
# 1        242040     False  {'isrc': 'USEE10800667'}
# 2        242040     False  {'isrc': 'USEE10800667'}
# 3        242040     False  {'isrc': 'USEE10800667'}
# 4        242040     False  {'isrc': 'USEE10800667'}
# 5        242040     False  {'isrc': 'USEE10800667'}
# 6        242040     False  {'isrc': 'USEE10800667'}
# 7        214213     False  {'isrc': 'USEE10800666'}
# 8        242040     False  {'isrc': 'USEE10800667'}
# 9        243941     False  {'isrc': 'USEE11400815'}
# 10       242946     False  {'isrc': 'USEE10800667'}
# 11       242946     False  {'isrc': 'USEE10800667'}
# 12       312800     False  {'isrc': 'USEE10901222'}
# 13       287093     False  {'isrc': 'USEE10800763'}
# 14       257359     False  {'isrc': 'USEE10413988'}
# 15       242040     False  {'isrc': 'USEE10800667'}
# 16       242946     False  {'isrc': 'USEE10800667'}
# 17       242040     False  {'isrc': 'USEE10800667'}
# 18       303774     False  {'isrc': 'QMRSZ2101526'}
# 19       211853     False  {'isrc': 'USEE10800666'}
#
#                                         external_urls  \
# 0   {'spotify': 'https://open.spotify.com/track/1E...
# 1   {'spotify': 'https://open.spotify.com/track/00...
# 2   {'spotify': 'https://open.spotify.com/track/5W...
# 3   {'spotify': 'https://open.spotify.com/track/37...
# 4   {'spotify': 'https://open.spotify.com/track/6c...
# 5   {'spotify': 'https://open.spotify.com/track/3H...
# 6   {'spotify': 'https://open.spotify.com/track/2U...
# 7   {'spotify': 'https://open.spotify.com/track/1j...
# 8   {'spotify': 'https://open.spotify.com/track/2V...
# 9   {'spotify': 'https://open.spotify.com/track/1j...
# 10  {'spotify': 'https://open.spotify.com/track/57...
# 11  {'spotify': 'https://open.spotify.com/track/36...
# 12  {'spotify': 'https://open.spotify.com/track/3O...
# 13  {'spotify': 'https://open.spotify.com/track/0U...
# 14  {'spotify': 'https://open.spotify.com/track/4U...
# 15  {'spotify': 'https://open.spotify.com/track/00...
# 16  {'spotify': 'https://open.spotify.com/track/08...
# 17  {'spotify': 'https://open.spotify.com/track/66...
# 18  {'spotify': 'https://open.spotify.com/track/4A...
# 19  {'spotify': 'https://open.spotify.com/track/2p...
#
#                                                  href                      id  \
# 0   https://api.spotify.com/v1/tracks/1EzrEOXmMH3G...  1EzrEOXmMH3G43AXT1y7pA
# 1   https://api.spotify.com/v1/tracks/00Dr2e9a3Ut6...  00Dr2e9a3Ut6aUVGe8IoHH
# 2   https://api.spotify.com/v1/tracks/5Wgjc8n0W2SD...  5Wgjc8n0W2SDKgfBsqF46L
# 3   https://api.spotify.com/v1/tracks/37QJGL7UHOSv...  37QJGL7UHOSveSq1JfIyom
# 4   https://api.spotify.com/v1/tracks/6cAlQrApxMYd...  6cAlQrApxMYdz9lt4FWVBH
# 5   https://api.spotify.com/v1/tracks/3HN0AC9gB2DJ...  3HN0AC9gB2DJjOlPsI25br
# 6   https://api.spotify.com/v1/tracks/2U9jmCadmcaJ...  2U9jmCadmcaJiGgT9FH1XM
# 7   https://api.spotify.com/v1/tracks/1jTeSfeZ4nma...  1jTeSfeZ4nmaLeAPEDfFac
# 8   https://api.spotify.com/v1/tracks/2VIRAajP1QOn...  2VIRAajP1QOneP9zJ9v2y8
# 9   https://api.spotify.com/v1/tracks/1j5cGcXWdHKT...  1j5cGcXWdHKTPQ2XgXODJI
# 10  https://api.spotify.com/v1/tracks/57URzGoYgSj0...  57URzGoYgSj0AiXclvqD6y
# 11  https://api.spotify.com/v1/tracks/36j4mlX0IWUt...  36j4mlX0IWUtWlWqiwvWXI
# 12  https://api.spotify.com/v1/tracks/3OGcceoTcTwR...  3OGcceoTcTwRQjJmh1K5jF
# 13  https://api.spotify.com/v1/tracks/0UCwB06x7avK...  0UCwB06x7avKQDFAkNVg2T
# 14  https://api.spotify.com/v1/tracks/4UI1Ow2RwIOg...  4UI1Ow2RwIOg0BLsJf2k9w
# 15  https://api.spotify.com/v1/tracks/00EsQu3vriau...  00EsQu3vriau5a9df7mrS5
# 16  https://api.spotify.com/v1/tracks/08rQ80583Ale...  08rQ80583Alesr2BMMAVfQ
# 17  https://api.spotify.com/v1/tracks/66BVPsCvlfSe...  66BVPsCvlfSeFRNKENpMsx
# 18  https://api.spotify.com/v1/tracks/4AC7IWNxwTgu...  4AC7IWNxwTguS9jdQsLr2U
# 19  https://api.spotify.com/v1/tracks/2ppFosjLbRP2...  2ppFosjLbRP2bnc2RHvx4S
#
#     is_local                                               name  popularity  \
# 0      False                                          I'm Yours          79
# 1      False                                          I'm Yours           0
# 2      False                                          I'm Yours           0
# 3      False                                          I'm Yours           0
# 4      False                                          I'm Yours           0
# 5      False                                          I'm Yours           0
# 6      False                                          I'm Yours           0
# 7      False                             I'm Yours - Radio Edit           0
# 8      False                                          I'm Yours          35
# 9      False                       I'm Yours - Live on HSN Live          55
# 10     False                                          I'm Yours          34
# 11     False                                          I'm Yours          33
# 12     False  I'm Yours - Live at the Charter One Pavilion, ...          46
# 13     False            I'm Yours - From the Casa Nova Sessions          27
# 14     False                                   I'm Yours - Demo          26
# 15     False                                          I'm Yours          32
# 16     False                                          I'm Yours          32
# 17     False                                          I'm Yours          21
# 18     False                         I'm Yours - Deluxe Version          24
# 19     False                                          I'm Yours          13
#
#                                           preview_url  track_number   type  \
# 0   https://p.scdn.co/mp3-preview/975f7acc6041b1b7...             2  track
# 1   https://p.scdn.co/mp3-preview/a4fd098ade918bf6...            70  track
# 2   https://p.scdn.co/mp3-preview/a4fd098ade918bf6...             3  track
# 3   https://p.scdn.co/mp3-preview/a4fd098ade918bf6...            20  track
# 4   https://p.scdn.co/mp3-preview/a4fd098ade918bf6...            68  track
# 5   https://p.scdn.co/mp3-preview/a4fd098ade918bf6...            63  track
# 6   https://p.scdn.co/mp3-preview/a4fd098ade918bf6...            44  track
# 7   https://p.scdn.co/mp3-preview/4c9e5bac42684029...            25  track
# 8   https://p.scdn.co/mp3-preview/c782977ab382a245...             1  track
# 9   https://p.scdn.co/mp3-preview/9204645792ba99b5...             6  track
# 10  https://p.scdn.co/mp3-preview/975f7acc6041b1b7...             1  track
# 11  https://p.scdn.co/mp3-preview/975f7acc6041b1b7...             2  track
# 12  https://p.scdn.co/mp3-preview/4dbaef98a0f8db54...            11  track
# 13  https://p.scdn.co/mp3-preview/33c43f51a36dac12...            13  track
# 14  https://p.scdn.co/mp3-preview/f3c78733294e5a49...             2  track
# 15  https://p.scdn.co/mp3-preview/a4fd098ade918bf6...             6  track
# 16  https://p.scdn.co/mp3-preview/975f7acc6041b1b7...             1  track
# 17  https://p.scdn.co/mp3-preview/c782977ab382a245...            16  track
# 18  https://p.scdn.co/mp3-preview/8ff7e7e502582218...             1  track
# 19  https://p.scdn.co/mp3-preview/2be4b3cbc9c6ff53...            38  track
#
#                                      uri
# 0   spotify:track:1EzrEOXmMH3G43AXT1y7pA
# 1   spotify:track:00Dr2e9a3Ut6aUVGe8IoHH
# 2   spotify:track:5Wgjc8n0W2SDKgfBsqF46L
# 3   spotify:track:37QJGL7UHOSveSq1JfIyom
# 4   spotify:track:6cAlQrApxMYdz9lt4FWVBH
# 5   spotify:track:3HN0AC9gB2DJjOlPsI25br
# 6   spotify:track:2U9jmCadmcaJiGgT9FH1XM
# 7   spotify:track:1jTeSfeZ4nmaLeAPEDfFac
# 8   spotify:track:2VIRAajP1QOneP9zJ9v2y8
# 9   spotify:track:1j5cGcXWdHKTPQ2XgXODJI
# 10  spotify:track:57URzGoYgSj0AiXclvqD6y
# 11  spotify:track:36j4mlX0IWUtWlWqiwvWXI
# 12  spotify:track:3OGcceoTcTwRQjJmh1K5jF
# 13  spotify:track:0UCwB06x7avKQDFAkNVg2T
# 14  spotify:track:4UI1Ow2RwIOg0BLsJf2k9w
# 15  spotify:track:00EsQu3vriau5a9df7mrS5
# 16  spotify:track:08rQ80583Alesr2BMMAVfQ
# 17  spotify:track:66BVPsCvlfSeFRNKENpMsx
# 18  spotify:track:4AC7IWNxwTguS9jdQsLr2U
# 19  spotify:track:2ppFosjLbRP2bnc2RHvx4S

# %%
test3.head(1)
# Out:
#                                                album  \
# 0  {'album_type': 'album', 'artists': [{'external...
#
#                                              artists  \
# 0  [{'external_urls': {'spotify': 'https://open.s...
#
#                                    available_markets  disc_number  \
# 0  [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...            1
#
#    duration_ms  explicit              external_ids  \
# 0       242946     False  {'isrc': 'USEE10800667'}
#
#                                        external_urls  \
# 0  {'spotify': 'https://open.spotify.com/track/1E...
#
#                                                 href                      id  \
# 0  https://api.spotify.com/v1/tracks/1EzrEOXmMH3G...  1EzrEOXmMH3G43AXT1y7pA
#
#    is_local       name  popularity  \
# 0     False  I'm Yours          79
#
#                                          preview_url  track_number   type  \
# 0  https://p.scdn.co/mp3-preview/975f7acc6041b1b7...             2  track
#
#                                     uri
# 0  spotify:track:1EzrEOXmMH3G43AXT1y7pA
