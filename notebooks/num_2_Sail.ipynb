# %%
# import packages

# %%
from pandas.io.json import json_normalize
import json
from pandasql import sqldf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from bs4 import BeautifulSoup
import io
import requests
import json
import base64
import datetime
from urllib.parse import urlencode

# %%
# client id

# %%
client_id = '6e24789ec7874259a220f747fcd7e93e'
client_secret = '9bd8ff1ad2f34ef6a87f00124be070b2'

# %%
class SpotifyAPI(object):
    access_token = None
    access_token_expires = datetime.datetime.now()
    access_token_did_expire = True
    client_id = None
    client_secret = None
    token_url = "https://accounts.spotify.com/api/token"



    def __init__(self, client_id, client_secret, *args, **kwargs):
        super().__init__(*args, **kwargs)
        self.client_id = client_id
        self.client_secret = client_secret

    def getClientCreds(self):
        '''Returns b64 encoded string'''
        client_id = self.client_id
        client_secret = self.client_secret

        if client_id == None or client_secret == None:
            raise Exception('Must set a client id and secret')

        client_creds  = f"{client_id}:{client_secret}"
        client_creds_b64 = base64.b64encode(client_creds.encode())
        return client_creds_b64.decode()

    def getTokenHeader(self):
        client_creds_b64 = self.getClientCreds()
        return {
            'Authorization':f"Basic {client_creds_b64}"
        }

    def getTokenData(self):
        return {
            "grant_type":"client_credentials"
        }

    def perform_auth(self):
        token_url = self.token_url
        token_data = self.getTokenData()
        token_header = self.getTokenHeader()

        r = requests.post(token_url, data=token_data, headers=token_header)

        if r.status_code  not in range(200,299):
            raise Exception('Could not authenticate client.')
            #return False

        now = datetime.datetime.now()
        token_response_data = r.json()
        access_token = token_response_data['access_token']
        expires_in = token_response_data['expires_in']
        expires = now + datetime.timedelta(seconds=expires_in)
        self.access_token = access_token
        self.access_token_expires = expires
        self.access_token_did_expire = expires < now


        return True

    def get_access_token(self):
        token = self.access_token
        expires = self.access_token_expires
        now= datetime.datetime.now()
        if expires < now:
            self.perform_auth()
            return self.get_access_token()
        elif token == None:
            self.perform_auth()
            return self.get_access_token() 
        return token
    
    def get_resource_header(self):
        access_token = self.get_access_token()
        headers = {
            "Authorization": f"Bearer {access_token}", 
        }
        return headers
    
    def get_resource(self, lookup_id, resource_type='albums', version='v1'):
        endpoint = f'https://api.spotify.com/{version}/{resource_type}/{lookup_id}'
        headers = self.get_resource_header()
        r = requests.get(endpoint, headers = headers)
        if r.status_code not in range (200, 299):
            return {}
        return r.json()
    
    def get_album(self, _id ):
        return self.get_resource(_id, resource_type='albums')
    
    def get_artist(self, _id ):
        return self.get_resource(_id, resource_type='artists')
    
    def get_playlist(self, _id):
        return self.get_resource(_id, resource_type='playlists')
    
    
    def base_search(self, query_params): #type
        access_token = self.get_access_token()
        headers = self.get_resource_header()
        endpoint = "https://api.spotify.com/v1/search"
        lookup_URL = f"{endpoint}?{query_params}"
        r = requests.get(lookup_URL, headers=headers)
        if r.status_code not in range (200, 299):
            return {}
        return r.json()
    
    def search(self, query=None, operator=None, operator_query=None, search_type='artist'):
        if query == None:
            raise Exception('A query is required')
        if isinstance(query, dict):
            query = ' '.join([f'{k}:{v}' for k,v in query.items()])
        if operator != None and operator_query != None:
            if operator.lower() == 'or' or operator.lower() == 'not':
                operator = operator.upper()
                if isinstance(operator_query, str):
                    query = f'{query} {operator} {operator_query}'
        query_params = urlencode({'q': query, 'type': search_type.lower()})
        return self.base_search(query_params)

# %%
spotify = SpotifyAPI(client_id, client_secret)

# %%
# radioactive

# %%
radioactive = spotify.search({'track': 'Sail', 'artist': 'AWOL'}, search_type ='track')
radioactive
# Out:
# {'tracks': {'href': 'https://api.spotify.com/v1/search?query=track%3ASail+artist%3AAWOL&type=track&offset=0&limit=20',
#   'items': [{'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4njdEjTnLfcGImKZu1iSrz'},
#        'href': 'https://api.spotify.com/v1/artists/4njdEjTnLfcGImKZu1iSrz',
#        'id': '4njdEjTnLfcGImKZu1iSrz',
#        'name': 'AWOLNATION',
#        'type': 'artist',
#        'uri': 'spotify:artist:4njdEjTnLfcGImKZu1iSrz'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/1fag8cnc5p4Umu4tRMAsLv'},
#      'href': 'https://api.spotify.com/v1/albums/1fag8cnc5p4Umu4tRMAsLv',
#      'id': '1fag8cnc5p4Umu4tRMAsLv',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27332f1572738340ddc9569c54b',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0232f1572738340ddc9569c54b',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485132f1572738340ddc9569c54b',
#        'width': 64}],
#      'name': 'Megalithic Symphony',
#      'release_date': '2011-03-15',
#      'release_date_precision': 'day',
#      'total_tracks': 14,
#      'type': 'album',
#      'uri': 'spotify:album:1fag8cnc5p4Umu4tRMAsLv'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4njdEjTnLfcGImKZu1iSrz'},
#       'href': 'https://api.spotify.com/v1/artists/4njdEjTnLfcGImKZu1iSrz',
#       'id': '4njdEjTnLfcGImKZu1iSrz',
#       'name': 'AWOLNATION',
#       'type': 'artist',
#       'uri': 'spotify:artist:4njdEjTnLfcGImKZu1iSrz'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 259093,
#     'explicit': False,
#     'external_ids': {'isrc': 'USP6L1000053'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/7ueP5u2qkdZbIPN2YA6LR0'},
#     'href': 'https://api.spotify.com/v1/tracks/7ueP5u2qkdZbIPN2YA6LR0',
#     'id': '7ueP5u2qkdZbIPN2YA6LR0',
#     'is_local': False,
#     'name': 'Sail',
#     'popularity': 74,
#     'preview_url': 'https://p.scdn.co/mp3-preview/39fe4367061eac834b5da72bddc9af6c8d7c3def?cid=6e24789ec7874259a220f747fcd7e93e',
#     'track_number': 10,
#     'type': 'track',
#     'uri': 'spotify:track:7ueP5u2qkdZbIPN2YA6LR0'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4njdEjTnLfcGImKZu1iSrz'},
#        'href': 'https://api.spotify.com/v1/artists/4njdEjTnLfcGImKZu1iSrz',
#        'id': '4njdEjTnLfcGImKZu1iSrz',
#        'name': 'AWOLNATION',
#        'type': 'artist',
#        'uri': 'spotify:artist:4njdEjTnLfcGImKZu1iSrz'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5JNXvM5u7H04wj71hDLfux'},
#      'href': 'https://api.spotify.com/v1/albums/5JNXvM5u7H04wj71hDLfux',
#      'id': '5JNXvM5u7H04wj71hDLfux',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2730f9d33cae4a0275e8fd28b93',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e020f9d33cae4a0275e8fd28b93',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048510f9d33cae4a0275e8fd28b93',
#        'width': 64}],
#      'name': 'Megalithic Symphony (10th Anniversary Deluxe Edition)',
#      'release_date': '2021-03-15',
#      'release_date_precision': 'day',
#      'total_tracks': 41,
#      'type': 'album',
#      'uri': 'spotify:album:5JNXvM5u7H04wj71hDLfux'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4njdEjTnLfcGImKZu1iSrz'},
#       'href': 'https://api.spotify.com/v1/artists/4njdEjTnLfcGImKZu1iSrz',
#       'id': '4njdEjTnLfcGImKZu1iSrz',
#       'name': 'AWOLNATION',
#       'type': 'artist',
#       'uri': 'spotify:artist:4njdEjTnLfcGImKZu1iSrz'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/5FWi1mowu6uiU2ZHwr1rby'},
#       'href': 'https://api.spotify.com/v1/artists/5FWi1mowu6uiU2ZHwr1rby',
#       'id': '5FWi1mowu6uiU2ZHwr1rby',
#       'name': 'Feed Me',
#       'type': 'artist',
#       'uri': 'spotify:artist:5FWi1mowu6uiU2ZHwr1rby'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 209276,
#     'explicit': False,
#     'external_ids': {'isrc': 'USP6L1280129'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/24mf5NTXbNe1de7w6rjaEn'},
#     'href': 'https://api.spotify.com/v1/tracks/24mf5NTXbNe1de7w6rjaEn',
#     'id': '24mf5NTXbNe1de7w6rjaEn',
#     'is_local': False,
#     'name': 'Sail - Feed Me Remix',
#     'popularity': 53,
#     'preview_url': 'https://p.scdn.co/mp3-preview/a6e773d08a3ea3c2c6f0c044963b800cdb159bab?cid=6e24789ec7874259a220f747fcd7e93e',
#     'track_number': 39,
#     'type': 'track',
#     'uri': 'spotify:track:24mf5NTXbNe1de7w6rjaEn'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4njdEjTnLfcGImKZu1iSrz'},
#        'href': 'https://api.spotify.com/v1/artists/4njdEjTnLfcGImKZu1iSrz',
#        'id': '4njdEjTnLfcGImKZu1iSrz',
#        'name': 'AWOLNATION',
#        'type': 'artist',
#        'uri': 'spotify:artist:4njdEjTnLfcGImKZu1iSrz'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5JNXvM5u7H04wj71hDLfux'},
#      'href': 'https://api.spotify.com/v1/albums/5JNXvM5u7H04wj71hDLfux',
#      'id': '5JNXvM5u7H04wj71hDLfux',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2730f9d33cae4a0275e8fd28b93',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e020f9d33cae4a0275e8fd28b93',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048510f9d33cae4a0275e8fd28b93',
#        'width': 64}],
#      'name': 'Megalithic Symphony (10th Anniversary Deluxe Edition)',
#      'release_date': '2021-03-15',
#      'release_date_precision': 'day',
#      'total_tracks': 41,
#      'type': 'album',
#      'uri': 'spotify:album:5JNXvM5u7H04wj71hDLfux'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4njdEjTnLfcGImKZu1iSrz'},
#       'href': 'https://api.spotify.com/v1/artists/4njdEjTnLfcGImKZu1iSrz',
#       'id': '4njdEjTnLfcGImKZu1iSrz',
#       'name': 'AWOLNATION',
#       'type': 'artist',
#       'uri': 'spotify:artist:4njdEjTnLfcGImKZu1iSrz'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/0yQosVg3rwqj4yD7BHiTjF'},
#       'href': 'https://api.spotify.com/v1/artists/0yQosVg3rwqj4yD7BHiTjF',
#       'id': '0yQosVg3rwqj4yD7BHiTjF',
#       'name': 'Unlimited Gravity',
#       'type': 'artist',
#       'uri': 'spotify:artist:0yQosVg3rwqj4yD7BHiTjF'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 349654,
#     'explicit': False,
#     'external_ids': {'isrc': 'USP6L1180110'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3kX6cdhy9XQBPL81GvEt0Q'},
#     'href': 'https://api.spotify.com/v1/tracks/3kX6cdhy9XQBPL81GvEt0Q',
#     'id': '3kX6cdhy9XQBPL81GvEt0Q',
#     'is_local': False,
#     'name': 'Sail - Unlimited Gravity Remix',
#     'popularity': 46,
#     'preview_url': 'https://p.scdn.co/mp3-preview/72f0893e5def96e42ae5b0c9fbbc14d3e2f2486d?cid=6e24789ec7874259a220f747fcd7e93e',
#     'track_number': 41,
#     'type': 'track',
#     'uri': 'spotify:track:3kX6cdhy9XQBPL81GvEt0Q'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4njdEjTnLfcGImKZu1iSrz'},
#        'href': 'https://api.spotify.com/v1/artists/4njdEjTnLfcGImKZu1iSrz',
#        'id': '4njdEjTnLfcGImKZu1iSrz',
#        'name': 'AWOLNATION',
#        'type': 'artist',
#        'uri': 'spotify:artist:4njdEjTnLfcGImKZu1iSrz'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2vbBCOu3B7kTIONAjf0LgQ'},
#      'href': 'https://api.spotify.com/v1/albums/2vbBCOu3B7kTIONAjf0LgQ',
#      'id': '2vbBCOu3B7kTIONAjf0LgQ',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273f40ad52afcecbe77fa7950cc',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02f40ad52afcecbe77fa7950cc',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851f40ad52afcecbe77fa7950cc',
#        'width': 64}],
#      'name': 'RE/Sail',
#      'release_date': '2012-04-10',
#      'release_date_precision': 'day',
#      'total_tracks': 9,
#      'type': 'album',
#      'uri': 'spotify:album:2vbBCOu3B7kTIONAjf0LgQ'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4njdEjTnLfcGImKZu1iSrz'},
#       'href': 'https://api.spotify.com/v1/artists/4njdEjTnLfcGImKZu1iSrz',
#       'id': '4njdEjTnLfcGImKZu1iSrz',
#       'name': 'AWOLNATION',
#       'type': 'artist',
#       'uri': 'spotify:artist:4njdEjTnLfcGImKZu1iSrz'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 349537,
#     'explicit': False,
#     'external_ids': {'isrc': 'USP6L1180110'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/7qAWdfgvuDJQlhjppYtAfA'},
#     'href': 'https://api.spotify.com/v1/tracks/7qAWdfgvuDJQlhjppYtAfA',
#     'id': '7qAWdfgvuDJQlhjppYtAfA',
#     'is_local': False,
#     'name': 'Sail - Unlimited Gravity Remix',
#     'popularity': 42,
#     'preview_url': 'https://p.scdn.co/mp3-preview/9ae4e713856763d3073e6e40346c12c2e4c1799b?cid=6e24789ec7874259a220f747fcd7e93e',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:7qAWdfgvuDJQlhjppYtAfA'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4njdEjTnLfcGImKZu1iSrz'},
#        'href': 'https://api.spotify.com/v1/artists/4njdEjTnLfcGImKZu1iSrz',
#        'id': '4njdEjTnLfcGImKZu1iSrz',
#        'name': 'AWOLNATION',
#        'type': 'artist',
#        'uri': 'spotify:artist:4njdEjTnLfcGImKZu1iSrz'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5JNXvM5u7H04wj71hDLfux'},
#      'href': 'https://api.spotify.com/v1/albums/5JNXvM5u7H04wj71hDLfux',
#      'id': '5JNXvM5u7H04wj71hDLfux',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2730f9d33cae4a0275e8fd28b93',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e020f9d33cae4a0275e8fd28b93',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048510f9d33cae4a0275e8fd28b93',
#        'width': 64}],
#      'name': 'Megalithic Symphony (10th Anniversary Deluxe Edition)',
#      'release_date': '2021-03-15',
#      'release_date_precision': 'day',
#      'total_tracks': 41,
#      'type': 'album',
#      'uri': 'spotify:album:5JNXvM5u7H04wj71hDLfux'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4njdEjTnLfcGImKZu1iSrz'},
#       'href': 'https://api.spotify.com/v1/artists/4njdEjTnLfcGImKZu1iSrz',
#       'id': '4njdEjTnLfcGImKZu1iSrz',
#       'name': 'AWOLNATION',
#       'type': 'artist',
#       'uri': 'spotify:artist:4njdEjTnLfcGImKZu1iSrz'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/0g9vAlRPK9Gt3FKCekk4TW'},
#       'href': 'https://api.spotify.com/v1/artists/0g9vAlRPK9Gt3FKCekk4TW',
#       'id': '0g9vAlRPK9Gt3FKCekk4TW',
#       'name': 'Ab-Soul',
#       'type': 'artist',
#       'uri': 'spotify:artist:0g9vAlRPK9Gt3FKCekk4TW'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/2YZyLoL8N0Wb9xBt1NhZWg'},
#       'href': 'https://api.spotify.com/v1/artists/2YZyLoL8N0Wb9xBt1NhZWg',
#       'id': '2YZyLoL8N0Wb9xBt1NhZWg',
#       'name': 'Kendrick Lamar',
#       'type': 'artist',
#       'uri': 'spotify:artist:2YZyLoL8N0Wb9xBt1NhZWg'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/6zztB1gC7Dtck1wPv2GbHe'},
#       'href': 'https://api.spotify.com/v1/artists/6zztB1gC7Dtck1wPv2GbHe',
#       'id': '6zztB1gC7Dtck1wPv2GbHe',
#       'name': 'TDE',
#       'type': 'artist',
#       'uri': 'spotify:artist:6zztB1gC7Dtck1wPv2GbHe'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 240779,
#     'explicit': False,
#     'external_ids': {'isrc': 'USP6L1380136'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/5GChOpEKNxYXIRUxto2bWp'},
#     'href': 'https://api.spotify.com/v1/tracks/5GChOpEKNxYXIRUxto2bWp',
#     'id': '5GChOpEKNxYXIRUxto2bWp',
#     'is_local': False,
#     'name': 'Sail (feat. Kendrick Lamar & Ab Soul) - TDE Remix',
#     'popularity': 42,
#     'preview_url': 'https://p.scdn.co/mp3-preview/a5081f7e73252f8cc8f139cf4eed51d446e6a4df?cid=6e24789ec7874259a220f747fcd7e93e',
#     'track_number': 40,
#     'type': 'track',
#     'uri': 'spotify:track:5GChOpEKNxYXIRUxto2bWp'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4njdEjTnLfcGImKZu1iSrz'},
#        'href': 'https://api.spotify.com/v1/artists/4njdEjTnLfcGImKZu1iSrz',
#        'id': '4njdEjTnLfcGImKZu1iSrz',
#        'name': 'AWOLNATION',
#        'type': 'artist',
#        'uri': 'spotify:artist:4njdEjTnLfcGImKZu1iSrz'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2vbBCOu3B7kTIONAjf0LgQ'},
#      'href': 'https://api.spotify.com/v1/albums/2vbBCOu3B7kTIONAjf0LgQ',
#      'id': '2vbBCOu3B7kTIONAjf0LgQ',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273f40ad52afcecbe77fa7950cc',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02f40ad52afcecbe77fa7950cc',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851f40ad52afcecbe77fa7950cc',
#        'width': 64}],
#      'name': 'RE/Sail',
#      'release_date': '2012-04-10',
#      'release_date_precision': 'day',
#      'total_tracks': 9,
#      'type': 'album',
#      'uri': 'spotify:album:2vbBCOu3B7kTIONAjf0LgQ'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4njdEjTnLfcGImKZu1iSrz'},
#       'href': 'https://api.spotify.com/v1/artists/4njdEjTnLfcGImKZu1iSrz',
#       'id': '4njdEjTnLfcGImKZu1iSrz',
#       'name': 'AWOLNATION',
#       'type': 'artist',
#       'uri': 'spotify:artist:4njdEjTnLfcGImKZu1iSrz'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 261046,
#     'explicit': False,
#     'external_ids': {'isrc': 'USP6L1180113'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1DqGEFrotFhhPsowbbiSJf'},
#     'href': 'https://api.spotify.com/v1/tracks/1DqGEFrotFhhPsowbbiSJf',
#     'id': '1DqGEFrotFhhPsowbbiSJf',
#     'is_local': False,
#     'name': 'Sail - LED Remix',
#     'popularity': 31,
#     'preview_url': 'https://p.scdn.co/mp3-preview/dfcba7af50b33b9e1d8435beca34c1bfeaad4961?cid=6e24789ec7874259a220f747fcd7e93e',
#     'track_number': 4,
#     'type': 'track',
#     'uri': 'spotify:track:1DqGEFrotFhhPsowbbiSJf'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4njdEjTnLfcGImKZu1iSrz'},
#        'href': 'https://api.spotify.com/v1/artists/4njdEjTnLfcGImKZu1iSrz',
#        'id': '4njdEjTnLfcGImKZu1iSrz',
#        'name': 'AWOLNATION',
#        'type': 'artist',
#        'uri': 'spotify:artist:4njdEjTnLfcGImKZu1iSrz'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5JNXvM5u7H04wj71hDLfux'},
#      'href': 'https://api.spotify.com/v1/albums/5JNXvM5u7H04wj71hDLfux',
#      'id': '5JNXvM5u7H04wj71hDLfux',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2730f9d33cae4a0275e8fd28b93',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e020f9d33cae4a0275e8fd28b93',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048510f9d33cae4a0275e8fd28b93',
#        'width': 64}],
#      'name': 'Megalithic Symphony (10th Anniversary Deluxe Edition)',
#      'release_date': '2021-03-15',
#      'release_date_precision': 'day',
#      'total_tracks': 41,
#      'type': 'album',
#      'uri': 'spotify:album:5JNXvM5u7H04wj71hDLfux'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4njdEjTnLfcGImKZu1iSrz'},
#       'href': 'https://api.spotify.com/v1/artists/4njdEjTnLfcGImKZu1iSrz',
#       'id': '4njdEjTnLfcGImKZu1iSrz',
#       'name': 'AWOLNATION',
#       'type': 'artist',
#       'uri': 'spotify:artist:4njdEjTnLfcGImKZu1iSrz'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 259092,
#     'explicit': False,
#     'external_ids': {'isrc': 'USP6L1000053'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/5UGE88CogQMcdsQhwhSZce'},
#     'href': 'https://api.spotify.com/v1/tracks/5UGE88CogQMcdsQhwhSZce',
#     'id': '5UGE88CogQMcdsQhwhSZce',
#     'is_local': False,
#     'name': 'Sail',
#     'popularity': 30,
#     'preview_url': 'https://p.scdn.co/mp3-preview/15d4731f7d1f1cb94059e3a500d0c92f9b7851ca?cid=6e24789ec7874259a220f747fcd7e93e',
#     'track_number': 10,
#     'type': 'track',
#     'uri': 'spotify:track:5UGE88CogQMcdsQhwhSZce'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4njdEjTnLfcGImKZu1iSrz'},
#        'href': 'https://api.spotify.com/v1/artists/4njdEjTnLfcGImKZu1iSrz',
#        'id': '4njdEjTnLfcGImKZu1iSrz',
#        'name': 'AWOLNATION',
#        'type': 'artist',
#        'uri': 'spotify:artist:4njdEjTnLfcGImKZu1iSrz'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
# ...
#       'id': '4njdEjTnLfcGImKZu1iSrz',
#       'name': 'AWOLNATION',
#       'type': 'artist',
#       'uri': 'spotify:artist:4njdEjTnLfcGImKZu1iSrz'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 326596,
#     'explicit': False,
#     'external_ids': {'isrc': 'USP6L1080070'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/2J5Fgr9ak4ijU1IznV9hnX'},
#     'href': 'https://api.spotify.com/v1/tracks/2J5Fgr9ak4ijU1IznV9hnX',
#     'id': '2J5Fgr9ak4ijU1IznV9hnX',
#     'is_local': False,
#     'name': 'Sail - Innerpartysystem Remix',
#     'popularity': 12,
#     'preview_url': 'https://p.scdn.co/mp3-preview/2c59a5e4fecc4e8e8734b8ccc955737c1dedeb62?cid=6e24789ec7874259a220f747fcd7e93e',
#     'track_number': 8,
#     'type': 'track',
#     'uri': 'spotify:track:2J5Fgr9ak4ijU1IznV9hnX'},
#    {'album': {'album_type': 'compilation',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#        'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#        'id': '0LyfQWJT6nXafLPZqxe9Of',
#        'name': 'Various Artists',
#        'type': 'artist',
#        'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/0OuvSbT8h4nUHGvpnbZUlW'},
#      'href': 'https://api.spotify.com/v1/albums/0OuvSbT8h4nUHGvpnbZUlW',
#      'id': '0OuvSbT8h4nUHGvpnbZUlW',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273902742e7f6f79b48446fb28e',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02902742e7f6f79b48446fb28e',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851902742e7f6f79b48446fb28e',
#        'width': 64}],
#      'name': 'Relaxing Classical Playlist: Peaceful Heart of Winter',
#      'release_date': '2018-12-19',
#      'release_date_precision': 'day',
#      'total_tracks': 10,
#      'type': 'album',
#      'uri': 'spotify:album:0OuvSbT8h4nUHGvpnbZUlW'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6UvnpN4AYDmDbLwgqsdLrD'},
#       'href': 'https://api.spotify.com/v1/artists/6UvnpN4AYDmDbLwgqsdLrD',
#       'id': '6UvnpN4AYDmDbLwgqsdLrD',
#       'name': 'Awolnantion',
#       'type': 'artist',
#       'uri': 'spotify:artist:6UvnpN4AYDmDbLwgqsdLrD'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/63q73JjN6aDkgRvqNX9IB2'},
#       'href': 'https://api.spotify.com/v1/artists/63q73JjN6aDkgRvqNX9IB2',
#       'id': '63q73JjN6aDkgRvqNX9IB2',
#       'name': 'Giorgia Stella',
#       'type': 'artist',
#       'uri': 'spotify:artist:63q73JjN6aDkgRvqNX9IB2'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 178831,
#     'explicit': False,
#     'external_ids': {'isrc': 'PLS921748135'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/7auZAZQWm5Am8zU91qPCar'},
#     'href': 'https://api.spotify.com/v1/tracks/7auZAZQWm5Am8zU91qPCar',
#     'id': '7auZAZQWm5Am8zU91qPCar',
#     'is_local': False,
#     'name': 'Sail - Acoustic Cover',
#     'popularity': 8,
#     'preview_url': 'https://p.scdn.co/mp3-preview/727b681aefb8c056b4f6eb1b34193a2e57c5dae4?cid=6e24789ec7874259a220f747fcd7e93e',
#     'track_number': 5,
#     'type': 'track',
#     'uri': 'spotify:track:7auZAZQWm5Am8zU91qPCar'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4njdEjTnLfcGImKZu1iSrz'},
#        'href': 'https://api.spotify.com/v1/artists/4njdEjTnLfcGImKZu1iSrz',
#        'id': '4njdEjTnLfcGImKZu1iSrz',
#        'name': 'AWOLNATION',
#        'type': 'artist',
#        'uri': 'spotify:artist:4njdEjTnLfcGImKZu1iSrz'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2vbBCOu3B7kTIONAjf0LgQ'},
#      'href': 'https://api.spotify.com/v1/albums/2vbBCOu3B7kTIONAjf0LgQ',
#      'id': '2vbBCOu3B7kTIONAjf0LgQ',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273f40ad52afcecbe77fa7950cc',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02f40ad52afcecbe77fa7950cc',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851f40ad52afcecbe77fa7950cc',
#        'width': 64}],
#      'name': 'RE/Sail',
#      'release_date': '2012-04-10',
#      'release_date_precision': 'day',
#      'total_tracks': 9,
#      'type': 'album',
#      'uri': 'spotify:album:2vbBCOu3B7kTIONAjf0LgQ'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4njdEjTnLfcGImKZu1iSrz'},
#       'href': 'https://api.spotify.com/v1/artists/4njdEjTnLfcGImKZu1iSrz',
#       'id': '4njdEjTnLfcGImKZu1iSrz',
#       'name': 'AWOLNATION',
#       'type': 'artist',
#       'uri': 'spotify:artist:4njdEjTnLfcGImKZu1iSrz'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 274921,
#     'explicit': False,
#     'external_ids': {'isrc': 'USP6L1080071'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6gaJhEdGpvZrtKV3Ba5b0t'},
#     'href': 'https://api.spotify.com/v1/tracks/6gaJhEdGpvZrtKV3Ba5b0t',
#     'id': '6gaJhEdGpvZrtKV3Ba5b0t',
#     'is_local': False,
#     'name': 'Sail - Dan The Automator Remix',
#     'popularity': 9,
#     'preview_url': 'https://p.scdn.co/mp3-preview/4e365e13d23f11979c400911a7308aeabc52ba95?cid=6e24789ec7874259a220f747fcd7e93e',
#     'track_number': 9,
#     'type': 'track',
#     'uri': 'spotify:track:6gaJhEdGpvZrtKV3Ba5b0t'}],
#   'limit': 20,
#   'next': None,
#   'offset': 0,
#   'previous': None,
#   'total': 16}}

# %%
test = pd.DataFrame.from_dict(radioactive,orient='columns')
test
# Out:
#                                                      tracks
# href      https://api.spotify.com/v1/search?query=track%...
# items     [{'album': {'album_type': 'album', 'artists': ...
# limit                                                    20
# next                                                   None
# offset                                                    0
# previous                                               None
# total                                                    16

# %%
test= test.tracks.apply(pd.Series)
test
# Out:
# /var/folders/91/wchv5p25455f2k8078kdjvm40000gn/T/ipykernel_26593/2977931382.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   test= test.tracks.apply(pd.Series)
# /var/folders/91/wchv5p25455f2k8078kdjvm40000gn/T/ipykernel_26593/2977931382.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   test= test.tracks.apply(pd.Series)
#                                                           0  \
# href      https://api.spotify.com/v1/search?query=track%...
# items     {'album': {'album_type': 'album', 'artists': [...
# limit                                                  20.0
# next                                                    NaN
# offset                                                  0.0
# previous                                                NaN
# total                                                  16.0
#
#                                                           1  \
# href                                                    NaN
# items     {'album': {'album_type': 'album', 'artists': [...
# limit                                                   NaN
# next                                                    NaN
# offset                                                  NaN
# previous                                                NaN
# total                                                   NaN
#
#                                                           2  \
# href                                                    NaN
# items     {'album': {'album_type': 'album', 'artists': [...
# limit                                                   NaN
# next                                                    NaN
# offset                                                  NaN
# previous                                                NaN
# total                                                   NaN
#
#                                                           3  \
# href                                                    NaN
# items     {'album': {'album_type': 'single', 'artists': ...
# limit                                                   NaN
# next                                                    NaN
# offset                                                  NaN
# previous                                                NaN
# total                                                   NaN
#
#                                                           4  \
# href                                                    NaN
# items     {'album': {'album_type': 'album', 'artists': [...
# limit                                                   NaN
# next                                                    NaN
# offset                                                  NaN
# previous                                                NaN
# total                                                   NaN
#
#                                                           5  \
# href                                                    NaN
# items     {'album': {'album_type': 'single', 'artists': ...
# limit                                                   NaN
# next                                                    NaN
# offset                                                  NaN
# previous                                                NaN
# total                                                   NaN
#
#                                                           6  \
# href                                                    NaN
# items     {'album': {'album_type': 'album', 'artists': [...
# limit                                                   NaN
# next                                                    NaN
# offset                                                  NaN
# previous                                                NaN
# total                                                   NaN
#
#                                                           7  \
# href                                                    NaN
# items     {'album': {'album_type': 'album', 'artists': [...
# limit                                                   NaN
# next                                                    NaN
# offset                                                  NaN
# previous                                                NaN
# total                                                   NaN
#
#                                                           8  \
# href                                                    NaN
# items     {'album': {'album_type': 'single', 'artists': ...
# limit                                                   NaN
# next                                                    NaN
# offset                                                  NaN
# previous                                                NaN
# total                                                   NaN
#
#                                                           9  \
# href                                                    NaN
# items     {'album': {'album_type': 'album', 'artists': [...
# limit                                                   NaN
# next                                                    NaN
# offset                                                  NaN
# previous                                                NaN
# total                                                   NaN
#
#                                                          10  \
# href                                                    NaN
# items     {'album': {'album_type': 'album', 'artists': [...
# limit                                                   NaN
# next                                                    NaN
# offset                                                  NaN
# previous                                                NaN
# total                                                   NaN
#
#                                                          11  \
# href                                                    NaN
# items     {'album': {'album_type': 'single', 'artists': ...
# limit                                                   NaN
# next                                                    NaN
# offset                                                  NaN
# previous                                                NaN
# total                                                   NaN
#
#                                                          12  \
# href                                                    NaN
# items     {'album': {'album_type': 'single', 'artists': ...
# limit                                                   NaN
# next                                                    NaN
# offset                                                  NaN
# previous                                                NaN
# total                                                   NaN
#
#                                                          13  \
# href                                                    NaN
# items     {'album': {'album_type': 'single', 'artists': ...
# limit                                                   NaN
# next                                                    NaN
# offset                                                  NaN
# previous                                                NaN
# total                                                   NaN
#
#                                                          14  \
# href                                                    NaN
# items     {'album': {'album_type': 'compilation', 'artis...
# limit                                                   NaN
# next                                                    NaN
# offset                                                  NaN
# previous                                                NaN
# total                                                   NaN
#
#                                                          15
# href                                                    NaN
# items     {'album': {'album_type': 'single', 'artists': ...
# limit                                                   NaN
# next                                                    NaN
# offset                                                  NaN
# previous                                                NaN
# total                                                   NaN

# %%
test2 = pd.DataFrame(test.iloc[1])
test2
# Out:
#                                                 items
# 0   {'album': {'album_type': 'album', 'artists': [...
# 1   {'album': {'album_type': 'album', 'artists': [...
# 2   {'album': {'album_type': 'album', 'artists': [...
# 3   {'album': {'album_type': 'single', 'artists': ...
# 4   {'album': {'album_type': 'album', 'artists': [...
# 5   {'album': {'album_type': 'single', 'artists': ...
# 6   {'album': {'album_type': 'album', 'artists': [...
# 7   {'album': {'album_type': 'album', 'artists': [...
# 8   {'album': {'album_type': 'single', 'artists': ...
# 9   {'album': {'album_type': 'album', 'artists': [...
# 10  {'album': {'album_type': 'album', 'artists': [...
# 11  {'album': {'album_type': 'single', 'artists': ...
# 12  {'album': {'album_type': 'single', 'artists': ...
# 13  {'album': {'album_type': 'single', 'artists': ...
# 14  {'album': {'album_type': 'compilation', 'artis...
# 15  {'album': {'album_type': 'single', 'artists': ...

# %%
test3 = test2['items'].apply(pd.Series)
test3
# Out:
#                                                 album  \
# 0   {'album_type': 'album', 'artists': [{'external...
# 1   {'album_type': 'album', 'artists': [{'external...
# 2   {'album_type': 'album', 'artists': [{'external...
# 3   {'album_type': 'single', 'artists': [{'externa...
# 4   {'album_type': 'album', 'artists': [{'external...
# 5   {'album_type': 'single', 'artists': [{'externa...
# 6   {'album_type': 'album', 'artists': [{'external...
# 7   {'album_type': 'album', 'artists': [{'external...
# 8   {'album_type': 'single', 'artists': [{'externa...
# 9   {'album_type': 'album', 'artists': [{'external...
# 10  {'album_type': 'album', 'artists': [{'external...
# 11  {'album_type': 'single', 'artists': [{'externa...
# 12  {'album_type': 'single', 'artists': [{'externa...
# 13  {'album_type': 'single', 'artists': [{'externa...
# 14  {'album_type': 'compilation', 'artists': [{'ex...
# 15  {'album_type': 'single', 'artists': [{'externa...
#
#                                               artists  \
# 0   [{'external_urls': {'spotify': 'https://open.s...
# 1   [{'external_urls': {'spotify': 'https://open.s...
# 2   [{'external_urls': {'spotify': 'https://open.s...
# 3   [{'external_urls': {'spotify': 'https://open.s...
# 4   [{'external_urls': {'spotify': 'https://open.s...
# 5   [{'external_urls': {'spotify': 'https://open.s...
# 6   [{'external_urls': {'spotify': 'https://open.s...
# 7   [{'external_urls': {'spotify': 'https://open.s...
# 8   [{'external_urls': {'spotify': 'https://open.s...
# 9   [{'external_urls': {'spotify': 'https://open.s...
# 10  [{'external_urls': {'spotify': 'https://open.s...
# 11  [{'external_urls': {'spotify': 'https://open.s...
# 12  [{'external_urls': {'spotify': 'https://open.s...
# 13  [{'external_urls': {'spotify': 'https://open.s...
# 14  [{'external_urls': {'spotify': 'https://open.s...
# 15  [{'external_urls': {'spotify': 'https://open.s...
#
#                                     available_markets  disc_number  \
# 0   [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...            1
# 1   [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...            1
# 2   [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...            1
# 3   [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...            1
# 4   [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...            1
# 5   [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...            1
# 6   [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...            1
# 7   [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...            1
# 8   [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...            1
# 9   [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...            1
# 10  [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...            1
# 11  [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...            1
# 12  [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...            1
# 13  [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...            1
# 14  [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...            1
# 15  [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...            1
#
#     duration_ms  explicit              external_ids  \
# 0        259093     False  {'isrc': 'USP6L1000053'}
# 1        209276     False  {'isrc': 'USP6L1280129'}
# 2        349654     False  {'isrc': 'USP6L1180110'}
# 3        349537     False  {'isrc': 'USP6L1180110'}
# 4        240779     False  {'isrc': 'USP6L1380136'}
# 5        261046     False  {'isrc': 'USP6L1180113'}
# 6        259092     False  {'isrc': 'USP6L1000053'}
# 7        278482     False  {'isrc': 'USP6L1380130'}
# 8        286959     False  {'isrc': 'USP6L1180112'}
# 9        274988     False  {'isrc': 'USP6L1180071'}
# 10       572304     False  {'isrc': 'USP6L2100626'}
# 11       250771     False  {'isrc': 'USP6L1180114'}
# 12       259948     False  {'isrc': 'USP6L1180111'}
# 13       326596     False  {'isrc': 'USP6L1080070'}
# 14       178831     False  {'isrc': 'PLS921748135'}
# 15       274921     False  {'isrc': 'USP6L1080071'}
#
#                                         external_urls  \
# 0   {'spotify': 'https://open.spotify.com/track/7u...
# 1   {'spotify': 'https://open.spotify.com/track/24...
# 2   {'spotify': 'https://open.spotify.com/track/3k...
# 3   {'spotify': 'https://open.spotify.com/track/7q...
# 4   {'spotify': 'https://open.spotify.com/track/5G...
# 5   {'spotify': 'https://open.spotify.com/track/1D...
# 6   {'spotify': 'https://open.spotify.com/track/5U...
# 7   {'spotify': 'https://open.spotify.com/track/5n...
# 8   {'spotify': 'https://open.spotify.com/track/0y...
# 9   {'spotify': 'https://open.spotify.com/track/0j...
# 10  {'spotify': 'https://open.spotify.com/track/22...
# 11  {'spotify': 'https://open.spotify.com/track/47...
# 12  {'spotify': 'https://open.spotify.com/track/0y...
# 13  {'spotify': 'https://open.spotify.com/track/2J...
# 14  {'spotify': 'https://open.spotify.com/track/7a...
# 15  {'spotify': 'https://open.spotify.com/track/6g...
#
#                                                  href                      id  \
# 0   https://api.spotify.com/v1/tracks/7ueP5u2qkdZb...  7ueP5u2qkdZbIPN2YA6LR0
# 1   https://api.spotify.com/v1/tracks/24mf5NTXbNe1...  24mf5NTXbNe1de7w6rjaEn
# 2   https://api.spotify.com/v1/tracks/3kX6cdhy9XQB...  3kX6cdhy9XQBPL81GvEt0Q
# 3   https://api.spotify.com/v1/tracks/7qAWdfgvuDJQ...  7qAWdfgvuDJQlhjppYtAfA
# 4   https://api.spotify.com/v1/tracks/5GChOpEKNxYX...  5GChOpEKNxYXIRUxto2bWp
# 5   https://api.spotify.com/v1/tracks/1DqGEFrotFhh...  1DqGEFrotFhhPsowbbiSJf
# 6   https://api.spotify.com/v1/tracks/5UGE88CogQMc...  5UGE88CogQMcdsQhwhSZce
# 7   https://api.spotify.com/v1/tracks/5n41rCn10JV7...  5n41rCn10JV7WwvgoxYY24
# 8   https://api.spotify.com/v1/tracks/0yelSZvcDTGs...  0yelSZvcDTGsUmZMYIHkOM
# 9   https://api.spotify.com/v1/tracks/0jcTchBVBZXk...  0jcTchBVBZXkjOVJVF7eoC
# 10  https://api.spotify.com/v1/tracks/22WxRpIhS77P...  22WxRpIhS77PlEzwj1rCN1
# 11  https://api.spotify.com/v1/tracks/470wIZYoI7z4...  470wIZYoI7z4SVmFv5jG2J
# 12  https://api.spotify.com/v1/tracks/0ylslu5RtGM8...  0ylslu5RtGM8m14rzSxQGQ
# 13  https://api.spotify.com/v1/tracks/2J5Fgr9ak4ij...  2J5Fgr9ak4ijU1IznV9hnX
# 14  https://api.spotify.com/v1/tracks/7auZAZQWm5Am...  7auZAZQWm5Am8zU91qPCar
# 15  https://api.spotify.com/v1/tracks/6gaJhEdGpvZr...  6gaJhEdGpvZrtKV3Ba5b0t
#
#     is_local                                               name  popularity  \
# 0      False                                               Sail          74
# 1      False                               Sail - Feed Me Remix          53
# 2      False                     Sail - Unlimited Gravity Remix          46
# 3      False                     Sail - Unlimited Gravity Remix          42
# 4      False  Sail (feat. Kendrick Lamar & Ab Soul) - TDE Remix          42
# 5      False                                   Sail - LED Remix          31
# 6      False                                               Sail          30
# 7      False  Sail - Borgore Pop the Sweating I'm Sailing Remix          22
# 8      False                   Sail - Glitch Hop Remix Mongoose          20
# 9      False                     Sail - Dan the Automator Remix          20
# 10     False                            Sail - Live in Columbus          18
# 11     False                                Sail - MiSZap Remix          14
# 12     False                Sail - Edition Analogue by B. Earnd          14
# 13     False                      Sail - Innerpartysystem Remix          12
# 14     False                              Sail - Acoustic Cover           8
# 15     False                     Sail - Dan The Automator Remix           9
#
#                                           preview_url  track_number   type  \
# 0   https://p.scdn.co/mp3-preview/39fe4367061eac83...            10  track
# 1   https://p.scdn.co/mp3-preview/a6e773d08a3ea3c2...            39  track
# 2   https://p.scdn.co/mp3-preview/72f0893e5def96e4...            41  track
# 3   https://p.scdn.co/mp3-preview/9ae4e713856763d3...             1  track
# 4   https://p.scdn.co/mp3-preview/a5081f7e73252f8c...            40  track
# 5   https://p.scdn.co/mp3-preview/dfcba7af50b33b9e...             4  track
# 6   https://p.scdn.co/mp3-preview/15d4731f7d1f1cb9...            10  track
# 7   https://p.scdn.co/mp3-preview/8a07c59856308ddf...            37  track
# 8   https://p.scdn.co/mp3-preview/e1e9ed00f67c7996...             3  track
# 9   https://p.scdn.co/mp3-preview/9c53796e04348bbd...            38  track
# 10  https://p.scdn.co/mp3-preview/4d5bbc788c78c222...            26  track
# 11  https://p.scdn.co/mp3-preview/c3ae18b737417b38...             5  track
# 12  https://p.scdn.co/mp3-preview/a42cb23f7bf3f269...             2  track
# 13  https://p.scdn.co/mp3-preview/2c59a5e4fecc4e8e...             8  track
# 14  https://p.scdn.co/mp3-preview/727b681aefb8c056...             5  track
# 15  https://p.scdn.co/mp3-preview/4e365e13d23f1197...             9  track
#
#                                      uri
# 0   spotify:track:7ueP5u2qkdZbIPN2YA6LR0
# 1   spotify:track:24mf5NTXbNe1de7w6rjaEn
# 2   spotify:track:3kX6cdhy9XQBPL81GvEt0Q
# 3   spotify:track:7qAWdfgvuDJQlhjppYtAfA
# 4   spotify:track:5GChOpEKNxYXIRUxto2bWp
# 5   spotify:track:1DqGEFrotFhhPsowbbiSJf
# 6   spotify:track:5UGE88CogQMcdsQhwhSZce
# 7   spotify:track:5n41rCn10JV7WwvgoxYY24
# 8   spotify:track:0yelSZvcDTGsUmZMYIHkOM
# 9   spotify:track:0jcTchBVBZXkjOVJVF7eoC
# 10  spotify:track:22WxRpIhS77PlEzwj1rCN1
# 11  spotify:track:470wIZYoI7z4SVmFv5jG2J
# 12  spotify:track:0ylslu5RtGM8m14rzSxQGQ
# 13  spotify:track:2J5Fgr9ak4ijU1IznV9hnX
# 14  spotify:track:7auZAZQWm5Am8zU91qPCar
# 15  spotify:track:6gaJhEdGpvZrtKV3Ba5b0t

# %%
test3.head(1)
# Out:
#                                                album  \
# 0  {'album_type': 'album', 'artists': [{'external...
#
#                                              artists  \
# 0  [{'external_urls': {'spotify': 'https://open.s...
#
#                                    available_markets  disc_number  \
# 0  [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...            1
#
#    duration_ms  explicit              external_ids  \
# 0       259093     False  {'isrc': 'USP6L1000053'}
#
#                                        external_urls  \
# 0  {'spotify': 'https://open.spotify.com/track/7u...
#
#                                                 href                      id  \
# 0  https://api.spotify.com/v1/tracks/7ueP5u2qkdZb...  7ueP5u2qkdZbIPN2YA6LR0
#
#    is_local  name  popularity  \
# 0     False  Sail          74
#
#                                          preview_url  track_number   type  \
# 0  https://p.scdn.co/mp3-preview/39fe4367061eac83...            10  track
#
#                                     uri
# 0  spotify:track:7ueP5u2qkdZbIPN2YA6LR0
