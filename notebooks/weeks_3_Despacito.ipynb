# %%
# import packages

# %%
from pandas.io.json import json_normalize
import json
from pandasql import sqldf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from bs4 import BeautifulSoup
import io
import requests
import json
import base64
import datetime
from urllib.parse import urlencode

# %%
# client id

# %%
client_id = '6e24789ec7874259a220f747fcd7e93e'
client_secret = '9bd8ff1ad2f34ef6a87f00124be070b2'

# %%
class SpotifyAPI(object):
    access_token = None
    access_token_expires = datetime.datetime.now()
    access_token_did_expire = True
    client_id = None
    client_secret = None
    token_url = "https://accounts.spotify.com/api/token"



    def __init__(self, client_id, client_secret, *args, **kwargs):
        super().__init__(*args, **kwargs)
        self.client_id = client_id
        self.client_secret = client_secret

    def getClientCreds(self):
        '''Returns b64 encoded string'''
        client_id = self.client_id
        client_secret = self.client_secret

        if client_id == None or client_secret == None:
            raise Exception('Must set a client id and secret')

        client_creds  = f"{client_id}:{client_secret}"
        client_creds_b64 = base64.b64encode(client_creds.encode())
        return client_creds_b64.decode()

    def getTokenHeader(self):
        client_creds_b64 = self.getClientCreds()
        return {
            'Authorization':f"Basic {client_creds_b64}"
        }

    def getTokenData(self):
        return {
            "grant_type":"client_credentials"
        }

    def perform_auth(self):
        token_url = self.token_url
        token_data = self.getTokenData()
        token_header = self.getTokenHeader()

        r = requests.post(token_url, data=token_data, headers=token_header)

        if r.status_code  not in range(200,299):
            raise Exception('Could not authenticate client.')
            #return False

        now = datetime.datetime.now()
        token_response_data = r.json()
        access_token = token_response_data['access_token']
        expires_in = token_response_data['expires_in']
        expires = now + datetime.timedelta(seconds=expires_in)
        self.access_token = access_token
        self.access_token_expires = expires
        self.access_token_did_expire = expires < now


        return True

    def get_access_token(self):
        token = self.access_token
        expires = self.access_token_expires
        now= datetime.datetime.now()
        if expires < now:
            self.perform_auth()
            return self.get_access_token()
        elif token == None:
            self.perform_auth()
            return self.get_access_token() 
        return token
    
    def get_resource_header(self):
        access_token = self.get_access_token()
        headers = {
            "Authorization": f"Bearer {access_token}", 
        }
        return headers
    
    def get_resource(self, lookup_id, resource_type='albums', version='v1'):
        endpoint = f'https://api.spotify.com/{version}/{resource_type}/{lookup_id}'
        headers = self.get_resource_header()
        r = requests.get(endpoint, headers = headers)
        if r.status_code not in range (200, 299):
            return {}
        return r.json()
    
    def get_album(self, _id ):
        return self.get_resource(_id, resource_type='albums')
    
    def get_artist(self, _id ):
        return self.get_resource(_id, resource_type='artists')
    
    def get_playlist(self, _id):
        return self.get_resource(_id, resource_type='playlists')
    
    
    def base_search(self, query_params): #type
        access_token = self.get_access_token()
        headers = self.get_resource_header()
        endpoint = "https://api.spotify.com/v1/search"
        lookup_URL = f"{endpoint}?{query_params}"
        r = requests.get(lookup_URL, headers=headers)
        if r.status_code not in range (200, 299):
            return {}
        return r.json()
    
    def search(self, query=None, operator=None, operator_query=None, search_type='artist'):
        if query == None:
            raise Exception('A query is required')
        if isinstance(query, dict):
            query = ' '.join([f'{k}:{v}' for k,v in query.items()])
        if operator != None and operator_query != None:
            if operator.lower() == 'or' or operator.lower() == 'not':
                operator = operator.upper()
                if isinstance(operator_query, str):
                    query = f'{query} {operator} {operator_query}'
        query_params = urlencode({'q': query, 'type': search_type.lower()})
        return self.base_search(query_params)

# %%
spotify = SpotifyAPI(client_id, client_secret)

# %%
# radioactive

# %%
radioactive = spotify.search({'track': 'Despacito', 'artist': 'Luis'}, search_type ='track')
radioactive
# Out:
# {'tracks': {'href': 'https://api.spotify.com/v1/search?query=track%3ADespacito+artist%3ALuis&type=track&offset=0&limit=20',
#   'items': [{'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4V8Sr092TqfHkfAA5fXXqG'},
#        'href': 'https://api.spotify.com/v1/artists/4V8Sr092TqfHkfAA5fXXqG',
#        'id': '4V8Sr092TqfHkfAA5fXXqG',
#        'name': 'Luis Fonsi',
#        'type': 'artist',
#        'uri': 'spotify:artist:4V8Sr092TqfHkfAA5fXXqG'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5C0YLr4OoRGFDaqdMQmkeH'},
#      'href': 'https://api.spotify.com/v1/albums/5C0YLr4OoRGFDaqdMQmkeH',
#      'id': '5C0YLr4OoRGFDaqdMQmkeH',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273ef0d4234e1a645740f77d59c',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02ef0d4234e1a645740f77d59c',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851ef0d4234e1a645740f77d59c',
#        'width': 64}],
#      'name': 'VIDA',
#      'release_date': '2019-02-01',
#      'release_date_precision': 'day',
#      'total_tracks': 15,
#      'type': 'album',
#      'uri': 'spotify:album:5C0YLr4OoRGFDaqdMQmkeH'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4V8Sr092TqfHkfAA5fXXqG'},
#       'href': 'https://api.spotify.com/v1/artists/4V8Sr092TqfHkfAA5fXXqG',
#       'id': '4V8Sr092TqfHkfAA5fXXqG',
#       'name': 'Luis Fonsi',
#       'type': 'artist',
#       'uri': 'spotify:artist:4V8Sr092TqfHkfAA5fXXqG'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/4VMYDCV2IEDYJArk749S6m'},
#       'href': 'https://api.spotify.com/v1/artists/4VMYDCV2IEDYJArk749S6m',
#       'id': '4VMYDCV2IEDYJArk749S6m',
#       'name': 'Daddy Yankee',
#       'type': 'artist',
#       'uri': 'spotify:artist:4VMYDCV2IEDYJArk749S6m'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 229360,
#     'explicit': False,
#     'external_ids': {'isrc': 'USUM71607007'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6habFhsOp2NvshLv26DqMb'},
#     'href': 'https://api.spotify.com/v1/tracks/6habFhsOp2NvshLv26DqMb',
#     'id': '6habFhsOp2NvshLv26DqMb',
#     'is_local': False,
#     'name': 'Despacito',
#     'popularity': 80,
#     'preview_url': 'https://p.scdn.co/mp3-preview/3228a37350f226ab9158a2307d3699ee18d8081a?cid=6e24789ec7874259a220f747fcd7e93e',
#     'track_number': 9,
#     'type': 'track',
#     'uri': 'spotify:track:6habFhsOp2NvshLv26DqMb'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4V8Sr092TqfHkfAA5fXXqG'},
#        'href': 'https://api.spotify.com/v1/artists/4V8Sr092TqfHkfAA5fXXqG',
#        'id': '4V8Sr092TqfHkfAA5fXXqG',
#        'name': 'Luis Fonsi',
#        'type': 'artist',
#        'uri': 'spotify:artist:4V8Sr092TqfHkfAA5fXXqG'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/4VMYDCV2IEDYJArk749S6m'},
#        'href': 'https://api.spotify.com/v1/artists/4VMYDCV2IEDYJArk749S6m',
#        'id': '4VMYDCV2IEDYJArk749S6m',
#        'name': 'Daddy Yankee',
#        'type': 'artist',
#        'uri': 'spotify:artist:4VMYDCV2IEDYJArk749S6m'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/3Gq2Dme9nesdgoqNNlcN8O'},
#      'href': 'https://api.spotify.com/v1/albums/3Gq2Dme9nesdgoqNNlcN8O',
#      'id': '3Gq2Dme9nesdgoqNNlcN8O',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273a6a335d613d151c626895a83',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02a6a335d613d151c626895a83',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851a6a335d613d151c626895a83',
#        'width': 64}],
#      'name': 'Despacito Feat. Justin Bieber (Remix)',
#      'release_date': '2017-04-17',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:3Gq2Dme9nesdgoqNNlcN8O'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4V8Sr092TqfHkfAA5fXXqG'},
#       'href': 'https://api.spotify.com/v1/artists/4V8Sr092TqfHkfAA5fXXqG',
#       'id': '4V8Sr092TqfHkfAA5fXXqG',
#       'name': 'Luis Fonsi',
#       'type': 'artist',
#       'uri': 'spotify:artist:4V8Sr092TqfHkfAA5fXXqG'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/4VMYDCV2IEDYJArk749S6m'},
#       'href': 'https://api.spotify.com/v1/artists/4VMYDCV2IEDYJArk749S6m',
#       'id': '4VMYDCV2IEDYJArk749S6m',
#       'name': 'Daddy Yankee',
#       'type': 'artist',
#       'uri': 'spotify:artist:4VMYDCV2IEDYJArk749S6m'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/1uNFoZAHBGtllmzznpCI3s'},
#       'href': 'https://api.spotify.com/v1/artists/1uNFoZAHBGtllmzznpCI3s',
#       'id': '1uNFoZAHBGtllmzznpCI3s',
#       'name': 'Justin Bieber',
#       'type': 'artist',
#       'uri': 'spotify:artist:1uNFoZAHBGtllmzznpCI3s'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 228826,
#     'explicit': False,
#     'external_ids': {'isrc': 'USUM71703825'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6rPO02ozF3bM7NnOV4h6s2'},
#     'href': 'https://api.spotify.com/v1/tracks/6rPO02ozF3bM7NnOV4h6s2',
#     'id': '6rPO02ozF3bM7NnOV4h6s2',
#     'is_local': False,
#     'name': 'Despacito - Remix',
#     'popularity': 71,
#     'preview_url': 'https://p.scdn.co/mp3-preview/6fd23fecd7e84bc52b19315b1ff0b2502aef3977?cid=6e24789ec7874259a220f747fcd7e93e',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:6rPO02ozF3bM7NnOV4h6s2'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4V8Sr092TqfHkfAA5fXXqG'},
#        'href': 'https://api.spotify.com/v1/artists/4V8Sr092TqfHkfAA5fXXqG',
#        'id': '4V8Sr092TqfHkfAA5fXXqG',
#        'name': 'Luis Fonsi',
#        'type': 'artist',
#        'uri': 'spotify:artist:4V8Sr092TqfHkfAA5fXXqG'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5C0YLr4OoRGFDaqdMQmkeH'},
#      'href': 'https://api.spotify.com/v1/albums/5C0YLr4OoRGFDaqdMQmkeH',
#      'id': '5C0YLr4OoRGFDaqdMQmkeH',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273ef0d4234e1a645740f77d59c',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02ef0d4234e1a645740f77d59c',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851ef0d4234e1a645740f77d59c',
#        'width': 64}],
#      'name': 'VIDA',
#      'release_date': '2019-02-01',
#      'release_date_precision': 'day',
#      'total_tracks': 15,
#      'type': 'album',
#      'uri': 'spotify:album:5C0YLr4OoRGFDaqdMQmkeH'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4V8Sr092TqfHkfAA5fXXqG'},
#       'href': 'https://api.spotify.com/v1/artists/4V8Sr092TqfHkfAA5fXXqG',
#       'id': '4V8Sr092TqfHkfAA5fXXqG',
#       'name': 'Luis Fonsi',
#       'type': 'artist',
#       'uri': 'spotify:artist:4V8Sr092TqfHkfAA5fXXqG'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/4VMYDCV2IEDYJArk749S6m'},
#       'href': 'https://api.spotify.com/v1/artists/4VMYDCV2IEDYJArk749S6m',
#       'id': '4VMYDCV2IEDYJArk749S6m',
#       'name': 'Daddy Yankee',
#       'type': 'artist',
#       'uri': 'spotify:artist:4VMYDCV2IEDYJArk749S6m'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/1uNFoZAHBGtllmzznpCI3s'},
#       'href': 'https://api.spotify.com/v1/artists/1uNFoZAHBGtllmzznpCI3s',
#       'id': '1uNFoZAHBGtllmzznpCI3s',
#       'name': 'Justin Bieber',
#       'type': 'artist',
#       'uri': 'spotify:artist:1uNFoZAHBGtllmzznpCI3s'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 230413,
#     'explicit': False,
#     'external_ids': {'isrc': 'USUM71703825'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1vnnXMrBeEWiRg3YCMCjQq'},
#     'href': 'https://api.spotify.com/v1/tracks/1vnnXMrBeEWiRg3YCMCjQq',
#     'id': '1vnnXMrBeEWiRg3YCMCjQq',
#     'is_local': False,
#     'name': 'Despacito - Remix',
#     'popularity': 69,
#     'preview_url': 'https://p.scdn.co/mp3-preview/978c915797a63f665af1a33a940894e1e9027370?cid=6e24789ec7874259a220f747fcd7e93e',
#     'track_number': 13,
#     'type': 'track',
#     'uri': 'spotify:track:1vnnXMrBeEWiRg3YCMCjQq'},
#    {'album': {'album_type': 'compilation',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#        'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#        'id': '0LyfQWJT6nXafLPZqxe9Of',
#        'name': 'Various Artists',
#        'type': 'artist',
#        'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#      'available_markets': ['AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GH',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JP',
#       'KE',
#       'KH',
#       'KR',
#       'KW',
#       'LB',
#       'LK',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SN',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TT',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VE',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5QBNugYv15wT1A3PRgJFnw'},
#      'href': 'https://api.spotify.com/v1/albums/5QBNugYv15wT1A3PRgJFnw',
#      'id': '5QBNugYv15wT1A3PRgJFnw',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273bc5fd481b78b041d1dbc8c70',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02bc5fd481b78b041d1dbc8c70',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851bc5fd481b78b041d1dbc8c70',
#        'width': 64}],
#      'name': 'World Championship Qatar 2022',
#      'release_date': '2022-12-01',
#      'release_date_precision': 'day',
#      'total_tracks': 74,
#      'type': 'album',
#      'uri': 'spotify:album:5QBNugYv15wT1A3PRgJFnw'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4V8Sr092TqfHkfAA5fXXqG'},
#       'href': 'https://api.spotify.com/v1/artists/4V8Sr092TqfHkfAA5fXXqG',
#       'id': '4V8Sr092TqfHkfAA5fXXqG',
#       'name': 'Luis Fonsi',
#       'type': 'artist',
#       'uri': 'spotify:artist:4V8Sr092TqfHkfAA5fXXqG'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/4VMYDCV2IEDYJArk749S6m'},
#       'href': 'https://api.spotify.com/v1/artists/4VMYDCV2IEDYJArk749S6m',
#       'id': '4VMYDCV2IEDYJArk749S6m',
#       'name': 'Daddy Yankee',
#       'type': 'artist',
#       'uri': 'spotify:artist:4VMYDCV2IEDYJArk749S6m'}],
#     'available_markets': ['AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GH',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JP',
#      'KE',
#      'KH',
#      'KR',
#      'KW',
#      'LB',
#      'LK',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SN',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TT',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VE',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 230466,
#     'explicit': False,
#     'external_ids': {'isrc': 'USUM71607007'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/7cCkP2dHAEcoWT9OZjM72q'},
#     'href': 'https://api.spotify.com/v1/tracks/7cCkP2dHAEcoWT9OZjM72q',
#     'id': '7cCkP2dHAEcoWT9OZjM72q',
#     'is_local': False,
#     'name': 'Despacito',
#     'popularity': 0,
#     'preview_url': 'https://p.scdn.co/mp3-preview/77872071f147e12943c4712f1cc30704f0ee3b86?cid=6e24789ec7874259a220f747fcd7e93e',
#     'track_number': 15,
#     'type': 'track',
#     'uri': 'spotify:track:7cCkP2dHAEcoWT9OZjM72q'},
#    {'album': {'album_type': 'compilation',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#        'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#        'id': '0LyfQWJT6nXafLPZqxe9Of',
#        'name': 'Various Artists',
#        'type': 'artist',
#        'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#      'available_markets': ['AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GH',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JP',
#       'KE',
#       'KH',
#       'KR',
#       'KW',
#       'LB',
#       'LK',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SN',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TT',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VE',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4gw5cEdOIS8frNaTx8FlaU'},
#      'href': 'https://api.spotify.com/v1/albums/4gw5cEdOIS8frNaTx8FlaU',
#      'id': '4gw5cEdOIS8frNaTx8FlaU',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273ec5510feb128946e08a11988',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02ec5510feb128946e08a11988',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851ec5510feb128946e08a11988',
#        'width': 64}],
#      'name': 'Silvester 2022',
#      'release_date': '2022-12-02',
#      'release_date_precision': 'day',
#      'total_tracks': 88,
#      'type': 'album',
#      'uri': 'spotify:album:4gw5cEdOIS8frNaTx8FlaU'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4V8Sr092TqfHkfAA5fXXqG'},
#       'href': 'https://api.spotify.com/v1/artists/4V8Sr092TqfHkfAA5fXXqG',
#       'id': '4V8Sr092TqfHkfAA5fXXqG',
#       'name': 'Luis Fonsi',
#       'type': 'artist',
#       'uri': 'spotify:artist:4V8Sr092TqfHkfAA5fXXqG'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/4VMYDCV2IEDYJArk749S6m'},
#       'href': 'https://api.spotify.com/v1/artists/4VMYDCV2IEDYJArk749S6m',
#       'id': '4VMYDCV2IEDYJArk749S6m',
#       'name': 'Daddy Yankee',
#       'type': 'artist',
#       'uri': 'spotify:artist:4VMYDCV2IEDYJArk749S6m'}],
#     'available_markets': ['AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GH',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JP',
#      'KE',
#      'KH',
#      'KR',
#      'KW',
#      'LB',
#      'LK',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SN',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TT',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VE',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 230466,
#     'explicit': False,
#     'external_ids': {'isrc': 'USUM71607007'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/5zv6B3NsMqluXwV2XEgCju'},
#     'href': 'https://api.spotify.com/v1/tracks/5zv6B3NsMqluXwV2XEgCju',
#     'id': '5zv6B3NsMqluXwV2XEgCju',
#     'is_local': False,
#     'name': 'Despacito',
#     'popularity': 0,
#     'preview_url': 'https://p.scdn.co/mp3-preview/77872071f147e12943c4712f1cc30704f0ee3b86?cid=6e24789ec7874259a220f747fcd7e93e',
#     'track_number': 27,
#     'type': 'track',
#     'uri': 'spotify:track:5zv6B3NsMqluXwV2XEgCju'},
#    {'album': {'album_type': 'compilation',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#        'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#        'id': '0LyfQWJT6nXafLPZqxe9Of',
#        'name': 'Various Artists',
#        'type': 'artist',
#        'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#      'available_markets': ['AE',
#       'AL',
#       'AR',
#       'AT',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GH',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JP',
#       'KE',
#       'KH',
#       'KR',
#       'KW',
#       'LB',
#       'LK',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SN',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TT',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VE',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/0B3B9TOLKZ4qKAEQvly6vg'},
#      'href': 'https://api.spotify.com/v1/albums/0B3B9TOLKZ4qKAEQvly6vg',
#      'id': '0B3B9TOLKZ4qKAEQvly6vg',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273c736bb619c03793fb7987705',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02c736bb619c03793fb7987705',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851c736bb619c03793fb7987705',
#        'width': 64}],
#      'name': 'Soccer World Championship 2022',
#      'release_date': '2022-12-01',
#      'release_date_precision': 'day',
#      'total_tracks': 80,
#      'type': 'album',
#      'uri': 'spotify:album:0B3B9TOLKZ4qKAEQvly6vg'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4V8Sr092TqfHkfAA5fXXqG'},
#       'href': 'https://api.spotify.com/v1/artists/4V8Sr092TqfHkfAA5fXXqG',
#       'id': '4V8Sr092TqfHkfAA5fXXqG',
#       'name': 'Luis Fonsi',
#       'type': 'artist',
#       'uri': 'spotify:artist:4V8Sr092TqfHkfAA5fXXqG'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/4VMYDCV2IEDYJArk749S6m'},
#       'href': 'https://api.spotify.com/v1/artists/4VMYDCV2IEDYJArk749S6m',
#       'id': '4VMYDCV2IEDYJArk749S6m',
#       'name': 'Daddy Yankee',
#       'type': 'artist',
#       'uri': 'spotify:artist:4VMYDCV2IEDYJArk749S6m'}],
#     'available_markets': ['AE',
#      'AL',
#      'AR',
#      'AT',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GH',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JP',
#      'KE',
#      'KH',
#      'KR',
#      'KW',
#      'LB',
#      'LK',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SN',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TT',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VE',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 230466,
#     'explicit': False,
#     'external_ids': {'isrc': 'USUM71607007'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/27nDrpu5mVh7Lbsg2topzJ'},
#     'href': 'https://api.spotify.com/v1/tracks/27nDrpu5mVh7Lbsg2topzJ',
#     'id': '27nDrpu5mVh7Lbsg2topzJ',
#     'is_local': False,
#     'name': 'Despacito',
#     'popularity': 0,
#     'preview_url': 'https://p.scdn.co/mp3-preview/77872071f147e12943c4712f1cc30704f0ee3b86?cid=6e24789ec7874259a220f747fcd7e93e',
#     'track_number': 39,
#     'type': 'track',
#     'uri': 'spotify:track:27nDrpu5mVh7Lbsg2topzJ'},
#    {'album': {'album_type': 'compilation',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#        'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#        'id': '0LyfQWJT6nXafLPZqxe9Of',
#        'name': 'Various Artists',
#        'type': 'artist',
#        'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#      'available_markets': ['AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GH',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JP',
#       'KE',
#       'KH',
#       'KR',
#       'KW',
#       'LB',
#       'LK',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SN',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TT',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VE',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/1fwYr4a3fcgiajTSxaLtZV'},
#      'href': 'https://api.spotify.com/v1/albums/1fwYr4a3fcgiajTSxaLtZV',
#      'id': '1fwYr4a3fcgiajTSxaLtZV',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2738e22d64d71bfd6f1e0a186d3',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e028e22d64d71bfd6f1e0a186d3',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048518e22d64d71bfd6f1e0a186d3',
#        'width': 64}],
#      'name': 'WM Katar 2022',
#      'release_date': '2022-12-01',
#      'release_date_precision': 'day',
#      'total_tracks': 80,
#      'type': 'album',
#      'uri': 'spotify:album:1fwYr4a3fcgiajTSxaLtZV'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4V8Sr092TqfHkfAA5fXXqG'},
#       'href': 'https://api.spotify.com/v1/artists/4V8Sr092TqfHkfAA5fXXqG',
#       'id': '4V8Sr092TqfHkfAA5fXXqG',
#       'name': 'Luis Fonsi',
#       'type': 'artist',
#       'uri': 'spotify:artist:4V8Sr092TqfHkfAA5fXXqG'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/4VMYDCV2IEDYJArk749S6m'},
#       'href': 'https://api.spotify.com/v1/artists/4VMYDCV2IEDYJArk749S6m',
#       'id': '4VMYDCV2IEDYJArk749S6m',
#       'name': 'Daddy Yankee',
#       'type': 'artist',
#       'uri': 'spotify:artist:4VMYDCV2IEDYJArk749S6m'}],
#     'available_markets': ['AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GH',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JP',
#      'KE',
#      'KH',
#      'KR',
#      'KW',
#      'LB',
#      'LK',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SN',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TT',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VE',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 230466,
#     'explicit': False,
#     'external_ids': {'isrc': 'USUM71607007'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3vrEEERwVkqZMEXLrXGC2c'},
#     'href': 'https://api.spotify.com/v1/tracks/3vrEEERwVkqZMEXLrXGC2c',
#     'id': '3vrEEERwVkqZMEXLrXGC2c',
#     'is_local': False,
#     'name': 'Despacito',
#     'popularity': 0,
#     'preview_url': 'https://p.scdn.co/mp3-preview/77872071f147e12943c4712f1cc30704f0ee3b86?cid=6e24789ec7874259a220f747fcd7e93e',
#     'track_number': 73,
#     'type': 'track',
#     'uri': 'spotify:track:3vrEEERwVkqZMEXLrXGC2c'},
#    {'album': {'album_type': 'compilation',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#        'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#        'id': '0LyfQWJT6nXafLPZqxe9Of',
#        'name': 'Various Artists',
#        'type': 'artist',
#        'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#      'available_markets': ['AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GH',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JP',
#       'KE',
#       'KH',
#       'KR',
#       'KW',
#       'LB',
#       'LK',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SN',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TT',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VE',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5M3QVLdlU6p2n6L0IxQoTx'},
#      'href': 'https://api.spotify.com/v1/albums/5M3QVLdlU6p2n6L0IxQoTx',
#      'id': '5M3QVLdlU6p2n6L0IxQoTx',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273abfd7fdf925387af64609518',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02abfd7fdf925387af64609518',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851abfd7fdf925387af64609518',
#        'width': 64}],
#      'name': 'WM Hits 2022',
#      'release_date': '2022-12-01',
#      'release_date_precision': 'day',
#      'total_tracks': 80,
#      'type': 'album',
#      'uri': 'spotify:album:5M3QVLdlU6p2n6L0IxQoTx'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4V8Sr092TqfHkfAA5fXXqG'},
#       'href': 'https://api.spotify.com/v1/artists/4V8Sr092TqfHkfAA5fXXqG',
#       'id': '4V8Sr092TqfHkfAA5fXXqG',
#       'name': 'Luis Fonsi',
#       'type': 'artist',
#       'uri': 'spotify:artist:4V8Sr092TqfHkfAA5fXXqG'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/4VMYDCV2IEDYJArk749S6m'},
#       'href': 'https://api.spotify.com/v1/artists/4VMYDCV2IEDYJArk749S6m',
#       'id': '4VMYDCV2IEDYJArk749S6m',
#       'name': 'Daddy Yankee',
#       'type': 'artist',
#       'uri': 'spotify:artist:4VMYDCV2IEDYJArk749S6m'}],
#     'available_markets': ['AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GH',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JP',
#      'KE',
#      'KH',
#      'KR',
#      'KW',
#      'LB',
#      'LK',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SN',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TT',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VE',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 230466,
#     'explicit': False,
#     'external_ids': {'isrc': 'USUM71607007'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/5sG2vrEZVjkmZoHORzokbz'},
#     'href': 'https://api.spotify.com/v1/tracks/5sG2vrEZVjkmZoHORzokbz',
#     'id': '5sG2vrEZVjkmZoHORzokbz',
#     'is_local': False,
#     'name': 'Despacito',
#     'popularity': 0,
#     'preview_url': 'https://p.scdn.co/mp3-preview/77872071f147e12943c4712f1cc30704f0ee3b86?cid=6e24789ec7874259a220f747fcd7e93e',
#     'track_number': 20,
#     'type': 'track',
#     'uri': 'spotify:track:5sG2vrEZVjkmZoHORzokbz'},
#    {'album': {'album_type': 'compilation',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#        'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#        'id': '0LyfQWJT6nXafLPZqxe9Of',
#        'name': 'Various Artists',
#        'type': 'artist',
#        'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#      'available_markets': ['AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GH',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JP',
#       'KE',
#       'KH',
#       'KR',
#       'KW',
#       'LB',
#       'LK',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SN',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TT',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VE',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5FA0tRYFkY3kG5jhTU9VB9'},
#      'href': 'https://api.spotify.com/v1/albums/5FA0tRYFkY3kG5jhTU9VB9',
#      'id': '5FA0tRYFkY3kG5jhTU9VB9',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273847bcd72e673159dcce3035d',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02847bcd72e673159dcce3035d',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851847bcd72e673159dcce3035d',
#        'width': 64}],
#      'name': 'Venga le digo',
#      'release_date': '2022-12-02',
#      'release_date_precision': 'day',
#      'total_tracks': 35,
#      'type': 'album',
#      'uri': 'spotify:album:5FA0tRYFkY3kG5jhTU9VB9'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4V8Sr092TqfHkfAA5fXXqG'},
#       'href': 'https://api.spotify.com/v1/artists/4V8Sr092TqfHkfAA5fXXqG',
#       'id': '4V8Sr092TqfHkfAA5fXXqG',
#       'name': 'Luis Fonsi',
#       'type': 'artist',
#       'uri': 'spotify:artist:4V8Sr092TqfHkfAA5fXXqG'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/4VMYDCV2IEDYJArk749S6m'},
#       'href': 'https://api.spotify.com/v1/artists/4VMYDCV2IEDYJArk749S6m',
#       'id': '4VMYDCV2IEDYJArk749S6m',
#       'name': 'Daddy Yankee',
#       'type': 'artist',
#       'uri': 'spotify:artist:4VMYDCV2IEDYJArk749S6m'}],
#     'available_markets': ['AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GH',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JP',
#      'KE',
#      'KH',
#      'KR',
#      'KW',
#      'LB',
#      'LK',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'ME',
#      'MK',
# ...
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 228200,
#     'explicit': False,
#     'external_ids': {'isrc': 'USUM71607007'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/5AgTL2WmiCvoObA8fpncKs'},
#     'href': 'https://api.spotify.com/v1/tracks/5AgTL2WmiCvoObA8fpncKs',
#     'id': '5AgTL2WmiCvoObA8fpncKs',
#     'is_local': False,
#     'name': 'Despacito',
#     'popularity': 50,
#     'preview_url': 'https://p.scdn.co/mp3-preview/678bb5a1c777226f2b64fd93df9f7269d23f97ca?cid=6e24789ec7874259a220f747fcd7e93e',
#     'track_number': 26,
#     'type': 'track',
#     'uri': 'spotify:track:5AgTL2WmiCvoObA8fpncKs'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4V8Sr092TqfHkfAA5fXXqG'},
#        'href': 'https://api.spotify.com/v1/artists/4V8Sr092TqfHkfAA5fXXqG',
#        'id': '4V8Sr092TqfHkfAA5fXXqG',
#        'name': 'Luis Fonsi',
#        'type': 'artist',
#        'uri': 'spotify:artist:4V8Sr092TqfHkfAA5fXXqG'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/7bX9PK9BzyHuGAe8kEkm8o'},
#      'href': 'https://api.spotify.com/v1/albums/7bX9PK9BzyHuGAe8kEkm8o',
#      'id': '7bX9PK9BzyHuGAe8kEkm8o',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27323a10878295ddea1a4ef0f3d',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0223a10878295ddea1a4ef0f3d',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485123a10878295ddea1a4ef0f3d',
#        'width': 64}],
#      'name': 'Despacito (Versión Pop)',
#      'release_date': '2017-03-17',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:7bX9PK9BzyHuGAe8kEkm8o'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4V8Sr092TqfHkfAA5fXXqG'},
#       'href': 'https://api.spotify.com/v1/artists/4V8Sr092TqfHkfAA5fXXqG',
#       'id': '4V8Sr092TqfHkfAA5fXXqG',
#       'name': 'Luis Fonsi',
#       'type': 'artist',
#       'uri': 'spotify:artist:4V8Sr092TqfHkfAA5fXXqG'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/4KLOMib6zqzNayKwLWTs2Q'},
#       'href': 'https://api.spotify.com/v1/artists/4KLOMib6zqzNayKwLWTs2Q',
#       'id': '4KLOMib6zqzNayKwLWTs2Q',
#       'name': 'Andrés Torres',
#       'type': 'artist',
#       'uri': 'spotify:artist:4KLOMib6zqzNayKwLWTs2Q'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/7p3ipw2PvGG0X2x6zL1DLO'},
#       'href': 'https://api.spotify.com/v1/artists/7p3ipw2PvGG0X2x6zL1DLO',
#       'id': '7p3ipw2PvGG0X2x6zL1DLO',
#       'name': 'Mauricio Rengifo',
#       'type': 'artist',
#       'uri': 'spotify:artist:7p3ipw2PvGG0X2x6zL1DLO'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 228546,
#     'explicit': False,
#     'external_ids': {'isrc': 'USUM71700112'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/36NOKjPLZVSqVJSC7iOHIm'},
#     'href': 'https://api.spotify.com/v1/tracks/36NOKjPLZVSqVJSC7iOHIm',
#     'id': '36NOKjPLZVSqVJSC7iOHIm',
#     'is_local': False,
#     'name': 'Despacito',
#     'popularity': 52,
#     'preview_url': 'https://p.scdn.co/mp3-preview/716142f0a95c4d365815f9af63ae048a04d83905?cid=6e24789ec7874259a220f747fcd7e93e',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:36NOKjPLZVSqVJSC7iOHIm'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4V8Sr092TqfHkfAA5fXXqG'},
#        'href': 'https://api.spotify.com/v1/artists/4V8Sr092TqfHkfAA5fXXqG',
#        'id': '4V8Sr092TqfHkfAA5fXXqG',
#        'name': 'Luis Fonsi',
#        'type': 'artist',
#        'uri': 'spotify:artist:4V8Sr092TqfHkfAA5fXXqG'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/122giwKyFajejrXs0Mu4qg'},
#      'href': 'https://api.spotify.com/v1/albums/122giwKyFajejrXs0Mu4qg',
#      'id': '122giwKyFajejrXs0Mu4qg',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27390cb1adf7500126d95e5c278',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0290cb1adf7500126d95e5c278',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485190cb1adf7500126d95e5c278',
#        'width': 64}],
#      'name': 'Despacito (Versión Salsa)',
#      'release_date': '2017-03-17',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:122giwKyFajejrXs0Mu4qg'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4V8Sr092TqfHkfAA5fXXqG'},
#       'href': 'https://api.spotify.com/v1/artists/4V8Sr092TqfHkfAA5fXXqG',
#       'id': '4V8Sr092TqfHkfAA5fXXqG',
#       'name': 'Luis Fonsi',
#       'type': 'artist',
#       'uri': 'spotify:artist:4V8Sr092TqfHkfAA5fXXqG'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/4N5fp4zhTsVITZTVfsXpc2'},
#       'href': 'https://api.spotify.com/v1/artists/4N5fp4zhTsVITZTVfsXpc2',
#       'id': '4N5fp4zhTsVITZTVfsXpc2',
#       'name': 'Víctor Manuelle',
#       'type': 'artist',
#       'uri': 'spotify:artist:4N5fp4zhTsVITZTVfsXpc2'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/0r3y7sISJoUIfT5E85AYII'},
#       'href': 'https://api.spotify.com/v1/artists/0r3y7sISJoUIfT5E85AYII',
#       'id': '0r3y7sISJoUIfT5E85AYII',
#       'name': 'Victor M. Ruiz',
#       'type': 'artist',
#       'uri': 'spotify:artist:0r3y7sISJoUIfT5E85AYII'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 205666,
#     'explicit': False,
#     'external_ids': {'isrc': 'USUM71700713'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/5aPZ8WDKgtij3zbknGFnhC'},
#     'href': 'https://api.spotify.com/v1/tracks/5aPZ8WDKgtij3zbknGFnhC',
#     'id': '5aPZ8WDKgtij3zbknGFnhC',
#     'is_local': False,
#     'name': 'Despacito - Versión Salsa',
#     'popularity': 47,
#     'preview_url': 'https://p.scdn.co/mp3-preview/745333230c41fa280449455a5dddfa8160b6aefe?cid=6e24789ec7874259a220f747fcd7e93e',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:5aPZ8WDKgtij3zbknGFnhC'}],
#   'limit': 20,
#   'next': 'https://api.spotify.com/v1/search?query=track%3ADespacito+artist%3ALuis&type=track&offset=20&limit=20',
#   'offset': 0,
#   'previous': None,
#   'total': 1589}}

# %%
test = pd.DataFrame.from_dict(radioactive,orient='columns')
test
# Out:
#                                                      tracks
# href      https://api.spotify.com/v1/search?query=track%...
# items     [{'album': {'album_type': 'album', 'artists': ...
# limit                                                    20
# next      https://api.spotify.com/v1/search?query=track%...
# offset                                                    0
# previous                                               None
# total                                                  1589

# %%
test= test.tracks.apply(pd.Series)
test
# Out:
# /var/folders/91/wchv5p25455f2k8078kdjvm40000gn/T/ipykernel_27913/2977931382.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   test= test.tracks.apply(pd.Series)
#                                                           0  \
# href      https://api.spotify.com/v1/search?query=track%...
# items     {'album': {'album_type': 'album', 'artists': [...
# limit                                                  20.0
# next      https://api.spotify.com/v1/search?query=track%...
# offset                                                  0.0
# previous                                                NaN
# total                                                1589.0
#
#                                                           1  \
# href                                                    NaN
# items     {'album': {'album_type': 'single', 'artists': ...
# limit                                                   NaN
# next                                                    NaN
# offset                                                  NaN
# previous                                                NaN
# total                                                   NaN
#
#                                                           2  \
# href                                                    NaN
# items     {'album': {'album_type': 'album', 'artists': [...
# limit                                                   NaN
# next                                                    NaN
# offset                                                  NaN
# previous                                                NaN
# total                                                   NaN
#
#                                                           3  \
# href                                                    NaN
# items     {'album': {'album_type': 'compilation', 'artis...
# limit                                                   NaN
# next                                                    NaN
# offset                                                  NaN
# previous                                                NaN
# total                                                   NaN
#
#                                                           4  \
# href                                                    NaN
# items     {'album': {'album_type': 'compilation', 'artis...
# limit                                                   NaN
# next                                                    NaN
# offset                                                  NaN
# previous                                                NaN
# total                                                   NaN
#
#                                                           5  \
# href                                                    NaN
# items     {'album': {'album_type': 'compilation', 'artis...
# limit                                                   NaN
# next                                                    NaN
# offset                                                  NaN
# previous                                                NaN
# total                                                   NaN
#
#                                                           6  \
# href                                                    NaN
# items     {'album': {'album_type': 'compilation', 'artis...
# limit                                                   NaN
# next                                                    NaN
# offset                                                  NaN
# previous                                                NaN
# total                                                   NaN
#
#                                                           7  \
# href                                                    NaN
# items     {'album': {'album_type': 'compilation', 'artis...
# limit                                                   NaN
# next                                                    NaN
# offset                                                  NaN
# previous                                                NaN
# total                                                   NaN
#
#                                                           8  \
# href                                                    NaN
# items     {'album': {'album_type': 'compilation', 'artis...
# limit                                                   NaN
# next                                                    NaN
# offset                                                  NaN
# previous                                                NaN
# total                                                   NaN
#
#                                                           9  \
# href                                                    NaN
# items     {'album': {'album_type': 'compilation', 'artis...
# limit                                                   NaN
# next                                                    NaN
# offset                                                  NaN
# previous                                                NaN
# total                                                   NaN
#
#                                                          10  \
# href                                                    NaN
# items     {'album': {'album_type': 'compilation', 'artis...
# limit                                                   NaN
# next                                                    NaN
# offset                                                  NaN
# previous                                                NaN
# total                                                   NaN
#
#                                                          11  \
# href                                                    NaN
# items     {'album': {'album_type': 'compilation', 'artis...
# limit                                                   NaN
# next                                                    NaN
# offset                                                  NaN
# previous                                                NaN
# total                                                   NaN
#
#                                                          12  \
# href                                                    NaN
# items     {'album': {'album_type': 'compilation', 'artis...
# limit                                                   NaN
# next                                                    NaN
# offset                                                  NaN
# previous                                                NaN
# total                                                   NaN
#
#                                                          13  \
# href                                                    NaN
# items     {'album': {'album_type': 'compilation', 'artis...
# limit                                                   NaN
# next                                                    NaN
# offset                                                  NaN
# previous                                                NaN
# total                                                   NaN
#
#                                                          14  \
# href                                                    NaN
# items     {'album': {'album_type': 'compilation', 'artis...
# limit                                                   NaN
# next                                                    NaN
# offset                                                  NaN
# previous                                                NaN
# total                                                   NaN
#
#                                                          15  \
# href                                                    NaN
# items     {'album': {'album_type': 'compilation', 'artis...
# limit                                                   NaN
# next                                                    NaN
# offset                                                  NaN
# previous                                                NaN
# total                                                   NaN
#
#                                                          16  \
# href                                                    NaN
# items     {'album': {'album_type': 'compilation', 'artis...
# limit                                                   NaN
# next                                                    NaN
# offset                                                  NaN
# previous                                                NaN
# total                                                   NaN
#
#                                                          17  \
# href                                                    NaN
# items     {'album': {'album_type': 'compilation', 'artis...
# limit                                                   NaN
# next                                                    NaN
# offset                                                  NaN
# previous                                                NaN
# total                                                   NaN
#
#                                                          18  \
# href                                                    NaN
# items     {'album': {'album_type': 'single', 'artists': ...
# limit                                                   NaN
# next                                                    NaN
# offset                                                  NaN
# previous                                                NaN
# total                                                   NaN
#
#                                                          19
# href                                                    NaN
# items     {'album': {'album_type': 'single', 'artists': ...
# limit                                                   NaN
# next                                                    NaN
# offset                                                  NaN
# previous                                                NaN
# total                                                   NaN

# %%
test2 = pd.DataFrame(test.iloc[1])
test2
# Out:
#                                                 items
# 0   {'album': {'album_type': 'album', 'artists': [...
# 1   {'album': {'album_type': 'single', 'artists': ...
# 2   {'album': {'album_type': 'album', 'artists': [...
# 3   {'album': {'album_type': 'compilation', 'artis...
# 4   {'album': {'album_type': 'compilation', 'artis...
# 5   {'album': {'album_type': 'compilation', 'artis...
# 6   {'album': {'album_type': 'compilation', 'artis...
# 7   {'album': {'album_type': 'compilation', 'artis...
# 8   {'album': {'album_type': 'compilation', 'artis...
# 9   {'album': {'album_type': 'compilation', 'artis...
# 10  {'album': {'album_type': 'compilation', 'artis...
# 11  {'album': {'album_type': 'compilation', 'artis...
# 12  {'album': {'album_type': 'compilation', 'artis...
# 13  {'album': {'album_type': 'compilation', 'artis...
# 14  {'album': {'album_type': 'compilation', 'artis...
# 15  {'album': {'album_type': 'compilation', 'artis...
# 16  {'album': {'album_type': 'compilation', 'artis...
# 17  {'album': {'album_type': 'compilation', 'artis...
# 18  {'album': {'album_type': 'single', 'artists': ...
# 19  {'album': {'album_type': 'single', 'artists': ...

# %%
test3 = test2['items'].apply(pd.Series)
test3
# Out:
#                                                 album  \
# 0   {'album_type': 'album', 'artists': [{'external...
# 1   {'album_type': 'single', 'artists': [{'externa...
# 2   {'album_type': 'album', 'artists': [{'external...
# 3   {'album_type': 'compilation', 'artists': [{'ex...
# 4   {'album_type': 'compilation', 'artists': [{'ex...
# 5   {'album_type': 'compilation', 'artists': [{'ex...
# 6   {'album_type': 'compilation', 'artists': [{'ex...
# 7   {'album_type': 'compilation', 'artists': [{'ex...
# 8   {'album_type': 'compilation', 'artists': [{'ex...
# 9   {'album_type': 'compilation', 'artists': [{'ex...
# 10  {'album_type': 'compilation', 'artists': [{'ex...
# 11  {'album_type': 'compilation', 'artists': [{'ex...
# 12  {'album_type': 'compilation', 'artists': [{'ex...
# 13  {'album_type': 'compilation', 'artists': [{'ex...
# 14  {'album_type': 'compilation', 'artists': [{'ex...
# 15  {'album_type': 'compilation', 'artists': [{'ex...
# 16  {'album_type': 'compilation', 'artists': [{'ex...
# 17  {'album_type': 'compilation', 'artists': [{'ex...
# 18  {'album_type': 'single', 'artists': [{'externa...
# 19  {'album_type': 'single', 'artists': [{'externa...
#
#                                               artists  \
# 0   [{'external_urls': {'spotify': 'https://open.s...
# 1   [{'external_urls': {'spotify': 'https://open.s...
# 2   [{'external_urls': {'spotify': 'https://open.s...
# 3   [{'external_urls': {'spotify': 'https://open.s...
# 4   [{'external_urls': {'spotify': 'https://open.s...
# 5   [{'external_urls': {'spotify': 'https://open.s...
# 6   [{'external_urls': {'spotify': 'https://open.s...
# 7   [{'external_urls': {'spotify': 'https://open.s...
# 8   [{'external_urls': {'spotify': 'https://open.s...
# 9   [{'external_urls': {'spotify': 'https://open.s...
# 10  [{'external_urls': {'spotify': 'https://open.s...
# 11  [{'external_urls': {'spotify': 'https://open.s...
# 12  [{'external_urls': {'spotify': 'https://open.s...
# 13  [{'external_urls': {'spotify': 'https://open.s...
# 14  [{'external_urls': {'spotify': 'https://open.s...
# 15  [{'external_urls': {'spotify': 'https://open.s...
# 16  [{'external_urls': {'spotify': 'https://open.s...
# 17  [{'external_urls': {'spotify': 'https://open.s...
# 18  [{'external_urls': {'spotify': 'https://open.s...
# 19  [{'external_urls': {'spotify': 'https://open.s...
#
#                                     available_markets  disc_number  \
# 0   [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...            1
# 1   [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...            1
# 2   [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...            1
# 3   [AE, AL, AR, AT, AU, BA, BE, BG, BH, BO, BR, C...            1
# 4   [AE, AL, AR, AT, AU, BA, BE, BG, BH, BO, BR, C...            1
# 5   [AE, AL, AR, AT, BA, BE, BG, BH, BO, BR, CA, C...            1
# 6   [AE, AL, AR, AT, AU, BA, BE, BG, BH, BO, BR, C...            1
# 7   [AE, AL, AR, AT, AU, BA, BE, BG, BH, BO, BR, C...            1
# 8   [AE, AL, AR, AT, AU, BA, BE, BG, BH, BO, BR, C...            1
# 9   [AE, BG, BH, CY, EE, EG, FI, GR, HK, ID, IL, I...            1
# 10  [AE, AL, AR, AT, AU, BA, BE, BG, BH, BO, BR, C...            1
# 11  [AE, AL, AR, AT, AU, BA, BE, BG, BH, BO, BR, C...            1
# 12  [AE, AL, AR, AT, AU, BA, BE, BG, BH, BO, BR, C...            1
# 13  [AE, AL, AR, AT, AU, BA, BG, BH, BO, BR, CA, C...            1
# 14  [AE, AL, AR, AT, AU, BA, BE, BG, BH, BO, BR, C...            1
# 15  [AE, AL, AR, AT, BA, BE, BG, BH, BO, BR, CA, C...            1
# 16  [AE, AL, AR, AT, AU, BA, BE, BG, BH, BO, BR, C...            1
# 17  [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...            1
# 18  [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...            1
# 19  [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...            1
#
#     duration_ms  explicit              external_ids  \
# 0        229360     False  {'isrc': 'USUM71607007'}
# 1        228826     False  {'isrc': 'USUM71703825'}
# 2        230413     False  {'isrc': 'USUM71703825'}
# 3        230466     False  {'isrc': 'USUM71607007'}
# 4        230466     False  {'isrc': 'USUM71607007'}
# 5        230466     False  {'isrc': 'USUM71607007'}
# 6        230466     False  {'isrc': 'USUM71607007'}
# 7        230466     False  {'isrc': 'USUM71607007'}
# 8        230466     False  {'isrc': 'USUM71607007'}
# 9        230466     False  {'isrc': 'USUM71607007'}
# 10       230466     False  {'isrc': 'USUM71607007'}
# 11       230466     False  {'isrc': 'USUM71607007'}
# 12       230693     False  {'isrc': 'USUM71703825'}
# 13       230693     False  {'isrc': 'USUM71703825'}
# 14       230693     False  {'isrc': 'USUM71703825'}
# 15       230693     False  {'isrc': 'USUM71703825'}
# 16       230693     False  {'isrc': 'USUM71703825'}
# 17       228200     False  {'isrc': 'USUM71607007'}
# 18       228546     False  {'isrc': 'USUM71700112'}
# 19       205666     False  {'isrc': 'USUM71700713'}
#
#                                         external_urls  \
# 0   {'spotify': 'https://open.spotify.com/track/6h...
# 1   {'spotify': 'https://open.spotify.com/track/6r...
# 2   {'spotify': 'https://open.spotify.com/track/1v...
# 3   {'spotify': 'https://open.spotify.com/track/7c...
# 4   {'spotify': 'https://open.spotify.com/track/5z...
# 5   {'spotify': 'https://open.spotify.com/track/27...
# 6   {'spotify': 'https://open.spotify.com/track/3v...
# 7   {'spotify': 'https://open.spotify.com/track/5s...
# 8   {'spotify': 'https://open.spotify.com/track/6T...
# 9   {'spotify': 'https://open.spotify.com/track/6T...
# 10  {'spotify': 'https://open.spotify.com/track/4F...
# 11  {'spotify': 'https://open.spotify.com/track/0J...
# 12  {'spotify': 'https://open.spotify.com/track/0I...
# 13  {'spotify': 'https://open.spotify.com/track/42...
# 14  {'spotify': 'https://open.spotify.com/track/2T...
# 15  {'spotify': 'https://open.spotify.com/track/6E...
# 16  {'spotify': 'https://open.spotify.com/track/7m...
# 17  {'spotify': 'https://open.spotify.com/track/5A...
# 18  {'spotify': 'https://open.spotify.com/track/36...
# 19  {'spotify': 'https://open.spotify.com/track/5a...
#
#                                                  href                      id  \
# 0   https://api.spotify.com/v1/tracks/6habFhsOp2Nv...  6habFhsOp2NvshLv26DqMb
# 1   https://api.spotify.com/v1/tracks/6rPO02ozF3bM...  6rPO02ozF3bM7NnOV4h6s2
# 2   https://api.spotify.com/v1/tracks/1vnnXMrBeEWi...  1vnnXMrBeEWiRg3YCMCjQq
# 3   https://api.spotify.com/v1/tracks/7cCkP2dHAEco...  7cCkP2dHAEcoWT9OZjM72q
# 4   https://api.spotify.com/v1/tracks/5zv6B3NsMqlu...  5zv6B3NsMqluXwV2XEgCju
# 5   https://api.spotify.com/v1/tracks/27nDrpu5mVh7...  27nDrpu5mVh7Lbsg2topzJ
# 6   https://api.spotify.com/v1/tracks/3vrEEERwVkqZ...  3vrEEERwVkqZMEXLrXGC2c
# 7   https://api.spotify.com/v1/tracks/5sG2vrEZVjkm...  5sG2vrEZVjkmZoHORzokbz
# 8   https://api.spotify.com/v1/tracks/6Tl2OMIg8M9d...  6Tl2OMIg8M9dXmSHndZ7He
# 9   https://api.spotify.com/v1/tracks/6TnBZIIPGSQr...  6TnBZIIPGSQr2EBRrd0whG
# 10  https://api.spotify.com/v1/tracks/4F7pJ8x2GIrS...  4F7pJ8x2GIrSwa9StQu4RB
# 11  https://api.spotify.com/v1/tracks/0JNZMaI0BpS5...  0JNZMaI0BpS5HJCmceL1GZ
# 12  https://api.spotify.com/v1/tracks/0IV0enCN0mk2...  0IV0enCN0mk2LZJXJco6Q8
# 13  https://api.spotify.com/v1/tracks/42bNKVCiuesd...  42bNKVCiuesdktFvyPVQ1x
# 14  https://api.spotify.com/v1/tracks/2TYDZhzV5frv...  2TYDZhzV5frvKpMOk4Cz6g
# 15  https://api.spotify.com/v1/tracks/6EYQy69cTjSo...  6EYQy69cTjSonAaucxLnVG
# 16  https://api.spotify.com/v1/tracks/7mecZFxedxwx...  7mecZFxedxwxcgmJEScoap
# 17  https://api.spotify.com/v1/tracks/5AgTL2WmiCvo...  5AgTL2WmiCvoObA8fpncKs
# 18  https://api.spotify.com/v1/tracks/36NOKjPLZVSq...  36NOKjPLZVSqVJSC7iOHIm
# 19  https://api.spotify.com/v1/tracks/5aPZ8WDKgtij...  5aPZ8WDKgtij3zbknGFnhC
#
#     is_local                       name  popularity  \
# 0      False                  Despacito          80
# 1      False          Despacito - Remix          71
# 2      False          Despacito - Remix          69
# 3      False                  Despacito           0
# 4      False                  Despacito           0
# 5      False                  Despacito           0
# 6      False                  Despacito           0
# 7      False                  Despacito           0
# 8      False                  Despacito           0
# 9      False                  Despacito           0
# 10     False                  Despacito           0
# 11     False                  Despacito           0
# 12     False          Despacito - Remix           0
# 13     False          Despacito - Remix           1
# 14     False          Despacito - Remix           0
# 15     False          Despacito - Remix           1
# 16     False          Despacito - Remix           1
# 17     False                  Despacito          50
# 18     False                  Despacito          52
# 19     False  Despacito - Versión Salsa          47
#
#                                           preview_url  track_number   type  \
# 0   https://p.scdn.co/mp3-preview/3228a37350f226ab...             9  track
# 1   https://p.scdn.co/mp3-preview/6fd23fecd7e84bc5...             1  track
# 2   https://p.scdn.co/mp3-preview/978c915797a63f66...            13  track
# 3   https://p.scdn.co/mp3-preview/77872071f147e129...            15  track
# 4   https://p.scdn.co/mp3-preview/77872071f147e129...            27  track
# 5   https://p.scdn.co/mp3-preview/77872071f147e129...            39  track
# 6   https://p.scdn.co/mp3-preview/77872071f147e129...            73  track
# 7   https://p.scdn.co/mp3-preview/77872071f147e129...            20  track
# 8   https://p.scdn.co/mp3-preview/77872071f147e129...            23  track
# 9   https://p.scdn.co/mp3-preview/77872071f147e129...            52  track
# 10  https://p.scdn.co/mp3-preview/77872071f147e129...            26  track
# 11  https://p.scdn.co/mp3-preview/77872071f147e129...             7  track
# 12  https://p.scdn.co/mp3-preview/3571619095cce9c1...            33  track
# 13  https://p.scdn.co/mp3-preview/3571619095cce9c1...            36  track
# 14  https://p.scdn.co/mp3-preview/f516b9ff7fa47ec6...            48  track
# 15  https://p.scdn.co/mp3-preview/3571619095cce9c1...            17  track
# 16  https://p.scdn.co/mp3-preview/3571619095cce9c1...            49  track
# 17  https://p.scdn.co/mp3-preview/678bb5a1c777226f...            26  track
# 18  https://p.scdn.co/mp3-preview/716142f0a95c4d36...             1  track
# 19  https://p.scdn.co/mp3-preview/745333230c41fa28...             1  track
#
#                                      uri
# 0   spotify:track:6habFhsOp2NvshLv26DqMb
# 1   spotify:track:6rPO02ozF3bM7NnOV4h6s2
# 2   spotify:track:1vnnXMrBeEWiRg3YCMCjQq
# 3   spotify:track:7cCkP2dHAEcoWT9OZjM72q
# 4   spotify:track:5zv6B3NsMqluXwV2XEgCju
# 5   spotify:track:27nDrpu5mVh7Lbsg2topzJ
# 6   spotify:track:3vrEEERwVkqZMEXLrXGC2c
# 7   spotify:track:5sG2vrEZVjkmZoHORzokbz
# 8   spotify:track:6Tl2OMIg8M9dXmSHndZ7He
# 9   spotify:track:6TnBZIIPGSQr2EBRrd0whG
# 10  spotify:track:4F7pJ8x2GIrSwa9StQu4RB
# 11  spotify:track:0JNZMaI0BpS5HJCmceL1GZ
# 12  spotify:track:0IV0enCN0mk2LZJXJco6Q8
# 13  spotify:track:42bNKVCiuesdktFvyPVQ1x
# 14  spotify:track:2TYDZhzV5frvKpMOk4Cz6g
# 15  spotify:track:6EYQy69cTjSonAaucxLnVG
# 16  spotify:track:7mecZFxedxwxcgmJEScoap
# 17  spotify:track:5AgTL2WmiCvoObA8fpncKs
# 18  spotify:track:36NOKjPLZVSqVJSC7iOHIm
# 19  spotify:track:5aPZ8WDKgtij3zbknGFnhC

# %%
test3.head(1)
# Out:
#                                                album  \
# 0  {'album_type': 'album', 'artists': [{'external...
#
#                                              artists  \
# 0  [{'external_urls': {'spotify': 'https://open.s...
#
#                                    available_markets  disc_number  \
# 0  [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...            1
#
#    duration_ms  explicit              external_ids  \
# 0       229360     False  {'isrc': 'USUM71607007'}
#
#                                        external_urls  \
# 0  {'spotify': 'https://open.spotify.com/track/6h...
#
#                                                 href                      id  \
# 0  https://api.spotify.com/v1/tracks/6habFhsOp2Nv...  6habFhsOp2NvshLv26DqMb
#
#    is_local       name  popularity  \
# 0     False  Despacito          80
#
#                                          preview_url  track_number   type  \
# 0  https://p.scdn.co/mp3-preview/3228a37350f226ab...             9  track
#
#                                     uri
# 0  spotify:track:6habFhsOp2NvshLv26DqMb
